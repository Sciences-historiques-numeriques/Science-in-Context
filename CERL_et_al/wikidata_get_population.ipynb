# %% [markdown]
# # Seeking the population to be studied using Wikidata
#
#
# Wikidata provides the [occupation (P106)](https://www.wikidata.org/wiki/Property:P106) property that seems to represent a good entry point to define the perimeter of the population of astronomers and other related professions.
#
# We will start from following occupations , then explore the related ones.
#
#
# See also ["field of work" (Property:P101)](http://www.wikidata.org/entity/P101), ["position held" (Property:P39)](http://www.wikidata.org/entity/P39)
#
# ---

# %%
from SPARQLWrapper import SPARQLWrapper, SPARQLWrapper2, JSON, TURTLE, XML, RDFXML

# %%
import csv
import sqlite3 as sql
from datetime import datetime
from importlib import reload
import pprint
import json
import ast

# %%
import sparql_functions as spqf
# reload(spqf)

# %% [markdown]
# ## Storing, documenting and executing SPARQL queries

# %%
db = 'db_stores/sparql_queries.db'

# %%
### Inspect existing SPARQL queries

cn = sql.connect(db)
c = cn.cursor()
c.execute('SELECT pk_query, label, description, sparql_endpoint FROM query')
r_all = c.fetchall()
cn.close()
r_all[:200]
# Out:
# [(1,
#   'Properties of astronomers',
#   "Get and count the outgoing and incoming properties of people having astronomer as an occupation:\n\n?person  wdt:P106  wd:Q11063\n\nCette requête ne marche pas lorsque elle est exécutée depuis le SPARQLWrapper. Je l'ai donc exécutée directement dans l'éditeur de requêtes de Wikidata, téléchargé le fichier JSON verbeux du résultat et produit une ligne de la table 'result'. Elle est horodatée.",
#   'https://query.wikidata.org/sparql'),
#  (2,
#   'Properties of physician (Q39631)',
#   "Get and count the outgoing and incoming properties of people having physician as an occupation:\n\n?person  wdt:P106  wd:Q39631\t\n\nCette requête ne marche pas lorsque elle est exécutée depuis le SPARQLWrapper. Je l'ai donc exécutée directement dans l'éditeur de requêtes de Wikidata, téléchargé le fichier JSON verbeux du résultat et produit une ligne de la table 'result'. Elle est horodatée.",
#   'https://query.wikidata.org/sparql'),
#  (3,
#   'Find astronomers and insert basic properties',
#   'Insert basic properties (label, birthDate, original occupation, into the local triplestore',
#   'http://192.168.0.21:7200/repositories/early-modern-astronomy/statements'),
#  (4,
#   'Add all occupations of astronomers',
#   'Get all occupations from Wikidata for the astronomers stored in the local triplestore',
#   'http://192.168.0.21:7200/repositories/early-modern-astronomy/statements')]

# %% [markdown]
# ### Execute a specific SPARQL query

# %%
### Define the line of the database to be used (insert the query into the database first)

pk_query = 2

cn = sql.connect(db)
c = cn.cursor()
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query])
rc = c.fetchone()
cn.close()

# %%
print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" + rc[5])
# Out:
# Get and count the outgoing and incoming properties of people having physician as an occupation:
#
# ?person  wdt:P106  wd:Q39631
#
# Cette requête ne marche pas lorsque elle est exécutée depuis le SPARQLWrapper. Je l'ai donc exécutée directement dans l'éditeur de requêtes de Wikidata, téléchargé le fichier JSON verbeux du résultat et produit une ligne de la table 'result'. Elle est horodatée.
# -----
# https://query.wikidata.org/sparql
# -----
# PREFIX  bd:   <http://www.bigdata.com/rdf#>
# PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>
# PREFIX  wikibase: <http://wikiba.se/ontology#>
# PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
# PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX  wd:   <http://www.wikidata.org/entity/>
#
# SELECT  ?prop ?propLabel ?direction ?eff
# WHERE
#   { { SELECT  ?prop ?direction (count(*) AS ?eff)
#       WHERE
#         { {   { ?person  ?p                    ?o .
#                 ?prop    wikibase:directClaim  ?p
#                 BIND("out" AS ?direction)
#               }
#             UNION
#               { ?s     ?p                    ?person .
#                 ?prop  wikibase:directClaim  ?p
#                 BIND("in" AS ?direction)
#               }
#             { ?person  wdt:P106  wd:Q39631 ;
#                        wdt:P569  ?dateBirth
#               FILTER ( ( ?dateBirth > "1401-01-01"^^xsd:dateTime ) && ( ?dateBirth < "1800-12-31"^^xsd:dateTime ) )
#             }
#           }
#         }
#       GROUP BY ?prop ?direction
#     }
#     SERVICE wikibase:label
#       { bd:serviceParam
#                   wikibase:language  "en"
#       }
#   }
# ORDER BY DESC(?eff)

# %%
### Execute the SPARQL query
qr = spqf.get_json_sparql_result(rc[4],rc[5])
# Out:
# <class 'dict'>

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:50]
# Out:
# 1089
# [['http://www.wikidata.org/entity/P106', 'occupation', 'out', '20496'],
#  ['http://www.wikidata.org/entity/P569', 'date of birth', 'out', '11422'],
#  ['http://www.wikidata.org/entity/P570', 'date of death', 'out', '10755'],
#  ['http://www.wikidata.org/entity/P31', 'instance of', 'out', '10595'],
#  ['http://www.wikidata.org/entity/P735', 'given name', 'out', '10567'],
#  ['http://www.wikidata.org/entity/P21', 'sex or gender', 'out', '10423'],
#  ['http://www.wikidata.org/entity/P214', 'VIAF ID', 'out', '9115'],
#  ['http://www.wikidata.org/entity/P1343',
#   'described by source',
#   'out',
#   '8024'],
#  ['http://www.wikidata.org/entity/P1871', 'CERL Thesaurus ID', 'out', '7868'],
#  ['http://www.wikidata.org/entity/P227', 'GND ID', 'out', '7359'],
#  ['http://www.wikidata.org/entity/P7859',
#   'WorldCat Identities ID',
#   'out',
#   '7054'],
#  ['http://www.wikidata.org/entity/P19', 'place of birth', 'out', '6558'],
#  ['http://www.wikidata.org/entity/P213', 'ISNI', 'out', '5975'],
#  ['http://www.wikidata.org/entity/P27',
#   'country of citizenship',
#   'out',
#   '5654'],
#  ['http://www.wikidata.org/entity/P20', 'place of death', 'out', '5319'],
#  ['http://www.wikidata.org/entity/P921', 'main subject', 'in', '5142'],
#  ['http://www.wikidata.org/entity/P1412',
#   'languages spoken, written or signed',
#   'out',
#   '4948'],
#  ['http://www.wikidata.org/entity/P734', 'family name', 'out', '4798'],
#  ['http://www.wikidata.org/entity/P7902',
#   'Deutsche Biographie (GND) ID',
#   'out',
#   '4788'],
#  ['http://www.wikidata.org/entity/P244',
#   'Library of Congress authority ID',
#   'out',
#   '4118'],
#  ['http://www.wikidata.org/entity/P50', 'author', 'in', '3791'],
#  ['http://www.wikidata.org/entity/P269', 'IdRef ID', 'out', '3737'],
#  ['http://www.wikidata.org/entity/P2671',
#   'Google Knowledge Graph ID',
#   'out',
#   '3594'],
#  ['http://www.wikidata.org/entity/P69', 'educated at', 'out', '3293'],
#  ['http://www.wikidata.org/entity/P1006',
#   'Nationale Thesaurus voor Auteurs ID',
#   'out',
#   '3015'],
#  ['http://www.wikidata.org/entity/P463', 'member of', 'out', '3004'],
#  ['http://www.wikidata.org/entity/P648', 'Open Library ID', 'out', '2968'],
#  ['http://www.wikidata.org/entity/P18', 'image', 'out', '2763'],
#  ['http://www.wikidata.org/entity/P691', 'NKCR AUT ID', 'out', '2522'],
#  ['http://www.wikidata.org/entity/P373', 'Commons category', 'out', '2398'],
#  ['http://www.wikidata.org/entity/P101', 'field of work', 'out', '2357'],
#  ['http://www.wikidata.org/entity/P1207', 'NUKAT ID', 'out', '2200'],
#  ['http://www.wikidata.org/entity/P2163', 'FAST ID', 'out', '2190'],
#  ['http://www.wikidata.org/entity/P268',
#   'Bibliothèque nationale de France ID',
#   'out',
#   '2183'],
#  ['http://www.wikidata.org/entity/P646', 'Freebase ID', 'out', '2069'],
#  ['http://www.wikidata.org/entity/P8034',
#   'Vatican Library VcBA ID',
#   'out',
#   '1977'],
#  ['http://www.wikidata.org/entity/P138', 'named after', 'in', '1976'],
#  ['http://www.wikidata.org/entity/P6821',
#   'Uppsala University Alvin ID',
#   'out',
#   '1833'],
#  ['http://www.wikidata.org/entity/P22', 'father', 'in', '1823'],
#  ['http://www.wikidata.org/entity/P40', 'child', 'out', '1804'],
#  ['http://www.wikidata.org/entity/P108', 'employer', 'out', '1800'],
#  ['http://www.wikidata.org/entity/P7293', 'PLWABN ID', 'out', '1629'],
#  ['http://www.wikidata.org/entity/P5375',
#   'BIU Santé person ID',
#   'out',
#   '1583'],
#  ['http://www.wikidata.org/entity/P8189',
#   'National Library of Israel J9U ID',
#   'out',
#   '1509'],
#  ['http://www.wikidata.org/entity/P10480', 'symogih.org ID', 'out', '1375'],
#  ['http://www.wikidata.org/entity/P937', 'work location', 'out', '1320'],
#  ['http://www.wikidata.org/entity/P166', 'award received', 'out', '1279'],
#  ['http://www.wikidata.org/entity/P1017',
#   'Vatican Library ID (former scheme)',
#   'out',
#   '1173'],
#  ['http://www.wikidata.org/entity/P8947',
#   'Museo Galileo authority ID',
#   'out',
#   '1124'],
#  ['http://www.wikidata.org/entity/P39', 'position held', 'out', '1118']]

# %%
# Inspect the first 10 lines
i = 0
for l in qr['results']['bindings']:
    if i < 10:
        print(l)
        i += 1

# %% [markdown]
# ###  Store and retrieve the JSON result of the former SPARQL query

# %%
### OPTIONAL

cn = sql.connect(db)
c = cn.cursor()
values = (pk_query, str(qr))
c.execute("INSERT INTO result (fk_query, result) VALUES (?,?)", values)

## Activate to persist INSERT
## DISABLED !!! ## cn.commit()
cn.close()

# %%
### Define the row of the database to be searched (inspect the database first)

pk_result = ['2']
cn = sql.connect(db)
c = cn.cursor()
c.execute('SELECT * FROM result WHERE pk_result = ?', pk_result)
qr = c.fetchone()
cn.close()

# %%
### Transform string to dict
## Doc.: https://stackoverflow.com/questions/988228/convert-a-string-representation-of-a-dictionary-to-a-dictionary
d = ast.literal_eval(qr[3])
try:
    r = [l for l in spqf.sparql_result_to_list(d)]
    print(len(r))
except Exception as e:
    print(e)
r[:100]
# Out:
# 901
# [['http://www.wikidata.org/entity/P106', 'occupation', 'out', '15619'],
#  ['http://www.wikidata.org/entity/P569', 'date of birth', 'out', '8715'],
#  ['http://www.wikidata.org/entity/P570', 'date of death', 'out', '8089'],
#  ['http://www.wikidata.org/entity/P31', 'instance of', 'out', '8019'],
#  ['http://www.wikidata.org/entity/P21', 'sex or gender', 'out', '7934'],
#  ['http://www.wikidata.org/entity/P735', 'given name', 'out', '7669'],
#  ['http://www.wikidata.org/entity/P214', 'VIAF ID', 'out', '6581'],
#  ['http://www.wikidata.org/entity/P1343',
#   'described by source',
#   'out',
#   '6551'],
#  ['http://www.wikidata.org/entity/P19', 'place of birth', 'out', '5439'],
#  ['http://www.wikidata.org/entity/P7859',
#   'WorldCat Identities ID',
#   'out',
#   '5343'],
#  ['http://www.wikidata.org/entity/P227', 'GND ID', 'out', '5242'],
#  ['http://www.wikidata.org/entity/P1871', 'CERL Thesaurus ID', 'out', '5180'],
#  ['http://www.wikidata.org/entity/P27',
#   'country of citizenship',
#   'out',
#   '4921'],
#  ['http://www.wikidata.org/entity/P213', 'ISNI', 'out', '4562'],
#  ['http://www.wikidata.org/entity/P20', 'place of death', 'out', '4473'],
#  ['http://www.wikidata.org/entity/P921', 'main subject', 'in', '4024'],
#  ['http://www.wikidata.org/entity/P1412',
#   'languages spoken, written or signed',
#   'out',
#   '3767'],
#  ['http://www.wikidata.org/entity/P7902',
#   'Deutsche Biographie ID',
#   'out',
#   '3499'],
#  ['http://www.wikidata.org/entity/P244',
#   'Library of Congress authority ID',
#   'out',
#   '3418'],
#  ['http://www.wikidata.org/entity/P2671',
#   'Google Knowledge Graph ID',
#   'out',
#   '3292'],
#  ['http://www.wikidata.org/entity/P734', 'family name', 'out', '3168'],
#  ['http://www.wikidata.org/entity/P69', 'educated at', 'out', '2715'],
#  ['http://www.wikidata.org/entity/P50', 'author', 'in', '2575'],
#  ['http://www.wikidata.org/entity/P463', 'member of', 'out', '2533'],
#  ['http://www.wikidata.org/entity/P1006',
#   'Nationale Thesaurus voor Auteurs ID',
#   'out',
#   '2470'],
#  ['http://www.wikidata.org/entity/P18', 'image', 'out', '2391'],
#  ['http://www.wikidata.org/entity/P648', 'Open Library ID', 'out', '2367'],
#  ['http://www.wikidata.org/entity/P269', 'IdRef ID', 'out', '2294'],
#  ['http://www.wikidata.org/entity/P2163', 'FAST ID', 'out', '1970'],
#  ['http://www.wikidata.org/entity/P646', 'Freebase ID', 'out', '1962'],
#  ['http://www.wikidata.org/entity/P268',
#   'Bibliothèque nationale de France ID',
#   'out',
#   '1816'],
#  ['http://www.wikidata.org/entity/P1207', 'NUKAT ID', 'out', '1705'],
#  ['http://www.wikidata.org/entity/P691', 'NKCR AUT ID', 'out', '1672'],
#  ['http://www.wikidata.org/entity/P108', 'employer', 'out', '1616'],
#  ['http://www.wikidata.org/entity/P6821',
#   'Uppsala University Alvin ID',
#   'out',
#   '1569'],
#  ['http://www.wikidata.org/entity/P8034',
#   'Vatican Library VcBA ID',
#   'out',
#   '1513'],
#  ['http://www.wikidata.org/entity/P373', 'Commons category', 'out', '1488'],
#  ['http://www.wikidata.org/entity/P22', 'father', 'in', '1425'],
#  ['http://www.wikidata.org/entity/P40', 'child', 'out', '1406'],
#  ['http://www.wikidata.org/entity/P5375',
#   'BIU Santé person ID',
#   'out',
#   '1305'],
#  ['http://www.wikidata.org/entity/P7293', 'PLWABN ID', 'out', '1251'],
#  ['http://www.wikidata.org/entity/P166', 'award received', 'out', '1158'],
#  ['http://www.wikidata.org/entity/P138', 'named after', 'in', '1098'],
#  ['http://www.wikidata.org/entity/P8947',
#   'Museo Galileo authority ID',
#   'out',
#   '955'],
#  ['http://www.wikidata.org/entity/P1017',
#   'Vatican Library ID (former scheme)',
#   'out',
#   '948'],
#  ['http://www.wikidata.org/entity/P1559',
#   'name in native language',
#   'out',
#   '900'],
#  ['http://www.wikidata.org/entity/P950',
#   'Biblioteca Nacional de España ID',
#   'out',
#   '866'],
#  ['http://www.wikidata.org/entity/P39', 'position held', 'out', '859'],
#  ['http://www.wikidata.org/entity/P906', 'SELIBR ID', 'out', '859'],
#  ['http://www.wikidata.org/entity/P3430', 'SNAC ARK ID', 'out', '856'],
#  ['http://www.wikidata.org/entity/P1415',
#   'Oxford Dictionary of National Biography ID',
#   'out',
#   '852'],
#  ['http://www.wikidata.org/entity/P937', 'work location', 'out', '848'],
#  ['http://www.wikidata.org/entity/P5587', 'Libris-URI', 'out', '841'],
#  ['http://www.wikidata.org/entity/P3762', 'openMLOL author ID', 'out', '836'],
#  ['http://www.wikidata.org/entity/P4081', 'BHL creator ID', 'out', '819'],
#  ['http://www.wikidata.org/entity/P101', 'field of work', 'out', '792'],
#  ['http://www.wikidata.org/entity/P40', 'child', 'in', '784'],
#  ['http://www.wikidata.org/entity/P3348',
#   'National Library of Greece ID',
#   'out',
#   '775'],
#  ['http://www.wikidata.org/entity/P949',
#   'National Library of Israel ID',
#   'out',
#   '685'],
#  ['http://www.wikidata.org/entity/P1005',
#   'Portuguese National Library ID',
#   'out',
#   '651'],
#  ['http://www.wikidata.org/entity/P1315', 'NLA Trove ID', 'out', '609'],
#  ['http://www.wikidata.org/entity/P1015', 'BIBSYS ID', 'out', '605'],
#  ['http://www.wikidata.org/entity/P22', 'father', 'out', '589'],
#  ['http://www.wikidata.org/entity/P1066', 'student of', 'in', '552'],
#  ['http://www.wikidata.org/entity/P3373', 'sibling', 'in', '547'],
#  ['http://www.wikidata.org/entity/P3373', 'sibling', 'out', '547'],
#  ['http://www.wikidata.org/entity/P3413',
#   'Leopoldina member ID',
#   'out',
#   '536'],
#  ['http://www.wikidata.org/entity/P119', 'place of burial', 'out', '531'],
#  ['http://www.wikidata.org/entity/P1802', 'EMLO person ID', 'out', '513'],
#  ['http://www.wikidata.org/entity/P3987',
#   'SHARE Catalogue author ID',
#   'out',
#   '506'],
#  ['http://www.wikidata.org/entity/P6264',
#   'Harvard Index of Botanists ID',
#   'out',
#   '496'],
#  ['http://www.wikidata.org/entity/P2949', 'WikiTree person ID', 'out', '474'],
#  ['http://www.wikidata.org/entity/P1280', 'CONOR.SI ID', 'out', '466'],
#  ['http://www.wikidata.org/entity/P802', 'student', 'out', '463'],
#  ['http://www.wikidata.org/entity/P1066', 'student of', 'out', '462'],
#  ['http://www.wikidata.org/entity/P1711',
#   'British Museum person or institution ID',
#   'out',
#   '449'],
#  ['http://www.wikidata.org/entity/P586', 'IPNI author ID', 'out', '430'],
#  ['http://www.wikidata.org/entity/P428',
#   'botanist author abbreviation',
#   'out',
#   '429'],
#  ['http://www.wikidata.org/entity/P2941', "Munk's Roll ID", 'out', '417'],
#  ['http://www.wikidata.org/entity/P170', 'creator', 'in', '414'],
#  ['http://www.wikidata.org/entity/P180', 'depicts', 'in', '400'],
#  ['http://www.wikidata.org/entity/P1273', 'CANTIC ID', 'out', '394'],
#  ['http://www.wikidata.org/entity/P802', 'student', 'in', '372'],
#  ['http://www.wikidata.org/entity/P1580',
#   'University of Barcelona authority ID',
#   'out',
#   '370'],
#  ['http://www.wikidata.org/entity/P2600', 'Geni.com profile ID', 'out', '369'],
#  ['http://www.wikidata.org/entity/P26', 'spouse', 'in', '357'],
#  ['http://www.wikidata.org/entity/P6886', 'writing language', 'out', '356'],
#  ['http://www.wikidata.org/entity/P3029',
#   'UK National Archives ID',
#   'out',
#   '354'],
#  ['http://www.wikidata.org/entity/P5370',
#   'Entomologists of the World ID',
#   'out',
#   '351'],
#  ['http://www.wikidata.org/entity/P409',
#   'Libraries Australia ID',
#   'out',
#   '340'],
#  ['http://www.wikidata.org/entity/P1296',
#   'Gran Enciclopèdia Catalana ID',
#   'out',
#   '338'],
#  ['http://www.wikidata.org/entity/P1986',
#   "Treccani's Dizionario biografico degli italiani ID",
#   'out',
#   '332'],
#  ['http://www.wikidata.org/entity/P26', 'spouse', 'out', '327'],
#  ['http://www.wikidata.org/entity/P396', 'SBN author ID', 'out', '325'],
#  ['http://www.wikidata.org/entity/P1695', 'NLP ID (unique)', 'out', '322'],
#  ['http://www.wikidata.org/entity/P8826',
#   'edition humboldt digital ID',
#   'out',
#   '319'],
#  ['http://www.wikidata.org/entity/P512', 'academic degree', 'out', '313'],
#  ['http://www.wikidata.org/entity/P2401',
#   'Six Degrees of Francis Bacon ID',
#   'out',
#   '313'],
#  ['http://www.wikidata.org/entity/P7763',
#   'copyright status as a creator',
#   'out',
#   '311'],
#  ['http://www.wikidata.org/entity/P1417',
#   'Encyclopædia Britannica Online ID',
#   'out',
#   '309']]

# %%
### Mettre en argument de la fonction setQuery, qui définit la requête, le nom de la variable correspondante
#  On définit le format du resultat (JSON), puis on effectue la requête en ligne 
# et on inspecte le type de résultat: le résultat en JSON a été transformé en une variable 'dictionnaire'

sparql.setQuery(query)
sparql.setReturnFormat(JSON)
rc = sparql.queryAndConvert()
type(rc)
# Out:
# dict

# %%
sparql = SPARQLWrapper("http://192.168.0.21:7200/repositories/test")

# %%
sparql = SPARQLWrapper("http://10.211.55.14:7200/repositories/early-modern-astronomy")

# %%
query_3 = """
SELECT * { GRAPH <http://my_test_graph.org> {
  << ?s ?p ?o >> ?q ?z .
}
}
"""

# %%
query_3 = """
SELECT * { GRAPH ?g {
  # ?s?q ?z .
}
}
"""

# %%
query = """PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>
PREFIX  wd:   <http://www.wikidata.org/entity/>
PREFIX bd: <http://www.bigdata.com/rdf#>
SELECT ?person 
WHERE { 
    
    {SELECT ?person
        WHERE {
    {
GRAPH <http://my_project.org/original/wikidata> {
# astronomers in the graph
# ?person  wdt:P106  wd:Q11063.
            }
        }
   }
LIMIT 10}}"""

# %%
try:
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    sparql.setMethod('POST')
    sparql.setCredentials("admin", "root")
    rc = sparql.query().convert()
except Exception as e:
    print(e)

# %%
rl = spqf.sparql_result_to_list(rc)
print(len(rl))
rl[:10]
# Out:
# 10
# [['http://www.wikidata.org/entity/Q10400374'],
#  ['http://www.wikidata.org/entity/Q11380799'],
#  ['http://www.wikidata.org/entity/Q11427609'],
#  ['http://www.wikidata.org/entity/Q12191704'],
#  ['http://www.wikidata.org/entity/Q15066880'],
#  ['http://www.wikidata.org/entity/Q15688159'],
#  ['http://www.wikidata.org/entity/Q15691867'],
#  ['http://www.wikidata.org/entity/Q15915482'],
#  ['http://www.wikidata.org/entity/Q28106362'],
#  ['http://www.wikidata.org/entity/Q28591139']]

# %%
rc
# Out:
# {'head': {'vars': ['g', 's', 'p', 'o', 'q', 'z']},
#  'results': {'bindings': [{'p': {'type': 'uri',
#      'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:ba9656af-92cc-41ab-a3d8-9ccc6f1dad8f'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g1'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a3105ddc-bc4b-4e54-95f9-23b7b41a1da6'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a3105ddc-bc4b-4e54-95f9-23b7b41a1da6'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:4a0bdd4c-e66a-406e-b1b7-2d135497400e'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:4a0bdd4c-e66a-406e-b1b7-2d135497400e'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:46f01299-de9e-47a0-ad67-b025288c84a2'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:46f01299-de9e-47a0-ad67-b025288c84a2'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:3aed2d93-3b7c-4201-b015-5d180eadb920'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:3aed2d93-3b7c-4201-b015-5d180eadb920'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a856dbc7-48fe-41e8-9138-8d07b2da67d3'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a856dbc7-48fe-41e8-9138-8d07b2da67d3'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9ac590c7-cf44-439d-b1ad-4609e76c0bad'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9ac590c7-cf44-439d-b1ad-4609e76c0bad'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:34ccfb5b-d4a1-4f9c-851d-898c8122a2cc'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:34ccfb5b-d4a1-4f9c-851d-898c8122a2cc'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:4ebe4464-beaf-4b34-8dfc-bf2dbb3093de'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:4ebe4464-beaf-4b34-8dfc-bf2dbb3093de'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:678e463f-ba85-4a68-bb63-ba9d3c807d35'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:678e463f-ba85-4a68-bb63-ba9d3c807d35'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:fbe3aa3e-4afb-49cb-a4e0-5aa633b4589b'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:fbe3aa3e-4afb-49cb-a4e0-5aa633b4589b'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g2'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:49cb7736-140f-4f65-b121-eebf3c8c3431'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:49cb7736-140f-4f65-b121-eebf3c8c3431'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Quebec'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a9dc5faf-ae90-4d65-927e-a0ee41c237af'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:a9dc5faf-ae90-4d65-927e-a0ee41c237af'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Montreal'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:d90befa4-2f20-4bb8-836e-ea87f3888222'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:d90befa4-2f20-4bb8-836e-ea87f3888222'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/German_Empire'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:f64fc2a4-a92f-419f-ba6f-25bd220c4796'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:f64fc2a4-a92f-419f-ba6f-25bd220c4796'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Berlin'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:3bda653c-e80a-4d3d-b02f-9c0e716b4850'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:3bda653c-e80a-4d3d-b02f-9c0e716b4850'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lviv'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:fc4f0691-e722-4f01-9b7d-8ee52ef07b54'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:fc4f0691-e722-4f01-9b7d-8ee52ef07b54'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Kingdom_of_Galicia_and_Lodomeria'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:73b170d7-2247-43b1-a64e-09ef9e4e02b6'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:73b170d7-2247-43b1-a64e-09ef9e4e02b6'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Austria-Hungary'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9e57a7d5-183d-4638-bcb5-724c19645e62'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9e57a7d5-183d-4638-bcb5-724c19645e62'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Congress_Poland'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:0c4fb7d4-5fa7-41f7-9ec7-da54bcc7a59e'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:0c4fb7d4-5fa7-41f7-9ec7-da54bcc7a59e'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Tomaszów_Mazowiecki'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://purl.org/dc/terms/source'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9e97c45b-40d0-4ded-bb76-4fc8638c0da2'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'type': 'uri', 'value': 'http://dbpedia.org/'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'https://ontome.net/property/1599'},
#     'q': {'type': 'uri', 'value': 'http://myontology.org/certainty'},
#     's': {'type': 'uri',
#      'value': 'urn:uuid:9e97c45b-40d0-4ded-bb76-4fc8638c0da2'},
#     'g': {'type': 'uri', 'value': 'http://myontology.org/g3'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '2'},
#     'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Naples'}},
#    {'p': {'type': 'uri', 'value': 'http://my_projects.org/hasSpouse'},
#     'q': {'type': 'uri', 'value': 'http://my_projects.org/certainty'},
#     's': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Lucky_Luke'},
#     'g': {'type': 'uri', 'value': 'http://my_test_graph.org'},
#     'z': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#      'type': 'literal',
#      'value': '0.9'},
#     'o': {'type': 'uri',
#      'value': 'http://dbpedia.org/resource/Cindy_Engel'}}]}}

# %%
insert = """

PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>
PREFIX  wikibase: <http://wikiba.se/ontology#>
PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  wd:   <http://www.wikidata.org/entity/>
PREFIX bd: <http://www.bigdata.com/rdf#>

INSERT {GRAPH <http://my_project.org/original/wikidata> {
# ?person  wdt:P106  ?occupation.
# ?occupation rdfs:label ?occupationLabel.
}
}
WHERE {
SERVICE <https://query.wikidata.org/sparql> {
SELECT DISTINCT ?person ?occupation ?occupationLabel
WHERE
  { 
      # ?person  wdt:P106  ?occupation.

    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en,nl,fr". }
}
}
{
GRAPH <http://my_project.org/original/wikidata> {
# astronomers in the graph
# ?person  wdt:P106  wd:Q11063.
}
}
}
"""

# %%
sparul = SPARQLWrapper("http://192.168.0.21:7200/repositories/early-modern-astronomy/statements")

# %%
sparul = SPARQLWrapper("http://192.168.0.21:7200/repositories/test/statements")

# %%
try:
    sparul.setQuery(insert)
    sparul.setCredentials("admin", "root")
    sparul.setMethod('POST')
    results = sparul.query()
    print(results.response.read())
except Exception as e:
    print(e)
# Out:
# EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Unkown record type: 83'

# %% [markdown]
# ### Execute a specific SPARUL query

# %%
### Define the line of the database to be used (insert the query into the database first)

pk_query = 4

cn = sql.connect(db)
c = cn.cursor()
c.execute('SELECT * FROM query WHERE pk_query = ?', [pk_query])
rc = c.fetchone()
cn.close()
print(rc[2] +  "\n-----\n" + rc[4] +  "\n-----\n" + rc[5])
# Out:
# Get all occupations from Wikidata for the astronomers stored in the local triplestore
# -----
# http://192.168.0.21:7200/repositories/early-modern-astronomy/statements
# -----
# PREFIX  bd:   <http://www.bigdata.com/rdf#>
# PREFIX  wd:   <http://www.wikidata.org/entity/>
# PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>
# PREFIX  wikibase: <http://wikiba.se/ontology#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX ontocl: <https://ontome.net/class/>
#
# INSERT { GRAPH <http://my_project.org/original/wikidata> {
#         ?person wdt:P106 ?occupation.
#         ?occupation  a ontocl:636.
#         ontocl:636 rdfs:label 'Occupation (SDHSS Soc)'.
#     ?occupation rdfs:label ?label}}
# WHERE
#   { SERVICE <https://query.wikidata.org/sparql>
#       { ?person  wdt:P106  ?occupation.
#         OPTIONAL {?occupation rdfs:label ?label. FILTER (lang(?label) in ('e', 'fr'))}
#         }
#     { SELECT  ?person
#       WHERE
#         { GRAPH <http://my_project.org/original/wikidata>
#               { ?person  wdt:P106  wd:Q11063 }
#         }
#
#     }
#   }

# %%
sparul = SPARQLWrapper(rc[4])

# %%
repo = "http://192.168.0.21:7200/repositories/test/statements"
sparul = SPARQLWrapper(repo)

# %%
try:
    sparul.setQuery(rc[5])
    sparul.setCredentials("admin", "root")
    sparul.setMethod('POST')
    results = sparul.query()
    print(results.response.read())
except Exception as e:
    print(e)
# Out:
# b''

# %%
PREFIX  wdt:  <http://www.wikidata.org/prop/direct/>
PREFIX  wikibase: <http://wikiba.se/ontology#>
PREFIX  xsd:  <http://www.w3.org/2001/XMLSchema#>
PREFIX  rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX  wd:   <http://www.wikidata.org/entity/>

SELECT  ?prop ?propLabel ?direction ?eff

{
    {
  SELECT   ?prop ?direction  (COUNT(*) as ?eff) # ?pLabel
 WHERE
  { 
  hint:Query hint:optimizer "None" .
      { ?person  wdt:P106  wd:Q170790.
       # ?person ?p ?o.
       # ?prop wikibase:directClaim ?p .  
       BIND("out" AS ?direction)
      }
  UNION
       {
       # ?person  wdt:P106  wd:Q11063.
       # ?s ?p ?person.
       # ?prop wikibase:directClaim ?p .  
       BIND("in" AS ?direction)
      }
    UNION
       {
       # ?person  wdt:P106  wd:Q155647.
       # ?s ?p ?person.
       # ?prop wikibase:directClaim ?p .  
       BIND("in" AS ?direction)
      }
  }
  
GROUP BY ?prop ?direction # ?pLabel
               }
SERVICE wikibase:label {bd:serviceParam wikibase:language "en" }
}


ORDER BY DESC(?eff)
