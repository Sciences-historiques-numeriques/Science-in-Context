# %% [markdown]
# <h1>Charting the Field of Astronomy in Early Modern Europe Using Linked Open Data</h1>
#
#
#
# <h2>[Summary / Tags]</h2>

# %% [markdown]
# In the early Nineties, Richard S. Westfall (1924–1996), a historian of science concerned with the cultural and social context of scientific activity, collected a considerable amount of information about a population of 630 scientists considered to have participated in the Scientific Revolution or in any case deserving of an entry in the Dictionary of Scientific Biography (Charles Gillispie, ed., 1979-1980). The extent of the population was thus defined by the representative character of these scholars from the encyclopedic point of view and brought together representatives from different scientific fields. The analysis of the rich information systematically collected by R. Westfall in different sources, and stored in a local database, allowed him to draw up a first profile of this population —with a primarily heuristic function— in an article published in 1996 [1]. The database was then made available to researchers on a website by Albert Van den Velden [2] and then incorporated into a website published by Robert A. Hatch where it is still available [3].

# %% [markdown]
# The multiplication of online resources over the last twenty years makes it possible to take Westfall's research agenda into a new dimension, in particular by enlarging the considered population and virtually integrating all the actors who have published works in this field. The starting point of this undertaking will be the bibliographic records of libraries and the correspondent authority files that provide basic information about the authors of the works held by these institutions. In addition, the vision of the LOD [4,5] has led to the linking of these resources through their identifiers or URIs which creates an information graph also involving platforms such as DBPedia, Wikidata, etc. Finally, more and more research projects in humanities and social sciences, particularly in the field of the history of knowledge, are making data available using semantic web technologies and connecting them to identifiers provided by authority files, following the logic of LOD [6, 7].

# %% [markdown]
# For the digital historian, the challenge therefore becomes to question these resources and to use this data for his/her own research agenda. In this paper, I will present a first stage of this approach using the ‘metadata’ about books and authors present in library authory file records, and show how the information they contain can be collected, wrangled and used to answer research questions. I will focus on a specific discipline, astronomy, and —in the same perspective as Richard Westfall, and considering the same historical period— use this information to ‘chart’ a scientific field, and more specifically the geographical origins of its actors, the places of publication of their books, and also, as far as possible, their places of activity and their evolution in time. I will also inspect the classifications provided by the librarians about books and their authors using a more or less controlled terminology, the co-occurrences of classification terms and their evolution over time with respect to the considered historical object, and, if possible, the networks of relationships emerging from this ‘metadata’. In contrast, the contents of the texts themselves will be left out of scope in this first approach.

# %% [markdown]
# The Thesaurus of CERL (Consortium of European Research Libraries) [8] will be at the heart of this endeavour. It aggregates authority files from several European Libraries, and notably the BNF and GND resources, for the period between 1450 and 1830 [9]. The aggregated data are published as LOD and provide a link to the original resources and external ones. These resources are being parsed and integrated using Python libraries. The methodology adopted will be presented in a series of Jupyter notebooks allowing to follow the process of data recovery, cleansing and integration. In order to combine data stemming from different repositories and data models, a common ontology suitable for intellectual history will be applied, and the data consequently wrangled and published —in the end of the process— in RDF format. Finally, a couple of dedicated Jupyter notebooks will propose a ‘chart’ of the field of astronomy in Early Modern Europe according to the mentioned line of inquiry (geographical mapping, classification, relationships and their and evolution in time) and thus support and accompany the storytelling of the paper that will present a possible model, i.e. a representation of the considered intellectual space from the point of view of the available information.

# %%
from lxml import etree
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


from importlib import reload
import pprint
import time
from shutil import copyfile
from operator import itemgetter
from collections import Counter

import requests
import re

import sqlite3 as sql
import csv
import json
import ast

# %%
from ipywidgets import (
    interact, fixed,
    interactive, Button,
    HTML, Layout,GridspecLayout,
    Output, jslink,
    IntSlider, ColorPicker,
    Text, SelectionRangeSlider,
    FloatRangeSlider, SelectMultiple, Checkbox,
    VBox, HBox)

# %%
from ipyleaflet import (Map,
                        basemap_to_tiles,
                        basemaps,
                        CircleMarker,
                        MarkerCluster,
                        LayerGroup, 
                        LayersControl,
                        WidgetControl,
                        Popup,
                        SplitMapControl
                       )
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# #  Get the list of the relevant persons

# %%
### The maximum result number in one page is 100, 
#  this web scraping script parses the result and walks over all the pages

parser = etree.HTMLParser(recover=True)


### Documentation concerning pagination in Elasticsearch – and CERL
#   https://mindmajix.com/elasticsearch/pagination-and-retrieving-of-documents

###  Supported REST parameters:
#   https://www.elastic.co/guide/en/elasticsearch/reference/master/sql-rest-fields.html


from_pag = 0
interv = 100

id_list = []
id_count = []

while from_pag < 3500:  # Number defined according to the manual inspected query result, 3101 on 4 March 2021

    url = 'https://data.cerl.org/thesaurus/_search?query=(mathé*+OR+mathe*+OR+matem*+OR+astro*)+AND+type%3Acnp+AND+year_start:>1450+AND+year_end:<1771&size=100&from=' + str(from_pag)

    from_pag += interv 
    
    r = requests.get(url)

    et = etree.HTML(r.content, parser)

    id_count.append(len(et.xpath('//a/@href[contains(.,"rus/cnp")]')))
    
    [id_list.append(e.replace('/thesaurus/', '')) for e in et.xpath('//a/@href[contains(.,"rus/cnp")]') if e.replace('/thesaurus/', '') ] # not in id_list

# %%
len(id_list)

# %% [markdown]
# Result number:
# * Begin of March 2021: 3102
# *  18 March 2021 : 2998
# *  19 April 2021 : 3091

# %%
id_list[-5:]

# %% [markdown]
# ## Store result in CSV
#
# Stored on 2nd April 2021

# %%
#  STOP : deactivated 
# with open('spreadsheets/query_cerl_persons_list.csv', 'w', newline='') as csvfile:
    r_writer = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    i = 0
    r_writer.writerow(['index', 'value'])
    for l in id_list:
        r_writer.writerow([i, l])
        i += 1

# %% [markdown]
# # Get the data using the new JSON files

# %% [markdown]
# ### Creating SQLite database
#
# Documentation : https://docs.python.org/3/library/sqlite3.html

# %%
### Create database (if not existing) and connect

cn = sql.connect('db_stores/CERL.db')

# %%
c = cn.cursor()

""" Deactivated after table creation

# Drop table if exists
# c.execute('''DROP TABLE new_json_files;''')

# Create table 
c.execute('''CREATE TABLE new_json_files
             (pk_new_json_files INTEGER PRIMARY KEY, id_entity text, entity_std_name varchar (250), json text, timestmp text )''')

# Save (commit) the changes
cn.commit()


"""


cn.close()

# %% [markdown]
# ###  Versioning of the SQLite database
#
# This should be done before each relevant operation on the database

# %%
def timestamp_formatted_for_file_name():
    is_now = time.strftime('%Y%m%d_%H%M%S')
    return is_now
# timestamp_formatted_for_file_name()
original_db = 'db_stores/CERL.db'
timestamped_db_copy = 'db_stores/CERL_' + timestamp_formatted_for_file_name() + '.db'
### Documentation:
# https://docs.python.org/3/library/shutil.htmlcopied_db = copyfile(original_db, timestamped_db_copy)
copied_db = copyfile(original_db, timestamped_db_copy)
### Documentation:
# https://docs.python.org/3/library/shutil.htmlcopied_db = copyfile(original_db, timestamped_db_copy)
copied_db = copyfile(original_db, timestamped_db_copy)
copied_db

# %%
db = sql.connect(original_db)

# %%
c = db.cursor()
# STOP #  c.execute('DELETE FROM new_json_files')
c.execute('SELECT COUNT(*) FROM new_json_files')
print(c.fetchone())
db.close()

# %% [markdown]
# ## Get the JSON files from the CERL server and store them into the SQLite database

# %% [markdown]
# #### Preparing address list

# %%
lread = []
with open('spreadsheets/query_cerl_persons_list.csv', newline='') as csvfile:
    fread = csv.reader(csvfile, delimiter=',')
    lread = [l for l in fread]

# %%
cnp_list = [l[1] for l in lread[1:]]
print(len(cnp_list))
cnp_list[:3]

# %% [markdown]
# ### Querying the CERL database

# %%
cn = sql.connect('db_stores/CERL.db')

# %%
##  Import JSON files into database

imported_json_files = []
for f in cnp_list:
    id_file = f
    try:
        r = requests.get('https://data.cerl.org/thesaurus/'+ id_file +'?format=json&pretty')
        time.sleep(0.1)
        json_doc = r.text.replace("'", "''")
        ## STOP ##          cn.execute("INSERT INTO new_json_files (id_entity, json, timestmp) VALUES ('"+ \
                  f + "','" + json_doc + "', datetime('now', 'localtime'))")
        ## STOP ##         cn.commit()
    except Exception as e:         
        imported_json_files.append([f,False,e])
    else:
        imported_json_files.append([f,True, ''])

# %%
print(imported_json_files[-5:])
len(imported_json_files)

# %%
### write imported file list
with open('db_stores/imported_json_files.csv', 'w', newline='') as csvfile:
    #  STOP  #     r_writer = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)

    r_writer.writerow(['file', 'result', 'error'])
    for l in imported_json_files:
        r_writer.writerow(l)

# %%
cn.close()

# %%
### there where no errors at import
errors = []
for e in imported_json_files:
    if e[1] == False:
        errors.append(e[0])
        ### Errors : 0
len(errors)

# %% [markdown]
# ### Count the produced data

# %%
cn = sql.connect('db_stores/CERL.db')

# %%
### Imported : 3019
c = cn.cursor()
# STOP #  c.execute('DELETE FROM new_json_files')
c.execute('SELECT COUNT(*) FROM new_json_files')
print(c.fetchone()[0])

# %%
cn.close()

# %% [markdown]
# # Explore the inserted data

# %% [markdown]
# ### Explore the JSON documents' structure

# %%
cn = sql.connect('db_stores/CERL.db')

# %%
c = cn.cursor()
c.execute('SELECT * FROM new_json_files')
result_l = c.fetchall()

# %% [markdown]
# #### Inspect stored data (example)

# %%
print(len(result_l))
## inspect result ##   pprint.pprint(result_l[:2])

d = ast.literal_eval(result_l[1][3])
type(d)

# %%
print(d['_id'])
z = [print(e) for e in d['data']['extDataset'] if e['typeOfResource'] == 'orig']
[(e['start'], e['end']) for e in d['data']['bioDates'] ][0]

# %%
### Keys ('fields') available in a specific document

(d['_id'],d['data'].keys())

# %% [markdown]
# ###  Parse the JSON files
#
#
# After storing the JSON web documents into the SQLite database you have to parse them into a dictionary Python document in order to be able to extract information.
#
# During this process, 16 documents out of 3101 showed to have '502 Proxy Error'. See below.

# %%
documents = []
keys_list = []
cerl_cpn_list = []
errors = []
for i in result_l:
    try:
        ## used ast.literal_eval instead of json.loads
        d = ast.literal_eval(i[3])
        keys_list.append([i[1],list(d['data'].keys())])
        documents.append([])
    except Exception as e:
        errors.append([i[0], e])
        cerl_cpn_list.append([i[1], e])

# %%
### Errors list

print(len(errors))
l_errors = [e[0] for e in errors]
print(l_errors)
print(len(cerl_cpn_list))
lcpn_errors = [e[0] for e in cerl_cpn_list]
print(lcpn_errors)

# %%
len(keys_list)

# %% [markdown]
# ### Get missing data (because of proxy errors) and update the database
#
#
# At first inspection, no data appeared to be missing but parsing the JSON data in the next step showed that around 0.5 % of the files had not been correctly retrieved.
#
# The list of not retrieved files was stored in the _lcpn_errors_ variable.
#
#
# The followin script retreives once again the missing files and updates the JSON fields with the new data.

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

# %%
### Exemple of found errors, before new retrieval: 
#  ['cnp01880566', 'cnp01342319', 'cnp00611867', 'cnp01341256']

errors = lcpn_errors
errors

# %%
##  Import JSON files into database

imported_json_files = []
for f in errors:
    id_file = f
    try:
        r = requests.get('https://data.cerl.org/thesaurus/'+ id_file +'?format=json&pretty')
        time.sleep(0.2)
        json_doc = r.text.replace("'", "''")
        
        ## STOP ##          
        c.execute("UPDATE new_json_files SET json = '"+ json_doc  \
                  + "', timestmp = datetime('now', 'localtime') WHERE id_entity = '" \
                 + str(id_file) + "'")
    except Exception as e:         
        imported_json_files.append([f,False,e])
    else:
        imported_json_files.append([f,True, ''])

## STOP ##   cn.commit()     

# imported_json_files

# %%
cn.close()

# %% [markdown]
# # Split the 'fields' in the database
#
# This step is needed in order to facilitate data inspection and information extraction.
#
# A new table is created with the values of the fiels

# %% [markdown]
# ## Get the keys' (fields') list and frequency
#
# Fields description:  https://www.cerl.org/resources/cerl_thesaurus/editing/format

# %% [markdown]
# ### Count fields per document

# %%
keys_list[:2]

# %%
count_list = []
for l in keys_list:
    count_list.append([l[0],Counter(l[1])])

# %%
z = [print(c) for c in count_list[10][1].items()]

# %%
print(len(count_list))
count_list[10][0], list(count_list[10][1].values()), list(count_list[10][1].keys())

# %% [markdown]
# ###  Test if any document has multiple instances of the same field
#
# No document has twice or more the same field. Probably these are database fields in the original information system.

# %%
multiple_values_list = []
fields_per_document = []
reference_list = []
for l in count_list:
    freq_single = 0
    freq_multiple = 0
    multiple_list = []
    for i in l[1].items():
        if i[1] > 1:
            freq_multiple += 1
            multiple_list.append(i)
        else:
            freq_single += 1
    multiple_values_list.append([l[0],freq_single, freq_multiple, multiple_list])
len(multiple_values_list)

# %%
a = [i[2] for i in multiple_values_list if i[2] > 0]
print(len(a))
multiple_values_list[10]

# %%
[print(i[0]) for i in multiple_values_list if i[2] > 0 ]

# %% [markdown]
# ### Fields frequency per document

# %%
sl = sorted(Counter([i[1] for i in multiple_values_list]).items(), key = itemgetter(0))
print(sl)

# %%
### https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html

freq = [l[0] for l in sl]
height = [l[1] for l in sl]

x = np.arange(len(freq))  # the label locations
width = 0.7  # the width of the bars

fig, ax = plt.subplots( figsize=(12,6))

rects1 = ax.bar(x, height, width, label='Frequency')

try: 
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Frequency')
    ax.set_xlabel('Number of fields per document')
    ax.set_title('Frequency by number of fields per document')
    ax.set_xticks(x)
    ax.set_xticklabels(freq)
except Exception as e:
    print(e)

ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Field total frequency

# %%
fields_list = []
for l in keys_list:
    fields_list += l[1]
c_list = Counter(fields_list)
d_list = sorted(dict(c_list).items(), key = itemgetter(1), reverse = True)
print(len(d_list))
d_list
# Out:
# 19
# [('typeOfEntry', 3091),
#  ('heading', 3091),
#  ('external', 3087),
#  ('actNote', 2826),
#  ('extDataset', 2751),
#  ('foundIn', 2730),
#  ('name', 2729),
#  ('bioDates', 2705),
#  ('generalNote', 2558),
#  ('geoNote', 2302),
#  ('imprintSource', 2061),
#  ('place', 1846),
#  ('gender', 1644),
#  ('previousId', 1496),
#  ('related', 1176),
#  ('actDates', 848),
#  ('extResource', 632),
#  ('sign', 46),
#  ('booksOwned', 7)]

# %%
### https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html

freq = [l[0] for l in d_list]
height = [l[1] for l in d_list]

width = 0.7  # the width of the bars

fig, ax = plt.subplots(figsize=(15,6))

rects1 = ax.bar(freq, height, width, label='Frequency')

try: 
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Frequency')
    ax.set_title('Frequency by number of fields per document')
    ax.set_xticks(freq)
    ax.set_xticklabels(freq, rotation = 45)
except Exception as e:
    print(e)

ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Create new table in SQLite database with splitted fields

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

# Create table
# c.execute('''DROP TABLE person_properties;''')
c.execute('''CREATE TABLE person_properties
             (pk_person_properties INTEGER PRIMARY KEY, fk_new_json_files, id_person text, std_name text,
             typeOfEntry text, heading text, external text, actNote text, extDataset text, name text, foundIn text, 
             bioDates text, generalNote text, geoNote text, imprintSource text, place text, gender text, previousId text, 
             related text, actDates text, extResource text, sign text, booksOwned text, timestmp text,
             FOREIGN KEY(fk_new_json_files) REFERENCES new_json_files(pk_new_json_files))''')


# Save (commit) the changes 
# STOP # cn.commit()
cn.close()

# %% [markdown]
# ### CERL fields description
#
# * Fields description: https://www.cerl.org/resources/cerl_thesaurus/editing/format
# * Codes: https://www.cerl.org/help/thesaurus/main
# * Available search fields: https://www.cerl.org/resources/cerl_thesaurus/editing/indexing

# %% [markdown]
# #### Prepare inserts

# %%
documents = []
inserts = []
errors = []
for i in result_l:
    try:
        pk = i[0]
        id = i[1]
        d = json.loads(i[3])

        try:
            typeOfEntry = str(d['data']['typeOfEntry'])
        except Exception as e:
            typeOfEntry = ''
        try:
            heading = str(d['data']['heading'])
        except Exception as e:
            heading = '' 
        try:
            external = str(d['data']['external'])
        except Exception as e:
            external = ''    
        try:
            actNote = str(d['data']['actNote'])
        except Exception as e:
            actNote = ''    
        try:
            extDataset = str(d['data']['extDataset'])
        except Exception as e:
            extDataset = ''    
        try:
            name = str(d['data']['name'])
        except Exception as e:
            name = ''    
        try:
            foundIn = str(d['data']['foundIn'])
        except Exception as e:
            foundIn = ''    
        try:
            bioDates = str(d['data']['bioDates'])
        except Exception as e:
            bioDates = ''    
        try:
            generalNote = str(d['data']['generalNote'])
        except Exception as e:
            generalNote = ''    
        try:
            geoNote = str(d['data']['geoNote'])
        except Exception as e:
            geoNote = ''    
        try:
            imprintSource = str(d['data']['imprintSource'])
        except Exception as e:
            imprintSource = ''    
        try:
            place = str(d['data']['place'])
        except Exception as e:
            place = ''    
        try:
            gender = str(d['data']['gender'])
        except Exception as e:
            gender = ''    
        try:
            previousId = str(d['data']['previousId'])
        except Exception as e:
            previousId = ''    
        try:
            related = str(d['data']['related'])
        except Exception as e:
            related = ''    
        try:
            actDates = str(d['data']['actDates'])
        except Exception as e:
            actDates = ''    
        try:
            extResource = str(d['data']['extResource'])
        except Exception as e:
            extResource = ''    
        try:
            sign = str(d['data']['sign'])
        except Exception as e:
            sign = ''    
        try:
            booksOwned = str(d['data']['booksOwned'])
        except Exception as e:
            booksOwned = ''    

        inserts.append([id, pk, typeOfEntry, heading, external, actNote, extDataset, name, foundIn, bioDates, generalNote, geoNote, imprintSource, place, gender, previousId, related, actDates, extResource, sign, booksOwned ])
        
    except Exception as e:
        errors.append([i[0], e])


## inspect ## inserts[5:7]

# %%
c = cn.cursor()

try:

    # Empty table
    # c.execute('''DELETE FROM person_properties;''')
    # Fill table
    c.executemany('''INSERT INTO person_properties (id_person,fk_new_json_files,  
                 typeOfEntry, heading, external, actNote, extDataset, name, foundIn, 
                 bioDates, generalNote, geoNote, imprintSource, place, gender, previousId, 
                 related, actDates, extResource, sign, booksOwned, timestmp) 
                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?, datetime('now', 'localtime'))''', inserts)

except Exception as e:
    print(e)
    pass

# Save (commit) the changes 
# STOP # cn.commit()
cn.close()

# %% [markdown]
# # Explore data
#
#
#
#
# * CERL: [Insitution and file codes in heading fields](https://cerl.org/resources/cerl_thesaurus/editing/format/list_of_insitution_and_file_codes_used_in_heading_fields)

# %% [markdown]
# ## Produce standard name

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT pk_person_properties, heading 
FROM person_properties
"""
c.execute(query)
cl = c.fetchall()
cn.close()
len(cl)

# %%
names_list = []
for i in cl:
    part = (ast.literal_eval(i[1]))[0]['part']
    try:
        entry = part[0]['entry']
    except Exception as e:
        entry = ''
    try:
        firstname = ', ' + part[1]['firstname']
    except Exception as e:
        firstname = ''
    names_list.append([entry + firstname, i[0]])

# Inspect result
names_list[3000]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

try:
    c.executemany("UPDATE person_properties SET std_name = ? WHERE pk_person_properties = ? ", names_list)
except Exception as e:
    print(e)
    pass

# Save (commit) the changes
# STOP #  cn.commit()

# %%
c = cn.cursor()
query = """
SELECT pk_person_properties, fk_new_json_files, std_name 
FROM person_properties
"""
c.execute(query)
cl = c.fetchall()
len(cl)

# %%
names_list = [[i[2], i[1]] for i in cl]
names_list[5]

# %%
c = cn.cursor()


try:
    c.executemany("UPDATE new_json_files SET entity_std_name = ? WHERE pk_new_json_files = ? ", names_list)
except Exception as e:
    print(e)
    pass

# Save (commit) the changes
# STOP #  
cn.commit()

# %%
cn.close()

# %% [markdown]
# ## New table to store splitted properties

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

# DROP table !
#  c.execute('''DROP TABLE entity_property;''')

try:
    c.execute('''CREATE TABLE entity_property
             (pk_entity_property INTEGER PRIMARY KEY, fk_new_json_files,
             property text, value text, 
             add_prop_1 text, add_val_1 text, 
             add_prop_2 text, add_val_2 text, 
             add_prop_3 text, add_val_3 text, 
             timestmp text,
             FOREIGN KEY(fk_new_json_files) REFERENCES new_json_files(pk_new_json_files))''')
except Exception as e:
    print(e)
    
# Save (commit) the changes
# STOP #  cn.commit()      

cn.close()

# %% [markdown]
# ## Get dates

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT fk_new_json_files, bioDates, pk_person_properties
FROM person_properties
"""
c.execute(query)
cl = c.fetchall()
cn.close()
len(cl)

# %%
properties = []
try: 
    jl = ast.literal_eval(cl[0][1])
    print(jl)
    for e in jl:
        print(e)
        print(e['start'])        
        print(e['end'])
        print(e['text'])
except Exception as e:
    print(e)

# %%
properties = []
errors = []
errors_field = []
for l in cl:
    try:
        jl = ast.literal_eval(l[1])
        for k in jl:
            try:
                properties.append([l[0], 'bioStart', str(k['start'])])
            except Exception as e:
                errors.append([l[0],e])
            try:
                properties.append([l[0], 'bioEnd', str(k['end'])])
            except Exception as e:
                errors.append([l[0],e])
            try:
                properties.append([l[0], 'bioText', str(k['text'])])
            except Exception as e:
                errors.append([l[0],e])
    except Exception as e:
         errors_field.append([l[0],e])
            
            
print(len(properties), len(errors), len(errors_field))
properties[1000]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
try:    
    # Empty table # c.execute('''DELETE FROM person_properties;''')
    # Fill table
    c.executemany('''INSERT INTO entity_property (fk_new_json_files,  
                 property, value, timestmp) 
                 VALUES (?,?,?, datetime('now', 'localtime'))''', properties)

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP #  cn.commit()
cn.close()

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT MIN(psp.value)
FROM entity_property psp
WHERE property = 'bioStart'
GROUP BY fk_new_json_files;
"""
c.execute(query)
cl = c.fetchall()
cn.close()
len(cl)

# %% [markdown]
# ### Plot dates

# %%
c_list = Counter([e[0] for e in cl])
d_list = [[int(e[0]), e[1]] for e in sorted(dict(c_list).items(), key = itemgetter(0), reverse = False) if e[0] >= '1400']
print(len(d_list))
print(d_list[:10])

# %%
### Create a list of 20 years periods, i.e. the list of the first year, starting 1381
g_list = []
period = 20
d_start = 1381
i = 0
g_list = []
g_list.append(d_start)

while i < 21:
    d_start = d_start + period
    g_list.append(d_start)
    i += 1

# %%
print(g_list[:2])
min(g_list), max(g_list)

# %%
# Group by 20 years periods
i_list = []
for i in g_list:
    i_n = 0
    for l in d_list:
        if l[0] >= i and l[0] < (i + 20):
            i_n = i_n + l[1]
    i_list.append([i, i_n])

# %%
print(i_list)

# %%
### https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html

freq = [l[0] for l in i_list]
height = [l[1] for l in i_list]

width = 15/len(i_list)*15  # the width of the bars

fig, ax = plt.subplots(figsize=(15,7))

rects1 = ax.bar(freq, height, width, label='Frequency')

try: 
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_xlabel('20 year periods')
    ax.set_ylabel('Frequency')
    ax.set_title('Frequency by number of begin dates per 20 year periods')
    ax.set_xticks(freq)
    ax.set_xticklabels(freq, rotation = 45)
except Exception as e:
    print(e)

ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Get sameAs URIs

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT fk_new_json_files, extDataset, pk_person_properties
FROM person_properties
"""
c.execute(query)
cl = c.fetchall()
cn.close()
len(cl)

# %%
properties = []
try: 
    jl = ast.literal_eval(cl[0][1])
    print(jl)
except Exception as e:
    print(e)

# %%
properties = []
errors = []
errors_field = []
for l in cl:
    try:
        jl = ast.literal_eval(l[1])
        for k in jl:
            try:
                searchTerm = str(k['searchTerm'])
            except Exception as e:
                errors.append([l[0],e])
            try:
                typeOfResource = str(k['typeOfResource'])
            except Exception as e:
                errors.append([l[0],e])
            try:
                code = str(k['code'])
            except Exception as e:
                errors.append([l[0],e])
                
            properties.append([l[0], 'sameAs', searchTerm, 'typeOfResource', typeOfResource, 'code', code])
            
    except Exception as e:
         errors_field.append([l[0],e])
            
print(len(properties), len(errors), len(errors_field))
properties[1000:1003]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

try:    
    # Empty table # c.execute('''DELETE FROM person_properties;''')
    # Fill table
    c.executemany('''INSERT INTO entity_property (fk_new_json_files,  
                 property, value, 
                 add_prop_1, add_val_1, 
                 add_prop_2, add_val_2, 
                 timestmp) 
                 VALUES (?,?,?,?,?,?,?, datetime('now', 'localtime'))''', properties)

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP #  cn.commit()

cn.close()

# %% [markdown]
# ### Explore references to external sources
#
# These SQL queries can be executed directly on the database using a SQLite client, e.g. DBeaver
#
# <code>
# -- Group by type
# SELECT count(*) AS eff, add_val_1
# FROM entity_property psp
# WHERE property = 'sameAs'
# GROUP BY add_val_1
# ORDER BY eff DESC  ;
#
# -- Group by origin
# SELECT count(*) AS eff, add_val_2
# FROM entity_property psp
# WHERE property = 'sameAs'
# GROUP BY add_val_2
# ORDER BY eff DESC  ;
#
# -- Group by both type and origin
# SELECT count(*) AS eff, add_val_1, add_val_2
# FROM entity_property psp
# WHERE property = 'sameAs'
# GROUP BY add_val_1, add_val_2
# ORDER BY add_val_1, add_val_2;
#
# -- double matching
# WITH tw1 AS (
# SELECT fk_new_json_files, value
# FROM entity_property psp
# WHERE property = 'sameAs'
# AND add_val_1 IN ('orig', 'same')
# ORDER BY fk_new_json_files
# ),
# tw2 AS (
# SELECT DISTINCT t1.fk_new_json_files id1, t2.fk_new_json_files id2
# FROM tw1 t1, tw1 t2
# WHERE t1.value = t2.value
# AND t1.fk_new_json_files &lt; t2.fk_new_json_files
# )
# SELECT id2, COUNT(\*), GROUP_CONCAT(id1)
# FROM tw2
# GROUP BY id2
# HAVING COUNT(\*) &gt; 1 ;
# </code>

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT *
FROM entity_property psp
WHERE property = 'sameAs'
AND add_val_1 IN ('orig', 'same')
"""
c.execute(query)
cl = c.fetchall()
cn.close()
print(len(cl))
cl[3]

# %% [markdown]
# ## Get places

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT fk_new_json_files, place, pk_person_properties
FROM person_properties
"""
c.execute(query)
cl = c.fetchall()
cn.close()
len(cl)

# %%
properties = []
try: 
    jl = ast.literal_eval(cl[1][1])
    print(jl)
except Exception as e:
    print(e)

# %%
properties = []
errors = []
errors_field = []
for l in cl:
    try:
        jl = ast.literal_eval(l[1])
        for k in jl:
            try:
                typeOfPlace = str(k['typeOfPlace'])
            except Exception as e:
                typeOfPlace = ''
                errors.append([l[0],e])
            try:
                id = str(k['id'])
            except Exception as e:
                id = ''
                errors.append([l[0],e])
            try:
                name = str(k['part'][0]['name'])
            except Exception as e:
                name = ''
                errors.append([l[0],e])
                
            properties.append([l[0], 'idPlace', id, 'typeOfPlace', typeOfPlace, 'name', name])
            
    except Exception as e:
         errors_field.append([l[0],e])
            
print(len(properties), len(errors), len(errors_field))
properties[61:65]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
try:    
    # Fill table
    c.executemany('''INSERT INTO entity_property (fk_new_json_files,  
                 property, value, 
                 add_prop_1, add_val_1, 
                 add_prop_2, add_val_2, 
                 timestmp) 
                 VALUES (?,?,?,?,?,?,?, datetime('now', 'localtime'))''', properties)

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP # cn.commit()

cn.close()

# %% [markdown]
# ### Inspect the geographical place data
#
# It appears that in the data :
# * the same places have different cnl codes
# * some places without code have a code (alphabetical order shows this)
# * in the JSON files are aware of this internal links but they cannot be directly retrieved, the places IDs where not changed in the persons' files after matching
# * it is therefore unavoidable to have redundancy in the retrieved data
# * there are also some IDs that are not _cnl_ and therefore must be excluded
#
# <code>
#
# SELECT add_val_1,
#        count( * ) eff
#   FROM entity_property psp
#  WHERE add_prop_1 = 'typeOfPlace'
#  GROUP BY add_val_1
#  ORDER BY eff DESC;
#
# SELECT value ,
#        count( * ) eff
#   FROM entity_property psp
#  WHERE add_prop_1 = 'typeOfPlace'
#  GROUP BY value
#  ORDER BY eff DESC;
#
#     WITH tw1 AS (SELECT DISTINCT value, add_val_2
#   FROM entity_property psp
#  WHERE add_prop_1 = 'typeOfPlace')
# SELECT *
# FROM tw1
# WHERE value LIKE 'cnl%'
# ORDER BY add_val_2;
#
# </code>

# %% [markdown]
# ## Get the JSON files about geogr. places from the CERL server and store them into the SQLite database

# %% [markdown]
# #### Preparing address list

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
query = """
SELECT DISTINCT value
  FROM entity_property psp
 WHERE add_prop_1 = 'typeOfPlace'
 AND value LIKE 'cnl%'
"""
c.execute(query)
cl = c.fetchall()
cn.close()
print(len(cl))
cl[1:3]

# %%
id_list = [i[0] for i in cl]
print(len(id_list))
id_list[1]

# %% [markdown]
# ### Get the data from the CERL API

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

# %%
##  Import JSON files into database

imported_json_files = []
for f in id_list:
    id_file = f
    try:
        r = requests.get('https://data.cerl.org/thesaurus/'+ id_file +'?format=json&pretty')
        time.sleep(0.2)
        json_doc = r.text.replace("'", "''")
  
        ## STOP ##        
        c.execute("INSERT INTO new_json_files (id_entity, json, timestmp) VALUES ('"+ \
                  f + "','" + json_doc + "', datetime('now', 'localtime'))")
  
        ## STOP ##        cn.commit()
    
    except Exception as e:         
        imported_json_files.append([f,False,e])
    else:
        imported_json_files.append([f,True, ''])

# %%
c = cn.cursor()
c.execute("SELECT COUNT(*) FROM new_json_files WHERE id_entity LIKE 'cnl%'")
print(c.fetchone())
cn.close()

# %%
print(imported_json_files[-5:])
len(imported_json_files)

# %%
with open('db_stores/imported_json_files_places.csv', 'w', newline='') as csvfile:
    #  STOP  #     r_writer = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)

    r_writer.writerow(['file', 'result', 'error'])
    for l in imported_json_files:
        r_writer.writerow(l)

# %%
### there where no errors at import
errors = []
for e in imported_json_files:
    if e[1] == False:
        errors.append(e[0])
len(errors)

# %% [markdown]
# ## Explore the inserted data: get the places and geographical coordinates

# %% [markdown]
# ### Add location data

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
c.execute("SELECT pk_new_json_files, id_entity, json FROM new_json_files WHERE id_entity LIKE 'cnl%';")
result_l = c.fetchall()
cn.close()

# %%
properties = []
errors = []
errors_field = []
for l in result_l:
    try:
        k = ast.literal_eval(l[2])
        try:
            place_st_name = str(k['data']['heading'][0]['part'][0]['entry'])            
        except Exception as e:
            place_st_name = ''
            errors.append([l[0],e])
        try:
            id = str(k['_id'])
        except Exception as e:
            id = ''
            errors.append([l[0],e])
        try:
            long = str(k['data']['location']['point']['long'])
        except Exception as e:
            long = ''
            errors.append([l[0],e])
        try:
            lat = str(k['data']['location']['point']['lat'])
        except Exception as e:
            lat = ''
            errors.append([l[0],e])

        properties.append([l[0], 'place_st_name', place_st_name, 'cerl_id', id, 'long', long, 'lat', lat])
            
    except Exception as e:
         errors_field.append([l[1],e])
            
print(len(properties), len(errors), len(errors_field))

# %%
print(errors_field[:3])
errors_id = [i[0] for i in errors_field]

### BEWARE : in not empty reload JSON with query
errors_id

# %% [markdown]
# #### Issue : not existing CERL documents
#
# These documents are not available any more : 'cnl00017057', 'cnl00017393' – although still referred to in the data

# %%
### Locations are missing...

errors[:10]

# %% [markdown]
# ## Produce new entity properties with geog. location

# %%
print(len(properties))
properties[61]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

try:    
    c.executemany('''INSERT INTO entity_property (fk_new_json_files,  
                 property, value, 
                 add_prop_1, add_val_1, 
                 add_prop_2, add_val_2, 
                 add_prop_3, add_val_3, 
                 timestmp) 
                 VALUES (?,?,?,?,?,?,?,?,?, datetime('now', 'localtime'))''', properties)

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP #  cn.commit()

cn.close()

# %% [markdown]
# ## Get identical places using long/lat coordinates
#
#
# <code>
#     WITH tw1 AS (
#     SELECT group_concat(add_val_1) cerl_ids,
#            CAST (add_val_2 AS FLOAT) long,
#            CAST (add_val_3 AS FLOAT) lat,
#            count( * ),
#            group_concat(value) noms
#       FROM entity_property
#      WHERE add_val_2 > '' AND
#            add_prop_2 = 'long'
#      GROUP BY add_val_2,
#               add_val_3
#      ORDER BY noms
# )
# --SELECT * FROM tw1 ;
# SELECT t1.noms,
#        t1.long,
#        t1.lat,
#        t2.noms,
#        t2.long,
#        t2.lat
#   FROM tw1 t1,
#        tw1 t2
#  WHERE t1.cerl_ids > t2.cerl_ids AND
#        t1.lat BETWEEN t2.lat - 0.02 AND t2.lat + 0.02 AND
#        t1.long BETWEEN t2.long - 0.02 AND t2.long + 0.02;
# </code>

# %% [markdown]
# ### Create internal references

# %%
result_l[0][0], result_l[0][1], ast.literal_eval(result_l[0][2])['data']['previousId']

# %% [markdown]
# ## Add the references to previous Id numbers of places

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
c.execute("SELECT pk_new_json_files, id_entity, json FROM new_json_files WHERE id_entity LIKE 'cnl%';")
result_l = c.fetchall()
cn.close()

# %% [markdown]
# ### Inspect stored data

# %%
print(len(result_l))
## inspect result ##   pprint.pprint(result_l[:2])
d = json.loads(result_l[1][2])
type(d)

# %%
 ast.literal_eval(result_l[2][2])['data']['previousId']

# %%
ld = [[z[1],  ast.literal_eval(z[2])['data']['previousId']] for z in result_l[:2]]
pprint.pprint(ld)

# %% [markdown]
# ### Add references to previous Id numbers data

# %%
properties = []
errors = []
errors_field = []
for l in result_l:
    try:
        k = ast.literal_eval(l[2])
        kpid_list = []

        try:
            for kpid in k['data']['previousId']:                
                kpid_list.append([l[0], 'cerl_id', l[1], 'previous_cerl_id', kpid])
        except Exception as e:
            errors.append([l[0],e])

        properties += kpid_list
        # properties.append([l[0], 'place_st_name', place_st_name, 'cerl_id', id, 'long', long, 'lat', lat])
            
    except Exception as e:
         errors_field.append([l[1],e])
            
print(len(properties), len(errors), len(errors_field))

# %%
print(errors_field[:3])
errors_id = [i[0] for i in errors_field]

### BEWARE : in not empty reload JSON with query
errors_id

# %% [markdown]
# #### Issue : not existing CERL documents
#
# These documents are not available any more : 'cnl00017057', 'cnl00017393' – although still referred to in the data

# %%
### Locations are missing...

errors[:10]

# %% [markdown]
# ## Produce new Id number correspondences

# %%
print(len(properties))
properties[61]

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

try:    
    c.executemany('''INSERT INTO entity_property (fk_new_json_files,  
                 property, value, 
                 add_prop_1, add_val_1, 
                 timestmp) 
                 VALUES (?,?,?,?,?, datetime('now', 'localtime'))''', properties)

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP # cn.commit()

cn.close()

# %% [markdown]
# # Map births' dates and places

# %% [markdown]
# ### Create new SQL view

# %%
### NEW QUERY VIEW
drop_view = "DROP VIEW v_persons_birth_year_and_place;"

create_view = """
CREATE VIEW v_persons_birth_year_and_place AS
WITH geo_places AS (
SELECT value, add_val_1, add_val_2, add_val_3 
FROM entity_property ep 
WHERE ep.property = 'place_st_name'
AND LENGTH(add_val_2) > 0),
tw1 AS (
SELECT DISTINCT njf.pk_new_json_files, njf.id_entity person_id, njf.entity_std_name, ep3.value v1, ep2.value v2,  gp.value v3, gp.add_val_2 v4, gp.add_val_3 v5, ep2.fk_new_json_files 
FROM entity_property ep2 
LEFT JOIN geo_places gp ON gp.add_val_1 = ep2.value 
LEFT JOIN new_json_files njf ON njf.pk_new_json_files = ep2.fk_new_json_files 
LEFT JOIN entity_property ep3 ON ep3.fk_new_json_files = ep2.fk_new_json_files AND ep3.property ='bioStart'
WHERE ep2.property = 'idPlace'
AND LENGTH(ep2.value) > 0
AND ep2.add_val_1 = 'brth'
AND length(gp.add_val_2) > 0
AND ep3.value > '1399'
UNION 
SELECT DISTINCT njf.pk_new_json_files, njf.id_entity person_id, njf.entity_std_name, ep3.value v1, ep2.value v2,  gp.value v3, gp.add_val_2 v4, gp.add_val_3 v5, ep2.fk_new_json_files 
FROM entity_property ep2 
LEFT JOIN entity_property ep4 ON ep4.add_val_1 = ep2.value AND ep4.add_prop_1 = 'previous_cerl_id'
LEFT JOIN geo_places gp ON gp.add_val_1 = ep4.value AND ep4.property = 'cerl_id'
LEFT JOIN new_json_files njf ON njf.pk_new_json_files = ep2.fk_new_json_files 
LEFT JOIN entity_property ep3 ON ep3.fk_new_json_files = ep2.fk_new_json_files AND ep3.property ='bioStart'
WHERE ep2.property = 'idPlace'
AND LENGTH(ep2.value) > 0
AND ep2.add_val_1 = 'brth'
AND length(gp.add_val_2) > 0
AND ep3.value > '1399'
)
SELECT pk_new_json_files, person_id, entity_std_name, min(v1) AS v1, min(v2), min(v3), min(v4), min(v5) FROM tw1
GROUP BY pk_new_json_files, entity_std_name
ORDER BY v1;
"""

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()

try:    

    c.execute(create_view)   # drop_view
    cv = c.fetchone()

except Exception as e:
    print(e)

# Save (commit) the changes
# STOP # cn.commit()

cn.close()

# %% [markdown]
# ### Some persons are present more then once
#
# Execute in the SQLite graphical client:
#
# <pre><code sql>
# SELECT MAX(person_id) AS person_id, entity_std_name,
# v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)", group_concat(person_id), COUNT(*) freq
# FROM v_persons_birth_year_and_place
# GROUP BY entity_std_name,  v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)"
# ORDER BY freq DESC ;
#
#
#
# SELECT COUNT(*), MAX(person_id), group_concat(person_id),group_concat(entity_std_name),
# v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)"
# FROM v_persons_birth_year_and_place
# GROUP BY  v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)" ;
# </code> </pre>

# %% [markdown]
# # Interactively plot the birth dates

# %%
query = """
SELECT MAX(person_id) AS person_id, entity_std_name, 
v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)"
FROM v_persons_birth_year_and_place
GROUP BY entity_std_name,  v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)" 
ORDER BY v1 ;
"""

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
c.execute(query)
result_l = c.fetchall()
cn.close()
print(len(result_l))
result_l[:2]  ## number : 1030 persons
# Out:
# 1030
# [('cnp01352012',
#   'Matthaeus Silvagius',
#   '1400',
#   'cnl00008119',
#   'Catania',
#   '15.0894444444444',
#   '37.5'),
#  ('cnp02088071',
#   'Salio, Girolamo',
#   '1400',
#   'cnl00009081',
#   'Faenza',
#   '11.88',
#   '44.28')]

# %%
df_result = pd.DataFrame(result_l, \
                         columns= ['person_id', 'entity_std_name', \
                                   'birth_year', 'id_place', 'place_label', 'long', 'lat'])
df_result.head(10)
# Out:
#      person_id             entity_std_name birth_year     id_place  \
# 0  cnp01352012         Matthaeus Silvagius       1400  cnl00008119
# 1  cnp02088071             Salio, Girolamo       1400  cnl00009081
# 2  cnp01881207              Kues, Nikolaus       1401  cnl00019522
# 3  cnp01879247      Leonico Tomeo, Niccolò       1428  cnl00006586
# 4  cnp00996213                      Paulus       1445  cnl00011695
# 5  cnp01320054  Avraham ben Shemuʾel Zakut       1450  cnl00027007
# 6  cnp01363268              Gazio, Antonio       1450  cnl00027154
# 7  cnp01241028           Vespucci, Amerigo       1451  cnl00017011
# 8  cnp00873006                  Franciscus       1452  cnl00006586
# 9  cnp01329886         Barbarus, Hermolaus       1453  cnl00006586
#
#        place_label              long               lat
# 0          Catania  15.0894444444444              37.5
# 1           Faenza             11.88             44.28
# 2  Bernkastel-Kues  7.06472222222222  49.9166666666667
# 3          Venezia             11.55  45.4391666666667
# 4       Middelburg              3.62              51.5
# 5        Salamanca             -5.65  40.9691666666667
# 6           Padova             11.88             45.42
# 7          Firenze             11.25  43.7830555555556
# 8          Venezia             12.33  45.4391666666667
# 9          Venezia             12.33  45.4391666666667

# %% [markdown]
# ## Distribution of birth years grouped by periods

# %%
year_count = df_result.groupby(['birth_year', ], as_index=False) \
      .agg({'person_id': 'count'}).sort_values(by=['birth_year'])
print(len(year_count))
year_count[:50] #[130:150]
# Out:
# 263
#    birth_year  person_id
# 0        1400          2
# 1        1401          1
# 2        1428          1
# 3        1445          1
# 4        1450          2
# 5        1451          1
# 6        1452          1
# 7        1453          1
# 8        1454          1
# 9        1455          2
# 10       1456          1
# 11       1459          2
# 12       1460          6
# 13       1462          2
# 14       1465          2
# 15       1466          1
# 16       1467          2
# 17       1468          1
# 18       1470          2
# 19       1471          1
# 20       1472          1
# 21       1473          2
# 22       1475          3
# 23       1476          1
# 24       1477          2
# 25       1478          1
# 26       1479          1
# 27       1480          3
# 28       1481          2
# 29       1485          1
# 30       1486          1
# 31       1487          4
# 32       1488          6
# 33       1490          2
# 34       1492          1
# 35       1493          3
# 36       1494          4
# 37       1495          2
# 38       1496          1
# 39       1497          1
# 40       1498          2
# 41       1499          5
# 42       1500         13
# 43       1501          3
# 44       1502          4
# 45       1503          3
# 46       1504          2
# 47       1505          3
# 48       1508          2
# 49       1509          2

# %%
year_l = year_count.values.tolist() 
print(year_l[-1:])
year_l[:3]
# Out:
# [['1799', 1]]
# [['1400', 2], ['1401', 1], ['1428', 1]]

# %%
### Create a list with intervals of 10 years, corresponding approximately to one generation.

def create_years_list(period = 10, y_start = 1391, y_end = 1801):

    y_list = []
    y_list.append(y_start)

    while y_start < y_end:
        y_start += period
        y_list.append(y_start)
    return y_list

# %%
period = 10 
y_list = create_years_list(period = period, y_start = 1391, y_end = 1801)
print(y_list[:2])
min(y_list), max(y_list)
# Out:
# [1391, 1401]
# (1391, 1801)

# %%
# Births grouped by periods of 10 years
i_list = []
for i in y_list:
    i_n = 0
    for l in year_l:
        if int(l[0]) >= i and int(l[0]) < (i + period):
            i_n = i_n + l[1]
    i_list.append([i, i_n]) 
print(i_list)
# Out:
# [[1391, 2], [1401, 1], [1411, 0], [1421, 1], [1431, 0], [1441, 3], [1451, 15], [1461, 10], [1471, 15], [1481, 16], [1491, 32], [1501, 26], [1511, 23], [1521, 43], [1531, 51], [1541, 26], [1551, 33], [1561, 49], [1571, 40], [1581, 61], [1591, 65], [1601, 41], [1611, 48], [1621, 36], [1631, 50], [1641, 51], [1651, 50], [1661, 51], [1671, 55], [1681, 41], [1691, 40], [1701, 31], [1711, 13], [1721, 8], [1731, 1], [1741, 1], [1751, 0], [1761, 0], [1771, 0], [1781, 0], [1791, 1], [1801, 0]]

# %%
# Distribution by 10 years periods
def interactive_periods(period=10):
    
    y_list = create_years_list(period = period, y_start = 1391, y_end = 1801)

    i_list = []
    for i in y_list:
        i_n = 0
        for l in year_l:
            if int(l[0]) >= i and int(l[0]) < (i + period):
                i_n = i_n + l[1]
        i_list.append([i, i_n]) 

    periods = [e[0] for e in i_list]
    eff = [e[1] for e in i_list]

    p1 = plt.bar(periods, eff, width= period - (period * 20 / 100))

    plt.xticks([i - period / 2 for i in y_list])
    plt.ylabel('Frequency')
    plt.title('Births per '+ str(period) +' years')
    plt.gcf().set_size_inches(14, 7)
    #plt.gca().axes.get_xaxis().set_visible(False)
    # supported formats: eps, pdf, pgf, png, ps, raw, rgba, svg, svgz
    #plt.savefig('exported_pictures/effectifs_naissances_par_annee.png', dpi=100, bbox_inches = "tight") #pdf, svg
    plt.xticks(rotation=45)
    plt.show()

# %%
i = interact(interactive_periods, period=IntSlider(min=10, max=100, step=5, value=20))
# Out:
# interactive(children=(IntSlider(value=20, description='period', min=10, step=5), Output()), _dom_classes=('wid…

# %% [markdown]
# ## Map the population birth places in relation to (interactive) time spans

# %%
### Concatenation of the person label values !
# Needed for the popup
df_result['concat_person'] = df_result['person_id'] + '|' + df_result['entity_std_name'] + ' (' + df_result['birth_year'] + ')'

# %%
df_result.head()

# %%
place_count = df_result.groupby(['id_place', 'place_label', 'long', 'lat'], as_index=False) \
      .agg({'concat_person': ','.join, 'person_id': 'count'}).sort_values(by=['place_label'])
print(len(place_count))
place_count[130:150]

# %%
place_count[place_count['place_label'] == 'Milano']

# %%
def update_layer(m, begin_end, color):
    
    # [m.remove_layer(n) for n in m.layers if n.name in ['Clusters', 'Flat locs']]
    
    [m.remove_control(n) for n in m.controls if 'LayersControl' in str(type(n)) ]
    
        
    begin = begin_end[0]
    end = begin_end[1]
    x = df_result[(df_result['birth_year'].astype(int) >= begin) \
                  & (df_result['birth_year'].astype(int) < end)]
    xgb = x.groupby(['id_place', 'place_label', 'long', 'lat'], as_index=False) \
      .agg({'concat_person': '#'.join, 'person_id': 'count'})
    place_count = xgb.rename(columns={'person_id': 'count_persons'})


    markers = []
    popups = []
    

    for i,j in place_count.iterrows():
    # print(j['id_place'])
        message = HTML()
        p_elements = ''
        for z in j['concat_person'].split('#'):
            if '|' in z:
                zs = z.split('|')
                p_elements += f"""<a href="https://data.cerl.org/thesaurus/{zs[0]}">{zs[1]}</a><br/>"""
            else:
                p_elements = ''

        message.value = f"<h4>{j['place_label']}</h4>" + p_elements
        a = HBox([message], layout=Layout(width='200px', height='200px', overflow_y='auto',overflow="auto"))


        circle = CircleMarker(location=(j['lat'], j['long']), color="black", name=f"{j['place_label']}", \
                              fill_color=color, radius = j['count_persons']+2, weight=1)

        circle.popup = a
        
        markers.append(circle)


    print("Markers' number " + str(len(markers)))
    
    name_part = str(begin_end[0]) + '-' + str(begin_end[1]) + ' (' +  color + ')'
    
    lg1 = LayerGroup(name='Birth places ' + name_part, layers=(markers))
    # lg2 = MarkerCluster(name='Clusters' + name_part, markers=markers)

    m.add_layer(lg1)
    # m.add_layer(lg2)
    
    control = LayersControl(name='layCont', position='topright')
    m.add_control(control)
    return n_iterations

# %%
df_year_set = sorted(list(set(df_result['birth_year'].astype(int))))
print(len(df_year_set))
min_y = min(df_year_set)
max_y = max(df_year_set)
i = 0
srs = SelectionRangeSlider(
    options=df_year_set,
    index=(0, len(df_year_set)-1),
    description='Years', 
    continous_update=False
    # , disabled=False
)

# %%
watercolor = basemap_to_tiles(basemaps.Stamen.Watercolor)
# esri_sat = basemap_to_tiles(basemaps.Esri.WorldImagery)

## https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html
m = Map(layers=(watercolor,), center=(45, 15), layout=Layout(width='100%', height='600px'),\
        zoom_control=False        # , zoom=4, scroll_wheel_zoom= True
       )

zoom_slider = IntSlider(description='Zoom level:', min=0, max=15, value=4)
jslink((zoom_slider, 'value'), (m, 'zoom'))
widget_control1 = WidgetControl(widget=zoom_slider, position='bottomright')
m.add_control(widget_control1)

m

# %%
### https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html
n_iterations = 0
colors = ['blue', 'red', 'black', 'purple', 'yellow' ]
a = interactive(update_layer, {'manual':True}, m = fixed(m), color = colors, begin_end = srs);
display(a)

# %%
i = interact(interactive_periods, period=IntSlider(min=10, max=100, step=10, value=20))

# %%
[m.remove_control(n) for n in m.controls if 'LayersControl' in str(type(n)) ]

# %%
[m.remove_control(n) for n in m.controls if 'LayerGroup' in str(type(n)) if n.name == 'Birth places 1550-1620 (yellow)']

# %% [markdown]
# # Activities
#
# Connect to the database and get the CERL fields where persons' activities are documenteted

# %%
query = """
SELECT v1.person_id, entity_std_name, v1.v1, pp.actNote, 
       pp.generalNote, v1."min(v2)" , v1."min(v3)" , v1."min(v4)" , v1."min(v5)" 
FROM v_persons_birth_year_and_place AS v1 
LEFT JOIN  person_properties pp ON pp.fk_new_json_files = v1.pk_new_json_files 
"""

# %%
cn = sql.connect('db_stores/CERL.db')
c = cn.cursor()
c.execute(query)
result_l = c.fetchall()
cn.close()

# %%
print(len(result_l))
result_l[:2]  ## number : 1035 persons – but about 20 redundant, mentioned twice
# Out:
# 1046
# [('cnp01352012',
#   'Matthaeus Silvagius',
#   '1400',
#   "[{'lang': 'eng', 'intro': 'lang', 'text': 'Latin'}, {'text': 'Auteur', 'lang': 'fre', 'intro': 'irsp'}, {'uri': 'http://d-nb.info/gnd/4059756-8', 'text': 'Theologe', 'lang': 'ger', 'intro': 'acti', 'authority': 'gnd'}]",
#   "[{'text': 'Franciscain. - Actif en 1490', 'lang': 'fre'}, {'lang': 'fre', 'text': 'Source(s) consultée(s) en vain: BN Cat. gén.. - Arch. biogr. italiano, index. - Encicl. italiana. - Buchwald. - PMA. - Clavis SGL. - Larousse 19e s.'}, {'lang': 'ger', 'text': 'Italien. franziskanischer Theologe aus Catania'}, {'text': 'OFM; Joh.I, 1-14; Liber de tribus peregrinis', 'lang': 'ger'}, {'lang': 'ita', 'text': 'Teologo francescano di Catania nato nel 1490 e morto nel 1542'}]",
#   'cnl00008119',
#   'Catania',
#   '15.0894444444444',
#   '37.5'),
#  ('cnp02088071',
#   'Salio, Girolamo',
#   '1400',
#   "[{'uri': 'http://d-nb.info/gnd/4003157-3', 'text': 'Arzt', 'lang': 'ger', 'intro': 'acti', 'authority': 'gnd'}, {'lang': 'ger', 'intro': 'acti', 'authority': 'gnd', 'uri': 'http://d-nb.info/gnd/4415075-1', 'text': 'Astrologe'}, {'uri': 'http://d-nb.info/gnd/4045790-4', 'text': 'Philosoph', 'authority': 'gnd', 'intro': 'acti', 'lang': 'ger'}]",
#   "[{'lang': 'eng', 'text': 'Not found in: LUI'}, {'lang': 'ger', 'text': 'Ital. Arzt, Philosoph und Astrologe aus Faenza; Korrektor und Herausgeber von aus dem Arabischen übersetzten medizinischen Werken'}, {'text': 'Ital. Humanist, Korrektor', 'lang': 'ger'}]",
#   'cnl00009081',
#   'Faenza',
#   '11.88',
#   '44.28')]

# %% [markdown]
# ## Inspect the activity notes field and code the activities
#
# Original activities are those annotated as such in CERL, i.e. in the actNotes field:
#
# In this part they are grouped, inspected and coded

# %% [markdown]
# ### Produce the original activities list
#
# Original activities are those annotated as such in CRL, i.e. in the actNotes field

# %%
ast.literal_eval(result_l[0][3])

# %%
ast.literal_eval(result_l[0][4])

# %%
orig_activities_list = []
errors_list = []

for l in result_l:
    
    try:
        gnd_activities  = []

        for t in ast.literal_eval(l[3]):        
            try:
                if  t['intro']=='acti' and t['authority'] == 'gnd':
                    gnd_activities.append(t['text'])

            except Exception as e:
                # print(e)
                pass

        orig_activities_list.append([l[0], gnd_activities])
    except Exception as x:
        errors_list.append([l[0], x])

# %%
print(len(errors_list))
errors_list
# Out:
# 8
# [['cnp02178661',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp00702380',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp01159238',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp02330985',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp01282497',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp02057613',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp02306744',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp01167338',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))]]

# %%
print(len(orig_activities_list))
orig_activities_list[:10]

# %% [markdown]
# ### Group and count the activities

# %%
tokens_li = []

for z in [ t[1] for t in orig_activities_list]:
    tokens_li += z

# %%
print(len(tokens_li))
tokens_li[:10]

# %%
counter= Counter([t for t in tokens_li])

# %%
c_result = list(zip(counter.keys(), counter.values()))

# %%
s_tokens_li = sorted(c_result, key=itemgetter(1), reverse=True)
s_tokens_li
# Out:
# [('Mathematiker', 482),
#  ('Astronom', 202),
#  ('Arzt', 140),
#  ('Hochschullehrer', 109),
#  ('Philosoph', 91),
#  ('Theologe', 67),
#  ('Physiker', 66),
#  ('Schriftsteller', 56),
#  ('Pfarrer', 50),
#  ('Jurist', 38),
#  ('Kartograf', 36),
#  ('Evangelischer Theologe', 34),
#  ('Architekt', 31),
#  ('Historiker', 30),
#  ('Astrologe', 28),
#  ('Naturwissenschaftler', 28),
#  ('Geograf', 28),
#  ('Lehrer', 28),
#  ('Gymnasiallehrer', 25),
#  ('Ingenieur', 19),
#  ('Katholischer Theologe', 18),
#  ('Philologe', 18),
#  ('Humanist', 17),
#  ('Rechenmeister', 17),
#  ('Rektor', 15),
#  ('Bibliothekar', 14),
#  ('Maler', 13),
#  ('Selbstverleger', 12),
#  ('Missionar', 12),
#  ('Kupferstecher', 11),
#  ('Musiker', 11),
#  ('Pädagoge', 11),
#  ('Gelehrter', 10),
#  ('Geistlicher', 10),
#  ('Superintendent', 10),
#  ('Übersetzer', 9),
#  ('Hebraist', 9),
#  ('Botaniker', 9),
#  ('Prediger', 8),
#  ('Adel', 8),
#  ('Komponist', 8),
#  ('Mönch', 7),
#  ('Polyhistor', 7),
#  ('Orientalist', 7),
#  ('Ratsherr', 7),
#  ('Bischof', 6),
#  ('Künstler', 6),
#  ('Drucker', 6),
#  ('Reformator', 6),
#  ('Verleger', 6),
#  ('Schreibmeister', 6),
#  ('Mechaniker', 6),
#  ('Priester', 6),
#  ('Hofrat', 6),
#  ('Politiker', 5),
#  ('Diplomat', 5),
#  ('Klassischer Philologe', 5),
#  ('Baumeister', 5),
#  ('Meteorologe', 5),
#  ('Privatlehrer', 5),
#  ('Festungsbaumeister', 4),
#  ('Autor', 4),
#  ('Diakon', 4),
#  ('Dramatiker', 4),
#  ('Musikwissenschaftler', 4),
#  ('Leibarzt', 4),
#  ('Hofprediger', 4),
#  ('Bürgermeister', 4),
#  ('Dozent', 4),
#  ('Kaufmann', 3),
#  ('Zeichner', 3),
#  ('Buchdrucker', 3),
#  ('Alchemist', 3),
#  ('Radierer', 3),
#  ('Mathematiklehrer', 3),
#  ('Kunsthandwerker', 3),
#  ('Instrumentenbauer', 3),
#  ('Forschungsreisender', 3),
#  ('Topograf', 3),
#  ('Buchhändler', 3),
#  ('Organist', 3),
#  ('Student', 3),
#  ('Gräzist', 3),
#  ('Vermessungsingenieur', 3),
#  ('Laienbruder', 3),
#  ('Logiker', 3),
#  ('Publizist', 3),
#  ('Astronomin', 3),
#  ('Seefahrer', 2),
#  ('Feldherr', 2),
#  ('Grafiker', 2),
#  ('Kirchenlieddichter', 2),
#  ('Kanoniker', 2),
#  ('Domkapitular', 2),
#  ('Magier', 2),
#  ('Sammler', 2),
#  ('Goldschmied', 2),
#  ('Büchsenmacher', 2),
#  ('Korrektor', 2),
#  ('Medizinstudent', 2),
#  ('Bildhauer', 2),
#  ('Herausgeber', 2),
#  ('Chronist', 2),
#  ('Apotheker', 2),
#  ('Geschichtsschreiber', 2),
#  ('Chemiker', 2),
#  ('Linguist', 2),
#  ('Mineraloge', 2),
#  ('Moraltheologe', 2),
#  ('Sänger', 2),
#  ('Archäologe', 2),
#  ('Abt', 2),
#  ('Ordenspriester', 2),
#  ('Offizier', 2),
#  ('Philosophin', 2),
#  ('Zensor', 2),
#  ('Librettist', 2),
#  ('Kardinal', 1),
#  ('Anglikanischer Theologe', 1),
#  ('Seemann', 1),
#  ('Entdecker', 1),
#  ('Reisender', 1),
#  ('Ritter', 1),
#  ('Prior', 1),
#  ('Barbier', 1),
#  ('Naturphilosoph', 1),
#  ('Uhrmacher', 1),
#  ('Pfarrer (evangelisch)', 1),
#  ('Formschneider', 1),
#  ('Kämmerer', 1),
#  ('Holzschneider', 1),
#  ('Miniaturist', 1),
#  ('Kunsthändler', 1),
#  ('Domprediger', 1),
#  ('Literaturkritiker', 1),
#  ('Kalligraph', 1),
#  ('Hofbeamter', 1),
#  ('Landsknecht', 1),
#  ('Okkultist', 1),
#  ('Glasmaler', 1),
#  ('Abenteurer', 1),
#  ('Doge', 1),
#  ('Unitarier', 1),
#  ('Anatom', 1),
#  ('Notar', 1),
#  ('Stadtschreiber', 1),
#  ('Domvikar', 1),
#  ('Kanalbauer', 1),
#  ('Unternehmer', 1),
#  ('Lexikograf', 1),
#  ('Erzbischof', 1),
#  ('Fürstbischof', 1),
#  ('Zollbeamter', 1),
#  ('Kantor', 1),
#  ('Diktator', 1),
#  ('Amtsarzt', 1),
#  ('Philologie', 1),
#  ('Admiral', 1),
#  ('Graveur', 1),
#  ('Mathematikstudent', 1),
#  ('Kanzleibeamter', 1),
#  ('Landgraf', 1),
#  ('Buchhalter', 1),
#  ('Buchbinder', 1),
#  ('Übersetzer (von Sallust, Velleius Paterculus u. Tacitus)', 1),
#  ('Verwaltungsbeamter', 1),
#  ('Schöffe', 1),
#  ('Stadtrat', 1),
#  ('Rabbiner', 1),
#  ('Bauherr', 1),
#  ('Jesuaten', 1),
#  ('Philosophielehrer', 1),
#  ('Christlicher Schriftsteller', 1),
#  ('Abgeordneter', 1),
#  ('Staatssekretär', 1),
#  ('Landschaftsmaler', 1),
#  ('Marinemaler', 1),
#  ('Respondent', 1),
#  ('Sozinianer', 1),
#  ('Bibliophiler', 1),
#  ('Zoologe', 1),
#  ('Prälat', 1),
#  ('Hofmeister', 1),
#  ('Schriftstellerin', 1),
#  ('Chorherren', 1),
#  ('Bauer', 1),
#  ('Jugendseelsorger', 1),
#  ('Artillerist', 1),
#  ('Literaturwissenschaftler', 1),
#  ('Kirchenhistoriker', 1),
#  ('Satiriker', 1),
#  ('Journalist', 1),
#  ('Heraldiker', 1),
#  ('Numismatiker', 1),
#  ('Stifter', 1),
#  ('Autorin', 1),
#  ('Feministin', 1),
#  ('Feinmechaniker', 1),
#  ('Genealoge', 1),
#  ('Pietist', 1),
#  ('Tischler', 1),
#  ('Kupferstecherin', 1),
#  ('Zeichnerin', 1),
#  ('Liederdichter', 1),
#  ('Generalsuperintendent', 1),
#  ('Regierungsrat', 1),
#  ('Musikschriftsteller', 1),
#  ('Gouverneur', 1),
#  ('Archivar', 1),
#  ('Lyriker', 1),
#  ('Innenminister', 1),
#  ('Major', 1),
#  ('Konstrukteur', 1),
#  ('Politologe', 1),
#  ('Rechtsanwalt', 1),
#  ('Gärtner', 1),
#  ('Konsistorialrat', 1),
#  ('Geiger', 1),
#  ('Musikdirektor', 1),
#  ('Jurastudent', 1),
#  ('Mathematikerin', 1),
#  ('Physikerin', 1),
#  ('Soldat', 1),
#  ('Orgelbauer', 1),
#  ('Techniker', 1)]

# %% [markdown]
# ### Write the grouped activites to a CSV file, inspect and code them
#
# The activities are written to a .csv file transformed to a .ods (Calc) file, then coded manually, then exported to a new CSV file and opened for inspection

# %%
with open('spreadsheets/manually_coded_orig_acti.csv', 'w', newline='') as csvfile:
    doc_writer = csv.writer(csvfile, delimiter='|',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    doc_writer.writerow(['token', 'freq', 'manual_code'])
    [doc_writer.writerow(r) for r in s_tokens_li]

# %% [markdown]
# ### Inspect the coded grouped activities
#
# This file is a CSV export from the manually encoded .csv file with the same name.

# %%
with open('spreadsheets/manually_coded_orig_acti_codes.csv', newline='') as csvfile:
    doc_reader = csv.reader(csvfile, delimiter='|', quotechar='"')
    orig_codes = []
    for row in doc_reader:
        if len(row[2]) > 0:
            orig_codes.append(row)

# %%
### grouped coded activities 
orig_codes
# Out:
# [['token', 'freq', 'manual_code'],
#  ['Mathematiker', '478', 'math'],
#  ['Astronom', '199', 'astron'],
#  ['Arzt', '136', 'med'],
#  ['Hochschullehrer', '107', 'prof'],
#  ['Philosoph', '91', 'philo'],
#  ['Physiker', '65', 'phys'],
#  ['Theologe', '64', 'theol'],
#  ['Schriftsteller', '56', 'liter'],
#  ['Pfarrer', '51', 'cleric'],
#  ['Jurist', '36', 'juri'],
#  ['Kartograf', '35', 'geo_carto'],
#  ['Evangelischer Theologe', '35', 'theol'],
#  ['Historiker', '30', 'histo'],
#  ['Naturwissenschaftler', '28', 'scholar'],
#  ['Architekt', '28', 'archi'],
#  ['Astrologe', '27', 'astrol'],
#  ['Geograf', '27', 'geo_carto'],
#  ['Lehrer', '26', 'prof'],
#  ['Gymnasiallehrer', '24', 'prof'],
#  ['Katholischer Theologe', '18', 'theol'],
#  ['Philologe', '18', 'anc_lang_philol'],
#  ['Ingenieur', '18', 'inge'],
#  ['Humanist', '17', 'huma'],
#  ['Bibliothekar', '14', 'book'],
#  ['Selbstverleger', '12', 'book'],
#  ['Missionar', '12', 'cleric'],
#  ['Maler', '11', 'artist'],
#  ['Musiker', '11', 'artist'],
#  ['Pädagoge', '11', 'prof'],
#  ['Gelehrter', '10', 'scholar'],
#  ['Geistlicher', '10', 'cleric'],
#  ['Kupferstecher', '10', 'artist']]

# %%
### Original activities
orig_activities_list[:3]

# %% [markdown]
# ### Code the original activities list
#
# This script produced a coded list of activities per person

# %%
pers_orig_activities = []
for al in orig_activities_list:
    al_codes = []
    for c in orig_codes[1:]:
        if c[0] in al[1]:
            al_codes.append(c[2])
    pers_orig_activities.append([al[0],sorted(list(set(al_codes)))])

# %%
print(len(pers_orig_activities))
pers_orig_activities
# Out:
# 1038
# [['cnp01352012', ['theol']],
#  ['cnp02088071', ['astrol', 'med', 'philo']],
#  ['cnp01881207', ['philo', 'theol']],
#  ['cnp01879247', ['huma', 'med']],
#  ['cnp00996213', ['astrol', 'math', 'med', 'prof']],
#  ['cnp01320054', ['astron', 'histo', 'scholar']],
#  ['cnp01363268', ['med']],
#  ['cnp01241028', []],
#  ['cnp00873006', ['anc_lang_philol']],
#  ['cnp01329886', ['huma', 'liter', 'math', 'philo']],
#  ['cnp01363122', ['huma', 'math', 'philo', 'theol']],
#  ['cnp00350996', ['astron', 'med', 'theol']],
#  ['cnp02222242', []],
#  ['cnp01884261', []],
#  ['cnp00397446', ['geo_carto', 'math']],
#  ['cnp01368034', ['med', 'philo']],
#  ['cnp01335792', ['philo', 'scholar']],
#  ['cnp00888506', ['prof', 'theol']],
#  ['cnp01879502', []],
#  ['cnp00556047', []],
#  ['cnp01362970', ['histo', 'philo']],
#  ['cnp01115869', ['math']],
#  ['cnp00402391', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01365166', ['med']],
#  ['cnp02088587', ['med', 'theol']],
#  ['cnp01409583', []],
#  ['cnp01114322', ['liter', 'math']],
#  ['cnp00100623', ['juri', 'liter', 'theol']],
#  ['cnp01352888', ['astrol', 'med']],
#  ['cnp01392374', ['astron', 'cleric', 'math']],
#  ['cnp01172052', ['artist', 'astron', 'geo_carto']],
#  ['cnp01876151', ['astron', 'geo_carto', 'huma', 'math', 'theol']],
#  ['cnp01317063', ['artist', 'math']],
#  ['cnp01319857', ['prof']],
#  ['cnp00398396', ['astrol', 'histo', 'med']],
#  ['cnp01471426', ['astron', 'math', 'med', 'philo']],
#  ['cnp00412417', ['math']],
#  ['cnp01875338', ['med']],
#  ['cnp01470125', ['artist']],
#  ['cnp01309925', []],
#  ['cnp01320896', ['astron', 'cleric', 'geo_carto', 'math']],
#  ['cnp00400924', ['cleric', 'theol']],
#  ['cnp01876860', ['med']],
#  ['cnp01331039', []],
#  ['cnp01329937', ['archi', 'inge']],
#  ['cnp01486719', ['astrol', 'med', 'theol']],
#  ['cnp01180030', ['archi', 'math']],
#  ['cnp01255966', []],
#  ['cnp01341438', []],
#  ['cnp01880057', ['huma']],
#  ['cnp01316341', ['med']],
#  ['cnp01233195', ['math']],
#  ['cnp01118781', ['astron', 'med']],
#  ['cnp01147469', ['astron', 'math']],
#  ['cnp00917420', ['math', 'theol']],
#  ['cnp01120503', ['math']],
#  ['cnp00526061', []],
#  ['cnp01320560', ['theol']],
#  ['cnp02223694', []],
#  ['cnp01329458', ['theol']],
#  ['cnp01875480', ['cleric', 'huma', 'math', 'theol']],
#  ['cnp02236633', ['math', 'prof', 'theol']],
#  ['cnp01919968', []],
#  ['cnp01877797', ['astron', 'math']],
#  ['cnp00639317', []],
#  ['cnp01884758', []],
#  ['cnp01330865',
#   ['anc_lang_philol',
#    'cleric',
#    'huma',
#    'math',
#    'med',
#    'philo',
#    'prof',
#    'scholar',
#    'theol']],
#  ['cnp01313334', ['math', 'prof']],
#  ['cnp01881119', ['artist', 'astron', 'geo_carto', 'math']],
#  ['cnp01290195', []],
#  ['cnp01876551', ['geo_carto', 'math', 'prof']],
#  ['cnp01019887', ['theol']],
#  ['cnp01347892', ['astron', 'geo_carto', 'math']],
#  ['cnp01323680', ['geo_carto', 'math', 'prof', 'theol']],
#  ['cnp01875467', ['med']],
#  ['cnp01880016', ['cleric', 'prof', 'theol']],
#  ['cnp00579703', ['artist']],
#  ['cnp01443317', ['astrol', 'histo', 'math']],
#  ['cnp01875826', ['huma', 'math']],
#  ['cnp00405470', ['math']],
#  ['cnp00569865', ['archi']],
#  ['cnp01356340', ['inge', 'math', 'prof']],
#  ['cnp01350201', ['inge', 'math']],
#  ['cnp01876658', ['theol']],
#  ['cnp01349348', ['anc_lang_philol', 'scholar']],
#  ['cnp01443388', ['math', 'med', 'scholar']],
#  ['cnp01121159', ['prof']],
#  ['cnp01392199', ['artist', 'geo_carto']],
#  ['cnp00545294', ['artist']],
#  ['cnp01875706', ['juri']],
#  ['cnp01084480', ['astron', 'math', 'prof']],
#  ['cnp00482208', ['archi', 'liter', 'math']],
#  ['cnp01364712', ['artist']],
#  ['cnp01112298', []],
#  ['cnp01114860', ['astron', 'math', 'prof']],
#  ['cnp01437248', ['astron', 'math', 'med', 'philo', 'scholar']],
#  ['cnp02156073', ['astron', 'math', 'philo']],
#  ['cnp02078749', ['astron', 'math']],
#  ['cnp01122000', ['astrol', 'cleric', 'prof', 'theol']],
#  ['cnp00950341', ['prof', 'theol']],
#  ['cnp01179438', ['histo', 'med']],
#  ['cnp01112480', ['med']],
#  ['cnp01468914', []],
#  ['cnp01345792', []],
#  ['cnp01876067', []],
#  ['cnp01875828', ['theol']],
#  ['cnp01875825', ['cleric', 'theol']],
#  ['cnp01877605', ['astron', 'histo', 'med', 'phys']],
#  ['cnp01336086', ['med']],
#  ['cnp00125017', ['astrol', 'astron', 'med']],
#  ['cnp01876979', ['astron', 'math', 'med']],
#  ['cnp01334753', ['liter', 'philo']],
#  ['cnp01879181', ['math', 'med']],
#  ['cnp01875669', []],
#  ['cnp01361113', ['liter']],
#  ['cnp01352300', ['archi']],
#  ['cnp01307139', ['math', 'philo', 'scholar']],
#  ['cnp01363533', []],
#  ['cnp01340478', ['med']],
#  ['cnp01324006', ['huma']],
#  ['cnp02239016', []],
#  ['cnp01395548', ['astron']],
#  ['cnp02163127', []],
#  ['cnp01292034', ['astrol']],
#  ['cnp01443254', ['astron', 'math']],
#  ['cnp01355754', ['geo_carto', 'math', 'philo', 'theol']],
#  ['cnp01875767', ['astrol', 'math', 'med']],
#  ['cnp01876433', ['cleric', 'prof', 'theol']],
#  ['cnp01875723', ['astron', 'math']],
#  ['cnp01323251', ['huma', 'math', 'philo', 'prof']],
#  ['cnp01120341', ['astrol', 'astron', 'math']],
#  ['cnp01387069', ['artist']],
#  ['cnp02170729', ['math', 'med', 'prof']],
#  ['cnp01337057', ['liter']],
#  ['cnp01303529', ['astron', 'math']],
#  ['cnp01124849', ['astron', 'math']],
#  ['cnp01287286', ['astron', 'med']],
#  ['cnp01368037', []],
#  ['cnp01875207', ['cleric', 'theol']],
#  ['cnp01200592', ['geo_carto', 'math']],
#  ['cnp02266756', []],
#  ['cnp02134922', ['math', 'med']],
#  ['cnp02230942', []],
#  ['cnp00989664', ['anc_lang_philol', 'cleric', 'theol']],
#  ['cnp01875685', ['med', 'philo']],
#  ['cnp01407758', []],
#  ['cnp01347099', ['book', 'histo', 'juri']],
#  ['cnp01481137', ['cleric', 'theol']],
#  ['cnp01089747', ['math']],
#  ['cnp01235486', ['math']],
#  ['cnp01356128', []],
#  ['cnp01358480', ['liter']],
#  ['cnp00402987', ['astron', 'book', 'geo_carto', 'inge', 'math']],
#  ['cnp01333594', []],
#  ['cnp01345049', ['math']],
#  ['cnp01441705', ['astron', 'math', 'med']],
#  ['cnp01443175', ['histo', 'huma', 'med', 'prof', 'scholar']],
#  ['cnp02163173', []],
#  ['cnp00888077', ['math', 'prof']],
#  ['cnp01318480', []],
#  ['cnp01904447', ['math']],
#  ['cnp01025752', ['liter', 'prof']],
#  ['cnp01124424', ['math']],
#  ['cnp00876424', ['theol']],
#  ['cnp02163146', []],
#  ['cnp01113305', ['math', 'med']],
#  ['cnp01877782', ['astrol', 'astron', 'math']],
#  ['cnp01056939', ['prof']],
#  ['cnp00450702', ['math', 'med']],
#  ['cnp02163189', []],
#  ['cnp01919710', []],
#  ['cnp01878121', ['med', 'prof']],
#  ['cnp01029668', ['astron', 'math']],
#  ['cnp01350014', ['artist', 'med', 'philo', 'prof']],
#  ['cnp01920049', []],
#  ['cnp01409038', ['astron', 'juri', 'math']],
#  ['cnp01078149', ['astron', 'math']],
#  ['cnp01302722', ['philo']],
#  ['cnp02252061', ['archi', 'math']],
#  ['cnp01368443', ['liter']],
#  ['cnp01880790', ['math', 'philo', 'phys']],
#  ['cnp01303321', ['artist', 'astron', 'math', 'med', 'prof']],
#  ['cnp01302340', ['juri', 'math']],
#  ['cnp01363433', ['astron', 'geo_carto', 'liter', 'math']],
#  ['cnp00453662', ['astron', 'med']],
#  ['cnp01302373', ['med', 'prof', 'scholar']],
#  ['cnp01240021', ['astron', 'math']],
#  ['cnp00394082', ['geo_carto', 'math', 'med']],
#  ['cnp01231917', ['huma']],
#  ['cnp01104400', ['astron', 'huma', 'math']],
#  ['cnp01390409', ['cleric']],
#  ['cnp01365922', ['math', 'med', 'philo']],
#  ['cnp01875401', ['astrol', 'med']],
#  ['cnp01333847', ['huma', 'liter', 'prof']],
#  ['cnp01337628', ['med']],
#  ['cnp01879907', ['astron', 'math']],
#  ['cnp01327594', ['astrol', 'med']],
#  ['cnp00122851', ['theol']],
#  ['cnp01237076', ['med']],
#  ['cnp01033767', ['math']],
#  ['cnp01919971', []],
#  ['cnp01113388', ['med']],
#  ['cnp01116302', ['math', 'prof']],
#  ['cnp01389779', []],
#  ['cnp01340100', ['astron', 'math', 'med']],
#  ['cnp00407311', ['math']],
#  ['cnp01107316', ['math']],
#  ['cnp02101603', []],
#  ['cnp00476702',
#   ['archi', 'artist', 'astron', 'geo_carto', 'inge', 'scholar', 'theol']],
#  ['cnp00014570', ['anc_lang_philol', 'histo', 'huma']],
#  ['cnp01105937', ['astron', 'liter']],
#  ['cnp01358036', ['math', 'med']],
#  ['cnp01919917', []],
#  ['cnp01320637', ['anc_lang_philol', 'math']],
#  ['cnp00444650', ['juri']],
#  ['cnp01307458', ['math']],
#  ['cnp01301986', ['astron', 'math']],
#  ['cnp01079978', ['math', 'med', 'prof']],
#  ['cnp01919930', []],
#  ['cnp01311921', ['math']],
#  ['cnp01880451', ['astron']],
#  ['cnp01109829', ['astron', 'math', 'med']],
#  ['cnp01920024', ['astrol', 'med']],
#  ['cnp00157873', ['math']],
#  ['cnp00485397', ['math', 'med', 'phys', 'prof']],
#  ['cnp02105686', ['astron']],
#  ['cnp01879549', ['archi']],
#  ['cnp00416575', ['cleric', 'math', 'theol']],
#  ['cnp01124562', ['archi', 'artist', 'astron', 'liter', 'med', 'prof']],
#  ['cnp01358244', []],
#  ['cnp01377638', ['archi', 'inge', 'math']],
#  ['cnp01919886', []],
#  ['cnp01103897', ['astron', 'geo_carto']],
#  ['cnp01306733', []],
#  ['cnp01880764', ['math']],
#  ['cnp00096056', ['anc_lang_philol', 'math']],
#  ['cnp01291699', ['med', 'prof', 'theol']],
#  ['cnp01322847', ['math']],
#  ['cnp02162972', []],
#  ['cnp01303545', ['astrol', 'astron', 'cleric', 'med', 'theol']],
#  ['cnp01919940', []],
#  ['cnp01082076', ['med', 'prof']],
#  ['cnp01045770', []],
#  ['cnp01113293', ['math', 'med', 'phys']],
#  ['cnp01422536', ['math']],
#  ['cnp01303513', ['histo', 'math', 'theol']],
#  ['cnp01355346', []],
#  ['cnp01368065', ['math']],
#  ['cnp02163025', []],
#  ['cnp00458518', ['astron', 'math']],
#  ['cnp00571276', ['astron']],
#  ['cnp01468084', ['liter']],
#  ['cnp00962892', ['math', 'med', 'phys', 'prof']],
#  ['cnp01237192', ['astron', 'philo']],
#  ['cnp01259618', ['inge', 'math']],
#  ['cnp01342652', ['math']],
#  ['cnp01919686', []],
#  ['cnp01919799', ['anc_lang_philol', 'book', 'huma', 'med', 'prof']],
#  ['cnp01309947', []],
#  ['cnp00922870', []],
#  ['cnp01338415', ['astron', 'math']],
#  ['cnp01112934', ['astron']],
#  ['cnp01944825', ['math']],
#  ['cnp02163156', []],
#  ['cnp01286849', ['astron']],
#  ['cnp01110021', ['astron', 'math', 'prof']],
#  ['cnp01879400', ['anc_lang_philol', 'inge', 'philo']],
#  ['cnp02163192', ['med']],
#  ['cnp00446750', ['huma']],
#  ['cnp01329248', []],
#  ['cnp02231369', ['juri', 'scholar']],
#  ['cnp00481169', ['geo_carto', 'math']],
#  ['cnp02163276', []],
#  ['cnp01467090', []],
#  ['cnp00605131', []],
#  ['cnp01104779', ['astron', 'book', 'math', 'prof']],
#  ['cnp01133177', ['geo_carto']],
#  ['cnp01919833', []],
#  ['cnp02163082', []],
#  ['cnp01377920', ['geo_carto', 'math']],
#  ['cnp01328166', ['astron']],
#  ['cnp01291829', ['math']],
#  ['cnp01356171', ['artist', 'astron', 'prof']],
#  ['cnp02237779', []],
#  ['cnp01316739', ['histo', 'liter']],
#  ['cnp02222256', ['astron', 'math']],
#  ['cnp00444503', ['astron', 'math', 'prof']],
#  ['cnp01359016', ['astron', 'liter', 'med', 'prof']],
#  ['cnp01919691', []],
#  ['cnp01895099', ['math', 'med', 'prof']],
#  ['cnp01878530', ['math']],
#  ['cnp00369337', ['cleric', 'math', 'med']],
#  ['cnp00444510', []],
#  ['cnp01343086', ['astron', 'math', 'phys']],
#  ['cnp01876902', ['astron', 'cleric', 'math', 'med']],
#  ['cnp01877738', ['math', 'med', 'phys']],
#  ['cnp00384901', ['med', 'prof']],
#  ['cnp00475665', ['cleric']],
#  ['cnp00386604', ['math', 'med']],
#  ['cnp00883349', ['math', 'med']],
#  ['cnp01327326', ['cleric', 'math']],
#  ['cnp00094435', []],
#  ['cnp01344864', ['math', 'med']],
#  ['cnp01024644', ['theol']],
#  ['cnp01307826', []],
#  ['cnp01054493', ['med']],
#  ['cnp01273329', ['astron', 'cleric']],
#  ['cnp01920011', ['astrol', 'math', 'med']],
#  ['cnp01920012', []],
#  ['cnp00543426', ['scholar']],
#  ['cnp01103907', ['astron']],
#  ['cnp00366743', ['artist', 'astron', 'cleric', 'math']],
#  ['cnp01919970', []],
#  ['cnp00099596', []],
#  ['cnp01330272', ['cleric', 'math', 'philo']],
#  ['cnp01919706', []],
#  ['cnp00976839', ['astron', 'book', 'cleric']],
#  ['cnp00951038', ['astron', 'math']],
#  ['cnp00394836', ['astron', 'math', 'philo', 'phys']],
#  ['cnp02163119', ['math']],
#  ['cnp01327958', ['astron', 'book', 'math', 'med', 'prof']],
#  ['cnp01920041', []],
#  ['cnp00424447', ['astron', 'math']],
#  ['cnp01879023', ['book', 'cleric', 'geo_carto', 'histo', 'philo', 'prof']],
#  ['cnp01347493', ['astron', 'math', 'prof']],
#  ['cnp01900808', []],
#  ['cnp01233501', ['geo_carto']],
#  ['cnp01395469', ['liter']],
#  ['cnp02143831', ['math']],
#  ['cnp01340415', []],
#  ['cnp02251223', ['archi', 'inge', 'math']],
#  ['cnp00871211', ['astron', 'math', 'scholar']],
#  ['cnp00468695', ['math', 'phys']],
#  ['cnp01406042', ['archi', 'math']],
#  ['cnp00877897', ['astron']],
#  ['cnp01106465', ['astron']],
#  ['cnp01919647', ['histo', 'prof']],
#  ['cnp00404027', ['med']],
#  ['cnp01358327', []],
#  ['cnp00892467', ['med']],
#  ['cnp02163051', ['cleric']],
#  ['cnp01908712', ['cleric', 'liter', 'math', 'philo', 'prof']],
#  ['cnp01408867', []],
#  ['cnp01108514', ['astron', 'cleric', 'theol']],
#  ['cnp01327988', ['astrol', 'astron', 'juri', 'math', 'med']],
#  ['cnp01355841', ['astron']],
#  ['cnp01208565', ['liter', 'theol']],
#  ['cnp01876214', ['anc_lang_philol', 'math', 'prof']],
#  ['cnp01378567', ['geo_carto', 'math']],
#  ['cnp01355990', ['artist', 'astrol', 'math']],
#  ['cnp01379493', ['archi', 'artist']],
#  ['cnp01321061', ['archi', 'artist']],
#  ['cnp01421274', []],
#  ['cnp01233301', []],
#  ['cnp00414862', ['geo_carto']],
#  ['cnp01877766', ['scholar']],
#  ['cnp01328010', ['astron', 'med', 'phys', 'prof']],
#  ['cnp01919680', []],
#  ['cnp01919798', []],
#  ['cnp00401494', ['astron', 'math', 'med']],
#  ['cnp02163157', []],
#  ['cnp00990253', []],
#  ['cnp00946324', ['cleric', 'math']],
#  ['cnp00519261', ['astrol', 'astron', 'geo_carto', 'math']],
#  ['cnp01919936', []],
#  ['cnp01073264', []],
#  ['cnp01920059', []],
#  ['cnp01026086', ['med', 'prof']],
#  ['cnp00951475', ['astron', 'math', 'prof']],
#  ['cnp00370488', ['cleric', 'math', 'scholar']],
#  ['cnp02224706', []],
#  ['cnp01908276', []],
#  ['cnp01351342', ['math']],
#  ['cnp01919735', ['astron', 'book', 'prof']],
#  ['cnp00125588', []],
#  ['cnp00386550', ['astron', 'math']],
#  ['cnp01399888', []],
#  ['cnp01121780', []],
#  ['cnp01919933', []],
#  ['cnp02330678', []],
#  ['cnp00125422', ['astron', 'math']],
#  ['cnp01395468', []],
#  ['cnp01877518', ['astron', 'book', 'liter', 'math', 'prof']],
#  ['cnp00455882', ['math']],
#  ['cnp01475871', ['math']],
#  ['cnp01391905', ['astron', 'geo_carto', 'math', 'med']],
#  ['cnp02163132', []],
#  ['cnp01917023', []],
#  ['cnp01391968', ['astron', 'math']],
#  ['cnp00370784', ['liter', 'math']],
#  ['cnp02094405', ['math', 'med']],
#  ['cnp00980603', ['liter', 'math']],
#  ['cnp01018318', ['math']],
#  ['cnp00506076', ['prof', 'theol']],
#  ['cnp00998676', ['astron', 'juri']],
#  ['cnp00951955', ['math']],
#  ['cnp01920892', ['anc_lang_philol', 'histo', 'math', 'prof']],
#  ['cnp01351361', ['scholar']],
#  ['cnp02163042', []],
#  ['cnp00623575', ['med']],
#  ['cnp01093544', ['math', 'med']],
#  ['cnp01002233', ['cleric']],
#  ['cnp01318008', ['astrol', 'astron', 'math', 'med']],
#  ['cnp01330261', []],
#  ['cnp00930944', []],
#  ['cnp00108734', ['math', 'theol']],
#  ['cnp01920048', ['astron', 'cleric']],
#  ['cnp00390667', ['philo', 'prof']],
#  ['cnp01344682', ['philo', 'phys', 'scholar']],
#  ['cnp01377073', []],
#  ['cnp00475681', ['liter', 'theol']],
#  ['cnp01313208', []],
#  ['cnp01334817', ['liter', 'med']],
#  ['cnp01374654', ['math', 'med', 'prof']],
#  ['cnp00389786', ['math', 'prof']],
#  ['cnp00385731', ['archi', 'inge', 'math']],
#  ['cnp01273893', ['liter', 'philo']],
#  ['cnp01316924', ['math', 'theol']],
#  ['cnp01899827', []],
#  ['cnp01045073', []],
#  ['cnp01304679', []],
#  ['cnp02163255', []],
#  ['cnp01303999', []],
#  ['cnp00915396', ['astron', 'math']],
#  ['cnp01037256', ['astron', 'prof', 'theol']],
#  ['cnp01377125', ['math', 'theol']],
#  ['cnp01322085', ['math', 'philo', 'phys', 'prof']],
#  ['cnp02033956', ['geo_carto', 'math']],
#  ['cnp00969971', ['anc_lang_philol', 'histo', 'math']],
#  ['cnp00389349', ['math']],
#  ['cnp02163239', []],
#  ['cnp00504169', ['math']],
#  ['cnp01919685', []],
#  ['cnp02149411', ['archi']],
#  ['cnp00921622', ['archi', 'math']],
#  ['cnp01327704', []],
#  ['cnp02163138', []],
#  ['cnp02248072', ['juri', 'math']],
#  ['cnp01033200', ['geo_carto', 'math']],
#  ['cnp02163160', []],
#  ['cnp00507343', ['astrol', 'astron', 'med']],
#  ['cnp01901801', []],
#  ['cnp00416849', ['astron', 'math', 'med']],
#  ['cnp02062689', ['math']],
#  ['cnp01291828', ['math']],
#  ['cnp02230350', []],
#  ['cnp00398978', ['geo_carto', 'liter', 'math']],
#  ['cnp00388107', ['math', 'med', 'phys']],
#  ['cnp00390875', ['juri', 'math']],
#  ['cnp01920009', []],
#  ['cnp01368847', []],
#  ['cnp01335791', ['math', 'philo']],
#  ['cnp01317013', ['archi', 'inge', 'math']],
#  ['cnp00447681', ['math', 'prof', 'scholar']],
#  ['cnp01440545', ['archi', 'book', 'geo_carto', 'math']],
#  ['cnp01089507', ['math']],
#  ['cnp00466008', ['med']],
#  ['cnp00295424', ['book', 'juri', 'liter']],
#  ['cnp01026399', ['cleric', 'inge', 'math']],
#  ['cnp00458133', ['cleric', 'math']],
#  ['cnp00497608', ['astron', 'cleric']],
#  ['cnp00918436', ['cleric']],
#  ['cnp01319583', []],
#  ['cnp00918450', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01390435', []],
#  ['cnp02205996', ['astron']],
#  ['cnp01919797', []],
#  ['cnp02206734', ['astron', 'med']],
#  ['cnp01053665', ['cleric', 'prof']],
#  ['cnp00390534', ['math', 'med']],
#  ['cnp01348997', []],
#  ['cnp01146927', ['math']],
#  ['cnp01339954', ['philo']],
#  ['cnp00354610', []],
#  ['cnp02239623', ['astron', 'math']],
#  ['cnp01325603', []],
#  ['cnp01919813', []],
#  ['cnp01341138', []],
#  ['cnp02163280', []],
#  ['cnp01921111', ['math', 'philo', 'phys', 'scholar']],
#  ['cnp00452326', ['astron', 'math', 'med']],
#  ['cnp01338526', ['astron']],
#  ['cnp02111485', ['juri', 'math', 'philo']],
#  ['cnp01877772', ['math', 'med']],
#  ['cnp02335717', []],
#  ['cnp02163012', []],
#  ['cnp02069815', []],
#  ['cnp00461448', ['math']],
#  ['cnp02234984', ['math']],
#  ['cnp01364670', ['astron']],
#  ['cnp01878958', ['math', 'med', 'prof']],
#  ['cnp00389779', ['book', 'math']],
#  ['cnp02163235', []],
#  ['cnp00401645', ['astron', 'math']],
#  ['cnp01093384', ['math']],
#  ['cnp01918226', []],
#  ['cnp00617340', ['geo_carto', 'math', 'phys']],
#  ['cnp02223923', []],
#  ['cnp00473662', ['astron', 'philo', 'theol']],
#  ['cnp02163183', ['theol']],
#  ['cnp02293390', []],
#  ['cnp00649901', ['math']],
#  ['cnp01003527', ['math', 'philo', 'prof', 'theol']],
#  ['cnp01085022', ['math', 'prof']],
#  ['cnp01487024', ['book', 'liter', 'math']],
#  ['cnp00384916', ['theol']],
#  ['cnp00689671', ['cleric', 'math', 'prof', 'scholar']],
#  ['cnp01328238', ['math', 'med']],
#  ['cnp02211160', ['astron', 'math', 'phys']],
#  ['cnp01321618', ['astron', 'histo', 'math', 'philo']],
#  ['cnp01470260', []],
#  ['cnp02063829', ['math']],
#  ['cnp01344806', []],
#  ['cnp01337555', ['astron']],
#  ['cnp00951915', []],
#  ['cnp02163131', []],
#  ['cnp01919977', []],
#  ['cnp01919983', []],
#  ['cnp00064282', ['math']],
#  ['cnp01316530', ['math']],
#  ['cnp01323244', ['astron', 'math', 'med']],
#  ['cnp00445951', ['cleric', 'prof']],
#  ['cnp02190631', ['astrol']],
#  ['cnp01330172', []],
#  ['cnp02163037', []],
#  ['cnp01919746', ['astron', 'math']],
#  ['cnp02163116', []],
#  ['cnp01323399', ['med']],
#  ['cnp01939722', []],
#  ['cnp02140267', ['math']],
#  ['cnp00105837', []],
#  ['cnp00506366', ['med']],
#  ['cnp02236952', []],
#  ['cnp00489873', ['geo_carto', 'math', 'theol']],
#  ['cnp02230372', []],
#  ['cnp01327695', []],
#  ['cnp01345096', ['astron', 'juri', 'math', 'theol']],
#  ['cnp01358202', ['astron', 'math', 'prof']],
#  ['cnp01341055', ['book', 'math', 'philo', 'theol']],
#  ['cnp02232803', ['philo', 'prof']],
#  ['cnp01391658', ['geo_carto', 'math']],
#  ['cnp01199180', ['math', 'philo']],
#  ['cnp01002799', ['math', 'prof', 'theol']],
#  ['cnp01229337', ['juri', 'scholar']],
#  ['cnp02230529', ['math']],
#  ['cnp01919890', []],
#  ['cnp00283188', []],
#  ['cnp00388517', ['astron', 'math', 'prof']],
#  ['cnp02261078', ['astron', 'math']],
#  ['cnp01345246', ['med']],
#  ['cnp02104967', ['math']],
#  ['cnp02078294', ['artist']],
#  ['cnp02236239', ['math', 'phys', 'prof']],
#  ['cnp00386587', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp02140516', ['astron']],
#  ['cnp00876263', ['math']],
#  ['cnp01908394', ['artist']],
#  ['cnp01392446', []],
#  ['cnp01377339', []],
#  ['cnp01919715', ['astrol']],
#  ['cnp01470045', ['juri', 'liter', 'math']],
#  ['cnp01325201', ['artist', 'astron', 'math']],
#  ['cnp00611392', ['astron', 'juri']],
#  ['cnp01380775', ['cleric', 'math', 'philo']],
#  ['cnp00106298', ['med']],
#  ['cnp00483287', ['math']],
#  ['cnp01341135', ['phys']],
#  ['cnp01483154', ['math']],
#  ['cnp00496933', ['math']],
#  ['cnp01375612', []],
#  ['cnp00352036', ['astrol', 'astron', 'book', 'math']],
#  ['cnp01127978', []],
#  ['cnp01324836', []],
#  ['cnp00387106', ['histo', 'math', 'med', 'prof']],
#  ['cnp01919870', []],
#  ['cnp00433134', ['math', 'med', 'prof']],
#  ['cnp00399615', ['math']],
#  ['cnp01435092', ['med']],
#  ['cnp01919694', ['astron']],
#  ['cnp00347201', []],
#  ['cnp01012117', ['astron', 'cleric']],
#  ['cnp00364411', ['math', 'philo', 'prof', 'theol']],
#  ['cnp02193879', ['book', 'math']],
#  ['cnp01469355', ['math']],
#  ['cnp00432861', ['juri', 'prof']],
#  ['cnp01364652', ['histo']],
#  ['cnp00390888', ['math', 'phys']],
#  ['cnp00482504', ['anc_lang_philol', 'med']],
#  ['cnp01330573', ['archi', 'book', 'inge', 'math']],
#  ['cnp00886194', []],
#  ['cnp00380320', ['med']],
#  ['cnp01002798', ['scholar', 'theol']],
#  ['cnp00038260', ['math', 'phys']],
#  ['cnp00877968', ['astron', 'math']],
#  ['cnp00391433', ['astron', 'math', 'med']],
#  ['cnp01340180', ['astron', 'math']],
#  ['cnp01010326', ['math', 'theol']],
#  ['cnp00069034', ['math']],
#  ['cnp00474060', ['med', 'prof']],
#  ['cnp01094218', ['math', 'philo', 'phys', 'prof']],
#  ['cnp02235964', ['med']],
#  ['cnp00454903', ['book', 'math', 'phys']],
#  ['cnp02299102', ['math']],
#  ['cnp01318964', ['astron', 'theol']],
#  ['cnp02327523', []],
#  ['cnp01919967', []],
#  ['cnp01920211', ['liter', 'phys']],
#  ['cnp01373606', ['artist']],
#  ['cnp01323643', []],
#  ['cnp00930960', ['archi', 'math']],
#  ['cnp01992297', ['astron', 'math']],
#  ['cnp00368388', ['math', 'prof']],
#  ['cnp01364676', ['astron', 'math', 'phys']],
#  ['cnp01320598', ['philo']],
#  ['cnp01320899', ['theol']],
#  ['cnp00147670', ['math']],
#  ['cnp02154944', []],
#  ['cnp01389635', ['math', 'phys']],
#  ['cnp02335307', ['astron', 'histo', 'theol']],
#  ['cnp02244888', ['liter', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01479020', ['liter', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01010218', ['astron', 'math', 'prof']],
#  ['cnp02163221', []],
#  ['cnp01440456', ['archi']],
#  ['cnp01316503', ['liter', 'math', 'med', 'phys']],
#  ['cnp01481978', ['astron']],
#  ['cnp00506412', ['astron']],
#  ['cnp01370532', []],
#  ['cnp01358935', ['histo', 'theol']],
#  ['cnp02338184', []],
#  ['cnp00385275', ['math', 'philo', 'prof']],
#  ['cnp01890712', []],
#  ['cnp00669927', []],
#  ['cnp00019029', ['anc_lang_philol', 'scholar', 'theol']],
#  ['cnp00529491', []],
#  ['cnp01476352', ['astron', 'math', 'phys']],
#  ['cnp01914334', []],
#  ['cnp00952066', ['prof', 'theol']],
#  ['cnp01919643', ['med', 'prof']],
#  ['cnp01338801', ['math', 'theol']],
#  ['cnp00951195', ['math']],
#  ['cnp00434558', ['math', 'prof']],
#  ['cnp01919866', []],
#  ['cnp01391974', ['inge']],
#  ['cnp00950513', ['math', 'phys']],
#  ['cnp01311444', ['cleric', 'math']],
#  ['cnp00455142', ['astron', 'juri']],
#  ['cnp00471549', ['math', 'theol']],
#  ['cnp00833377', ['math', 'med']],
#  ['cnp01891255', ['histo', 'phys']],
#  ['cnp02068029', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01919823', []],
#  ['cnp01497657', ['math', 'prof', 'theol']],
#  ['cnp01337449', []],
#  ['cnp00400188', ['astron', 'math']],
#  ['cnp00951338', ['geo_carto', 'math']],
#  ['cnp01377626', []],
#  ['cnp01390742', []],
#  ['cnp01919771', []],
#  ['cnp00597936', ['astron', 'cleric']],
#  ['cnp01390739', []],
#  ['cnp00952457', ['liter', 'prof']],
#  ['cnp02230304', []],
#  ['cnp02183983', ['astrol', 'astron', 'liter']],
#  ['cnp01481855', ['astron', 'cleric', 'juri', 'math', 'phys', 'prof']],
#  ['cnp00537706', ['math']],
#  ['cnp02163226', []],
#  ['cnp01439830', ['math', 'philo', 'phys', 'prof']],
#  ['cnp00369131', ['astron', 'cleric', 'liter', 'theol']],
#  ['cnp01289741', ['cleric']],
#  ['cnp00993973', ['astron', 'math']],
#  ['cnp01267785', ['astron', 'theol']],
#  ['cnp01049147', ['med', 'prof']],
#  ['cnp00908508', ['inge']],
#  ['cnp00386174', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01316493', []],
#  ['cnp02158412', ['math', 'theol']],
#  ['cnp01391574', []],
#  ['cnp00371858', ['math', 'med']],
#  ['cnp01440125', ['artist', 'astron', 'math']],
#  ['cnp01919777', []],
#  ['cnp01471258', ['math', 'prof', 'theol']],
#  ['cnp02179557', ['archi', 'artist', 'math']],
#  ['cnp01919770', ['astrol']],
#  ['cnp01919841', ['astron']],
#  ['cnp01329452', []],
#  ['cnp01391697', ['geo_carto']],
#  ['cnp00946101', ['math', 'philo', 'scholar']],
#  ['cnp02121737', ['math']],
#  ['cnp01392357', ['astron', 'math', 'philo']],
#  ['cnp00950867', ['juri', 'math', 'prof']],
#  ['cnp02163035', []],
#  ['cnp00387057', ['math', 'theol']],
#  ['cnp00967216', ['liter', 'math']],
#  ['cnp01327984', ['astron', 'math']],
#  ['cnp01324799', ['math', 'philo', 'theol']],
#  ['cnp01322061', ['math']],
#  ['cnp00937233', ['juri', 'prof']],
#  ['cnp00469354', ['astron', 'geo_carto', 'histo', 'math']],
#  ['cnp01471432', []],
#  ['cnp00681549', []],
#  ['cnp02163278', []],
#  ['cnp00557114', ['astron', 'cleric']],
#  ['cnp00301902', ['math', 'med', 'philo', 'scholar']],
#  ['cnp01940714', ['math', 'med', 'philo']],
#  ['cnp00670663', ['prof']],
#  ['cnp00388939', ['med']],
#  ['cnp00419809', ['math', 'med', 'philo', 'prof']],
#  ['cnp01316895', []],
#  ['cnp00438816', ['prof', 'theol']],
#  ['cnp01338123', []],
#  ['cnp00400398', ['astron']],
#  ['cnp01310386', ['cleric']],
#  ['cnp01905556', []],
#  ['cnp00343317', ['math', 'philo', 'prof', 'theol']],
#  ['cnp00395926', ['med']],
#  ['cnp00467311', []],
#  ['cnp00967217', ['geo_carto', 'inge', 'math']],
#  ['cnp01498919', ['book', 'juri', 'math', 'philo']],
#  ['cnp00950470', ['math']],
#  ['cnp02294466', []],
#  ['cnp01093464', []],
#  ['cnp02226095', []],
#  ['cnp00872719', ['math', 'theol']],
#  ['cnp01362737', ['liter', 'math']],
#  ['cnp01363143', []],
#  ['cnp00422532', ['anc_lang_philol', 'liter', 'math']],
#  ['cnp00552352', []],
#  ['cnp00449362', ['math', 'philo', 'phys', 'prof']],
#  ['cnp01989297', ['juri', 'math', 'prof']],
#  ['cnp02229154', []],
#  ['cnp01005388', ['prof']],
#  ['cnp00449554', ['math', 'med', 'phys', 'scholar']],
#  ['cnp02327618', ['math']],
#  ['cnp01273643', ['juri', 'math']],
#  ['cnp00846462', ['astron']],
#  ['cnp01281146', ['archi', 'artist', 'liter', 'math']],
#  ['cnp01427020', ['geo_carto', 'math', 'scholar']],
#  ['cnp02244185', ['math']],
#  ['cnp01324750', []],
#  ['cnp01341195', ['math', 'scholar']],
#  ['cnp02328440', ['math']],
#  ['cnp01403284', []],
#  ['cnp01320800', ['math']],
#  ['cnp01941103', ['juri', 'math']],
#  ['cnp00855016', ['math']],
#  ['cnp02135612', ['astron']],
#  ['cnp01511009', ['astron', 'math', 'prof']],
#  ['cnp01945055', ['math']],
#  ['cnp02163135', []],
#  ['cnp00978103', ['astron', 'book']],
#  ['cnp01939693', ['math']],
#  ['cnp00290787', ['math', 'philo', 'theol']],
#  ['cnp00399397', ['astron', 'book', 'med', 'prof']],
#  ['cnp01358620', ['math']],
#  ['cnp01482767', ['prof', 'theol']],
#  ['cnp01919860', []],
#  ['cnp00400516', ['math', 'phys']],
#  ['cnp01880566', ['cleric']],
#  ['cnp01323883', ['math', 'prof']],
#  ['cnp01919745', []],
#  ['cnp02163098', ['histo', 'math']],
#  ['cnp02338026', ['juri', 'prof', 'theol']],
#  ['cnp01306191', []],
#  ['cnp01325602', ['math']],
#  ['cnp02235906', ['med']],
#  ['cnp00613664', ['theol']],
#  ['cnp00390440', ['astron', 'math', 'med', 'phys', 'prof']],
#  ['cnp01327562', ['astron', 'cleric', 'geo_carto']],
#  ['cnp02239207', ['astron', 'math', 'philo']],
#  ['cnp01143314', ['archi', 'math']],
#  ['cnp01318599', []],
#  ['cnp01345497', ['cleric', 'math']],
#  ['cnp00345796', ['astron', 'inge', 'phys']],
#  ['cnp00940854', ['math', 'med', 'prof']],
#  ['cnp01130536', ['archi']],
#  ['cnp01358501', ['math', 'phys', 'scholar']],
#  ['cnp01344695', ['phys']],
#  ['cnp01310208', []],
#  ['cnp01438995', ['liter', 'philo', 'scholar']],
#  ['cnp00950783', ['math']],
#  ['cnp01073918', ['math', 'philo', 'theol']],
#  ['cnp01323465', ['liter', 'math', 'theol']],
#  ['cnp01381608', ['math', 'prof', 'theol']],
#  ['cnp00424957', ['astron', 'prof']],
#  ['cnp01049625', []],
#  ['cnp01331399', []],
#  ['cnp00289676', ['math']],
#  ['cnp00611867', ['astron', 'math', 'prof']],
#  ['cnp02163061', []],
#  ['cnp00459835', ['astron', 'math', 'prof']],
#  ['cnp02176412', []],
#  ['cnp01921159', []],
#  ['cnp01379874', []],
#  ['cnp01391847', []],
#  ['cnp01919821', []],
#  ['cnp02270525', ['cleric', 'math']],
#  ['cnp01969331', []],
#  ['cnp01208519', ['math', 'philo', 'theol']],
#  ['cnp01065866', ['math']],
#  ['cnp01386056', ['astron', 'math', 'med']],
#  ['cnp00950611', ['astron', 'math']],
#  ['cnp01884314', ['astron', 'liter', 'theol']],
#  ['cnp01033546', []],
#  ['cnp01321930', ['math', 'philo']],
#  ['cnp00526372', []],
#  ['cnp00376916', ['math', 'phys', 'prof']],
#  ['cnp01373057', []],
#  ['cnp00481758', ['astron', 'theol']],
#  ['cnp00394712', ['astron']],
#  ['cnp01320816', ['liter', 'math']],
#  ['cnp00634712', ['math', 'philo']],
#  ['cnp00474052', ['cleric', 'philo', 'prof']],
#  ['cnp02242965', ['math']],
#  ['cnp01956587', []],
#  ['cnp02087919', ['math', 'philo']],
#  ['cnp02134621', ['math', 'theol']],
#  ['cnp02128577', ['math', 'philo', 'theol']],
#  ['cnp02328026', ['math', 'prof']],
#  ['cnp02230235', []],
#  ['cnp00950396', ['math']],
#  ['cnp02266642', []],
#  ['cnp01336175', ['math', 'theol']],
#  ['cnp01337053', []],
#  ['cnp01436478', ['math', 'med', 'phys', 'prof']],
#  ['cnp01914406', []],
#  ['cnp00386421', ['astron', 'cleric', 'math']],
#  ['cnp02163036', []],
#  ['cnp00974393', ['math', 'prof']],
#  ['cnp00950031', ['cleric', 'math']],
#  ['cnp01358615', ['math']],
#  ['cnp01511015', ['histo', 'juri', 'math']],
#  ['cnp01881153', ['liter']],
#  ['cnp00405665', ['math', 'philo', 'theol']],
#  ['cnp02137514', ['math']],
#  ['cnp01371119', []],
#  ['cnp02329782', ['math']],
#  ['cnp01392135', ['cleric']],
#  ['cnp01944401', ['math']],
#  ['cnp01271878', ['artist', 'astron', 'math', 'prof']],
#  ['cnp01338632', ['math']],
#  ['cnp01905866', []],
#  ['cnp00406843', ['liter']],
#  ['cnp00389082', ['math', 'prof']],
#  ['cnp01267813', ['artist']],
#  ['cnp01920140', ['anc_lang_philol']],
#  ['cnp01946728', ['math']],
#  ['cnp01372944', []],
#  ['cnp01326948', ['math']],
#  ['cnp01340039', ['astron', 'math', 'phys']],
#  ['cnp01150291', ['math', 'theol']],
#  ['cnp01501297', ['math', 'phys']],
#  ['cnp00973415', ['astron', 'cleric', 'math', 'prof', 'theol']],
#  ['cnp01938795', ['math', 'phys']],
#  ['cnp00396411', ['med', 'scholar']],
#  ['cnp01341197', []],
#  ['cnp00942919', ['astron']],
#  ['cnp01166090', ['histo', 'math']],
#  ['cnp00387315', ['math', 'phys']],
#  ['cnp01360525', []],
#  ['cnp01330343', ['astron', 'liter', 'math']],
#  ['cnp00390358', ['cleric', 'math', 'phys', 'prof', 'scholar', 'theol']],
#  ['cnp01006233', ['med', 'prof']],
#  ['cnp01391728', ['geo_carto']],
#  ['cnp01416537', ['math', 'phys']],
#  ['cnp00458613', []],
#  ['cnp00408365', ['scholar']],
#  ['cnp02306517', []],
#  ['cnp01391475', ['juri', 'math', 'prof']],
#  ['cnp01128300', []],
#  ['cnp00415445', ['juri', 'math']],
#  ['cnp01397344', []],
#  ['cnp01310754', []],
#  ['cnp00873636', ['astron', 'math', 'prof']],
#  ['cnp02218403', []],
#  ['cnp01323455', ['math']],
#  ['cnp01327945', ['astron', 'geo_carto', 'math']],
#  ['cnp01353680', ['juri', 'prof']],
#  ['cnp01310736', []],
#  ['cnp00620144', ['phys']],
#  ['cnp02187878', ['astron', 'med']],
#  ['cnp01907258', []],
#  ['cnp00938379', ['math', 'philo']],
#  ['cnp00935714', ['math']],
#  ['cnp01355792', ['math', 'philo']],
#  ['cnp01956097', ['inge', 'math']],
#  ['cnp01337942', ['math', 'phys', 'prof']],
#  ['cnp01425174', ['cleric', 'math', 'theol']],
#  ['cnp01341011', ['math']],
#  ['cnp01296840', ['math', 'philo', 'scholar', 'theol']],
#  ['cnp00482858', ['astron', 'cleric', 'math', 'prof', 'theol']],
#  ['cnp02163250', []],
#  ['cnp01371511', ['book', 'theol']],
#  ['cnp01406883', ['math', 'theol']],
#  ['cnp02168144', []],
#  ['cnp01502265', ['cleric', 'theol']],
#  ['cnp01481635', ['math', 'philo', 'phys', 'prof', 'theol']],
#  ['cnp01283791', ['cleric', 'prof']],
#  ['cnp01294650', ['prof']],
#  ['cnp00555044', ['astron', 'cleric', 'math']],
#  ['cnp00114038', ['geo_carto', 'math']],
#  ['cnp01271242', ['math']],
#  ['cnp01427068', ['math']],
#  ['cnp01307036', ['liter', 'math']],
#  ['cnp02213909', ['inge', 'math']],
#  ['cnp00395781', ['artist', 'book']],
#  ['cnp00382785', ['math']],
#  ['cnp01313448', ['math']],
#  ['cnp02238866', ['math']],
#  ['cnp01386031', []],
#  ['cnp00959838', ['astron', 'math', 'prof']],
#  ['cnp00401670', ['archi', 'astron', 'math', 'phys']],
#  ['cnp01441824', ['geo_carto', 'histo', 'math']],
#  ['cnp00873272', ['astron', 'math', 'prof']],
#  ['cnp00420502', ['cleric']],
#  ['cnp01207886', ['math', 'philo', 'prof', 'scholar', 'theol']],
#  ['cnp02265415', []],
#  ['cnp01273354', ['astrol']],
#  ['cnp01229576', ['math']],
#  ['cnp00155913', ['med']],
#  ['cnp01328111', []],
#  ['cnp01311691', []],
#  ['cnp02163079', []],
#  ['cnp02091188', ['cleric', 'prof', 'theol']],
#  ['cnp01939035', ['archi', 'astron']],
#  ['cnp01411736', ['theol']],
#  ['cnp02060705', ['astron']],
#  ['cnp00149586', ['astron', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00357110', []],
#  ['cnp00405760', ['math']],
#  ['cnp01327508', []],
#  ['cnp01355708', ['liter']],
#  ['cnp01331171', ['astron', 'math', 'phys', 'scholar']],
#  ['cnp00616670', ['astron', 'geo_carto', 'phys']],
#  ['cnp01340546', ['geo_carto']],
#  ['cnp01361348', ['astron', 'liter', 'math']],
#  ['cnp01167073', ['math', 'prof']],
#  ['cnp01327525', ['astron', 'cleric']],
#  ['cnp00978256', ['math']],
#  ['cnp00398351', ['math']],
#  ['cnp00989107', []],
#  ['cnp01155894', ['math', 'phys']],
#  ['cnp00934743', ['astron', 'math', 'theol']],
#  ['cnp00454735', ['cleric']],
#  ['cnp01227314', ['math', 'prof']],
#  ['cnp02252448', ['juri']],
#  ['cnp01364665', ['math', 'phys']],
#  ['cnp01127346', ['book', 'math', 'philo']],
#  ['cnp01322254', ['liter', 'math', 'philo', 'theol']],
#  ['cnp02213004', ['astron', 'math']],
#  ['cnp02210701', ['math']],
#  ['cnp00421828', ['math']],
#  ['cnp01979544', ['prof']],
#  ['cnp00951342', ['prof']],
#  ['cnp02163090', ['astron']],
#  ['cnp00111937', ['math']],
#  ['cnp01281827', ['med']],
#  ['cnp00473300', []],
#  ['cnp00800049', ['math', 'theol']],
#  ['cnp01088897', ['juri', 'math']],
#  ['cnp02334268', []],
#  ['cnp01370536', ['med']],
#  ['cnp00102076', []],
#  ['cnp01167258', ['astron', 'math', 'prof']],
#  ['cnp01994802', ['med']],
#  ['cnp02207805', ['math']],
#  ['cnp01422962', ['juri']],
#  ['cnp00472229', ['histo', 'math', 'prof']],
#  ['cnp02189751', ['astron', 'math', 'philo']],
#  ['cnp02210773', ['astron', 'math']],
#  ['cnp01088135', []],
#  ['cnp00547788', ['math']],
#  ['cnp02071743', ['artist', 'math']],
#  ['cnp02209689', ['math', 'scholar', 'theol']],
#  ['cnp00105985', ['math', 'prof']],
#  ['cnp01304917', []],
#  ['cnp00352902', ['math', 'philo']],
#  ['cnp01317909', ['astron', 'math', 'phys']],
#  ['cnp00416288', ['math', 'philo', 'theol']],
#  ['cnp01375132', ['histo']],
#  ['cnp00424400', ['math', 'med', 'phys']],
#  ['cnp00381221', ['astron', 'cleric', 'prof', 'theol']],
#  ['cnp02213140', ['archi', 'math']],
#  ['cnp00387676', ['math', 'philo']],
#  ['cnp01339506', []],
#  ['cnp01885482', ['math', 'phys']],
#  ['cnp00384742', ['astron', 'math']],
#  ['cnp01336730', ['math']],
#  ['cnp01260483', ['anc_lang_philol', 'juri']],
#  ['cnp01229790', ['math', 'prof']],
#  ['cnp02153688', []],
#  ['cnp01340685', ['math', 'philo', 'phys']],
#  ['cnp00475918', ['med', 'philo', 'prof']],
#  ['cnp01387988', ['math']],
#  ['cnp02163844', ['astron', 'histo']],
#  ['cnp00415975', ['math']],
#  ['cnp02163209', []],
#  ['cnp02181704', ['math', 'philo']],
#  ['cnp01142873', []],
#  ['cnp02308630', []],
#  ...]

# %% [markdown]
# ## Inspect the general notes field and code the activities
#
# General notes also mention activities, i.e. in the actNotes field:
#
# In this part they are grouped, inspected and coded

# %% [markdown]
# ### General note list

# %%
ast.literal_eval(result_l[0][4])
# Out:
# [{'text': 'Franciscain. - Actif en 1490', 'lang': 'fre'},
#  {'lang': 'fre',
#   'text': 'Source(s) consultée(s) en vain: BN Cat. gén.. - Arch. biogr. italiano, index. - Encicl. italiana. - Buchwald. - PMA. - Clavis SGL. - Larousse 19e s.'},
#  {'lang': 'ger', 'text': 'Italien. franziskanischer Theologe aus Catania'},
#  {'text': 'OFM; Joh.I, 1-14; Liber de tribus peregrinis', 'lang': 'ger'},
#  {'lang': 'ita',
#   'text': 'Teologo francescano di Catania nato nel 1490 e morto nel 1542'}]

# %%
notes_list = []
notes_errors_list = []

for l in result_l:
    
    try:
        l_notes  = []

        for t in ast.literal_eval(l[4]):        
            try:
                if  'fre' in t['lang'] or 'ger' in t['lang'] :
                    l_notes_tokens = [tk for tk in re.split(r"[\s,.:;\(\)]",t['text']) if len(tk) > 3]
                    l_notes += l_notes_tokens
            except Exception as e:
                # print(e)
                pass

        notes_list.append([l[0], list(set(l_notes))])
    except Exception as x:
        notes_errors_list.append([l[0], x])

# %%
print(len(notes_errors_list))
notes_errors_list[:2]
# Out:
# 132
# [['cnp01172052',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))],
#  ['cnp01919968',
#   SyntaxError('unexpected EOF while parsing', ('<unknown>', 0, 0, ''))]]

# %%
len(notes_list)

# %%
notes_list[:2]

# %%
tokens_li_notes = []
for s in notes_list:
    tokens_li_notes += s[1]

# %%
print(len(tokens_li_notes))
counter= Counter([t for t in tokens_li_notes])
# Out:
# 13339

# %%
c_result_notes = list(zip(counter.keys(), counter.values()))

# %%
std_c_result_notes = sorted(c_result_notes, key=itemgetter(1), reverse=True)
std_c_result_notes
# Out:
# [('Mathematiker', 352),
#  ('Astronom', 158),
#  ('Mathematik', 149),
#  ('aussi', 139),
#  ('Professor', 132),
#  ('Mathématicien', 131),
#  ('Prof', 124),
#  ('latin', 113),
#  ('Theologe', 100),
#  ('Professeur', 96),
#  ('écrit', 89),
#  ('mathématicien', 88),
#  ('Ital', 69),
#  ('Philosoph', 68),
#  ('astronome', 68),
#  ('Mediziner', 67),
#  ('Note', 66),
#  ('regroupement', 66),
#  ('domaine', 66),
#  ('vain', 65),
#  ('consultée', 65),
#  ('Source', 65),
#  ('mathématiques', 65),
#  ('Student', 64),
#  ('Arzt', 63),
#  ('Jesuit', 60),
#  ('Astronome', 58),
#  ('Wittenberg', 58),
#  ('Univ', 55),
#  ('PND-Grundbestand', 48),
#  ('Rektor', 44),
#  ('traduit', 43),
#  ('Leipzig', 43),
#  ('Jésuite', 43),
#  ('Physiker', 42),
#  ('Italien', 40),
#  ('Franz', 40),
#  ('Magister', 38),
#  ('Médecin', 37),
#  ('Jena', 37),
#  ('Lehrer', 36),
#  ('Philosophie', 34),
#  ('VD-16', 34),
#  ('Studium', 34),
#  ('auch', 34),
#  ("l'Université", 34),
#  ('Universität', 33),
#  ('nach', 32),
#  ('Pfarrer', 32),
#  ('Membre', 32),
#  ('Verf', 31),
#  ('Philosophe', 31),
#  ('Jurist', 31),
#  ('Theologie', 31),
#  ('Humanist', 30),
#  ('Medizin', 30),
#  ('philosophe', 29),
#  ('Dichter', 29),
#  ('philosophie', 29),
#  ("l'Académie", 29),
#  ('Astrologe', 28),
#  ('Naturwissenschaftler', 28),
#  ('Sohn', 28),
#  ('Kalenderschreiber', 28),
#  ('Mitglied', 27),
#  ('Architekt', 27),
#  ('professeur', 27),
#  ('français', 27),
#  ('Théologien', 26),
#  ('italien', 26),
#  ('seit', 26),
#  ('Schriftsteller', 26),
#  ('Physik', 26),
#  ('verknuepft', 25),
#  ('DBL-Retro-Titeldaten', 25),
#  ('Maschinell', 25),
#  ('grec', 25),
#  ('Kartograph', 25),
#  ('Niederländ', 25),
#  ('Leiden', 25),
#  ('Astronomie', 24),
#  ('Nürnberg', 24),
#  ('puis', 23),
#  ('phil', 22),
#  ('Rostock', 22),
#  ('Helmstedt', 22),
#  ('Altdorf', 21),
#  ('Historiker', 20),
#  ('Basel', 20),
#  ('Pastor', 20),
#  ('Deutschland', 20),
#  ('physicien', 20),
#  ('Gymnasium', 20),
#  ('sciences', 20),
#  ('Philologe', 19),
#  ('Geograph', 19),
#  ('Poète', 19),
#  ('Königsberg', 19),
#  ('avec', 19),
#  ('médecine', 18),
#  ('Gelehrter', 18),
#  ('Paris', 18),
#  ('France', 18),
#  ('Beitr', 17),
#  ('médecin', 17),
#  ('théologie', 17),
#  ('Prediger', 17),
#  ('Mathématiques', 17),
#  ('Frankreich', 17),
#  ('später', 17),
#  ('Halle', 17),
#  ('Wirkungsort', 17),
#  ('dans', 16),
#  ('Tübingen', 16),
#  ('Johann', 16),
#  ('Greifswald', 16),
#  ('Dekan', 16),
#  ('Berlin', 16),
#  ('Akademie', 16),
#  ('ancien', 15),
#  ('Humaniste', 15),
#  ('théologien', 15),
#  ('allemand', 15),
#  ('Respondent', 15),
#  ('Diakon', 15),
#  ('Schweizer', 15),
#  ('Marburg', 15),
#  ('Pädagoge', 15),
#  ('Physicien', 15),
#  ('Stadtphysikus', 15),
#  ('studierte', 15),
#  ('Religion', 14),
#  ('sich', 14),
#  ('poète', 14),
#  ('lettres', 14),
#  ('Bologne', 14),
#  ('astrologue', 14),
#  ("d'astronomie", 14),
#  ('ingénieur', 14),
#  ('1960-1969', 14),
#  ('Leibarzt', 14),
#  ('historien', 13),
#  ('Heidelberg', 13),
#  ('theol', 13),
#  ('Hamburg', 13),
#  ('Schüler', 13),
#  ('Collège', 13),
#  ('Frankfurt', 13),
#  ('partir', 12),
#  ('Padua', 12),
#  ('Erfurt', 12),
#  ('géographe', 12),
#  ('Straßburg', 12),
#  ('Historien', 12),
#  ('wurde', 12),
#  ('Ingenieur', 12),
#  ('Engl', 12),
#  ('Bruder', 12),
#  ('Ingénieur', 12),
#  ('Fakultät', 12),
#  ('graveur', 11),
#  ('Maler', 11),
#  ('mort', 11),
#  ('Musiker', 11),
#  ('Rechenmeister', 11),
#  ('dann', 11),
#  ('Schweiz', 11),
#  ('Cartographe', 11),
#  ('Superintendent', 11),
#  ('Vater', 11),
#  ('Naturforscher', 11),
#  ('unter', 11),
#  ('Geistlicher', 11),
#  ("l'université", 11),
#  ('Wissenschaften', 11),
#  ('Docteur', 10),
#  ('cartographe', 10),
#  ('Auteur', 10),
#  ('Fils', 10),
#  ('Georg', 10),
#  ('Astrologue', 10),
#  ('Écrivit', 10),
#  ('Französ', 10),
#  ('sowie', 10),
#  ('Écrivait', 10),
#  ('1699', 10),
#  ('Architecte', 9),
#  ('gest', 9),
#  ('auteur', 9),
#  ('Peintre', 9),
#  ('evang', 9),
#  ('architecte', 9),
#  ('Verfasser', 9),
#  ('einer', 9),
#  ('pour', 9),
#  ('Wien', 9),
#  ('1714', 9),
#  ('sous', 9),
#  ('wirkte', 9),
#  ('confondre', 9),
#  ('Écrit', 9),
#  ('Sprachen', 9),
#  ('Allemagne', 9),
#  ('Dozent', 9),
#  ('Oder', 9),
#  ('dort', 9),
#  ('Logik', 9),
#  ('Royal', 9),
#  ('Bischof', 8),
#  ('Venise', 8),
#  ('lehrte', 8),
#  ('Sprache', 8),
#  ('Arts', 8),
#  ('Augsburg', 8),
#  ('Würzburg', 8),
#  ('Strasbourg', 8),
#  ('physique', 8),
#  ('1710', 8),
#  ('Prag', 8),
#  ('Promotion', 8),
#  ('Kupferstecher', 8),
#  ('GDEL', 8),
#  ('tätig', 8),
#  ('Mathematiklehrer', 8),
#  ('Friedrich', 8),
#  ('Sciences', 8),
#  ('associée', 8),
#  ('wieder', 8),
#  ('Bibliothekar', 8),
#  ('chaire', 8),
#  ('Phil', 8),
#  ('Breslau', 8),
#  ('Danzig', 8),
#  ('Chine', 8),
#  ('1664', 8),
#  ('Society', 8),
#  ('1695', 8),
#  ('Hofrat', 8),
#  ('1725', 8),
#  ('italiana', 7),
#  ('Universalgelehrter', 7),
#  ('Lebensdaten', 7),
#  ('Priester', 7),
#  ('Rome', 7),
#  ('Poet', 7),
#  ('Geburtsort', 7),
#  ('naturaliste', 7),
#  ('Zürich', 7),
#  ('1543', 7),
#  ('protestant', 7),
#  ('Münster', 7),
#  ('Reformator', 7),
#  ('über', 7),
#  ('droit', 7),
#  ('Bibliothek', 7),
#  ('seine', 7),
#  ('suppl', 7),
#  ('1730', 7),
#  ('1717', 7),
#  ('erster', 7),
#  ('eine', 7),
#  ('Michael', 7),
#  ('mathématique', 7),
#  ('Oxford', 7),
#  ('Schriften', 7),
#  ('Lyon', 7),
#  ('Pise', 7),
#  ('Deutscher', 7),
#  ('durch', 7),
#  ('anglais', 7),
#  ('Tochter', 7),
#  ('Missionar', 7),
#  ('China', 7),
#  ('1634', 7),
#  ('Bremen', 7),
#  ('Conseiller', 7),
#  ('1671', 7),
#  ('1654', 7),
#  ('1666', 7),
#  ('1684', 7),
#  ('1697', 7),
#  ('1702', 7),
#  ('1691', 7),
#  ('1704', 7),
#  ('1716', 7),
#  ('Encicl', 6),
#  ('Italienischer', 6),
#  ('Übersetzer', 6),
#  ('Géographe', 6),
#  ('géographie', 6),
#  ('Thematischer', 6),
#  ('Bezug', 6),
#  ('associé', 6),
#  ('Span', 6),
#  ('England', 6),
#  ('Hebräisch', 6),
#  ('stud', 6),
#  ('nicht', 6),
#  ('1564', 6),
#  ('Anna', 6),
#  ('Köln', 6),
#  ('Peter', 6),
#  ('Caspar', 6),
#  ('Saale', 6),
#  ('della', 6),
#  ('1560', 6),
#  ('Hauslehrer', 6),
#  ('Stadtarzt', 6),
#  ('royal', 6),
#  ('Komponist', 6),
#  ('1554', 6),
#  ('1550', 6),
#  ('Diensten', 6),
#  ('Coburg', 6),
#  ('Vécut', 6),
#  ('Bologna', 6),
#  ('Collegium', 6),
#  ('danach', 6),
#  ('Homme', 6),
#  ('Forme', 6),
#  ('Auteur/Titre', 6),
#  ('Erfinder', 6),
#  ('verheiratet', 6),
#  ('Wilhelm', 6),
#  ('London', 6),
#  ('1619', 6),
#  ('Londres', 6),
#  ('Göttingen', 6),
#  ('Adjunkt', 6),
#  ('1621', 6),
#  ('Missionnaire', 6),
#  ('française', 6),
#  ('Französischer', 6),
#  ('Gießen', 6),
#  ('Bürgermeister', 6),
#  ('collège', 6),
#  ('1656', 6),
#  ('1655', 6),
#  ('1659', 6),
#  ('1682', 6),
#  ('1687', 6),
#  ('membre', 6),
#  ('1686', 6),
#  ('1680', 6),
#  ('1703', 6),
#  ('1729', 6),
#  ('Petersburg', 6),
#  ('Philologue', 5),
#  ('philologue', 5),
#  ("d'Espagne", 5),
#  ('Portugal', 5),
#  ('Cour', 5),
#  ('Kosmograph', 5),
#  ('éditeur', 5),
#  ('Diplomat', 5),
#  ('Italie', 5),
#  ('zuletzt', 5),
#  ('lebte', 5),
#  ('1524', 5),
#  ('Zeichner', 5),
#  ('Quelle', 5),
#  ('actif', 5),
#  ('humaniste', 5),
#  ('Christoph', 5),
#  ('Enseigna', 5),
#  ('1559', 5),
#  ('1580', 5),
#  ('Ethik', 5),
#  ('1747', 5),
#  ('1568', 5),
#  ('1722', 5),
#  ('1718', 5),
#  ('Niederländischer', 5),
#  ('1549', 5),
#  ('Ingolstadt', 5),
#  ('Graveur', 5),
#  ('wegen', 5),
#  ('seiner', 5),
#  ('Dessinateur', 5),
#  ('père', 5),
#  ('Johannes', 5),
#  ('1562', 5),
#  ('littérature', 5),
#  ('Sankt', 5),
#  ('docteur', 5),
#  ('Littératures', 5),
#  ("l'Accademia", 5),
#  ('Padoue', 5),
#  ('seinem', 5),
#  ('math', 5),
#  ('Nürnberger', 5),
#  ('Rückkehr', 5),
#  ('Geschichte', 5),
#  ('Herzog', 5),
#  ('enseigna', 5),
#  ('1581', 5),
#  ('botaniste', 5),
#  ('ouvrages', 5),
#  ('Musiktheoretiker', 5),
#  ('Belg', 5),
#  ('ging', 5),
#  ('Niederlande', 5),
#  ('militaire', 5),
#  ('Père', 5),
#  ('1607', 5),
#  ('Provenienzmerkmal', 5),
#  ('cour', 5),
#  ('1582', 5),
#  ('1605', 5),
#  ('Jahre', 5),
#  ('Hannover', 5),
#  ('1637', 5),
#  ('Kopenhagen', 5),
#  ('Rhetorik', 5),
#  ('Philosophischen', 5),
#  ('Metaphysik', 5),
#  ('Orientalist', 5),
#  ('Amsterdam', 5),
#  ('Nantes', 5),
#  ('1667', 5),
#  ('Eintritt', 5),
#  ('Gesellschaft', 5),
#  ('1644', 5),
#  ('royale', 5),
#  ('1669', 5),
#  ('1660', 5),
#  ('Ehefrau', 5),
#  ('Konsistorialrat', 5),
#  ('Leyde', 5),
#  ('1685', 5),
#  ('1701', 5),
#  ('1694', 5),
#  ('1724', 5),
#  ('1706', 5),
#  ('1721', 5),
#  ('1744', 5),
#  ('1733', 5),
#  ('1726', 5),
#  ('1743', 5),
#  ('1734', 5),
#  ('Franciscain', 4),
#  ('Ferrara', 4),
#  ('Médecine', 4),
#  ('vécu', 4),
#  ("jusqu'en", 4),
#  ('Seefahrer', 4),
#  ('près', 4),
#  ('Nommé', 4),
#  ('Ansetzung', 4),
#  ("l'hébreu", 4),
#  ("d'hébreu", 4),
#  ('libraire', 4),
#  ('fils', 4),
#  ('chargé', 4),
#  ('août', 4),
#  ('Vorlesungen', 4),
#  ('Également', 4),
#  ('Louis', 4),
#  ('Publizist', 4),
#  ('Dominicain', 4),
#  ('Antwerpen', 4),
#  ('Schulmeister', 4),
#  ('Baumeister', 4),
#  ('Architekturtheoretiker', 4),
#  ('théoricien', 4),
#  ('oder', 4),
#  ('ligne', 4),
#  ('1521', 4),
#  ('pasteur', 4),
#  ('Chemiker', 4),
#  ('chimiste', 4),
#  ('Écrivain', 4),
#  ("d'histoire", 4),
#  ('plusieurs', 4),
#  ('heute', 4),
#  ('berufen', 4),
#  ('Magdalena', 4),
#  ('1740', 4),
#  ('1600', 4),
#  ('Bâle', 4),
#  ('1712', 4),
#  ('1738', 4),
#  ('Maria', 4),
#  ('1541', 4),
#  ('luthérien', 4),
#  ('1556', 4),
#  ('Autor', 4),
#  ('musique', 4),
#  ('Schulpforta', 4),
#  ('Verleger', 4),
#  ('Venedig', 4),
#  ('Militäringenieur', 4),
#  ('Mathematikprofessor', 4),
#  ('Société', 4),
#  ('Jacob', 4),
#  ('sauf', 4),
#  ('Stadtschule', 4),
#  ('Magdeburg', 4),
#  ('1545', 4),
#  ('Louvain', 4),
#  ('1578', 4),
#  ('1574', 4),
#  ('degli', 4),
#  ('traités', 4),
#  ('pseudonyme', 4),
#  ('entre', 4),
#  ('Géographie', 4),
#  ('Sachsen', 4),
#  ('1566', 4),
#  ('Theol', 4),
#  ('Generalsuperintendent', 4),
#  ('Inspektor', 4),
#  ('Carolinum', 4),
#  ('premier', 4),
#  ('vers', 4),
#  ("d'un", 4),
#  ('1555', 4),
#  ('Hofprediger', 4),
#  ('mehrfach', 4),
#  ('Botaniker', 4),
#  ('géométrie', 4),
#  ('Giovanni', 4),
#  ('Gymnasialprofessor', 4),
#  ('musicien', 4),
#  ('1584', 4),
#  ('Cosmographe', 4),
#  ('für', 4),
#  ('Directeur', 4),
#  ('Orientaliste', 4),
#  ('1591', 4),
#  ('Konrektor', 4),
#  ('Stettin', 4),
#  ('1602', 4),
#  ('République', 4),
#  ('1583', 4),
#  ('Polyhistor', 4),
#  ('ville', 4),
#  ('eines', 4),
#  ('Herzogs', 4),
#  ('Physique', 4),
#  ('Abbé', 4),
#  ('Geometer', 4),
#  ('1612', 4),
#  ('Ratsherr', 4),
#  ('Pays-Bas', 4),
#  ('Musique', 4),
#  ('Juriste', 4),
#  ('1609', 4),
#  ('promoviert', 4),
#  ('College', 4),
#  ('Pseud', 4),
#  ('Botanik', 4),
#  ('kaiserlichen', 4),
#  ('Polen', 4),
#  ('voyageur', 4),
#  ('Löwen', 4),
#  ('Groningen', 4),
#  ('néerlandais', 4),
#  ('1628', 4),
#  ('immatrikuliert', 4),
#  ('écrivain', 4),
#  ('1622', 4),
#  ('Frans', 4),
#  ('Schooten', 4),
#  ('1614', 4),
#  ('Prorektor', 4),
#  ('1625', 4),
#  ('fortifications', 4),
#  ('géomètre', 4),
#  ('ordiniert', 4),
#  ('daneben', 4),
#  ('Schreib-', 4),
#  ('1626', 4),
#  ('1652', 4),
#  ('1636', 4),
#  ('Hohen', 4),
#  ('1658', 4),
#  ('Mönch', 4),
#  ('rhétorique', 4),
#  ('zunächst', 4),
#  ('1642', 4),
#  ('1661', 4),
#  ('1662', 4),
#  ('Privatgelehrter', 4),
#  ('1653', 4),
#  ('1683', 4),
#  ('1692', 4),
#  ('archéologue', 4),
#  ('Bernoulli', 4),
#  ('Prinzenerzieher', 4),
#  ('1728', 4),
#  ('http', 4),
#  ('Naturwissenschaften', 4),
#  ('Akad', 4),
#  ('theoretischen', 4),
#  ('Jura', 4),
#  ('Leibniz', 4),
#  ('après', 4),
#  ('Meteorologe', 4),
#  ('1739', 4),
#  ('1707', 4),
#  ('Saint-Pétersbourg', 4),
#  ('1709', 4),
#  ('Assessor', 4),
#  ('1723', 4),
#  ('1731', 4),
#  ('1715', 4),
#  ('1751', 4),
#  ('biogr', 3),
#  ('Korrektor', 3),
#  ('Herausgeber', 3),
#  ('général', 3),
#  ('Kardinal', 3),
#  ('Nikolaus', 3),
#  ('Herkunftsort', 3),
#  ('Spanien', 3),
#  ('Pologne', 3),
#  ('Patrizier', 3),
#  ('pape', 3),
#  ('Ferrare', 3),
#  ('Geburtsjahr', 3),
#  ('homme', 3),
#  ('Maître', 3),
#  ('Commentateur', 3),
#  ('Hochschullehrer', 3),
#  ('griech', 3),
#  ('cette', 3),
#  ('1520', 3),
#  ('grecque', 3),
#  ('comme', 3),
#  ('hielt', 3),
#  ('Hongrie', 3),
#  ('Altphilologe', 3),
#  ('Böhmen', 3),
#  ('Olmütz', 3),
#  ('König', 3),
#  ("d'ouvrages", 3),
#  ('Peinture', 3),
#  ('graphiques', 3),
#  ('Chanoine', 3),
#  ('Bamberg', 3),
#  ('Nuremberg', 3),
#  ('Prédicateur', 3),
#  ('1534', 3),
#  ('Kirche', 3),
#  ('Alchemist', 3),
#  ('Ratsmitglied', 3),
#  ('Albrecht', 3),
#  ('Benediktiner', 3),
#  ('1526', 3),
#  ('prince', 3),
#  ('Titre', 3),
#  ('alchimiste', 3),
#  ('uniforme', 3),
#  ('Savoie', 3),
#  ('Iéna', 3),
#  ('Berthelot', 3),
#  ('Bildhauer', 3),
#  ('Ludwig', 3),
#  ('Kurfürst', 3),
#  ('trat', 3),
#  ('service', 3),
#  ('Jakob', 3),
#  ('reformierter', 3),
#  ('Catharina', 3),
#  ('1713', 3),
#  ('1606', 3),
#  ('Deventer', 3),
#  ('seines', 3),
#  ('Bearb', 3),
#  ('1544', 3),
#  ('hebr', 3),
#  ('Geschichtsschreiber', 3),
#  ('Premier', 3),
#  ('ordinaire', 3),
#  ('Savant', 3),
#  ("l'histoire", 3),
#  ('Neustadt', 3),
#  ('1577', 3),
#  ('Genf', 3),
#  ('Geboren', 3),
#  ('Architektur', 3),
#  ('Éditeur', 3),
#  ('Seit', 3),
#  ('dramatique', 3),
#  ("d'estampes", 3),
#  ('ital', 3),
#  ('1616', 3),
#  ('1553', 3),
#  ('Ansbach', 3),
#  ('neulat', 3),
#  ('Österr', 3),
#  ('peintre', 3),
#  ('Jean', 3),
#  ('Künstler', 3),
#  ('evangel', 3),
#  ('1546', 3),
#  ('1539', 3),
#  ('recteur', 3),
#  ('Erzbischof', 3),
#  ('schrieb', 3),
#  ('cosmographe', 3),
#  ('Landesschule', 3),
#  ('Anhänger', 3),
#  ('Mathematicus', 3),
#  ('réforme', 3),
#  ('Antoine', 3),
#  ('juriste', 3),
#  ('Doktor', 3),
#  ('1565', 3),
#  ('Königsberg/Preußen', 3),
#  ('Joachim', 3),
#  ('starb', 3),
#  ('1552', 3),
#  ('bibliothécaire', 3),
#  ('Geograf', 3),
#  ('Schwiegersohn', 3),
#  ('astronomische', 3),
#  ('Kalender', 3),
#  ('Meißen', 3),
#  ('Weimar', 3),
#  ('Griechisch', 3),
#  ('plan', 3),
#  ('Kroat', 3),
#  ('également', 3),
#  ('Fondateur', 3),
#  ('jésuite', 3),
#  ('Cologne', 3),
#  ('linguiste', 3),
#  ('1592', 3),
#  ('Philologie', 3),
#  ('Drucker', 3),
#  ('siècle', 3),
#  ('Jacobi', 3),
#  ('Professur', 3),
#  ('Herkunft', 3),
#  ('1588', 3),
#  ('1570', 3),
#  ('Stargard', 3),
#  ('Privatdozent', 3),
#  ('Rudolf', 3),
#  ('Kaiser', 3),
#  ('Marienkirche', 3),
#  ('1594', 3),
#  ('Freiburg', 3),
#  ('Gymnasialprof', 3),
#  ('Anatomie', 3),
#  ('Apotheker', 3),
#  ('Luzern', 3),
#  ('Galilée', 3),
#  ('Évêque', 3),
#  ('Staatsmann', 3),
#  ('compositeur', 3),
#  ('Recteur', 3),
#  ('Politiker', 3),
#  ('Lübeck', 3),
#  ('1613', 3),
#  ('-Rektor', 3),
#  ('heiratet', 3),
#  ('conseiller', 3),
#  ('1590', 3),
#  ('ernannt', 3),
#  ('1604', 3),
#  ('Berufung', 3),
#  ('1595', 3),
#  ('fürstl', 3),
#  ('Histoire', 3),
#  ('Groningue', 3),
#  ('Verheiratet', 3),
#  ('1601', 3),
#  ('1608', 3),
#  ('marine', 3),
#  ('Anvers', 3),
#  ('1611', 3),
#  ('Frère', 3),
#  ('wird', 3),
#  ('Schwed', 3),
#  ('Pasteur', 3),
#  ('Präsident', 3),
#  ('Compositeur', 3),
#  ('astronomiques', 3),
#  ('Plauen', 3),
#  ('Hevelius', 3),
#  ('Rudolph', 3),
#  ('Biologe', 3),
#  ("d'éloquence", 3),
#  ('Intendant', 3),
#  ('1624', 3),
#  ('Natur-', 3),
#  ('1629', 3),
#  ('Flèche', 3),
#  ('Rouen', 3),
#  ('China-Missionar', 3),
#  ('généraux', 3),
#  ('comparatifs', 3),
#  ('Sterbeort', 3),
#  ('1650', 3),
#  ('1643', 3),
#  ('Précepteur', 3),
#  ('Brit', 3),
#  ('Altenburg', 3),
#  ('Präses', 3),
#  ('Schule', 3),
#  ('zugleich', 3),
#  ('Dillingen', 3),
#  ('Graf', 3),
#  ('Metz', 3),
#  ('Pascal', 3),
#  ('Haag', 3),
#  ('Pierre', 3),
#  ('Gelati', 3),
#  ('1657', 3),
#  ('1641', 3),
#  ('1668', 3),
#  ('Begründer', 3),
#  ('Mathematikers', 3),
#  ('1681', 3),
#  ('Dänemark', 3),
#  ('Anatom', 3),
#  ('Bartholin', 3),
#  ('Grossbritannien', 3),
#  ('Utrecht', 3),
#  ('fondateur', 3),
#  ('Gründer', 3),
#  ('Naturphilosoph', 3),
#  ('orientalischen', 3),
#  ('1672', 3),
#  ('1673', 3),
#  ("l'Observatoire", 3),
#  ('Hollande', 3),
#  ('1651', 3),
#  ('einige', 3),
#  ('1663', 3),
#  ('1698', 3),
#  ('1674', 3),
#  ('Rinteln', 3),
#  ('1670', 3),
#  ('Direktor', 3),
#  ('dortigen', 3),
#  ('prakt', 3),
#  ('1693', 3),
#  ('contre', 3),
#  ('1678', 3),
#  ('Oratorien', 3),
#  ('Giessen', 3),
#  ('Leopoldina', 3),
#  ('zweite', 3),
#  ('1679', 3),
#  ('Ritterakademie', 3),
#  ('Lüneburg', 3),
#  ("l'Institut", 3),
#  ('Académie', 3),
#  ('Jesuitenorden', 3),
#  ('Louis-le-Grand', 3),
#  ('révocation', 3),
#  ("l'Édit", 3),
#  ('Jean-Baptiste', 3),
#  ('1708', 3),
#  ('1688', 3),
#  ('Comte', 3),
#  ('1700', 3),
#  ('1732', 3),
#  ('Erlangen', 3),
#  ('1727', 3),
#  ('Russland', 3),
#  ('1737', 3),
#  ('Voltaire', 3),
#  ('1490', 2),
#  ('Larousse', 2),
#  ('italiano', 2),
#  ('Cardinal', 2),
#  ('Übers', 2),
#  ('Niccolò', 2),
#  ('Identität', 2),
#  ('Fossombrone', 2),
#  ('1497', 2),
#  ('1512', 2),
#  ('Kaufmann', 2),
#  ('Venezian', 2),
#  ('Milan', 2),
#  ('grecs', 2),
#  ('Ambassadeur', 2),
#  ('classiques', 2),
#  ('gouverneur', 2),
#  ('1496', 2),
#  ('Magistrat', 2),
#  ('Adeliger', 2),
#  ('Ritter', 2),
#  ('Crète', 2),
#  ('écrits', 2),
#  ('Griech', 2),
#  ('Poln', 2),
#  ('Krakau', 2),
#  ('Feldherr', 2),
#  ("qu'il", 2),
#  ('était', 2),
#  ('Ludovico', 2),
#  ('encore', 2),
#  ('date', 2),
#  ('verschiedenen', 2),
#  ('1525', 2),
#  ('latine', 2),
#  ('meurt', 2),
#  ('anschließend', 2),
#  ('1505', 2),
#  ('geboren', 2),
#  ('Archevêque', 2),
#  ('Neapel', 2),
#  ('Freund', 2),
#  ('Dominikaner', 2),
#  ('tchèque', 2),
#  ('Breslauer', 2),
#  ('Tschech', 2),
#  ('Böhmen', 2),
#  ('grammaire', 2),
#  ('historiques', 2),
#  ('Kunsttheoretiker', 2),
#  ('Dessin', 2),
#  ('arts', 2),
#  ("d'art", 2),
#  ('décoratifs', 2),
#  ('Nördlingen', 2),
#  ('Naturgelehrter', 2),
#  ('Domherr', 2),
#  ('sculpteur', 2),
#  ('Pavie', 2),
#  ('Michaud', 2),
#  ('Karlstadt', 2),
#  ('kath', 2),
#  ('Strassburg', 2),
#  ('1518', 2),
#  ('Réformateur', 2),
#  ('Verona', 2),
#  ('nommé', 2),
#  ('Élève', 2),
#  ('Paul', 2),
#  ('poèmes', 2),
#  ("d'oeuvres", 2),
#  ('spécialiste', 2),
#  ('Naples', 2),
#  ('environ', 2),
#  ('enseigné', 2),
#  ('précepteur', 2),
#  ('obtient', 2),
#  ('Luthérien', 2),
#  ('historiographe', 2),
#  ('ésotérisme', 2),
#  ('Quint', 2),
#  ('occultisme', 2),
#  ('Charles', 2),
#  ('Parapsychologie', 2),
#  ('Kathedrale', 2),
#  ('bedeutende', 2),
#  ('Inventeur', 2),
#  ('Sculpteur', 2),
#  ('1529', 2),
#  ('1547', 2),
#  ('Franziskaner', 2),
#  ('einem', 2),
#  ('Luther', 2),
#  ('Entre', 2),
#  ('famille', 2),
#  ('Schreiblehrer', 2),
#  ('disp', 2),
#  ('mehr', 2),
#  ('Medizinstudent', 2),
#  ('1593', 2),
#  ('gewählt', 2),
#  ('1742', 2),
#  ('heraus', 2),
#  ('Sieur', 2),
#  ('1563', 2),
#  ('Reutlingen', 2),
#  ('Chevalier', 2),
#  ('Bienewitz', 2),
#  ('Apianus', 2),
#  ('Baseler', 2),
#  ('Henri', 2),
#  ('Gegner', 2),
#  ('Lorenz', 2),
#  ('1522', 2),
#  ('Königsberg', 2),
#  ('Goldschmied', 2),
#  ('Chronist', 2),
#  ('1532', 2),
#  ('1536', 2),
#  ('Fläm', 2),
#  ('Meurt', 2),
#  ('Pseudonyme', 2),
#  ("l'un", 2),
#  ('Cioranescu', 2),
#  ('cathédrale', 2),
#  ("l'astronomie", 2),
#  ('Ortelius', 2),
#  ('Abraham', 2),
#  ('édité', 2),
#  ('Grenoble', 2),
#  ('Jacques', 2),
#  ('bekannt', 2),
#  ('librettiste', 2),
#  ...]

# %% [markdown]
# ### Write CSV
#
# The activities are coded manually in a dedicated .ods file, then a CSV export of the encoded activities produced

# %%
with open('spreadsheets/manually_coded_activities.csv', 'w', newline='') as csvfile:
    doc_writer = csv.writer(csvfile, delimiter='|',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    doc_writer.writerow(['token', 'freq', 'manual_code'])
    [doc_writer. writerow((list(r))) for r in std_c_result_notes]

# %% [markdown]
# ### Inspect the coded grouped activities
#
# This file is a CSV export from the manually encoded .csv file with the same name.

# %%
with open('spreadsheets/manually_coded_activities_codes.csv', newline='') as csvfile:
    doc_reader = csv.reader(csvfile, delimiter='|', quotechar='"')
    codes = []
    for row in doc_reader:
        if len(row[2]) > 0:
            codes.append(row)

# %%
codes
# Out:
# [['token', 'freq', 'manual_code'],
#  ['Mathematiker', '347', 'math'],
#  ['Astronom', '155', 'astron'],
#  ['Mathematik', '147', 'math'],
#  ['Mathématicien', '130', 'math'],
#  ['Professor', '128', 'prof'],
#  ['Prof', '124', 'prof'],
#  ['latin', '112', 'anc_lang'],
#  ['Theologe', '97', 'theol'],
#  ['Professeur', '95', 'prof'],
#  ['mathématicien', '87', 'math'],
#  ['astronome', '68', 'astron'],
#  ['Philosoph', '67', 'philo'],
#  ['Mediziner', '67', 'med'],
#  ['mathématiques', '64', 'math'],
#  ['Arzt', '62', 'med'],
#  ['Jesuit', '60', 'cleric'],
#  ['Astronome', '55', 'astron'],
#  ['Jésuite', '43', 'cleric'],
#  ['Physiker', '42', 'phys'],
#  ['Rektor', '41', 'prof'],
#  ['Médecin', '35', 'med'],
#  ['Lehrer', '35', 'prof'],
#  ['Philosophie', '34', 'philo'],
#  ['Pfarrer', '33', 'cleric'],
#  ['Philosophe', '31', 'philo'],
#  ['Jurist', '31', 'juri'],
#  ['Medizin', '30', 'med'],
#  ['Theologie', '30', 'theol'],
#  ['Humanist', '29', 'huma'],
#  ['Dichter', '29', 'huma'],
#  ['Astrologe', '28', 'astrol'],
#  ['philosophe', '28', 'philo'],
#  ['Naturwissenschaftler', '28', 'scholar'],
#  ['philosophie', '28', 'philo'],
#  ['Kalenderschreiber', '28', 'astrol'],
#  ['Théologien', '26', 'theol'],
#  ['Architekt', '26', 'archi'],
#  ['professeur', '26', 'prof'],
#  ['Physik', '26', 'phys'],
#  ['Kartograph', '25', 'geo_carto'],
#  ['Schriftsteller', '25', 'huma'],
#  ['Astronomie', '24', 'astron'],
#  ['phil', '22', 'philo'],
#  ['physicien', '20', 'phys'],
#  ['Historiker', '19', 'histo'],
#  ['Philologe', '19', 'anc_lang'],
#  ['médecin', '17', 'med'],
#  ['Geograph', '17', 'geo_carto'],
#  ['médecine', '17', 'med'],
#  ['théologie', '17', 'theol'],
#  ['Mathématiques', '17', 'math'],
#  ['Gelehrter', '16', 'scholar'],
#  ['Humaniste', '15', 'huma'],
#  ['théologien', '15', 'theol'],
#  ['Prediger', '15', 'cleric'],
#  ['Pädagoge', '15', 'prof'],
#  ['Physicien', '15', 'phys'],
#  ['Stadtphysikus', '15', 'med'],
#  ['poète', '14', 'liter'],
#  ['astrologue', '14', 'astrol'],
#  ["d'astronomie", '14', 'astron'],
#  ['ingénieur', '14', 'inge'],
#  ['historien', '13', 'histo'],
#  ['lettres', '13', 'liter'],
#  ['theol', '13', 'theol'],
#  ['géographe', '12', 'geo_carto'],
#  ['Historien', '12', 'histo'],
#  ['Ingenieur', '12', 'inge'],
#  ['Maler', '11', 'artist'],
#  ['Musiker', '11', 'artist'],
#  ['Rechenmeister', '11', 'prof'],
#  ['Naturforscher', '11', 'scholar'],
#  ['Ingénieur', '11', 'inge'],
#  ['Geistlicher', '11', 'cleric'],
#  ['cartographe', '10', 'geo_carto'],
#  ['Cartographe', '10', 'geo_carto'],
#  ['Superintendent', '10', 'prof'],
#  ['Wissenschaften', '10', 'scholar'],
#  ['Écrivait', '10', 'liter'],
#  ['Docteur', '9', 'med'],
#  ['Peintre', '9', 'artist'],
#  ['architecte', '9', 'archi'],
#  ['Astrologue', '9', 'astrol'],
#  ['Écrivit', '9', 'liter'],
#  ['Sprachen', '9', 'anc_lang'],
#  ['Dozent', '9', 'prof'],
#  ['Logik', '9', 'philo'],
#  ['Sprache', '8', 'anc_lang'],
#  ['Architecte', '8', 'archi'],
#  ['Arts', '8', 'artist'],
#  ['evang', '8', 'cleric'],
#  ['physique', '8', 'phys'],
#  ['Mathematiklehrer', '8', 'math'],
#  ['Sciences', '8', 'scholar'],
#  ['Hofrat', '8', 'juri'],
#  ['Universalgelehrter', '7', 'prof'],
#  ['Priester', '7', 'cleric'],
#  ['Poet', '7', 'liter'],
#  ['naturaliste', '7', 'scholar'],
#  ['Kupferstecher', '7', 'artist'],
#  ['mathématique', '7', 'math'],
#  ['Missionar', '7', 'cleric'],
#  ['Conseiller', '7', 'juri'],
#  ['Géographe', '6', 'geo_carto']]

# %% [markdown]
# ### Coded general notes activities list

# %%
pers_activities = []
for nl in notes_list:
    nl_codes = []
    for c in codes[1:]:
        if c[0] in nl[1]:
            nl_codes.append(c[2])
    pers_activities.append([nl[0],sorted(list(set(nl_codes)))])

# %%
print(len(pers_activities))
pers_activities
# Out:
# 914
# [['cnp01352012', ['theol']],
#  ['cnp02088071', ['astrol', 'huma', 'med', 'philo']],
#  ['cnp01881207', ['cleric', 'huma', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01879247', ['anc_lang', 'huma', 'med', 'philo', 'prof']],
#  ['cnp00996213', ['astron', 'math', 'prof']],
#  ['cnp01320054', ['astron', 'histo', 'scholar']],
#  ['cnp01363268', ['huma', 'med']],
#  ['cnp01241028', []],
#  ['cnp00873006', ['anc_lang', 'cleric', 'math']],
#  ['cnp01329886', ['anc_lang', 'huma', 'philo']],
#  ['cnp01363122', ['anc_lang', 'huma', 'liter', 'math', 'philo', 'theol']],
#  ['cnp00350996', ['astron', 'med', 'theol']],
#  ['cnp02222242', ['math', 'med']],
#  ['cnp01884261', []],
#  ['cnp00397446', ['geo_carto']],
#  ['cnp01368034', ['anc_lang', 'histo', 'liter', 'med', 'philo', 'prof']],
#  ['cnp01335792', ['anc_lang', 'astron', 'math', 'med', 'philo']],
#  ['cnp00888506', ['math', 'philo']],
#  ['cnp01879502', ['math']],
#  ['cnp00556047', []],
#  ['cnp01362970',
#   ['anc_lang', 'histo', 'liter', 'math', 'med', 'philo', 'prof']],
#  ['cnp01115869', ['math']],
#  ['cnp00402391', ['astron', 'geo_carto', 'math']],
#  ['cnp01365166', ['anc_lang', 'astrol', 'med', 'scholar']],
#  ['cnp02088587', ['astron', 'med', 'theol']],
#  ['cnp01409583', ['astron', 'theol']],
#  ['cnp01114322', ['archi', 'astrol', 'huma', 'math', 'scholar']],
#  ['cnp00100623', ['astron', 'huma', 'juri', 'liter', 'theol']],
#  ['cnp01352888', ['astrol', 'med']],
#  ['cnp01392374', ['astron', 'geo_carto', 'math']],
#  ['cnp01876151', ['astron', 'geo_carto', 'math', 'prof', 'theol']],
#  ['cnp01317063', ['artist']],
#  ['cnp01319857', []],
#  ['cnp00398396', ['huma']],
#  ['cnp01471426', ['astron', 'juri', 'math', 'med']],
#  ['cnp00412417', ['huma', 'math']],
#  ['cnp01875338', []],
#  ['cnp01470125', ['archi', 'artist']],
#  ['cnp01309925', ['astron', 'math', 'philo', 'prof']],
#  ['cnp01320896', ['anc_lang', 'astron', 'geo_carto', 'math', 'prof']],
#  ['cnp00400924', ['cleric', 'theol']],
#  ['cnp01876860',
#   ['anc_lang',
#    'artist',
#    'astron',
#    'geo_carto',
#    'huma',
#    'math',
#    'med',
#    'philo',
#    'phys',
#    'prof',
#    'theol']],
#  ['cnp01331039', ['anc_lang', 'astron', 'huma', 'philo', 'scholar']],
#  ['cnp01329937', ['archi', 'inge', 'math']],
#  ['cnp01486719', ['astrol']],
#  ['cnp01180030', ['archi', 'math']],
#  ['cnp01255966', ['huma', 'math']],
#  ['cnp01341438', ['anc_lang']],
#  ['cnp01880057', ['huma', 'prof']],
#  ['cnp01316341', ['huma', 'med', 'philo', 'theol']],
#  ['cnp01233195', ['histo']],
#  ['cnp01118781', ['astrol']],
#  ['cnp01147469', ['astron', 'math']],
#  ['cnp00917420', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01120503', ['math', 'prof']],
#  ['cnp00526061', ['archi']],
#  ['cnp01320560', ['anc_lang', 'geo_carto', 'huma', 'math', 'prof', 'theol']],
#  ['cnp02223694', ['astron', 'math', 'prof', 'theol']],
#  ['cnp01329458', ['huma', 'math', 'philo', 'theol']],
#  ['cnp01875480', ['anc_lang', 'cleric', 'huma', 'math', 'theol']],
#  ['cnp02236633', ['math', 'prof', 'theol']],
#  ['cnp01877797', ['astron', 'math']],
#  ['cnp00639317', ['geo_carto', 'inge', 'math']],
#  ['cnp01884758', ['astrol', 'med', 'philo']],
#  ['cnp01330865',
#   ['anc_lang', 'cleric', 'huma', 'math', 'med', 'philo', 'prof', 'theol']],
#  ['cnp01313334', ['anc_lang', 'huma', 'math', 'prof']],
#  ['cnp01881119', ['artist', 'astron', 'geo_carto', 'math']],
#  ['cnp01290195', ['math', 'prof']],
#  ['cnp01876551', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01019887', ['cleric', 'prof', 'theol']],
#  ['cnp01347892', ['astron', 'geo_carto', 'math']],
#  ['cnp01323680', ['math', 'prof', 'theol']],
#  ['cnp01875467', ['math', 'med', 'philo', 'prof']],
#  ['cnp01880016', ['anc_lang', 'astron', 'cleric', 'math', 'prof', 'theol']],
#  ['cnp00579703', ['artist']],
#  ['cnp01443317', ['astrol', 'liter', 'math']],
#  ['cnp01875826', ['astrol', 'huma', 'math']],
#  ['cnp00405470', ['math']],
#  ['cnp00569865', []],
#  ['cnp01356340', ['archi', 'inge', 'math']],
#  ['cnp01350201', ['archi', 'inge', 'math', 'philo']],
#  ['cnp01876658', ['anc_lang', 'archi', 'inge', 'math', 'prof', 'theol']],
#  ['cnp01349348', ['math', 'philo', 'theol']],
#  ['cnp01443388', ['astron', 'math', 'med', 'phys', 'prof', 'scholar']],
#  ['cnp01121159', ['math', 'prof']],
#  ['cnp01392199', ['artist', 'geo_carto']],
#  ['cnp00545294', ['artist']],
#  ['cnp01875706', ['huma', 'juri', 'prof']],
#  ['cnp00482208', []],
#  ['cnp01364712', ['artist', 'med', 'philo']],
#  ['cnp01112298', []],
#  ['cnp01114860', ['astron', 'math', 'prof']],
#  ['cnp01437248', ['math', 'med', 'philo', 'scholar']],
#  ['cnp02156073', ['math']],
#  ['cnp02078749', ['math', 'prof']],
#  ['cnp01122000', ['astrol', 'cleric', 'philo', 'prof', 'theol']],
#  ['cnp00950341', ['prof']],
#  ['cnp01179438', ['huma', 'med']],
#  ['cnp01112480', ['med']],
#  ['cnp01468914', ['anc_lang', 'huma', 'liter', 'math']],
#  ['cnp01345792', ['archi', 'artist', 'math']],
#  ['cnp01876067', ['artist', 'geo_carto']],
#  ['cnp01875828', ['anc_lang', 'cleric', 'huma', 'prof', 'theol']],
#  ['cnp01875825', ['cleric', 'prof', 'theol']],
#  ['cnp01877605', ['anc_lang', 'astron', 'histo', 'med', 'phys']],
#  ['cnp01336086', ['med', 'philo']],
#  ['cnp00125017', ['astron', 'math', 'med']],
#  ['cnp01876979',
#   ['anc_lang', 'astron', 'geo_carto', 'math', 'med', 'prof', 'scholar']],
#  ['cnp01334753', ['anc_lang', 'astron', 'huma', 'philo', 'prof']],
#  ['cnp01879181', ['anc_lang', 'huma', 'math', 'med']],
#  ['cnp01875669', ['astrol', 'histo', 'liter', 'philo']],
#  ['cnp01361113', []],
#  ['cnp01352300', ['archi', 'math']],
#  ['cnp01307139', ['anc_lang', 'math', 'philo', 'scholar']],
#  ['cnp01363533', ['anc_lang', 'astrol', 'math']],
#  ['cnp01340478', ['anc_lang', 'astrol', 'astron', 'liter', 'math', 'med']],
#  ['cnp01324006', ['anc_lang', 'astron', 'huma', 'liter', 'prof']],
#  ['cnp02239016', ['huma', 'math', 'phys']],
#  ['cnp01395548', ['astrol', 'astron', 'math', 'philo']],
#  ['cnp01443254', ['astron', 'math']],
#  ['cnp01355754', ['geo_carto', 'math']],
#  ['cnp01875767', ['anc_lang', 'astrol', 'math', 'med']],
#  ['cnp01876433', ['cleric', 'huma', 'math', 'med', 'prof', 'theol']],
#  ['cnp01875723', ['astron', 'geo_carto', 'math', 'med', 'theol']],
#  ['cnp01323251', ['anc_lang', 'huma', 'math', 'philo', 'prof']],
#  ['cnp01120341', ['astrol', 'astron', 'math']],
#  ['cnp01387069', ['artist']],
#  ['cnp01337057', ['huma', 'math']],
#  ['cnp01303529', ['astron', 'math']],
#  ['cnp01124849', ['astron', 'math', 'prof']],
#  ['cnp01287286', []],
#  ['cnp01368037', ['anc_lang', 'histo', 'huma', 'math']],
#  ['cnp01875207', ['cleric', 'prof', 'theol']],
#  ['cnp01200592', ['geo_carto', 'math']],
#  ['cnp02266756', ['anc_lang', 'astrol', 'liter', 'med']],
#  ['cnp02230942', ['inge', 'math']],
#  ['cnp00989664', ['anc_lang', 'theol']],
#  ['cnp01875685', ['math', 'med', 'philo', 'prof']],
#  ['cnp01407758', ['astron', 'med']],
#  ['cnp01347099', ['anc_lang', 'histo', 'juri', 'philo', 'prof', 'theol']],
#  ['cnp01481137', ['anc_lang', 'prof', 'theol']],
#  ['cnp01089747', []],
#  ['cnp01235486', ['astrol', 'astron', 'math', 'theol']],
#  ['cnp01356128', ['math']],
#  ['cnp01358480', ['anc_lang', 'astrol', 'juri', 'liter', 'med', 'theol']],
#  ['cnp00402987', ['archi', 'astron', 'geo_carto', 'math']],
#  ['cnp01333594', ['astrol', 'med', 'philo']],
#  ['cnp01345049', ['astron', 'cleric', 'math', 'scholar', 'theol']],
#  ['cnp01441705', ['math', 'med', 'scholar']],
#  ['cnp01443175', ['histo', 'huma', 'math', 'med', 'philo', 'prof', 'scholar']],
#  ['cnp00888077', ['astrol', 'math', 'med', 'prof']],
#  ['cnp01318480', []],
#  ['cnp01904447', ['inge', 'math']],
#  ['cnp01025752', []],
#  ['cnp01124424', ['astron', 'math', 'prof']],
#  ['cnp00876424', ['cleric', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01113305', ['math', 'med', 'prof']],
#  ['cnp01877782', ['astrol', 'astron', 'math']],
#  ['cnp01056939', ['math', 'philo', 'prof']],
#  ['cnp00450702', ['astron', 'liter', 'math', 'med']],
#  ['cnp02163189', []],
#  ['cnp01878121', ['math', 'med', 'prof', 'theol']],
#  ['cnp01029668', ['math']],
#  ['cnp01350014', ['anc_lang', 'med', 'philo']],
#  ['cnp01409038', ['anc_lang', 'astron', 'juri', 'math', 'prof']],
#  ['cnp01078149', ['math', 'med']],
#  ['cnp01302722',
#   ['anc_lang', 'huma', 'juri', 'liter', 'math', 'med', 'philo', 'prof']],
#  ['cnp01368443', []],
#  ['cnp01880790', ['inge', 'math', 'philo', 'phys', 'prof']],
#  ['cnp01303321', ['artist', 'astron', 'math', 'med']],
#  ['cnp01302340', ['anc_lang', 'histo', 'juri', 'math', 'prof']],
#  ['cnp01363433', []],
#  ['cnp00453662', ['astrol', 'astron', 'med']],
#  ['cnp01302373', ['astron', 'math', 'med', 'phys', 'prof']],
#  ['cnp01240021', ['astron', 'math']],
#  ['cnp00394082', ['astron', 'geo_carto', 'math', 'med', 'phys', 'prof']],
#  ['cnp01231917', ['anc_lang', 'huma', 'liter', 'math', 'philo']],
#  ['cnp01104400', []],
#  ['cnp01390409', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01365922', ['astron', 'geo_carto', 'math', 'med', 'prof', 'scholar']],
#  ['cnp01875401', ['astrol', 'med']],
#  ['cnp01333847', ['anc_lang', 'huma', 'prof']],
#  ['cnp01337628', ['astrol', 'med']],
#  ['cnp01879907', ['astron', 'philo', 'prof']],
#  ['cnp01327594', ['anc_lang', 'astrol', 'med']],
#  ['cnp00122851', ['histo', 'math', 'prof', 'theol']],
#  ['cnp01237076', ['math', 'med']],
#  ['cnp01033767', ['math', 'phys', 'prof']],
#  ['cnp01113388', ['astron', 'med', 'philo', 'phys']],
#  ['cnp01116302', ['math', 'prof']],
#  ['cnp01389779', ['histo', 'liter']],
#  ['cnp01340100', ['astron', 'math', 'med', 'prof']],
#  ['cnp00407311', ['math', 'prof']],
#  ['cnp01107316', ['prof']],
#  ['cnp02101603', ['juri', 'philo']],
#  ['cnp00476702',
#   ['archi',
#    'artist',
#    'astron',
#    'geo_carto',
#    'inge',
#    'math',
#    'scholar',
#    'theol']],
#  ['cnp00014570', ['anc_lang', 'histo', 'huma', 'prof', 'theol']],
#  ['cnp01105937', []],
#  ['cnp01358036', ['anc_lang', 'math', 'med', 'prof']],
#  ['cnp01320637', ['math']],
#  ['cnp00444650', ['juri', 'math', 'prof']],
#  ['cnp01307458', ['anc_lang', 'astron', 'huma', 'math']],
#  ['cnp01301986', ['astron', 'cleric', 'math', 'prof']],
#  ['cnp01079978', ['math', 'med', 'prof']],
#  ['cnp01311921', ['astron', 'math', 'prof', 'scholar']],
#  ['cnp01880451', ['anc_lang', 'astron', 'liter']],
#  ['cnp01109829', ['math', 'med']],
#  ['cnp01920024', ['med']],
#  ['cnp00157873', ['math']],
#  ['cnp00485397', ['math', 'med', 'philo', 'phys', 'prof']],
#  ['cnp02105686', ['astron', 'histo', 'huma', 'math', 'scholar']],
#  ['cnp01879549', ['archi']],
#  ['cnp00416575', ['prof']],
#  ['cnp01124562', []],
#  ['cnp01358244', ['anc_lang', 'astrol', 'med']],
#  ['cnp01377638', ['inge', 'scholar']],
#  ['cnp01103897', []],
#  ['cnp01306733', ['liter', 'math', 'philo']],
#  ['cnp01880764', ['cleric', 'math']],
#  ['cnp00096056', ['anc_lang', 'math', 'philo', 'prof']],
#  ['cnp01291699', ['cleric', 'math', 'med', 'prof', 'theol']],
#  ['cnp01322847', ['math']],
#  ['cnp02162972', []],
#  ['cnp01303545', ['astrol', 'med', 'theol']],
#  ['cnp01082076', ['med', 'prof']],
#  ['cnp01045770', []],
#  ['cnp01113293', ['math', 'med', 'phys', 'prof']],
#  ['cnp01422536', ['math', 'prof']],
#  ['cnp01303513', ['math', 'prof', 'theol']],
#  ['cnp01355346', ['astron', 'histo', 'math', 'scholar']],
#  ['cnp01368065', ['astron', 'math']],
#  ['cnp00458518', ['artist', 'astron', 'cleric', 'math']],
#  ['cnp00571276', []],
#  ['cnp01468084', []],
#  ['cnp00962892', ['math', 'med', 'phys', 'prof']],
#  ['cnp02178661', ['scholar']],
#  ['cnp01237192', ['astron', 'philo']],
#  ['cnp01259618', ['anc_lang', 'archi', 'inge', 'math', 'prof']],
#  ['cnp01342652', ['anc_lang', 'inge', 'liter', 'math']],
#  ['cnp01919686', []],
#  ['cnp01919799', ['anc_lang', 'huma', 'math', 'med']],
#  ['cnp01309947', ['anc_lang', 'liter', 'math', 'theol']],
#  ['cnp00922870', ['inge']],
#  ['cnp01338415', ['astron', 'math', 'prof', 'theol']],
#  ['cnp01944825', []],
#  ['cnp01286849', []],
#  ['cnp01879400', ['anc_lang', 'huma', 'inge', 'math', 'philo', 'phys']],
#  ['cnp02163192', ['astron', 'math', 'med', 'prof']],
#  ['cnp00446750', ['huma', 'scholar']],
#  ['cnp01329248', ['anc_lang', 'histo', 'math']],
#  ['cnp02231369', ['scholar']],
#  ['cnp00481169', ['astrol', 'astron', 'geo_carto', 'math']],
#  ['cnp01467090', ['astron', 'math', 'philo']],
#  ['cnp01104779', ['math', 'prof']],
#  ['cnp01133177', ['geo_carto', 'math']],
#  ['cnp01377920', ['geo_carto', 'prof']],
#  ['cnp01328166', ['astrol', 'astron', 'geo_carto', 'math']],
#  ['cnp01291829', []],
#  ['cnp01356171', ['astron', 'histo']],
#  ['cnp02237779', ['astrol', 'astron', 'huma', 'math', 'prof', 'scholar']],
#  ['cnp01316739', ['histo', 'huma', 'math']],
#  ['cnp02222256', ['anc_lang', 'astron', 'math']],
#  ['cnp00444503', ['astrol', 'astron', 'huma', 'math', 'med', 'prof']],
#  ['cnp01359016', ['huma', 'med', 'prof']],
#  ['cnp01895099', ['math', 'med', 'prof', 'scholar']],
#  ['cnp01878530', ['math', 'prof']],
#  ['cnp00369337', ['med', 'prof']],
#  ['cnp00444510', ['prof', 'theol']],
#  ['cnp01343086', ['anc_lang', 'astron', 'math', 'phys']],
#  ['cnp01876902', ['astron', 'math', 'med', 'theol']],
#  ['cnp01877738', ['math', 'phys', 'prof', 'scholar']],
#  ['cnp00384901', ['math', 'med', 'prof']],
#  ['cnp00475665', ['anc_lang', 'cleric', 'huma', 'math', 'theol']],
#  ['cnp00386604', ['math', 'med', 'scholar']],
#  ['cnp00883349', ['astron', 'math', 'med', 'prof']],
#  ['cnp01327326', ['anc_lang', 'math', 'theol']],
#  ['cnp00094435', []],
#  ['cnp01344864', ['math', 'med', 'prof']],
#  ['cnp01024644', ['cleric', 'theol']],
#  ['cnp01307826', ['math']],
#  ['cnp01054493', ['med', 'theol']],
#  ['cnp01273329', ['astron', 'cleric', 'theol']],
#  ['cnp01920011', ['med', 'philo']],
#  ['cnp00543426', ['astron', 'math', 'scholar']],
#  ['cnp01103907', []],
#  ['cnp00366743', ['artist', 'astron', 'cleric', 'math']],
#  ['cnp00099596', []],
#  ['cnp01330272', ['cleric', 'math', 'philo', 'prof']],
#  ['cnp00976839', ['astron', 'cleric']],
#  ['cnp00951038', ['astron', 'cleric', 'math', 'prof']],
#  ['cnp00394836', ['anc_lang', 'astron', 'philo', 'phys']],
#  ['cnp02163119', ['math', 'prof']],
#  ['cnp01327958', ['astron', 'math', 'med', 'prof']],
#  ['cnp00424447', ['astrol', 'math', 'philo', 'prof']],
#  ['cnp01879023',
#   ['anc_lang', 'cleric', 'geo_carto', 'histo', 'math', 'prof', 'theol']],
#  ['cnp01347493', ['anc_lang', 'astron', 'math', 'prof']],
#  ['cnp01900808', ['astron', 'philo', 'prof']],
#  ['cnp01233501', ['geo_carto', 'inge', 'math']],
#  ['cnp01395469', ['astron', 'huma', 'liter', 'math', 'philo']],
#  ['cnp02143831', ['math']],
#  ['cnp01340415', ['astron', 'math', 'theol']],
#  ['cnp00871211', ['cleric', 'math', 'prof']],
#  ['cnp00468695', ['math', 'phys']],
#  ['cnp01406042', ['archi', 'cleric', 'math', 'phys', 'prof', 'theol']],
#  ['cnp00877897', []],
#  ['cnp01106465', []],
#  ['cnp01919647', ['anc_lang', 'histo', 'liter', 'prof']],
#  ['cnp00404027', ['math', 'med', 'prof', 'scholar']],
#  ['cnp01358327', ['math', 'prof', 'scholar']],
#  ['cnp00892467', ['med']],
#  ['cnp02163051', ['cleric', 'math', 'theol']],
#  ['cnp01908712', ['cleric', 'math', 'philo', 'phys', 'prof']],
#  ['cnp01408867', ['archi', 'astron', 'inge', 'math']],
#  ['cnp01108514', ['astron', 'theol']],
#  ['cnp01327988', ['astron', 'juri', 'math', 'med', 'prof']],
#  ['cnp01355841', ['astron']],
#  ['cnp01208565', ['astron', 'huma', 'philo', 'prof', 'scholar', 'theol']],
#  ['cnp01876214', ['anc_lang', 'math', 'philo', 'prof']],
#  ['cnp01378567', ['geo_carto', 'histo', 'math']],
#  ['cnp01355990', ['archi', 'artist', 'astrol', 'huma', 'math']],
#  ['cnp01379493', ['archi', 'artist', 'geo_carto']],
#  ['cnp01321061', ['archi', 'math']],
#  ['cnp01421274', ['math', 'med']],
#  ['cnp01233301', []],
#  ['cnp00414862', ['geo_carto', 'math']],
#  ['cnp01877766', ['math', 'phys', 'scholar']],
#  ['cnp01328010', ['math', 'med', 'phys', 'prof']],
#  ['cnp00401494', []],
#  ['cnp00990253', ['cleric', 'math', 'med', 'theol']],
#  ['cnp00946324', ['math']],
#  ['cnp00519261', ['astron']],
#  ['cnp01073264', ['cleric']],
#  ['cnp01920059', ['math', 'med']],
#  ['cnp01026086', ['astron', 'liter', 'math', 'med', 'prof']],
#  ['cnp00951475', ['math', 'prof']],
#  ['cnp00370488', ['cleric', 'math']],
#  ['cnp02224706', ['astron', 'math', 'med', 'scholar']],
#  ['cnp01908276', ['astron', 'geo_carto', 'huma', 'liter', 'math', 'scholar']],
#  ['cnp01351342', ['math']],
#  ['cnp01919735', ['prof']],
#  ['cnp00125588', ['cleric', 'math', 'theol']],
#  ['cnp00386550', ['astron', 'math']],
#  ['cnp01399888', ['math']],
#  ['cnp01121780', []],
#  ['cnp01919933', ['cleric', 'math']],
#  ['cnp02330678', []],
#  ['cnp00125422', ['astrol', 'astron', 'cleric', 'math']],
#  ['cnp01395468', ['astron', 'math', 'med', 'philo']],
#  ['cnp01877518', ['math', 'prof']],
#  ['cnp00455882', ['math']],
#  ['cnp01475871', ['archi', 'inge', 'math', 'prof']],
#  ['cnp01391905', ['astron', 'geo_carto', 'math', 'med', 'prof']],
#  ['cnp01917023', ['anc_lang', 'astron']],
#  ['cnp01391968', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp00370784', ['anc_lang', 'huma', 'math', 'scholar']],
#  ['cnp02094405', ['math', 'med']],
#  ['cnp00980603', ['cleric', 'huma', 'math']],
#  ['cnp01018318', []],
#  ['cnp00506076', ['math', 'prof', 'theol']],
#  ['cnp00998676', ['astron']],
#  ['cnp00951955', ['math', 'prof']],
#  ['cnp01920892', ['anc_lang', 'astron', 'histo', 'math', 'prof']],
#  ['cnp01351361', ['cleric', 'math', 'philo', 'prof']],
#  ['cnp00623575', ['astrol', 'med']],
#  ['cnp01093544', ['math', 'med']],
#  ['cnp01002233', ['cleric', 'math', 'prof']],
#  ['cnp01318008',
#   ['anc_lang', 'astrol', 'astron', 'liter', 'math', 'med', 'prof']],
#  ['cnp01330261', ['astrol', 'astron']],
#  ['cnp00930944', []],
#  ['cnp00108734', ['astron', 'math']],
#  ['cnp01920048', ['astrol', 'astron', 'med', 'theol']],
#  ['cnp00390667', ['math', 'philo', 'phys', 'prof']],
#  ['cnp01344682', ['astrol', 'inge', 'philo', 'phys', 'scholar', 'theol']],
#  ['cnp01377073', ['anc_lang', 'astron', 'liter']],
#  ['cnp00475681', ['cleric', 'math', 'theol']],
#  ['cnp01313208', ['cleric', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01334817',
#   ['astron',
#    'huma',
#    'liter',
#    'math',
#    'med',
#    'philo',
#    'phys',
#    'prof',
#    'scholar']],
#  ['cnp01374654', ['math', 'med', 'philo', 'prof']],
#  ['cnp00389786', ['anc_lang', 'math', 'prof']],
#  ['cnp00385731', ['inge']],
#  ['cnp01273893', ['math']],
#  ['cnp01316924', ['math', 'theol']],
#  ['cnp01899827', ['inge', 'math', 'prof']],
#  ['cnp01045073', ['math', 'prof']],
#  ['cnp01304679', ['math', 'prof']],
#  ['cnp01303999', ['astron', 'cleric']],
#  ['cnp01377125', ['math', 'phys', 'prof', 'theol']],
#  ['cnp01322085', ['math', 'philo', 'phys', 'prof']],
#  ['cnp00969971', []],
#  ['cnp00389349', ['math', 'prof']],
#  ['cnp00504169', []],
#  ['cnp02149411', ['archi', 'astrol', 'geo_carto', 'math']],
#  ['cnp00921622', ['archi', 'cleric', 'math', 'prof']],
#  ['cnp01327704', ['astron', 'cleric', 'liter', 'philo', 'prof', 'theol']],
#  ['cnp01033200', ['geo_carto', 'math']],
#  ['cnp00507343', []],
#  ['cnp01901801', ['anc_lang', 'inge', 'math']],
#  ['cnp02062689', ['cleric', 'math']],
#  ['cnp01291828', ['math']],
#  ['cnp02230350', ['anc_lang', 'astron', 'math', 'prof']],
#  ['cnp00398978', ['huma', 'prof']],
#  ['cnp00388107', ['math', 'med', 'prof', 'theol']],
#  ['cnp00390875', []],
#  ['cnp01368847', ['artist']],
#  ['cnp01335791', ['astron', 'math', 'med', 'philo']],
#  ['cnp01317013', ['archi', 'inge', 'math']],
#  ['cnp00447681', ['anc_lang', 'math', 'prof', 'scholar']],
#  ['cnp01440545', ['archi', 'artist', 'math']],
#  ['cnp01089507', ['astron', 'math']],
#  ['cnp00466008', ['astrol', 'astron', 'med']],
#  ['cnp00295424', ['histo', 'huma', 'juri', 'liter', 'math', 'philo', 'prof']],
#  ['cnp01026399', ['math', 'philo']],
#  ['cnp00458133', ['math', 'theol']],
#  ['cnp00497608', ['cleric']],
#  ['cnp00918436', ['astron', 'cleric', 'juri', 'math']],
#  ['cnp01319583', ['astron', 'math', 'prof']],
#  ['cnp00918450', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01390435', ['inge', 'math']],
#  ['cnp02205996', []],
#  ['cnp02206734', ['med']],
#  ['cnp01053665', ['anc_lang', 'math', 'prof', 'theol']],
#  ['cnp00390534', ['math', 'med', 'prof']],
#  ['cnp01348997', ['liter', 'math', 'philo']],
#  ['cnp01339954', ['math', 'philo', 'prof', 'theol']],
#  ['cnp02239623', ['astrol', 'astron', 'geo_carto', 'math']],
#  ['cnp01325603', ['inge', 'math']],
#  ['cnp01919813', ['astrol', 'math']],
#  ['cnp01341138', ['anc_lang', 'cleric', 'huma', 'math', 'prof']],
#  ['cnp02163280', []],
#  ['cnp01921111', ['anc_lang', 'math', 'philo', 'scholar']],
#  ['cnp00452326', ['astrol', 'math', 'med', 'phys', 'prof']],
#  ['cnp01338526', ['astron', 'math', 'med', 'prof']],
#  ['cnp01877772', ['anc_lang', 'astron', 'math', 'med']],
#  ['cnp02335717', ['astron', 'cleric', 'math']],
#  ['cnp02069815', ['prof']],
#  ['cnp00461448', ['cleric', 'math']],
#  ['cnp02234984', ['anc_lang', 'astron', 'math', 'prof']],
#  ['cnp01364670', ['astron', 'math']],
#  ['cnp01878958', ['math', 'med', 'philo']],
#  ['cnp00389779', ['astrol', 'astron', 'math', 'phys', 'prof']],
#  ['cnp00401645', ['anc_lang', 'astron', 'cleric', 'math', 'prof']],
#  ['cnp01093384', ['math']],
#  ['cnp01918226',
#   ['astron', 'cleric', 'histo', 'liter', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00617340', ['geo_carto', 'math', 'phys']],
#  ['cnp02223923', ['geo_carto', 'math', 'phys']],
#  ['cnp00473662', ['astron', 'cleric', 'philo', 'scholar']],
#  ['cnp02163183', ['astron', 'math', 'theol']],
#  ['cnp02293390', ['astron', 'math']],
#  ['cnp00649901', ['math', 'prof']],
#  ['cnp01003527', ['math', 'philo', 'prof']],
#  ['cnp01085022', ['math', 'philo', 'prof']],
#  ['cnp01487024', ['math']],
#  ['cnp00384916', ['anc_lang', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00689671',
#   ['cleric', 'math', 'philo', 'phys', 'prof', 'scholar', 'theol']],
#  ['cnp01328238', ['astron', 'math', 'med', 'prof']],
#  ['cnp01321618', ['anc_lang', 'cleric', 'math', 'prof']],
#  ['cnp01470260', ['cleric', 'math', 'philo', 'prof']],
#  ['cnp02063829', ['math']],
#  ['cnp01344806', ['math']],
#  ['cnp01337555', ['astrol', 'astron', 'histo', 'liter', 'math', 'theol']],
#  ['cnp00951915', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp00064282', ['astron', 'math']],
#  ['cnp01316530', ['math']],
#  ['cnp01323244', ['astron', 'math', 'med', 'philo', 'prof']],
#  ['cnp00702380', ['astrol', 'astron']],
#  ['cnp00445951', ['cleric', 'prof', 'theol']],
#  ['cnp01330172', ['cleric', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01919746', ['astron', 'math']],
#  ['cnp01323399', ['anc_lang', 'astrol', 'med']],
#  ['cnp01939722', ['math', 'philo']],
#  ['cnp00105837', ['math', 'prof']],
#  ['cnp00506366', ['astron', 'math', 'med']],
#  ['cnp02236952', ['astrol', 'math', 'prof']],
#  ['cnp02230372', ['anc_lang', 'juri', 'math']],
#  ['cnp01327695', ['astron', 'inge']],
#  ['cnp01345096', ['astron', 'math', 'theol']],
#  ['cnp01358202', ['anc_lang', 'astron', 'math', 'prof']],
#  ['cnp01341055', ['archi', 'huma', 'math', 'philo', 'theol']],
#  ['cnp02232803', ['math', 'philo', 'prof', 'theol']],
#  ['cnp01391658', ['geo_carto', 'math']],
#  ['cnp01199180', ['cleric', 'math', 'philo']],
#  ['cnp01002799', ['math', 'prof', 'theol']],
#  ['cnp01229337', ['astron', 'juri', 'math', 'prof']],
#  ['cnp02230529', ['cleric', 'math', 'prof']],
#  ['cnp00283188', ['astrol', 'cleric']],
#  ['cnp00388517', ['astron', 'math', 'prof']],
#  ['cnp02261078', ['astron']],
#  ['cnp01345246', ['math', 'med', 'philo', 'scholar']],
#  ['cnp02104967', ['cleric', 'math', 'philo', 'theol']],
#  ['cnp02236239', ['anc_lang', 'math', 'phys', 'prof']],
#  ['cnp00386587', ['math', 'prof', 'theol']],
#  ['cnp00876263', ['math', 'prof']],
#  ['cnp01908394', ['artist']],
#  ['cnp01392446', ['anc_lang', 'cleric', 'geo_carto', 'math', 'prof']],
#  ['cnp01377339', ['astron']],
#  ['cnp01919715', ['astrol']],
#  ['cnp01470045', ['archi', 'prof']],
#  ['cnp01325201', ['astron']],
#  ['cnp00611392', ['juri', 'math']],
#  ['cnp01380775', ['cleric', 'liter']],
#  ['cnp00106298', ['astron', 'math', 'med']],
#  ['cnp00483287', ['cleric', 'math', 'prof']],
#  ['cnp01341135', ['math', 'phys']],
#  ['cnp01483154', ['astron', 'cleric', 'math', 'philo', 'phys', 'prof']],
#  ['cnp00496933', ['math', 'theol']],
#  ['cnp01375612', ['anc_lang', 'math']],
#  ['cnp00352036', ['astrol', 'astron', 'math']],
#  ['cnp01127978', []],
#  ['cnp01324836', []],
#  ['cnp00387106', ['astrol', 'histo', 'math', 'med', 'prof']],
#  ['cnp00433134', ['math', 'med', 'prof']],
#  ['cnp00399615', ['prof']],
#  ['cnp01435092', ['math', 'med', 'prof', 'theol']],
#  ['cnp01919694', ['astrol', 'astron']],
#  ['cnp00347201', ['cleric', 'theol']],
#  ['cnp01012117', ['astrol', 'theol']],
#  ['cnp00364411', ['philo', 'prof', 'theol']],
#  ['cnp02193879', []],
#  ['cnp01469355', ['anc_lang', 'math', 'prof', 'theol']],
#  ['cnp00432861', ['juri', 'prof']],
#  ['cnp01364652', ['anc_lang', 'astrol', 'histo']],
#  ['cnp00390888', ['cleric', 'math', 'phys']],
#  ['cnp00482504', ['anc_lang', 'liter', 'med']],
#  ['cnp01330573', ['archi', 'inge', 'math', 'med', 'prof']],
#  ['cnp00886194', []],
#  ['cnp00380320', ['math', 'med', 'philo', 'prof']],
#  ['cnp01002798', ['prof']],
#  ['cnp00038260', ['anc_lang', 'philo', 'phys']],
#  ['cnp00877968', ['math', 'philo', 'prof', 'theol']],
#  ['cnp00391433', ['astrol', 'astron', 'math', 'med']],
#  ['cnp01340180', ['astron', 'math']],
#  ['cnp01010326', ['cleric', 'math', 'prof']],
#  ['cnp00069034', ['astron', 'math', 'prof']],
#  ['cnp00474060', ['astron', 'med', 'philo', 'phys', 'prof']],
#  ['cnp01094218', ['math', 'philo', 'phys', 'prof']],
#  ['cnp02235964', ['anc_lang', 'astrol', 'huma', 'med', 'philo']],
#  ['cnp00454903', ['math', 'prof']],
#  ['cnp01318964', ['astron', 'theol']],
#  ['cnp02327523', ['cleric', 'math', 'prof']],
#  ['cnp01920211', ['astron', 'geo_carto', 'huma', 'phys', 'scholar']],
#  ['cnp01373606', []],
#  ['cnp01323643',
#   ['anc_lang', 'artist', 'histo', 'liter', 'math', 'prof', 'theol']],
#  ['cnp00930960', ['cleric', 'math', 'prof']],
#  ['cnp01992297', ['astron', 'cleric', 'math', 'prof']],
#  ['cnp00368388', ['anc_lang', 'prof']],
#  ['cnp01364676', ['astron', 'math', 'phys']],
#  ['cnp01320598', ['anc_lang', 'cleric', 'inge', 'math', 'philo', 'prof']],
#  ['cnp01320899', ['anc_lang', 'cleric', 'math', 'philo', 'prof']],
#  ['cnp00147670', ['anc_lang', 'math']],
#  ['cnp02154944', []],
#  ['cnp01389635',
#   ['anc_lang', 'cleric', 'histo', 'math', 'philo', 'phys', 'prof']],
#  ['cnp02335307', ['astron', 'histo', 'theol']],
#  ['cnp02244888', []],
#  ['cnp01479020', ['huma', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01010218', ['prof']],
#  ['cnp01440456', ['archi', 'math', 'philo']],
#  ['cnp01316503', ['juri', 'math', 'med', 'phys', 'prof']],
#  ['cnp01481978', ['anc_lang', 'astron']],
#  ['cnp00506412', ['astron']],
#  ['cnp01370532', ['math']],
#  ['cnp01358935', ['math', 'prof', 'theol']],
#  ['cnp02338184', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp00385275', []],
#  ['cnp01890712', ['anc_lang', 'astron', 'math', 'prof']],
#  ['cnp00669927', ['artist', 'astron']],
#  ['cnp00019029', ['cleric', 'liter', 'math', 'prof', 'scholar', 'theol']],
#  ['cnp01476352', ['astron', 'liter', 'math', 'phys']],
#  ['cnp01914334', ['inge']],
#  ['cnp00952066', ['huma', 'math', 'prof', 'theol']],
#  ['cnp01919643', []],
#  ['cnp01338801', ['anc_lang', 'liter', 'math', 'theol']],
#  ['cnp00951195', ['astron', 'cleric', 'math']],
#  ['cnp00434558', ['math', 'philo', 'prof']],
#  ['cnp01391974', ['geo_carto', 'inge', 'math']],
#  ['cnp01159238', ['anc_lang', 'math', 'prof']],
#  ['cnp00950513', []],
#  ['cnp01311444', ['anc_lang', 'cleric', 'math', 'scholar']],
#  ['cnp00455142', ['juri', 'math', 'prof', 'scholar']],
#  ['cnp00471549', ['astron', 'math', 'phys', 'prof']],
#  ['cnp00833377', ['math', 'med']],
#  ['cnp01891255', ['cleric', 'histo', 'juri', 'math']],
#  ['cnp02068029', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01497657', ['math', 'prof', 'theol']],
#  ['cnp01337449', ['astron', 'math', 'med']],
#  ['cnp00400188', ['astron', 'math']],
#  ['cnp00951338', ['astrol', 'geo_carto', 'math', 'med']],
#  ['cnp01377626', ['math', 'philo', 'prof']],
#  ['cnp01390742', ['math', 'med']],
#  ['cnp00597936', []],
#  ['cnp01390739', ['anc_lang', 'inge', 'math', 'prof']],
#  ['cnp00952457', ['anc_lang', 'math', 'prof']],
#  ['cnp02230304', ['astron', 'liter']],
#  ['cnp02183983', ['astron', 'prof']],
#  ['cnp01481855',
#   ['artist', 'astron', 'cleric', 'juri', 'math', 'prof', 'scholar']],
#  ['cnp00537706', ['math', 'prof']],
#  ['cnp01439830', ['anc_lang', 'astrol', 'math', 'philo', 'phys', 'prof']],
#  ['cnp00369131', ['cleric', 'theol']],
#  ['cnp01289741', ['astron', 'cleric', 'huma']],
#  ['cnp00993973', ['prof']],
#  ['cnp01267785', ['astron', 'cleric', 'theol']],
#  ['cnp01049147', ['math', 'med', 'philo', 'prof']],
#  ['cnp00908508', ['inge', 'math']],
#  ['cnp01316493', ['math']],
#  ['cnp01391574', ['math', 'theol']],
#  ['cnp00371858', ['math', 'med', 'philo', 'prof']],
#  ['cnp01440125', ['artist', 'astron', 'math']],
#  ['cnp02179557', []],
#  ['cnp01919770', ['astrol']],
#  ['cnp01919841', ['astron']],
#  ['cnp01329452', ['anc_lang', 'histo', 'liter']],
#  ['cnp01391697', ['geo_carto', 'math']],
#  ['cnp00946101', ['cleric', 'math', 'philo', 'scholar']],
#  ['cnp02121737', []],
#  ['cnp01392357', ['astron', 'math', 'philo']],
#  ['cnp00950867', ['math', 'prof', 'theol']],
#  ['cnp00387057', ['math', 'prof', 'theol']],
#  ['cnp00967216', ['huma', 'math', 'prof']],
#  ['cnp01327984', ['archi', 'artist', 'astron', 'math', 'prof']],
#  ['cnp01324799', ['cleric', 'philo', 'scholar']],
#  ['cnp01322061', ['cleric', 'liter', 'math', 'prof']],
#  ['cnp00937233', ['juri', 'math', 'prof', 'theol']],
#  ['cnp00469354', ['scholar']],
#  ['cnp01471432', ['astron', 'math', 'phys']],
#  ['cnp00681549', ['anc_lang', 'math', 'prof']],
#  ['cnp00557114', ['astron', 'cleric', 'prof']],
#  ['cnp00301902', ['med', 'prof', 'scholar']],
#  ['cnp01940714', ['med', 'prof', 'scholar']],
#  ['cnp00670663', ['artist', 'liter', 'math', 'prof']],
#  ['cnp00388939', ['math', 'med', 'philo']],
#  ['cnp00419809', ['math', 'med', 'philo', 'prof', 'scholar']],
#  ['cnp01316895', ['math', 'phys']],
#  ['cnp00438816', ['cleric', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01338123', ['astron']],
#  ['cnp00400398', ['astron', 'juri']],
#  ['cnp02330985', ['math', 'prof']],
#  ['cnp01310386', ['anc_lang', 'astron', 'cleric', 'liter', 'math']],
#  ['cnp01905556', ['anc_lang', 'astron', 'math', 'theol']],
#  ['cnp00343317', ['math', 'philo', 'prof', 'theol']],
#  ['cnp00395926', ['math', 'med', 'phys', 'prof', 'scholar']],
#  ['cnp00467311', ['philo']],
#  ['cnp01498919', ['juri', 'math', 'philo', 'prof', 'scholar']],
#  ['cnp00950470', ['math']],
#  ['cnp02294466', ['math', 'phys', 'prof', 'theol']],
#  ['cnp01093464', []],
#  ['cnp02226095', ['astron']],
#  ['cnp00872719', ['math', 'prof']],
#  ['cnp01362737',
#   ['anc_lang',
#    'astron',
#    'cleric',
#    'huma',
#    'liter',
#    'math',
#    'philo',
#    'phys',
#    'prof']],
#  ['cnp01363143', ['cleric', 'histo', 'huma', 'liter', 'math', 'prof']],
#  ['cnp00422532', ['anc_lang', 'cleric', 'huma', 'math']],
#  ['cnp00552352', ['artist', 'juri', 'math']],
#  ['cnp00449362', ['phys', 'prof']],
#  ['cnp01989297', ['math', 'prof']],
#  ['cnp02229154', ['artist', 'math', 'philo']],
#  ['cnp01005388', ['prof']],
#  ['cnp00449554', ['math', 'prof']],
#  ['cnp02327618', ['cleric', 'prof']],
#  ['cnp01273643', ['math']],
#  ['cnp00846462', ['astron']],
#  ['cnp01281146', ['archi', 'artist', 'huma', 'math']],
#  ['cnp01427020', []],
#  ['cnp01324750',
#   ['anc_lang', 'astron', 'math', 'philo', 'phys', 'prof', 'theol']],
#  ['cnp01341195', ['cleric', 'math', 'prof', 'scholar']],
#  ['cnp02328440', ['math']],
#  ['cnp01403284', ['astron', 'inge', 'math']],
#  ['cnp01320800', ['scholar']],
#  ['cnp01941103', ['juri', 'math']],
#  ['cnp00855016', ['prof']],
#  ['cnp01511009', ['astron', 'math', 'prof']],
#  ['cnp02163135', []],
#  ['cnp00978103', ['scholar']],
#  ['cnp01939693', ['inge']],
#  ['cnp00290787', ['anc_lang', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00399397', ['med', 'prof']],
#  ['cnp01358620', ['math']],
#  ['cnp01482767', ['math', 'philo', 'prof', 'theol']],
#  ['cnp00400516', []],
#  ['cnp01880566', ['cleric', 'huma', 'math']],
#  ['cnp01323883', ['astron', 'math', 'prof']],
#  ['cnp01919745', ['astrol']],
#  ['cnp02163098', ['astrol']],
#  ['cnp02338026', ['math', 'prof']],
#  ['cnp01306191', ['math', 'theol']],
#  ['cnp01325602', ['anc_lang', 'cleric', 'math']],
#  ['cnp02235906', ['med', 'prof', 'scholar']],
#  ['cnp00613664', ['cleric', 'math', 'philo', 'phys', 'prof', 'theol']],
#  ['cnp00390440', ['anc_lang', 'astron', 'math', 'med', 'prof']],
#  ['cnp01327562', ['astron', 'cleric', 'geo_carto', 'math']],
#  ['cnp02239207', ['astrol', 'math', 'philo', 'phys', 'prof', 'scholar']],
#  ['cnp01318599', ['math', 'prof']],
#  ['cnp01345497', ['anc_lang', 'cleric']],
#  ['cnp00345796', []],
#  ['cnp00940854', ['med', 'prof']],
#  ['cnp01130536', ['math', 'prof']],
#  ['cnp01358501', ['math', 'med', 'phys', 'scholar']],
#  ['cnp01344695', ['anc_lang', 'astron', 'math', 'philo', 'phys', 'scholar']],
#  ['cnp01310208', ['astron', 'geo_carto']],
#  ['cnp01438995', ['huma', 'math', 'philo']],
#  ['cnp00950783', ['math', 'prof']],
#  ['cnp01073918', ['anc_lang', 'philo', 'prof', 'theol']],
#  ['cnp01323465', ['anc_lang', 'cleric', 'math', 'prof']],
#  ['cnp01381608', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp00424957', ['math', 'prof']],
#  ['cnp01049625', []],
#  ['cnp01331399', ['astron']],
#  ['cnp00289676', ['math']],
#  ['cnp00611867', ['astron', 'math', 'prof']],
#  ['cnp00459835', ['astron', 'math', 'med', 'prof', 'theol']],
#  ['cnp01921159', ['math', 'prof']],
#  ['cnp01379874', ['astron', 'math', 'prof']],
#  ['cnp01391847', ['astron', 'math']],
#  ['cnp02270525', ['cleric', 'math', 'philo', 'prof']],
#  ['cnp01208519', ['prof']],
#  ['cnp01282497', []],
#  ['cnp01065866', ['math']],
#  ['cnp01386056',
#   ['anc_lang', 'artist', 'astron', 'liter', 'math', 'med', 'prof']],
#  ['cnp01884314',
#   ['anc_lang', 'astron', 'histo', 'huma', 'phys', 'scholar', 'theol']],
#  ['cnp01033546', ['math', 'prof']],
#  ['cnp01321930', ['anc_lang', 'juri', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00526372', ['prof']],
#  ['cnp00376916', ['math', 'phys', 'prof']],
#  ['cnp01373057', ['archi', 'math', 'prof']],
#  ['cnp00394712', ['astron', 'math', 'phys', 'scholar']],
#  ['cnp01320816', ['huma']],
#  ['cnp00634712', ['cleric', 'prof']],
#  ['cnp00474052', ['math', 'philo', 'theol']],
#  ['cnp02242965', ['math', 'prof']],
#  ['cnp01956587', ['prof']],
#  ['cnp02087919', ['archi']],
#  ['cnp02134621', ['cleric', 'huma']],
#  ['cnp02328026', ['prof']],
#  ['cnp02230235', ['math']],
#  ['cnp02266642', []],
#  ['cnp01336175', ['cleric', 'theol']],
#  ['cnp01337053', ['math', 'med', 'phys', 'prof']],
#  ['cnp01436478', ['math', 'med', 'phys']],
#  ['cnp01914406', ['math', 'philo']],
#  ['cnp00386421', ['astron', 'cleric', 'math', 'theol']],
#  ['cnp00974393', ['prof']],
#  ['cnp01358615', ['math']],
#  ['cnp01511015', ['juri', 'math', 'prof']],
#  ['cnp01881153', ['liter']],
#  ['cnp00405665', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01371119', ['astron', 'geo_carto']],
#  ['cnp02329782', ['math', 'prof', 'scholar']],
#  ['cnp01392135', ['astron', 'cleric', 'geo_carto']],
#  ['cnp01271878', ['math', 'philo', 'theol']],
#  ['cnp01338632', ['math']],
#  ['cnp01905866', ['math']],
#  ['cnp00406843', ['astron', 'huma']],
#  ['cnp00389082', ['astrol', 'astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01267813', ['artist']],
#  ['cnp01920140', ['anc_lang', 'math', 'philo', 'prof']],
#  ['cnp01372944', ['astron', 'math', 'phys']],
#  ['cnp01326948',
#   ['anc_lang', 'cleric', 'liter', 'math', 'philo', 'prof', 'theol']],
#  ['cnp01340039', ['astron', 'math', 'prof']],
#  ['cnp01150291', ['cleric', 'prof']],
#  ['cnp01501297', ['math', 'med', 'philo', 'phys', 'prof']],
#  ['cnp00973415', ['math', 'prof']],
#  ['cnp01938795', []],
#  ['cnp00396411', ['astron', 'geo_carto', 'histo', 'med', 'scholar']],
#  ['cnp01341197', ['anc_lang', 'astron', 'histo', 'med', 'phys', 'scholar']],
#  ['cnp01166090', ['cleric', 'math']],
#  ['cnp00387315', ['math', 'prof']],
#  ['cnp01360525', ['cleric', 'math']],
#  ['cnp01330343', ['anc_lang', 'astron', 'huma', 'liter', 'math']],
#  ['cnp00390358', ['math', 'phys', 'prof', 'scholar', 'theol']],
#  ['cnp01006233', ['math', 'med', 'phys', 'prof']],
#  ['cnp01391728', ['astron', 'geo_carto']],
#  ['cnp01416537', ['math', 'phys', 'theol']],
#  ['cnp02306744', ['math', 'prof']],
#  ['cnp00458613', ['prof']],
#  ['cnp00408365', ['archi', 'math', 'phys', 'scholar']],
#  ['cnp02306517', ['cleric', 'math', 'prof']],
#  ['cnp01391475', ['juri', 'prof']],
#  ['cnp01128300', []],
#  ['cnp01397344', ['astron', 'math', 'prof']],
#  ['cnp01310754', ['astron', 'math']],
#  ['cnp01323455', ['huma', 'math']],
#  ['cnp01327945', ['anc_lang', 'astron', 'geo_carto', 'math', 'phys', 'prof']],
#  ['cnp01353680', ['anc_lang', 'juri', 'math', 'prof', 'theol']],
#  ['cnp01310736', ['astron']],
#  ['cnp00620144', ['math', 'phys', 'prof']],
#  ['cnp02187878', []],
#  ['cnp01907258', ['math', 'prof']],
#  ['cnp00938379', ['philo', 'prof']],
#  ['cnp00935714', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01355792', ['math', 'philo', 'prof']],
#  ['cnp01956097', ['huma']],
#  ['cnp01337942', ['math', 'philo', 'phys', 'prof', 'theol']],
#  ['cnp01425174', ['astron', 'math', 'theol']],
#  ['cnp01341011', ['math']],
#  ['cnp01296840', ['cleric', 'math', 'philo', 'prof']],
#  ['cnp00482858', ['philo', 'prof', 'theol']],
#  ['cnp01371511', ['math', 'philo', 'scholar', 'theol']],
#  ['cnp01406883', ['math', 'prof', 'scholar', 'theol']],
#  ['cnp02168144', ['cleric', 'math', 'philo']],
#  ['cnp01502265', ['cleric', 'theol']],
#  ['cnp01481635',
#   ['anc_lang', 'liter', 'math', 'philo', 'phys', 'prof', 'scholar']],
#  ['cnp01283791', ['cleric', 'math', 'prof']],
#  ['cnp01294650', ['math']],
#  ['cnp00555044', ['anc_lang', 'astron', 'cleric', 'math', 'prof']],
#  ['cnp01271242', ['math']],
#  ['cnp01427068', ['cleric', 'math']],
#  ['cnp01307036', ['cleric', 'huma', 'math', 'prof']],
#  ['cnp02213909', []],
#  ['cnp00395781', ['artist']],
#  ['cnp00382785', ['math', 'prof', 'theol']],
#  ['cnp01313448', ['math', 'scholar']],
#  ['cnp02238866', ['anc_lang', 'astron']],
#  ['cnp01386031', ['astron', 'math']],
#  ['cnp00959838', ['math', 'philo', 'prof', 'scholar']],
#  ['cnp01167338', ['cleric', 'math', 'prof']],
#  ['cnp01441824', ['geo_carto', 'histo', 'math']],
#  ['cnp00873272', ['astron', 'math', 'prof']],
#  ['cnp00420502', ['cleric']],
#  ['cnp02265415', ['astron']],
#  ['cnp01273354', ['astrol']],
#  ['cnp01229576', ['cleric', 'math', 'prof']],
#  ['cnp00155913', ['med']],
#  ['cnp01328111', ['anc_lang', 'math', 'phys']],
#  ['cnp01311691', ['astron', 'cleric']],
#  ['cnp02091188', ['astron', 'cleric']],
#  ['cnp01939035', ['astron']],
#  ['cnp01411736', ['anc_lang', 'math', 'phys', 'prof']],
#  ['cnp00149586', ['cleric', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00357110', []],
#  ['cnp00405760', ['cleric', 'math', 'philo']],
#  ['cnp01327508', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01355708', ['juri']],
#  ['cnp01331171', ['astron', 'liter', 'math', 'philo', 'phys', 'prof']],
#  ['cnp00616670', ['astron', 'geo_carto', 'math', 'phys', 'prof']],
#  ['cnp01340546', ['geo_carto', 'math']],
#  ['cnp01361348', ['astron', 'huma', 'math']],
#  ['cnp01167073', ['math']],
#  ['cnp01327525', ['astron', 'cleric', 'histo']],
#  ['cnp00978256', ['geo_carto', 'math', 'scholar']],
#  ['cnp00398351', ['math']],
#  ['cnp00989107', []],
#  ['cnp00934743', ['astron', 'math', 'prof', 'theol']],
#  ['cnp00454735', ['math', 'prof', 'theol']],
#  ['cnp01227314', ['math', 'prof']],
#  ['cnp02252448', ['astron', 'juri', 'math']],
#  ['cnp01364665',
#   ['anc_lang', 'astron', 'math', 'med', 'philo', 'phys', 'prof', 'scholar']],
#  ['cnp01127346', ['math', 'philo', 'prof']],
#  ['cnp01322254', ['juri', 'liter', 'prof', 'theol']],
#  ['cnp02210701', []],
#  ['cnp00421828', ['math', 'prof']],
#  ['cnp01979544', ['math', 'prof']],
#  ['cnp00951342', ['anc_lang', 'math', 'prof']],
#  ['cnp02163090', ['astron']],
#  ['cnp01281827', ['math', 'med', 'philo', 'prof']],
#  ['cnp00473300', ['cleric', 'math', 'phys']],
#  ['cnp00800049', ['astron', 'math']],
#  ['cnp01088897', ['juri', 'math']],
#  ['cnp02334268', ['math']],
#  ['cnp01370536', ['huma', 'med']],
#  ['cnp00102076', ['cleric']],
#  ['cnp01167258', []],
#  ['cnp01994802', ['math', 'med']],
#  ['cnp01422962', ['juri']],
#  ['cnp00472229', ['cleric', 'prof']],
#  ['cnp01088135', ['cleric', 'math', 'philo']],
#  ['cnp00547788', ['math']],
#  ['cnp02071743', ['artist']],
#  ['cnp00105985', ['inge', 'math']],
#  ['cnp01304917', ['math', 'prof']],
#  ['cnp01317909', ['astron', 'math', 'philo', 'phys', 'scholar']],
#  ['cnp00416288', []],
#  ['cnp01375132', ['histo', 'math', 'prof']],
#  ['cnp00424400', ['med', 'scholar']],
#  ['cnp00381221', ['cleric', 'prof', 'theol']],
#  ['cnp00387676', ['math', 'philo', 'phys', 'prof']],
#  ['cnp01339506', ['math', 'philo', 'prof']],
#  ['cnp01885482', ['math', 'phys', 'prof', 'scholar']],
#  ['cnp00384742', ['astron', 'math', 'med', 'philo', 'phys', 'prof']],
#  ['cnp01336730', ['cleric', 'math', 'theol']],
#  ['cnp01260483', []],
#  ['cnp01229790', ['juri']],
#  ['cnp01340685', ['math', 'prof']],
#  ['cnp00475918', ['math', 'med', 'philo']],
#  ['cnp01387988', ['anc_lang', 'math', 'med', 'philo', 'prof']],
#  ['cnp02163844', ['astron']],
#  ['cnp00415975', ['math']],
#  ['cnp02181704', ['prof']],
#  ['cnp01142873', []],
#  ['cnp02308630', ['liter']],
#  ['cnp00415435', []],
#  ['cnp01406818', ['math']],
#  ['cnp01326430', ['inge', 'math']],
#  ['cnp01085443', ['juri', 'math', 'med', 'philo', 'phys', 'prof', 'scholar']],
#  ['cnp01132050', ['math', 'philo', 'prof']],
#  ['cnp00514820', ['math', 'med', 'phys', 'prof']],
#  ['cnp00387153', ['astron', 'math']],
#  ['cnp00390713', ['astron', 'math', 'phys', 'prof']],
#  ['cnp00961968', []],
#  ['cnp01324793', ['juri', 'math', 'philo', 'prof', 'scholar']],
#  ['cnp01310072', ['math']],
#  ['cnp01196433', ['prof']],
#  ['cnp01428444', ['astron', 'math', 'phys']],
#  ['cnp02069898', ['cleric']],
#  ['cnp02128642', ['geo_carto', 'math']],
#  ['cnp00381182', ['anc_lang', 'juri', 'math', 'philo', 'theol']],
#  ['cnp01331537', ['huma', 'math', 'prof']],
#  ['cnp00936828', ['math', 'prof']],
#  ['cnp01406268', ['math', 'philo', 'prof']],
#  ['cnp01496383',
#   ['anc_lang', 'artist', 'huma', 'juri', 'math', 'prof', 'scholar']],
#  ['cnp02294549', ['cleric', 'math', 'phys', 'prof']],
#  ['cnp00388799', ['math', 'philo', 'prof']],
#  ['cnp01327702', ['anc_lang', 'astron', 'math']],
#  ['cnp01006600', []],
#  ['cnp01423328', ['math', 'prof']],
#  ['cnp01443734', ['math', 'philo', 'prof']],
#  ['cnp01303858', ['math']],
#  ['cnp01332040', ['huma', 'math']]]

# %% [markdown]
# ## Join codes lists

# %%
joined_list = []
for poa in pers_orig_activities:
    ll = []
    for pa in  pers_activities:        
        if pa[0] == poa[0]:
            ll = poa[1] + pa[1]

    joined_list.append([poa[0], poa[1], list(set(ll))])

# %%
print(len(joined_list))
# Out:
# 1038

# %%
pprint.pprint(joined_list)
# Out:
# [['cnp01352012', ['theol'], ['theol']],
#  ['cnp02088071',
#   ['astrol', 'med', 'philo'],
#   ['huma', 'philo', 'astrol', 'med']],
#  ['cnp01881207',
#   ['philo', 'theol'],
#   ['prof', 'huma', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp01879247', ['huma', 'med'], ['prof', 'huma', 'philo', 'anc_lang', 'med']],
#  ['cnp00996213',
#   ['astrol', 'math', 'med', 'prof'],
#   ['prof', 'astrol', 'astron', 'math', 'med']],
#  ['cnp01320054',
#   ['astron', 'histo', 'scholar'],
#   ['scholar', 'histo', 'astron']],
#  ['cnp01363268', ['med'], ['huma', 'med']],
#  ['cnp01241028', [], []],
#  ['cnp00873006',
#   ['anc_lang_philol'],
#   ['cleric', 'anc_lang', 'math', 'anc_lang_philol']],
#  ['cnp01329886',
#   ['huma', 'liter', 'math', 'philo'],
#   ['huma', 'math', 'philo', 'anc_lang', 'liter']],
#  ['cnp01363122',
#   ['huma', 'math', 'philo', 'theol'],
#   ['huma', 'theol', 'math', 'philo', 'anc_lang', 'liter']],
#  ['cnp00350996', ['astron', 'med', 'theol'], ['theol', 'med', 'astron']],
#  ['cnp02222242', [], ['math', 'med']],
#  ['cnp01884261', [], []],
#  ['cnp00397446', ['geo_carto', 'math'], ['math', 'geo_carto']],
#  ['cnp01368034',
#   ['med', 'philo'],
#   ['prof', 'histo', 'philo', 'anc_lang', 'med', 'liter']],
#  ['cnp01335792',
#   ['philo', 'scholar'],
#   ['astron', 'math', 'philo', 'anc_lang', 'scholar', 'med']],
#  ['cnp00888506', ['prof', 'theol'], ['prof', 'math', 'philo', 'theol']],
#  ['cnp01879502', [], ['math']],
#  ['cnp00556047', [], []],
#  ['cnp01362970',
#   ['histo', 'philo'],
#   ['prof', 'histo', 'math', 'philo', 'anc_lang', 'med', 'liter']],
#  ['cnp01115869', ['math'], ['math']],
#  ['cnp00402391',
#   ['astron', 'geo_carto', 'math', 'prof'],
#   ['prof', 'math', 'geo_carto', 'astron']],
#  ['cnp01365166', ['med'], ['anc_lang', 'astrol', 'med', 'scholar']],
#  ['cnp02088587', ['med', 'theol'], ['theol', 'med', 'astron']],
#  ['cnp01409583', [], ['theol', 'astron']],
#  ['cnp01114322',
#   ['liter', 'math'],
#   ['huma', 'astrol', 'archi', 'math', 'scholar', 'liter']],
#  ['cnp00100623',
#   ['juri', 'liter', 'theol'],
#   ['juri', 'huma', 'theol', 'astron', 'liter']],
#  ['cnp01352888', ['astrol', 'med'], ['astrol', 'med']],
#  ['cnp01392374',
#   ['astron', 'cleric', 'math'],
#   ['cleric', 'geo_carto', 'math', 'astron']],
#  ['cnp01172052', ['artist', 'astron', 'geo_carto'], []],
#  ['cnp01876151',
#   ['astron', 'geo_carto', 'huma', 'math', 'theol'],
#   ['prof', 'geo_carto', 'huma', 'theol', 'astron', 'math']],
#  ['cnp01317063', ['artist', 'math'], ['artist', 'math']],
#  ['cnp01319857', ['prof'], ['prof']],
#  ['cnp00398396',
#   ['astrol', 'histo', 'med'],
#   ['huma', 'histo', 'astrol', 'med']],
#  ['cnp01471426',
#   ['astron', 'math', 'med', 'philo'],
#   ['juri', 'astron', 'math', 'philo', 'med']],
#  ['cnp00412417', ['math'], ['huma', 'math']],
#  ['cnp01875338', ['med'], ['med']],
#  ['cnp01470125', ['artist'], ['artist', 'archi']],
#  ['cnp01309925', [], ['prof', 'math', 'philo', 'astron']],
#  ['cnp01320896',
#   ['astron', 'cleric', 'geo_carto', 'math'],
#   ['prof', 'geo_carto', 'astron', 'math', 'anc_lang', 'cleric']],
#  ['cnp00400924', ['cleric', 'theol'], ['cleric', 'theol']],
#  ['cnp01876860',
#   ['med'],
#   ['prof',
#    'geo_carto',
#    'artist',
#    'huma',
#    'phys',
#    'theol',
#    'astron',
#    'math',
#    'philo',
#    'anc_lang',
#    'med']],
#  ['cnp01331039', [], ['huma', 'astron', 'philo', 'anc_lang', 'scholar']],
#  ['cnp01329937', ['archi', 'inge'], ['inge', 'archi', 'math']],
#  ['cnp01486719', ['astrol', 'med', 'theol'], ['astrol', 'theol', 'med']],
#  ['cnp01180030', ['archi', 'math'], ['math', 'archi']],
#  ['cnp01255966', [], ['huma', 'math']],
#  ['cnp01341438', [], ['anc_lang']],
#  ['cnp01880057', ['huma'], ['prof', 'huma']],
#  ['cnp01316341', ['med'], ['huma', 'philo', 'theol', 'med']],
#  ['cnp01233195', ['math'], ['math', 'histo']],
#  ['cnp01118781', ['astron', 'med'], ['astrol', 'med', 'astron']],
#  ['cnp01147469', ['astron', 'math'], ['math', 'astron']],
#  ['cnp00917420', ['math', 'theol'], ['prof', 'math', 'cleric', 'theol']],
#  ['cnp01120503', ['math'], ['prof', 'math']],
#  ['cnp00526061', [], ['archi']],
#  ['cnp01320560',
#   ['theol'],
#   ['prof', 'geo_carto', 'huma', 'theol', 'math', 'anc_lang']],
#  ['cnp02223694', [], ['prof', 'math', 'theol', 'astron']],
#  ['cnp01329458', ['theol'], ['huma', 'philo', 'math', 'theol']],
#  ['cnp01875480',
#   ['cleric', 'huma', 'math', 'theol'],
#   ['huma', 'theol', 'math', 'anc_lang', 'cleric']],
#  ['cnp02236633', ['math', 'prof', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp01919968', [], []],
#  ['cnp01877797', ['astron', 'math'], ['math', 'astron']],
#  ['cnp00639317', [], ['inge', 'geo_carto', 'math']],
#  ['cnp01884758', [], ['philo', 'astrol', 'med']],
#  ['cnp01330865',
#   ['anc_lang_philol',
#    'cleric',
#    'huma',
#    'math',
#    'med',
#    'philo',
#    'prof',
#    'scholar',
#    'theol'],
#   ['prof',
#    'scholar',
#    'huma',
#    'theol',
#    'math',
#    'philo',
#    'anc_lang',
#    'anc_lang_philol',
#    'cleric',
#    'med']],
#  ['cnp01313334', ['math', 'prof'], ['prof', 'math', 'huma', 'anc_lang']],
#  ['cnp01881119',
#   ['artist', 'astron', 'geo_carto', 'math'],
#   ['artist', 'math', 'geo_carto', 'astron']],
#  ['cnp01290195', [], ['prof', 'math']],
#  ['cnp01876551',
#   ['geo_carto', 'math', 'prof'],
#   ['prof', 'math', 'geo_carto', 'astron']],
#  ['cnp01019887', ['theol'], ['prof', 'cleric', 'theol']],
#  ['cnp01347892',
#   ['astron', 'geo_carto', 'math'],
#   ['math', 'geo_carto', 'astron']],
#  ['cnp01323680',
#   ['geo_carto', 'math', 'prof', 'theol'],
#   ['prof', 'math', 'geo_carto', 'theol']],
#  ['cnp01875467', ['med'], ['prof', 'math', 'philo', 'med']],
#  ['cnp01880016',
#   ['cleric', 'prof', 'theol'],
#   ['prof', 'theol', 'astron', 'math', 'anc_lang', 'cleric']],
#  ['cnp00579703', ['artist'], ['artist']],
#  ['cnp01443317',
#   ['astrol', 'histo', 'math'],
#   ['math', 'histo', 'astrol', 'liter']],
#  ['cnp01875826', ['huma', 'math'], ['huma', 'astrol', 'math']],
#  ['cnp00405470', ['math'], ['math']],
#  ['cnp00569865', ['archi'], ['archi']],
#  ['cnp01356340', ['inge', 'math', 'prof'], ['prof', 'inge', 'archi', 'math']],
#  ['cnp01350201', ['inge', 'math'], ['inge', 'philo', 'archi', 'math']],
#  ['cnp01876658',
#   ['theol'],
#   ['prof', 'archi', 'theol', 'math', 'anc_lang', 'inge']],
#  ['cnp01349348',
#   ['anc_lang_philol', 'scholar'],
#   ['anc_lang_philol', 'theol', 'math', 'philo', 'scholar']],
#  ['cnp01443388',
#   ['math', 'med', 'scholar'],
#   ['prof', 'phys', 'astron', 'math', 'scholar', 'med']],
#  ['cnp01121159', ['prof'], ['prof', 'math']],
#  ['cnp01392199', ['artist', 'geo_carto'], ['artist', 'geo_carto']],
#  ['cnp00545294', ['artist'], ['artist']],
#  ['cnp01875706', ['juri'], ['prof', 'huma', 'juri']],
#  ['cnp01084480', ['astron', 'math', 'prof'], []],
#  ['cnp00482208', ['archi', 'liter', 'math'], ['math', 'archi', 'liter']],
#  ['cnp01364712', ['artist'], ['artist', 'philo', 'med']],
#  ['cnp01112298', [], []],
#  ['cnp01114860', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp01437248',
#   ['astron', 'math', 'med', 'philo', 'scholar'],
#   ['astron', 'math', 'philo', 'scholar', 'med']],
#  ['cnp02156073', ['astron', 'math', 'philo'], ['math', 'philo', 'astron']],
#  ['cnp02078749', ['astron', 'math'], ['prof', 'math', 'astron']],
#  ['cnp01122000',
#   ['astrol', 'cleric', 'prof', 'theol'],
#   ['prof', 'astrol', 'theol', 'philo', 'cleric']],
#  ['cnp00950341', ['prof', 'theol'], ['prof', 'theol']],
#  ['cnp01179438', ['histo', 'med'], ['huma', 'histo', 'med']],
#  ['cnp01112480', ['med'], ['med']],
#  ['cnp01468914', [], ['huma', 'anc_lang', 'math', 'liter']],
#  ['cnp01345792', [], ['artist', 'math', 'archi']],
#  ['cnp01876067', [], ['artist', 'geo_carto']],
#  ['cnp01875828', ['theol'], ['prof', 'huma', 'theol', 'anc_lang', 'cleric']],
#  ['cnp01875825', ['cleric', 'theol'], ['prof', 'cleric', 'theol']],
#  ['cnp01877605',
#   ['astron', 'histo', 'med', 'phys'],
#   ['histo', 'phys', 'astron', 'anc_lang', 'med']],
#  ['cnp01336086', ['med'], ['philo', 'med']],
#  ['cnp00125017',
#   ['astrol', 'astron', 'med'],
#   ['math', 'astrol', 'med', 'astron']],
#  ['cnp01876979',
#   ['astron', 'math', 'med'],
#   ['prof', 'geo_carto', 'astron', 'math', 'anc_lang', 'scholar', 'med']],
#  ['cnp01334753',
#   ['liter', 'philo'],
#   ['prof', 'huma', 'astron', 'philo', 'anc_lang', 'liter']],
#  ['cnp01879181', ['math', 'med'], ['huma', 'math', 'anc_lang', 'med']],
#  ['cnp01875669', [], ['philo', 'histo', 'astrol', 'liter']],
#  ['cnp01361113', ['liter'], ['liter']],
#  ['cnp01352300', ['archi'], ['math', 'archi']],
#  ['cnp01307139',
#   ['math', 'philo', 'scholar'],
#   ['math', 'philo', 'anc_lang', 'scholar']],
#  ['cnp01363533', [], ['math', 'anc_lang', 'astrol']],
#  ['cnp01340478',
#   ['med'],
#   ['astrol', 'astron', 'math', 'anc_lang', 'med', 'liter']],
#  ['cnp01324006', ['huma'], ['prof', 'huma', 'astron', 'anc_lang', 'liter']],
#  ['cnp02239016', [], ['huma', 'phys', 'math']],
#  ['cnp01395548', ['astron'], ['math', 'philo', 'astrol', 'astron']],
#  ['cnp02163127', [], []],
#  ['cnp01292034', ['astrol'], []],
#  ['cnp01443254', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01355754',
#   ['geo_carto', 'math', 'philo', 'theol'],
#   ['math', 'philo', 'geo_carto', 'theol']],
#  ['cnp01875767',
#   ['astrol', 'math', 'med'],
#   ['math', 'anc_lang', 'astrol', 'med']],
#  ['cnp01876433',
#   ['cleric', 'prof', 'theol'],
#   ['prof', 'huma', 'theol', 'math', 'cleric', 'med']],
#  ['cnp01875723',
#   ['astron', 'math'],
#   ['geo_carto', 'theol', 'astron', 'math', 'med']],
#  ['cnp01323251',
#   ['huma', 'math', 'philo', 'prof'],
#   ['prof', 'huma', 'math', 'philo', 'anc_lang']],
#  ['cnp01120341', ['astrol', 'astron', 'math'], ['math', 'astrol', 'astron']],
#  ['cnp01387069', ['artist'], ['artist']],
#  ['cnp02170729', ['math', 'med', 'prof'], []],
#  ['cnp01337057', ['liter'], ['huma', 'math', 'liter']],
#  ['cnp01303529', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01124849', ['astron', 'math'], ['prof', 'math', 'astron']],
#  ['cnp01287286', ['astron', 'med'], ['med', 'astron']],
#  ['cnp01368037', [], ['histo', 'huma', 'anc_lang', 'math']],
#  ['cnp01875207', ['cleric', 'theol'], ['prof', 'cleric', 'theol']],
#  ['cnp01200592', ['geo_carto', 'math'], ['math', 'geo_carto']],
#  ['cnp02266756', [], ['anc_lang', 'astrol', 'med', 'liter']],
#  ['cnp02134922', ['math', 'med'], []],
#  ['cnp02230942', [], ['inge', 'math']],
#  ['cnp00989664',
#   ['anc_lang_philol', 'cleric', 'theol'],
#   ['cleric', 'anc_lang', 'theol', 'anc_lang_philol']],
#  ['cnp01875685', ['med', 'philo'], ['prof', 'math', 'philo', 'med']],
#  ['cnp01407758', [], ['med', 'astron']],
#  ['cnp01347099',
#   ['book', 'histo', 'juri'],
#   ['prof', 'histo', 'book', 'juri', 'theol', 'philo', 'anc_lang']],
#  ['cnp01481137', ['cleric', 'theol'], ['prof', 'cleric', 'anc_lang', 'theol']],
#  ['cnp01089747', ['math'], ['math']],
#  ['cnp01235486', ['math'], ['math', 'astrol', 'theol', 'astron']],
#  ['cnp01356128', [], ['math']],
#  ['cnp01358480',
#   ['liter'],
#   ['juri', 'astrol', 'theol', 'anc_lang', 'med', 'liter']],
#  ['cnp00402987',
#   ['astron', 'book', 'geo_carto', 'inge', 'math'],
#   ['book', 'geo_carto', 'archi', 'astron', 'math', 'inge']],
#  ['cnp01333594', [], ['philo', 'astrol', 'med']],
#  ['cnp01345049', ['math'], ['theol', 'astron', 'math', 'scholar', 'cleric']],
#  ['cnp01441705',
#   ['astron', 'math', 'med'],
#   ['scholar', 'math', 'med', 'astron']],
#  ['cnp01443175',
#   ['histo', 'huma', 'med', 'prof', 'scholar'],
#   ['prof', 'histo', 'huma', 'math', 'philo', 'scholar', 'med']],
#  ['cnp02163173', [], []],
#  ['cnp00888077', ['math', 'prof'], ['prof', 'math', 'astrol', 'med']],
#  ['cnp01318480', [], []],
#  ['cnp01904447', ['math'], ['math', 'inge']],
#  ['cnp01025752', ['liter', 'prof'], ['prof', 'liter']],
#  ['cnp01124424', ['math'], ['prof', 'math', 'astron']],
#  ['cnp00876424', ['theol'], ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp02163146', [], []],
#  ['cnp01113305', ['math', 'med'], ['prof', 'math', 'med']],
#  ['cnp01877782', ['astrol', 'astron', 'math'], ['math', 'astrol', 'astron']],
#  ['cnp01056939', ['prof'], ['prof', 'math', 'philo']],
#  ['cnp00450702', ['math', 'med'], ['math', 'liter', 'med', 'astron']],
#  ['cnp02163189', [], []],
#  ['cnp01919710', [], []],
#  ['cnp01878121', ['med', 'prof'], ['prof', 'math', 'theol', 'med']],
#  ['cnp01029668', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01350014',
#   ['artist', 'med', 'philo', 'prof'],
#   ['prof', 'artist', 'philo', 'anc_lang', 'med']],
#  ['cnp01920049', [], []],
#  ['cnp01409038',
#   ['astron', 'juri', 'math'],
#   ['prof', 'juri', 'astron', 'math', 'anc_lang']],
#  ['cnp01078149', ['astron', 'math'], ['math', 'med', 'astron']],
#  ['cnp01302722',
#   ['philo'],
#   ['prof', 'juri', 'huma', 'math', 'philo', 'anc_lang', 'med', 'liter']],
#  ['cnp02252061', ['archi', 'math'], []],
#  ['cnp01368443', ['liter'], ['liter']],
#  ['cnp01880790',
#   ['math', 'philo', 'phys'],
#   ['prof', 'phys', 'math', 'philo', 'inge']],
#  ['cnp01303321',
#   ['artist', 'astron', 'math', 'med', 'prof'],
#   ['prof', 'artist', 'astron', 'math', 'med']],
#  ['cnp01302340',
#   ['juri', 'math'],
#   ['prof', 'histo', 'juri', 'math', 'anc_lang']],
#  ['cnp01363433',
#   ['astron', 'geo_carto', 'liter', 'math'],
#   ['liter', 'geo_carto', 'math', 'astron']],
#  ['cnp00453662', ['astron', 'med'], ['astrol', 'med', 'astron']],
#  ['cnp01302373',
#   ['med', 'prof', 'scholar'],
#   ['prof', 'phys', 'astron', 'math', 'scholar', 'med']],
#  ['cnp01240021', ['astron', 'math'], ['math', 'astron']],
#  ['cnp00394082',
#   ['geo_carto', 'math', 'med'],
#   ['prof', 'geo_carto', 'phys', 'astron', 'math', 'med']],
#  ['cnp01231917', ['huma'], ['huma', 'math', 'philo', 'anc_lang', 'liter']],
#  ['cnp01104400', ['astron', 'huma', 'math'], ['huma', 'math', 'astron']],
#  ['cnp01390409', ['cleric'], ['prof', 'cleric', 'math', 'theol']],
#  ['cnp01365922',
#   ['math', 'med', 'philo'],
#   ['prof', 'geo_carto', 'astron', 'math', 'philo', 'scholar', 'med']],
#  ['cnp01875401', ['astrol', 'med'], ['astrol', 'med']],
#  ['cnp01333847',
#   ['huma', 'liter', 'prof'],
#   ['prof', 'huma', 'anc_lang', 'liter']],
#  ['cnp01337628', ['med'], ['astrol', 'med']],
#  ['cnp01879907', ['astron', 'math'], ['prof', 'math', 'philo', 'astron']],
#  ['cnp01327594', ['astrol', 'med'], ['anc_lang', 'astrol', 'med']],
#  ['cnp00122851', ['theol'], ['prof', 'math', 'histo', 'theol']],
#  ['cnp01237076', ['med'], ['math', 'med']],
#  ['cnp01033767', ['math'], ['prof', 'math', 'phys']],
#  ['cnp01919971', [], []],
#  ['cnp01113388', ['med'], ['philo', 'phys', 'med', 'astron']],
#  ['cnp01116302', ['math', 'prof'], ['prof', 'math']],
#  ['cnp01389779', [], ['histo', 'liter']],
#  ['cnp01340100', ['astron', 'math', 'med'], ['prof', 'math', 'med', 'astron']],
#  ['cnp00407311', ['math'], ['prof', 'math']],
#  ['cnp01107316', ['math'], ['prof', 'math']],
#  ['cnp02101603', [], ['philo', 'juri']],
#  ['cnp00476702',
#   ['archi', 'artist', 'astron', 'geo_carto', 'inge', 'scholar', 'theol'],
#   ['geo_carto',
#    'artist',
#    'archi',
#    'theol',
#    'astron',
#    'math',
#    'scholar',
#    'inge']],
#  ['cnp00014570',
#   ['anc_lang_philol', 'histo', 'huma'],
#   ['prof', 'histo', 'huma', 'theol', 'anc_lang', 'anc_lang_philol']],
#  ['cnp01105937', ['astron', 'liter'], ['liter', 'astron']],
#  ['cnp01358036', ['math', 'med'], ['prof', 'math', 'anc_lang', 'med']],
#  ['cnp01919917', [], []],
#  ['cnp01320637', ['anc_lang_philol', 'math'], ['math', 'anc_lang_philol']],
#  ['cnp00444650', ['juri'], ['prof', 'math', 'juri']],
#  ['cnp01307458', ['math'], ['huma', 'math', 'anc_lang', 'astron']],
#  ['cnp01301986', ['astron', 'math'], ['prof', 'math', 'cleric', 'astron']],
#  ['cnp01079978', ['math', 'med', 'prof'], ['prof', 'math', 'med']],
#  ['cnp01919930', [], []],
#  ['cnp01311921', ['math'], ['prof', 'math', 'scholar', 'astron']],
#  ['cnp01880451', ['astron'], ['liter', 'anc_lang', 'astron']],
#  ['cnp01109829', ['astron', 'math', 'med'], ['math', 'med', 'astron']],
#  ['cnp01920024', ['astrol', 'med'], ['astrol', 'med']],
#  ['cnp00157873', ['math'], ['math']],
#  ['cnp00485397',
#   ['math', 'med', 'phys', 'prof'],
#   ['prof', 'phys', 'math', 'philo', 'med']],
#  ['cnp02105686', ['astron'], ['histo', 'huma', 'astron', 'math', 'scholar']],
#  ['cnp01879549', ['archi'], ['archi']],
#  ['cnp00416575',
#   ['cleric', 'math', 'theol'],
#   ['prof', 'cleric', 'math', 'theol']],
#  ['cnp01124562',
#   ['archi', 'artist', 'astron', 'liter', 'med', 'prof'],
#   ['prof', 'artist', 'archi', 'astron', 'med', 'liter']],
#  ['cnp01358244', [], ['anc_lang', 'astrol', 'med']],
#  ['cnp01377638',
#   ['archi', 'inge', 'math'],
#   ['inge', 'archi', 'math', 'scholar']],
#  ['cnp01919886', [], []],
#  ['cnp01103897', ['astron', 'geo_carto'], ['geo_carto', 'astron']],
#  ['cnp01306733', [], ['math', 'philo', 'liter']],
#  ['cnp01880764', ['math'], ['math', 'cleric']],
#  ['cnp00096056',
#   ['anc_lang_philol', 'math'],
#   ['prof', 'math', 'philo', 'anc_lang', 'anc_lang_philol']],
#  ['cnp01291699',
#   ['med', 'prof', 'theol'],
#   ['prof', 'theol', 'math', 'cleric', 'med']],
#  ['cnp01322847', ['math'], ['math']],
#  ['cnp02162972', [], []],
#  ['cnp01303545',
#   ['astrol', 'astron', 'cleric', 'med', 'theol'],
#   ['astrol', 'theol', 'astron', 'cleric', 'med']],
#  ['cnp01919940', [], []],
#  ['cnp01082076', ['med', 'prof'], ['prof', 'med']],
#  ['cnp01045770', [], []],
#  ['cnp01113293', ['math', 'med', 'phys'], ['prof', 'math', 'phys', 'med']],
#  ['cnp01422536', ['math'], ['prof', 'math']],
#  ['cnp01303513',
#   ['histo', 'math', 'theol'],
#   ['prof', 'math', 'histo', 'theol']],
#  ['cnp01355346', [], ['scholar', 'math', 'histo', 'astron']],
#  ['cnp01368065', ['math'], ['math', 'astron']],
#  ['cnp02163025', [], []],
#  ['cnp00458518', ['astron', 'math'], ['artist', 'math', 'cleric', 'astron']],
#  ['cnp00571276', ['astron'], ['astron']],
#  ['cnp01468084', ['liter'], ['liter']],
#  ['cnp00962892',
#   ['math', 'med', 'phys', 'prof'],
#   ['prof', 'math', 'phys', 'med']],
#  ['cnp01237192', ['astron', 'philo'], ['philo', 'astron']],
#  ['cnp01259618',
#   ['inge', 'math'],
#   ['prof', 'archi', 'math', 'anc_lang', 'inge']],
#  ['cnp01342652', ['math'], ['math', 'anc_lang', 'liter', 'inge']],
#  ['cnp01919686', [], []],
#  ['cnp01919799',
#   ['anc_lang_philol', 'book', 'huma', 'med', 'prof'],
#   ['prof', 'book', 'huma', 'math', 'anc_lang', 'anc_lang_philol', 'med']],
#  ['cnp01309947', [], ['math', 'anc_lang', 'theol', 'liter']],
#  ['cnp00922870', [], ['inge']],
#  ['cnp01338415', ['astron', 'math'], ['prof', 'math', 'theol', 'astron']],
#  ['cnp01112934', ['astron'], []],
#  ['cnp01944825', ['math'], ['math']],
#  ['cnp02163156', [], []],
#  ['cnp01286849', ['astron'], ['astron']],
#  ['cnp01110021', ['astron', 'math', 'prof'], []],
#  ['cnp01879400',
#   ['anc_lang_philol', 'inge', 'philo'],
#   ['huma', 'phys', 'math', 'philo', 'anc_lang', 'anc_lang_philol', 'inge']],
#  ['cnp02163192', ['med'], ['prof', 'math', 'med', 'astron']],
#  ['cnp00446750', ['huma'], ['huma', 'scholar']],
#  ['cnp01329248', [], ['histo', 'math', 'anc_lang']],
#  ['cnp02231369', ['juri', 'scholar'], ['juri', 'scholar']],
#  ['cnp00481169',
#   ['geo_carto', 'math'],
#   ['math', 'astrol', 'geo_carto', 'astron']],
#  ['cnp02163276', [], []],
#  ['cnp01467090', [], ['math', 'philo', 'astron']],
#  ['cnp00605131', [], []],
#  ['cnp01104779',
#   ['astron', 'book', 'math', 'prof'],
#   ['prof', 'math', 'book', 'astron']],
#  ['cnp01133177', ['geo_carto'], ['math', 'geo_carto']],
#  ['cnp01919833', [], []],
#  ['cnp02163082', [], []],
#  ['cnp01377920', ['geo_carto', 'math'], ['prof', 'math', 'geo_carto']],
#  ['cnp01328166', ['astron'], ['math', 'geo_carto', 'astrol', 'astron']],
#  ['cnp01291829', ['math'], ['math']],
#  ['cnp01356171',
#   ['artist', 'astron', 'prof'],
#   ['artist', 'histo', 'prof', 'astron']],
#  ['cnp02237779', [], ['prof', 'huma', 'astrol', 'astron', 'math', 'scholar']],
#  ['cnp01316739', ['histo', 'liter'], ['huma', 'histo', 'math', 'liter']],
#  ['cnp02222256', ['astron', 'math'], ['math', 'anc_lang', 'astron']],
#  ['cnp00444503',
#   ['astron', 'math', 'prof'],
#   ['prof', 'huma', 'astrol', 'astron', 'math', 'med']],
#  ['cnp01359016',
#   ['astron', 'liter', 'med', 'prof'],
#   ['prof', 'huma', 'astron', 'med', 'liter']],
#  ['cnp01919691', [], []],
#  ['cnp01895099', ['math', 'med', 'prof'], ['prof', 'math', 'med', 'scholar']],
#  ['cnp01878530', ['math'], ['prof', 'math']],
#  ['cnp00369337', ['cleric', 'math', 'med'], ['prof', 'cleric', 'math', 'med']],
#  ['cnp00444510', [], ['prof', 'theol']],
#  ['cnp01343086',
#   ['astron', 'math', 'phys'],
#   ['math', 'phys', 'anc_lang', 'astron']],
#  ['cnp01876902',
#   ['astron', 'cleric', 'math', 'med'],
#   ['theol', 'astron', 'math', 'cleric', 'med']],
#  ['cnp01877738',
#   ['math', 'med', 'phys'],
#   ['prof', 'phys', 'math', 'scholar', 'med']],
#  ['cnp00384901', ['med', 'prof'], ['prof', 'math', 'med']],
#  ['cnp00475665', ['cleric'], ['huma', 'theol', 'math', 'anc_lang', 'cleric']],
#  ['cnp00386604', ['math', 'med'], ['math', 'med', 'scholar']],
#  ['cnp00883349', ['math', 'med'], ['prof', 'math', 'med', 'astron']],
#  ['cnp01327326', ['cleric', 'math'], ['cleric', 'anc_lang', 'math', 'theol']],
#  ['cnp00094435', [], []],
#  ['cnp01344864', ['math', 'med'], ['prof', 'math', 'med']],
#  ['cnp01024644', ['theol'], ['cleric', 'theol']],
#  ['cnp01307826', [], ['math']],
#  ['cnp01054493', ['med'], ['theol', 'med']],
#  ['cnp01273329', ['astron', 'cleric'], ['cleric', 'theol', 'astron']],
#  ['cnp01920011', ['astrol', 'math', 'med'], ['math', 'philo', 'astrol', 'med']],
#  ['cnp01920012', [], []],
#  ['cnp00543426', ['scholar'], ['astron', 'math', 'scholar']],
#  ['cnp01103907', ['astron'], ['astron']],
#  ['cnp00366743',
#   ['artist', 'astron', 'cleric', 'math'],
#   ['artist', 'cleric', 'math', 'astron']],
#  ['cnp01919970', [], []],
#  ['cnp00099596', [], []],
#  ['cnp01330272',
#   ['cleric', 'math', 'philo'],
#   ['prof', 'cleric', 'philo', 'math']],
#  ['cnp01919706', [], []],
#  ['cnp00976839', ['astron', 'book', 'cleric'], ['cleric', 'book', 'astron']],
#  ['cnp00951038', ['astron', 'math'], ['prof', 'math', 'cleric', 'astron']],
#  ['cnp00394836',
#   ['astron', 'math', 'philo', 'phys'],
#   ['phys', 'astron', 'math', 'philo', 'anc_lang']],
#  ['cnp02163119', ['math'], ['prof', 'math']],
#  ['cnp01327958',
#   ['astron', 'book', 'math', 'med', 'prof'],
#   ['prof', 'book', 'astron', 'math', 'med']],
#  ['cnp01920041', [], []],
#  ['cnp00424447',
#   ['astron', 'math'],
#   ['prof', 'astrol', 'astron', 'math', 'philo']],
#  ['cnp01879023',
#   ['book', 'cleric', 'geo_carto', 'histo', 'philo', 'prof'],
#   ['prof',
#    'histo',
#    'book',
#    'geo_carto',
#    'theol',
#    'math',
#    'philo',
#    'anc_lang',
#    'cleric']],
#  ['cnp01347493',
#   ['astron', 'math', 'prof'],
#   ['prof', 'math', 'anc_lang', 'astron']],
#  ['cnp01900808', [], ['prof', 'philo', 'astron']],
#  ['cnp01233501', ['geo_carto'], ['inge', 'geo_carto', 'math']],
#  ['cnp01395469', ['liter'], ['huma', 'astron', 'math', 'philo', 'liter']],
#  ['cnp02143831', ['math'], ['math']],
#  ['cnp01340415', [], ['math', 'theol', 'astron']],
#  ['cnp02251223', ['archi', 'inge', 'math'], []],
#  ['cnp00871211',
#   ['astron', 'math', 'scholar'],
#   ['prof', 'astron', 'math', 'scholar', 'cleric']],
#  ['cnp00468695', ['math', 'phys'], ['math', 'phys']],
#  ['cnp01406042',
#   ['archi', 'math'],
#   ['prof', 'phys', 'archi', 'theol', 'math', 'cleric']],
#  ['cnp00877897', ['astron'], ['astron']],
#  ['cnp01106465', ['astron'], ['astron']],
#  ['cnp01919647', ['histo', 'prof'], ['prof', 'histo', 'anc_lang', 'liter']],
#  ['cnp00404027', ['med'], ['prof', 'math', 'med', 'scholar']],
#  ['cnp01358327', [], ['prof', 'math', 'scholar']],
#  ['cnp00892467', ['med'], ['med']],
#  ['cnp02163051', ['cleric'], ['cleric', 'math', 'theol']],
#  ['cnp01908712',
#   ['cleric', 'liter', 'math', 'philo', 'prof'],
#   ['prof', 'phys', 'math', 'philo', 'cleric', 'liter']],
#  ['cnp01408867', [], ['inge', 'archi', 'math', 'astron']],
#  ['cnp01108514', ['astron', 'cleric', 'theol'], ['cleric', 'theol', 'astron']],
#  ['cnp01327988',
#   ['astrol', 'astron', 'juri', 'math', 'med'],
#   ['prof', 'juri', 'astrol', 'astron', 'math', 'med']],
#  ['cnp01355841', ['astron'], ['astron']],
#  ['cnp01208565',
#   ['liter', 'theol'],
#   ['prof', 'huma', 'theol', 'astron', 'philo', 'scholar', 'liter']],
#  ['cnp01876214',
#   ['anc_lang_philol', 'math', 'prof'],
#   ['prof', 'math', 'philo', 'anc_lang', 'anc_lang_philol']],
#  ['cnp01378567', ['geo_carto', 'math'], ['math', 'histo', 'geo_carto']],
#  ['cnp01355990',
#   ['artist', 'astrol', 'math'],
#   ['artist', 'huma', 'astrol', 'archi', 'math']],
#  ['cnp01379493', ['archi', 'artist'], ['artist', 'geo_carto', 'archi']],
#  ['cnp01321061', ['archi', 'artist'], ['artist', 'math', 'archi']],
#  ['cnp01421274', [], ['math', 'med']],
#  ['cnp01233301', [], []],
#  ['cnp00414862', ['geo_carto'], ['math', 'geo_carto']],
#  ['cnp01877766', ['scholar'], ['math', 'phys', 'scholar']],
#  ['cnp01328010',
#   ['astron', 'med', 'phys', 'prof'],
#   ['prof', 'phys', 'astron', 'math', 'med']],
#  ['cnp01919680', [], []],
#  ['cnp01919798', [], []],
#  ['cnp00401494', ['astron', 'math', 'med'], ['math', 'med', 'astron']],
#  ['cnp02163157', [], []],
#  ['cnp00990253', [], ['cleric', 'theol', 'math', 'med']],
#  ['cnp00946324', ['cleric', 'math'], ['cleric', 'math']],
#  ['cnp00519261',
#   ['astrol', 'astron', 'geo_carto', 'math'],
#   ['math', 'geo_carto', 'astrol', 'astron']],
#  ['cnp01919936', [], []],
#  ['cnp01073264', [], ['cleric']],
#  ['cnp01920059', [], ['math', 'med']],
#  ['cnp01026086', ['med', 'prof'], ['prof', 'astron', 'math', 'med', 'liter']],
#  ['cnp00951475', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp00370488', ['cleric', 'math', 'scholar'], ['cleric', 'math', 'scholar']],
#  ['cnp02224706', [], ['scholar', 'math', 'med', 'astron']],
#  ['cnp01908276',
#   [],
#   ['geo_carto', 'huma', 'astron', 'math', 'scholar', 'liter']],
#  ['cnp01351342', ['math'], ['math']],
#  ['cnp01919735', ['astron', 'book', 'prof'], ['prof', 'book', 'astron']],
#  ['cnp00125588', [], ['cleric', 'math', 'theol']],
#  ['cnp00386550', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01399888', [], ['math']],
#  ['cnp01121780', [], []],
#  ['cnp01919933', [], ['cleric', 'math']],
#  ['cnp02330678', [], []],
#  ['cnp00125422', ['astron', 'math'], ['math', 'cleric', 'astrol', 'astron']],
#  ['cnp01395468', [], ['math', 'philo', 'med', 'astron']],
#  ['cnp01877518',
#   ['astron', 'book', 'liter', 'math', 'prof'],
#   ['prof', 'book', 'astron', 'math', 'liter']],
#  ['cnp00455882', ['math'], ['math']],
#  ['cnp01475871', ['math'], ['prof', 'math', 'archi', 'inge']],
#  ['cnp01391905',
#   ['astron', 'geo_carto', 'math', 'med'],
#   ['prof', 'geo_carto', 'astron', 'math', 'med']],
#  ['cnp02163132', [], []],
#  ['cnp01917023', [], ['anc_lang', 'astron']],
#  ['cnp01391968', ['astron', 'math'], ['prof', 'math', 'geo_carto', 'astron']],
#  ['cnp00370784',
#   ['liter', 'math'],
#   ['huma', 'math', 'anc_lang', 'scholar', 'liter']],
#  ['cnp02094405', ['math', 'med'], ['math', 'med']],
#  ['cnp00980603', ['liter', 'math'], ['huma', 'math', 'cleric', 'liter']],
#  ['cnp01018318', ['math'], ['math']],
#  ['cnp00506076', ['prof', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp00998676', ['astron', 'juri'], ['juri', 'astron']],
#  ['cnp00951955', ['math'], ['prof', 'math']],
#  ['cnp01920892',
#   ['anc_lang_philol', 'histo', 'math', 'prof'],
#   ['prof', 'histo', 'astron', 'math', 'anc_lang', 'anc_lang_philol']],
#  ['cnp01351361', ['scholar'], ['prof', 'math', 'philo', 'scholar', 'cleric']],
#  ['cnp02163042', [], []],
#  ['cnp00623575', ['med'], ['astrol', 'med']],
#  ['cnp01093544', ['math', 'med'], ['math', 'med']],
#  ['cnp01002233', ['cleric'], ['prof', 'cleric', 'math']],
#  ['cnp01318008',
#   ['astrol', 'astron', 'math', 'med'],
#   ['prof', 'astrol', 'astron', 'math', 'anc_lang', 'med', 'liter']],
#  ['cnp01330261', [], ['astrol', 'astron']],
#  ['cnp00930944', [], []],
#  ['cnp00108734', ['math', 'theol'], ['math', 'theol', 'astron']],
#  ['cnp01920048',
#   ['astron', 'cleric'],
#   ['astrol', 'theol', 'astron', 'cleric', 'med']],
#  ['cnp00390667', ['philo', 'prof'], ['prof', 'math', 'philo', 'phys']],
#  ['cnp01344682',
#   ['philo', 'phys', 'scholar'],
#   ['phys', 'astrol', 'theol', 'philo', 'scholar', 'inge']],
#  ['cnp01377073', [], ['liter', 'anc_lang', 'astron']],
#  ['cnp00475681', ['liter', 'theol'], ['cleric', 'math', 'theol', 'liter']],
#  ['cnp01313208', [], ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp01334817',
#   ['liter', 'med'],
#   ['prof',
#    'huma',
#    'phys',
#    'astron',
#    'math',
#    'philo',
#    'scholar',
#    'med',
#    'liter']],
#  ['cnp01374654', ['math', 'med', 'prof'], ['prof', 'math', 'philo', 'med']],
#  ['cnp00389786', ['math', 'prof'], ['prof', 'math', 'anc_lang']],
#  ['cnp00385731', ['archi', 'inge', 'math'], ['inge', 'archi', 'math']],
#  ['cnp01273893', ['liter', 'philo'], ['math', 'philo', 'liter']],
#  ['cnp01316924', ['math', 'theol'], ['math', 'theol']],
#  ['cnp01899827', [], ['prof', 'inge', 'math']],
#  ['cnp01045073', [], ['prof', 'math']],
#  ['cnp01304679', [], ['prof', 'math']],
#  ['cnp02163255', [], []],
#  ['cnp01303999', [], ['cleric', 'astron']],
#  ['cnp00915396', ['astron', 'math'], []],
#  ['cnp01037256', ['astron', 'prof', 'theol'], []],
#  ['cnp01377125', ['math', 'theol'], ['prof', 'math', 'phys', 'theol']],
#  ['cnp01322085',
#   ['math', 'philo', 'phys', 'prof'],
#   ['prof', 'math', 'philo', 'phys']],
#  ['cnp02033956', ['geo_carto', 'math'], []],
#  ['cnp00969971',
#   ['anc_lang_philol', 'histo', 'math'],
#   ['math', 'histo', 'anc_lang_philol']],
#  ['cnp00389349', ['math'], ['prof', 'math']],
#  ['cnp02163239', [], []],
#  ['cnp00504169', ['math'], ['math']],
#  ['cnp01919685', [], []],
#  ['cnp02149411', ['archi'], ['math', 'geo_carto', 'astrol', 'archi']],
#  ['cnp00921622', ['archi', 'math'], ['prof', 'math', 'cleric', 'archi']],
#  ['cnp01327704', [], ['prof', 'theol', 'astron', 'philo', 'cleric', 'liter']],
#  ['cnp02163138', [], []],
#  ['cnp02248072', ['juri', 'math'], []],
#  ['cnp01033200', ['geo_carto', 'math'], ['math', 'geo_carto']],
#  ['cnp02163160', [], []],
#  ['cnp00507343', ['astrol', 'astron', 'med'], ['astrol', 'med', 'astron']],
#  ['cnp01901801', [], ['inge', 'anc_lang', 'math']],
#  ['cnp00416849', ['astron', 'math', 'med'], []],
#  ['cnp02062689', ['math'], ['math', 'cleric']],
#  ['cnp01291828', ['math'], ['math']],
#  ['cnp02230350', [], ['prof', 'math', 'anc_lang', 'astron']],
#  ['cnp00398978',
#   ['geo_carto', 'liter', 'math'],
#   ['prof', 'geo_carto', 'huma', 'math', 'liter']],
#  ['cnp00388107',
#   ['math', 'med', 'phys'],
#   ['prof', 'phys', 'theol', 'math', 'med']],
#  ['cnp00390875', ['juri', 'math'], ['math', 'juri']],
#  ['cnp01920009', [], []],
#  ['cnp01368847', [], ['artist']],
#  ['cnp01335791', ['math', 'philo'], ['math', 'philo', 'med', 'astron']],
#  ['cnp01317013', ['archi', 'inge', 'math'], ['inge', 'archi', 'math']],
#  ['cnp00447681',
#   ['math', 'prof', 'scholar'],
#   ['prof', 'math', 'anc_lang', 'scholar']],
#  ['cnp01440545',
#   ['archi', 'book', 'geo_carto', 'math'],
#   ['book', 'geo_carto', 'artist', 'archi', 'math']],
#  ['cnp01089507', ['math'], ['math', 'astron']],
#  ['cnp00466008', ['med'], ['astrol', 'med', 'astron']],
#  ['cnp00295424',
#   ['book', 'juri', 'liter'],
#   ['prof', 'histo', 'book', 'juri', 'huma', 'math', 'philo', 'liter']],
#  ['cnp01026399',
#   ['cleric', 'inge', 'math'],
#   ['cleric', 'philo', 'math', 'inge']],
#  ['cnp00458133', ['cleric', 'math'], ['cleric', 'math', 'theol']],
#  ['cnp00497608', ['astron', 'cleric'], ['cleric', 'astron']],
#  ['cnp00918436', ['cleric'], ['cleric', 'math', 'juri', 'astron']],
#  ['cnp01319583', [], ['prof', 'math', 'astron']],
#  ['cnp00918450',
#   ['astron', 'geo_carto', 'math', 'prof'],
#   ['prof', 'math', 'geo_carto', 'astron']],
#  ['cnp01390435', [], ['inge', 'math']],
#  ['cnp02205996', ['astron'], ['astron']],
#  ['cnp01919797', [], []],
#  ['cnp02206734', ['astron', 'med'], ['med', 'astron']],
#  ['cnp01053665',
#   ['cleric', 'prof'],
#   ['prof', 'theol', 'math', 'anc_lang', 'cleric']],
#  ['cnp00390534', ['math', 'med'], ['prof', 'math', 'med']],
#  ['cnp01348997', [], ['math', 'philo', 'liter']],
#  ['cnp01146927', ['math'], []],
#  ['cnp01339954', ['philo'], ['prof', 'math', 'philo', 'theol']],
#  ['cnp00354610', [], []],
#  ['cnp02239623', ['astron', 'math'], ['math', 'geo_carto', 'astrol', 'astron']],
#  ['cnp01325603', [], ['inge', 'math']],
#  ['cnp01919813', [], ['math', 'astrol']],
#  ['cnp01341138', [], ['prof', 'huma', 'math', 'anc_lang', 'cleric']],
#  ['cnp02163280', [], []],
#  ['cnp01921111',
#   ['math', 'philo', 'phys', 'scholar'],
#   ['phys', 'math', 'philo', 'anc_lang', 'scholar']],
#  ['cnp00452326',
#   ['astron', 'math', 'med'],
#   ['prof', 'phys', 'astrol', 'astron', 'math', 'med']],
#  ['cnp01338526', ['astron'], ['prof', 'math', 'med', 'astron']],
#  ['cnp02111485', ['juri', 'math', 'philo'], []],
#  ['cnp01877772', ['math', 'med'], ['math', 'anc_lang', 'med', 'astron']],
#  ['cnp02335717', [], ['cleric', 'math', 'astron']],
#  ['cnp02163012', [], []],
#  ['cnp02069815', [], ['prof']],
#  ['cnp00461448', ['math'], ['math', 'cleric']],
#  ['cnp02234984', ['math'], ['prof', 'math', 'anc_lang', 'astron']],
#  ['cnp01364670', ['astron'], ['math', 'astron']],
#  ['cnp01878958', ['math', 'med', 'prof'], ['prof', 'math', 'philo', 'med']],
#  ['cnp00389779',
#   ['book', 'math'],
#   ['prof', 'book', 'phys', 'astrol', 'astron', 'math']],
#  ['cnp02163235', [], []],
#  ['cnp00401645',
#   ['astron', 'math'],
#   ['prof', 'astron', 'math', 'anc_lang', 'cleric']],
#  ['cnp01093384', ['math'], ['math']],
#  ['cnp01918226',
#   [],
#   ['prof', 'histo', 'theol', 'astron', 'math', 'philo', 'cleric', 'liter']],
#  ['cnp00617340', ['geo_carto', 'math', 'phys'], ['math', 'phys', 'geo_carto']],
#  ['cnp02223923', [], ['math', 'phys', 'geo_carto']],
#  ['cnp00473662',
#   ['astron', 'philo', 'theol'],
#   ['theol', 'astron', 'philo', 'scholar', 'cleric']],
#  ['cnp02163183', ['theol'], ['math', 'theol', 'astron']],
#  ['cnp02293390', [], ['math', 'astron']],
#  ['cnp00649901', ['math'], ['prof', 'math']],
#  ['cnp01003527',
#   ['math', 'philo', 'prof', 'theol'],
#   ['prof', 'math', 'philo', 'theol']],
#  ['cnp01085022', ['math', 'prof'], ['prof', 'math', 'philo']],
#  ['cnp01487024', ['book', 'liter', 'math'], ['math', 'book', 'liter']],
#  ['cnp00384916', ['theol'], ['prof', 'theol', 'math', 'philo', 'anc_lang']],
#  ['cnp00689671',
#   ['cleric', 'math', 'prof', 'scholar'],
#   ['prof', 'phys', 'theol', 'math', 'philo', 'scholar', 'cleric']],
#  ['cnp01328238', ['math', 'med'], ['prof', 'math', 'med', 'astron']],
#  ['cnp02211160', ['astron', 'math', 'phys'], []],
#  ['cnp01321618',
#   ['astron', 'histo', 'math', 'philo'],
#   ['prof', 'histo', 'astron', 'math', 'philo', 'anc_lang', 'cleric']],
#  ['cnp01470260', [], ['prof', 'cleric', 'philo', 'math']],
#  ['cnp02063829', ['math'], ['math']],
#  ['cnp01344806', [], ['math']],
#  ['cnp01337555',
#   ['astron'],
#   ['histo', 'astrol', 'theol', 'astron', 'math', 'liter']],
#  ['cnp00951915', [], ['prof', 'cleric', 'math', 'theol']],
#  ['cnp02163131', [], []],
#  ['cnp01919977', [], []],
#  ['cnp01919983', [], []],
#  ['cnp00064282', ['math'], ['math', 'astron']],
#  ['cnp01316530', ['math'], ['math']],
#  ['cnp01323244',
#   ['astron', 'math', 'med'],
#   ['prof', 'astron', 'math', 'philo', 'med']],
#  ['cnp00445951', ['cleric', 'prof'], ['prof', 'cleric', 'theol']],
#  ['cnp02190631', ['astrol'], []],
#  ['cnp01330172', [], ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp02163037', [], []],
#  ['cnp01919746', ['astron', 'math'], ['math', 'astron']],
#  ['cnp02163116', [], []],
#  ['cnp01323399', ['med'], ['anc_lang', 'astrol', 'med']],
#  ['cnp01939722', [], ['math', 'philo']],
#  ['cnp02140267', ['math'], []],
#  ['cnp00105837', [], ['prof', 'math']],
#  ['cnp00506366', ['med'], ['math', 'med', 'astron']],
#  ['cnp02236952', [], ['prof', 'math', 'astrol']],
#  ['cnp00489873', ['geo_carto', 'math', 'theol'], []],
#  ['cnp02230372', [], ['math', 'anc_lang', 'juri']],
#  ['cnp01327695', [], ['inge', 'astron']],
#  ['cnp01345096',
#   ['astron', 'juri', 'math', 'theol'],
#   ['math', 'juri', 'theol', 'astron']],
#  ['cnp01358202',
#   ['astron', 'math', 'prof'],
#   ['prof', 'math', 'anc_lang', 'astron']],
#  ['cnp01341055',
#   ['book', 'math', 'philo', 'theol'],
#   ['book', 'huma', 'archi', 'theol', 'math', 'philo']],
#  ['cnp02232803', ['philo', 'prof'], ['prof', 'math', 'philo', 'theol']],
#  ['cnp01391658', ['geo_carto', 'math'], ['math', 'geo_carto']],
#  ['cnp01199180', ['math', 'philo'], ['math', 'philo', 'cleric']],
#  ['cnp01002799', ['math', 'prof', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp01229337',
#   ['juri', 'scholar'],
#   ['prof', 'juri', 'astron', 'math', 'scholar']],
#  ['cnp02230529', ['math'], ['prof', 'math', 'cleric']],
#  ['cnp01919890', [], []],
#  ['cnp00283188', [], ['cleric', 'astrol']],
#  ['cnp00388517', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp02261078', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01345246', ['med'], ['math', 'philo', 'med', 'scholar']],
#  ['cnp02104967', ['math'], ['math', 'philo', 'cleric', 'theol']],
#  ['cnp02078294', ['artist'], []],
#  ['cnp02236239',
#   ['math', 'phys', 'prof'],
#   ['prof', 'math', 'phys', 'anc_lang']],
#  ['cnp00386587',
#   ['cleric', 'math', 'prof', 'theol'],
#   ['prof', 'cleric', 'math', 'theol']],
#  ['cnp02140516', ['astron'], []],
#  ['cnp00876263', ['math'], ['prof', 'math']],
#  ['cnp01908394', ['artist'], ['artist']],
#  ['cnp01392446', [], ['prof', 'geo_carto', 'math', 'anc_lang', 'cleric']],
#  ['cnp01377339', [], ['astron']],
#  ['cnp01919715', ['astrol'], ['astrol']],
#  ['cnp01470045',
#   ['juri', 'liter', 'math'],
#   ['prof', 'juri', 'archi', 'math', 'liter']],
#  ['cnp01325201', ['artist', 'astron', 'math'], ['artist', 'math', 'astron']],
#  ['cnp00611392', ['astron', 'juri'], ['math', 'juri', 'astron']],
#  ['cnp01380775',
#   ['cleric', 'math', 'philo'],
#   ['cleric', 'philo', 'math', 'liter']],
#  ['cnp00106298', ['med'], ['math', 'med', 'astron']],
#  ['cnp00483287', ['math'], ['prof', 'math', 'cleric']],
#  ['cnp01341135', ['phys'], ['math', 'phys']],
#  ['cnp01483154',
#   ['math'],
#   ['prof', 'phys', 'astron', 'math', 'philo', 'cleric']],
#  ['cnp00496933', ['math'], ['math', 'theol']],
#  ['cnp01375612', [], ['math', 'anc_lang']],
#  ['cnp00352036',
#   ['astrol', 'astron', 'book', 'math'],
#   ['math', 'book', 'astrol', 'astron']],
#  ['cnp01127978', [], []],
#  ['cnp01324836', [], []],
#  ['cnp00387106',
#   ['histo', 'math', 'med', 'prof'],
#   ['prof', 'histo', 'astrol', 'math', 'med']],
#  ['cnp01919870', [], []],
#  ['cnp00433134', ['math', 'med', 'prof'], ['prof', 'math', 'med']],
#  ['cnp00399615', ['math'], ['prof', 'math']],
#  ['cnp01435092', ['med'], ['prof', 'math', 'theol', 'med']],
#  ['cnp01919694', ['astron'], ['astrol', 'astron']],
#  ['cnp00347201', [], ['cleric', 'theol']],
#  ['cnp01012117', ['astron', 'cleric'], ['cleric', 'astrol', 'theol', 'astron']],
#  ['cnp00364411',
#   ['math', 'philo', 'prof', 'theol'],
#   ['prof', 'math', 'philo', 'theol']],
#  ['cnp02193879', ['book', 'math'], ['math', 'book']],
#  ['cnp01469355', ['math'], ['prof', 'math', 'anc_lang', 'theol']],
#  ['cnp00432861', ['juri', 'prof'], ['prof', 'juri']],
#  ['cnp01364652', ['histo'], ['histo', 'astrol', 'anc_lang']],
#  ['cnp00390888', ['math', 'phys'], ['math', 'phys', 'cleric']],
#  ['cnp00482504',
#   ['anc_lang_philol', 'med'],
#   ['liter', 'anc_lang', 'med', 'anc_lang_philol']],
#  ['cnp01330573',
#   ['archi', 'book', 'inge', 'math'],
#   ['prof', 'book', 'archi', 'math', 'inge', 'med']],
#  ['cnp00886194', [], []],
#  ['cnp00380320', ['med'], ['prof', 'math', 'philo', 'med']],
#  ['cnp01002798', ['scholar', 'theol'], ['prof', 'theol', 'scholar']],
#  ['cnp00038260', ['math', 'phys'], ['math', 'philo', 'phys', 'anc_lang']],
#  ['cnp00877968',
#   ['astron', 'math'],
#   ['prof', 'theol', 'astron', 'math', 'philo']],
#  ['cnp00391433',
#   ['astron', 'math', 'med'],
#   ['math', 'astrol', 'med', 'astron']],
#  ['cnp01340180', ['astron', 'math'], ['math', 'astron']],
#  ['cnp01010326', ['math', 'theol'], ['prof', 'math', 'cleric', 'theol']],
#  ['cnp00069034', ['math'], ['prof', 'math', 'astron']],
#  ['cnp00474060', ['med', 'prof'], ['prof', 'phys', 'astron', 'philo', 'med']],
#  ['cnp01094218',
#   ['math', 'philo', 'phys', 'prof'],
#   ['prof', 'math', 'philo', 'phys']],
#  ['cnp02235964', ['med'], ['huma', 'astrol', 'philo', 'anc_lang', 'med']],
#  ['cnp00454903', ['book', 'math', 'phys'], ['prof', 'math', 'book', 'phys']],
#  ['cnp02299102', ['math'], []],
#  ['cnp01318964', ['astron', 'theol'], ['theol', 'astron']],
#  ['cnp02327523', [], ['prof', 'cleric', 'math']],
#  ['cnp01919967', [], []],
#  ['cnp01920211',
#   ['liter', 'phys'],
#   ['geo_carto', 'huma', 'phys', 'astron', 'scholar', 'liter']],
#  ['cnp01373606', ['artist'], ['artist']],
#  ['cnp01323643',
#   [],
#   ['prof', 'histo', 'artist', 'theol', 'math', 'anc_lang', 'liter']],
#  ['cnp00930960', ['archi', 'math'], ['prof', 'math', 'cleric', 'archi']],
#  ['cnp01992297', ['astron', 'math'], ['prof', 'math', 'cleric', 'astron']],
#  ['cnp00368388', ['math', 'prof'], ['prof', 'math', 'anc_lang']],
#  ['cnp01364676', ['astron', 'math', 'phys'], ['math', 'phys', 'astron']],
#  ['cnp01320598',
#   ['philo'],
#   ['prof', 'math', 'philo', 'anc_lang', 'cleric', 'inge']],
#  ['cnp01320899',
#   ['theol'],
#   ['prof', 'theol', 'math', 'philo', 'anc_lang', 'cleric']],
#  ['cnp00147670', ['math'], ['math', 'anc_lang']],
#  ['cnp02154944', [], []],
#  ['cnp01389635',
#   ['math', 'phys'],
#   ['prof', 'histo', 'phys', 'math', 'philo', 'anc_lang', 'cleric']],
#  ['cnp02335307', ['astron', 'histo', 'theol'], ['histo', 'theol', 'astron']],
#  ['cnp02244888',
#   ['liter', 'math', 'philo', 'phys', 'theol'],
#   ['phys', 'theol', 'math', 'philo', 'liter']],
#  ['cnp01479020',
#   ['liter', 'math', 'philo', 'phys', 'theol'],
#   ['huma', 'phys', 'theol', 'math', 'philo', 'liter']],
#  ['cnp01010218', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp02163221', [], []],
#  ['cnp01440456', ['archi'], ['math', 'philo', 'archi']],
#  ['cnp01316503',
#   ['liter', 'math', 'med', 'phys'],
#   ['prof', 'juri', 'phys', 'math', 'med', 'liter']],
#  ['cnp01481978', ['astron'], ['anc_lang', 'astron']],
#  ['cnp00506412', ['astron'], ['astron']],
#  ['cnp01370532', [], ['math']],
#  ['cnp01358935', ['histo', 'theol'], ['prof', 'math', 'histo', 'theol']],
#  ['cnp02338184', [], ['prof', 'cleric', 'math', 'theol']],
#  ['cnp00385275', ['math', 'philo', 'prof'], ['prof', 'math', 'philo']],
#  ['cnp01890712', [], ['prof', 'math', 'anc_lang', 'astron']],
#  ['cnp00669927', [], ['artist', 'astron']],
#  ['cnp00019029',
#   ['anc_lang_philol', 'scholar', 'theol'],
#   ['prof', 'anc_lang_philol', 'theol', 'math', 'scholar', 'cleric', 'liter']],
#  ['cnp00529491', [], []],
#  ['cnp01476352',
#   ['astron', 'math', 'phys'],
#   ['math', 'phys', 'liter', 'astron']],
#  ['cnp01914334', [], ['inge']],
#  ['cnp00952066', ['prof', 'theol'], ['prof', 'huma', 'math', 'theol']],
#  ['cnp01919643', ['med', 'prof'], ['prof', 'med']],
#  ['cnp01338801', ['math', 'theol'], ['math', 'anc_lang', 'theol', 'liter']],
#  ['cnp00951195', ['math'], ['math', 'cleric', 'astron']],
#  ['cnp00434558', ['math', 'prof'], ['prof', 'math', 'philo']],
#  ['cnp01919866', [], []],
#  ['cnp01391974', ['inge'], ['inge', 'geo_carto', 'math']],
#  ['cnp00950513', ['math', 'phys'], ['math', 'phys']],
#  ['cnp01311444', ['cleric', 'math'], ['cleric', 'anc_lang', 'math', 'scholar']],
#  ['cnp00455142',
#   ['astron', 'juri'],
#   ['prof', 'juri', 'astron', 'math', 'scholar']],
#  ['cnp00471549',
#   ['math', 'theol'],
#   ['prof', 'phys', 'theol', 'astron', 'math']],
#  ['cnp00833377', ['math', 'med'], ['math', 'med']],
#  ['cnp01891255',
#   ['histo', 'phys'],
#   ['histo', 'juri', 'phys', 'math', 'cleric']],
#  ['cnp02068029',
#   ['cleric', 'math', 'prof', 'theol'],
#   ['prof', 'cleric', 'math', 'theol']],
#  ['cnp01919823', [], []],
#  ['cnp01497657', ['math', 'prof', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp01337449', [], ['math', 'med', 'astron']],
#  ['cnp00400188', ['astron', 'math'], ['math', 'astron']],
#  ['cnp00951338', ['geo_carto', 'math'], ['math', 'astrol', 'geo_carto', 'med']],
#  ['cnp01377626', [], ['prof', 'math', 'philo']],
#  ['cnp01390742', [], ['math', 'med']],
#  ['cnp01919771', [], []],
#  ['cnp00597936', ['astron', 'cleric'], ['cleric', 'astron']],
#  ['cnp01390739', [], ['prof', 'inge', 'anc_lang', 'math']],
#  ['cnp00952457', ['liter', 'prof'], ['prof', 'math', 'anc_lang', 'liter']],
#  ['cnp02230304', [], ['liter', 'astron']],
#  ['cnp02183983',
#   ['astrol', 'astron', 'liter'],
#   ['prof', 'liter', 'astrol', 'astron']],
#  ['cnp01481855',
#   ['astron', 'cleric', 'juri', 'math', 'phys', 'prof'],
#   ['prof', 'juri', 'artist', 'phys', 'astron', 'math', 'scholar', 'cleric']],
#  ['cnp00537706', ['math'], ['prof', 'math']],
#  ['cnp02163226', [], []],
#  ['cnp01439830',
#   ['math', 'philo', 'phys', 'prof'],
#   ['prof', 'phys', 'astrol', 'math', 'philo', 'anc_lang']],
#  ['cnp00369131',
#   ['astron', 'cleric', 'liter', 'theol'],
#   ['cleric', 'liter', 'theol', 'astron']],
#  ['cnp01289741', ['cleric'], ['huma', 'cleric', 'astron']],
#  ['cnp00993973', ['astron', 'math'], ['prof', 'math', 'astron']],
#  ['cnp01267785', ['astron', 'theol'], ['cleric', 'theol', 'astron']],
#  ['cnp01049147', ['med', 'prof'], ['prof', 'math', 'philo', 'med']],
#  ['cnp00908508', ['inge'], ['inge', 'math']],
#  ['cnp00386174', ['astron', 'geo_carto', 'math', 'prof'], []],
#  ['cnp01316493', [], ['math']],
#  ['cnp02158412', ['math', 'theol'], []],
#  ['cnp01391574', [], ['math', 'theol']],
#  ['cnp00371858', ['math', 'med'], ['prof', 'math', 'philo', 'med']],
#  ['cnp01440125', ['artist', 'astron', 'math'], ['artist', 'math', 'astron']],
#  ['cnp01919777', [], []],
#  ['cnp01471258', ['math', 'prof', 'theol'], []],
#  ['cnp02179557', ['archi', 'artist', 'math'], ['artist', 'math', 'archi']],
#  ['cnp01919770', ['astrol'], ['astrol']],
#  ['cnp01919841', ['astron'], ['astron']],
#  ['cnp01329452', [], ['histo', 'anc_lang', 'liter']],
#  ['cnp01391697', ['geo_carto'], ['math', 'geo_carto']],
#  ['cnp00946101',
#   ['math', 'philo', 'scholar'],
#   ['math', 'philo', 'cleric', 'scholar']],
#  ['cnp02121737', ['math'], ['math']],
#  ['cnp01392357', ['astron', 'math', 'philo'], ['math', 'philo', 'astron']],
#  ['cnp00950867', ['juri', 'math', 'prof'], ['prof', 'math', 'juri', 'theol']],
#  ['cnp02163035', [], []],
#  ['cnp00387057', ['math', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp00967216', ['liter', 'math'], ['huma', 'math', 'prof', 'liter']],
#  ['cnp01327984',
#   ['astron', 'math'],
#   ['prof', 'artist', 'archi', 'astron', 'math']],
#  ['cnp01324799',
#   ['math', 'philo', 'theol'],
#   ['theol', 'math', 'philo', 'scholar', 'cleric']],
#  ['cnp01322061', ['math'], ['prof', 'math', 'cleric', 'liter']],
#  ['cnp00937233', ['juri', 'prof'], ['prof', 'math', 'juri', 'theol']],
#  ['cnp00469354',
#   ['astron', 'geo_carto', 'histo', 'math'],
#   ['histo', 'geo_carto', 'astron', 'math', 'scholar']],
#  ['cnp01471432', [], ['math', 'phys', 'astron']],
#  ['cnp00681549', [], ['prof', 'math', 'anc_lang']],
#  ['cnp02163278', [], []],
#  ['cnp00557114', ['astron', 'cleric'], ['prof', 'cleric', 'astron']],
#  ['cnp00301902',
#   ['math', 'med', 'philo', 'scholar'],
#   ['prof', 'math', 'philo', 'scholar', 'med']],
#  ['cnp01940714',
#   ['math', 'med', 'philo'],
#   ['prof', 'math', 'philo', 'scholar', 'med']],
#  ['cnp00670663', ['prof'], ['prof', 'math', 'artist', 'liter']],
#  ['cnp00388939', ['med'], ['math', 'philo', 'med']],
#  ['cnp00419809',
#   ['math', 'med', 'philo', 'prof'],
#   ['prof', 'math', 'philo', 'scholar', 'med']],
#  ['cnp01316895', [], ['math', 'phys']],
#  ['cnp00438816',
#   ['prof', 'theol'],
#   ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp01338123', [], ['astron']],
#  ['cnp00400398', ['astron'], ['juri', 'astron']],
#  ['cnp01310386', ['cleric'], ['astron', 'math', 'anc_lang', 'cleric', 'liter']],
#  ['cnp01905556', [], ['math', 'anc_lang', 'theol', 'astron']],
#  ['cnp00343317',
#   ['math', 'philo', 'prof', 'theol'],
#   ['prof', 'math', 'philo', 'theol']],
#  ['cnp00395926', ['med'], ['prof', 'phys', 'math', 'scholar', 'med']],
#  ['cnp00467311', [], ['philo']],
#  ['cnp00967217', ['geo_carto', 'inge', 'math'], []],
#  ['cnp01498919',
#   ['book', 'juri', 'math', 'philo'],
#   ['prof', 'book', 'juri', 'math', 'philo', 'scholar']],
#  ['cnp00950470', ['math'], ['math']],
#  ['cnp02294466', [], ['prof', 'math', 'phys', 'theol']],
#  ['cnp01093464', [], []],
#  ['cnp02226095', [], ['astron']],
#  ['cnp00872719', ['math', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp01362737',
#   ['liter', 'math'],
#   ['prof',
#    'huma',
#    'phys',
#    'astron',
#    'math',
#    'philo',
#    'anc_lang',
#    'cleric',
#    'liter']],
#  ['cnp01363143', [], ['prof', 'histo', 'huma', 'math', 'cleric', 'liter']],
#  ['cnp00422532',
#   ['anc_lang_philol', 'liter', 'math'],
#   ['huma', 'math', 'anc_lang', 'anc_lang_philol', 'cleric', 'liter']],
#  ['cnp00552352', [], ['artist', 'math', 'juri']],
#  ['cnp00449362',
#   ['math', 'philo', 'phys', 'prof'],
#   ['prof', 'math', 'philo', 'phys']],
#  ['cnp01989297', ['juri', 'math', 'prof'], ['prof', 'math', 'juri']],
#  ['cnp02229154', [], ['artist', 'math', 'philo']],
#  ['cnp01005388', ['prof'], ['prof']],
#  ['cnp00449554',
# ...
#  ['cnp01310208', [], ['geo_carto', 'astron']],
#  ['cnp01438995',
#   ['liter', 'philo', 'scholar'],
#   ['huma', 'math', 'philo', 'scholar', 'liter']],
#  ['cnp00950783', ['math'], ['prof', 'math']],
#  ['cnp01073918',
#   ['math', 'philo', 'theol'],
#   ['prof', 'theol', 'math', 'philo', 'anc_lang']],
#  ['cnp01323465',
#   ['liter', 'math', 'theol'],
#   ['prof', 'theol', 'math', 'anc_lang', 'cleric', 'liter']],
#  ['cnp01381608',
#   ['math', 'prof', 'theol'],
#   ['prof', 'math', 'cleric', 'theol']],
#  ['cnp00424957', ['astron', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp01049625', [], []],
#  ['cnp01331399', [], ['astron']],
#  ['cnp00289676', ['math'], ['math']],
#  ['cnp00611867', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp02163061', [], []],
#  ['cnp00459835',
#   ['astron', 'math', 'prof'],
#   ['prof', 'theol', 'astron', 'math', 'med']],
#  ['cnp02176412', [], []],
#  ['cnp01921159', [], ['prof', 'math']],
#  ['cnp01379874', [], ['prof', 'math', 'astron']],
#  ['cnp01391847', [], ['math', 'astron']],
#  ['cnp01919821', [], []],
#  ['cnp02270525', ['cleric', 'math'], ['prof', 'cleric', 'philo', 'math']],
#  ['cnp01969331', [], []],
#  ['cnp01208519',
#   ['math', 'philo', 'theol'],
#   ['prof', 'math', 'philo', 'theol']],
#  ['cnp01065866', ['math'], ['math']],
#  ['cnp01386056',
#   ['astron', 'math', 'med'],
#   ['prof', 'artist', 'astron', 'math', 'anc_lang', 'med', 'liter']],
#  ['cnp00950611', ['astron', 'math'], []],
#  ['cnp01884314',
#   ['astron', 'liter', 'theol'],
#   ['histo', 'huma', 'phys', 'theol', 'astron', 'anc_lang', 'scholar', 'liter']],
#  ['cnp01033546', [], ['prof', 'math']],
#  ['cnp01321930',
#   ['math', 'philo'],
#   ['prof', 'juri', 'theol', 'math', 'philo', 'anc_lang']],
#  ['cnp00526372', [], ['prof']],
#  ['cnp00376916', ['math', 'phys', 'prof'], ['prof', 'math', 'phys']],
#  ['cnp01373057', [], ['prof', 'math', 'archi']],
#  ['cnp00481758', ['astron', 'theol'], []],
#  ['cnp00394712', ['astron'], ['scholar', 'math', 'phys', 'astron']],
#  ['cnp01320816', ['liter', 'math'], ['huma', 'math', 'liter']],
#  ['cnp00634712', ['math', 'philo'], ['prof', 'math', 'philo', 'cleric']],
#  ['cnp00474052',
#   ['cleric', 'philo', 'prof'],
#   ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp02242965', ['math'], ['prof', 'math']],
#  ['cnp01956587', [], ['prof']],
#  ['cnp02087919', ['math', 'philo'], ['math', 'philo', 'archi']],
#  ['cnp02134621', ['math', 'theol'], ['huma', 'math', 'cleric', 'theol']],
#  ['cnp02128577', ['math', 'philo', 'theol'], []],
#  ['cnp02328026', ['math', 'prof'], ['prof', 'math']],
#  ['cnp02230235', [], ['math']],
#  ['cnp00950396', ['math'], []],
#  ['cnp02266642', [], []],
#  ['cnp01336175', ['math', 'theol'], ['math', 'cleric', 'theol']],
#  ['cnp01337053', [], ['prof', 'math', 'phys', 'med']],
#  ['cnp01436478',
#   ['math', 'med', 'phys', 'prof'],
#   ['prof', 'math', 'phys', 'med']],
#  ['cnp01914406', [], ['math', 'philo']],
#  ['cnp00386421',
#   ['astron', 'cleric', 'math'],
#   ['cleric', 'math', 'theol', 'astron']],
#  ['cnp02163036', [], []],
#  ['cnp00974393', ['math', 'prof'], ['prof', 'math']],
#  ['cnp00950031', ['cleric', 'math'], []],
#  ['cnp01358615', ['math'], ['math']],
#  ['cnp01511015', ['histo', 'juri', 'math'], ['prof', 'math', 'histo', 'juri']],
#  ['cnp01881153', ['liter'], ['liter']],
#  ['cnp00405665',
#   ['math', 'philo', 'theol'],
#   ['prof', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp02137514', ['math'], []],
#  ['cnp01371119', [], ['geo_carto', 'astron']],
#  ['cnp02329782', ['math'], ['prof', 'math', 'scholar']],
#  ['cnp01392135', ['cleric'], ['cleric', 'geo_carto', 'astron']],
#  ['cnp01944401', ['math'], []],
#  ['cnp01271878',
#   ['artist', 'astron', 'math', 'prof'],
#   ['prof', 'artist', 'theol', 'astron', 'math', 'philo']],
#  ['cnp01338632', ['math'], ['math']],
#  ['cnp01905866', [], ['math']],
#  ['cnp00406843', ['liter'], ['astron', 'huma', 'liter']],
#  ['cnp00389082',
#   ['math', 'prof'],
#   ['prof', 'geo_carto', 'astrol', 'astron', 'math']],
#  ['cnp01267813', ['artist'], ['artist']],
#  ['cnp01920140',
#   ['anc_lang_philol'],
#   ['prof', 'math', 'philo', 'anc_lang', 'anc_lang_philol']],
#  ['cnp01946728', ['math'], []],
#  ['cnp01372944', [], ['math', 'phys', 'astron']],
#  ['cnp01326948',
#   ['math'],
#   ['prof', 'theol', 'math', 'philo', 'anc_lang', 'cleric', 'liter']],
#  ['cnp01340039',
#   ['astron', 'math', 'phys'],
#   ['prof', 'math', 'phys', 'astron']],
#  ['cnp01150291', ['math', 'theol'], ['prof', 'math', 'cleric', 'theol']],
#  ['cnp01501297', ['math', 'phys'], ['prof', 'phys', 'math', 'philo', 'med']],
#  ['cnp00973415',
#   ['astron', 'cleric', 'math', 'prof', 'theol'],
#   ['prof', 'theol', 'astron', 'math', 'cleric']],
#  ['cnp01938795', ['math', 'phys'], ['math', 'phys']],
#  ['cnp00396411',
#   ['med', 'scholar'],
#   ['histo', 'geo_carto', 'astron', 'scholar', 'med']],
#  ['cnp01341197', [], ['histo', 'phys', 'astron', 'anc_lang', 'scholar', 'med']],
#  ['cnp00942919', ['astron'], []],
#  ['cnp01166090', ['histo', 'math'], ['math', 'histo', 'cleric']],
#  ['cnp00387315', ['math', 'phys'], ['prof', 'math', 'phys']],
#  ['cnp01360525', [], ['cleric', 'math']],
#  ['cnp01330343',
#   ['astron', 'liter', 'math'],
#   ['huma', 'astron', 'math', 'anc_lang', 'liter']],
#  ['cnp00390358',
#   ['cleric', 'math', 'phys', 'prof', 'scholar', 'theol'],
#   ['prof', 'phys', 'theol', 'math', 'scholar', 'cleric']],
#  ['cnp01006233', ['med', 'prof'], ['prof', 'math', 'phys', 'med']],
#  ['cnp01391728', ['geo_carto'], ['geo_carto', 'astron']],
#  ['cnp01416537', ['math', 'phys'], ['math', 'phys', 'theol']],
#  ['cnp00458613', [], ['prof']],
#  ['cnp00408365', ['scholar'], ['math', 'phys', 'archi', 'scholar']],
#  ['cnp02306517', [], ['prof', 'cleric', 'math']],
#  ['cnp01391475', ['juri', 'math', 'prof'], ['prof', 'math', 'juri']],
#  ['cnp01128300', [], []],
#  ['cnp00415445', ['juri', 'math'], []],
#  ['cnp01397344', [], ['prof', 'math', 'astron']],
#  ['cnp01310754', [], ['math', 'astron']],
#  ['cnp00873636', ['astron', 'math', 'prof'], []],
#  ['cnp02218403', [], []],
#  ['cnp01323455', ['math'], ['huma', 'math']],
#  ['cnp01327945',
#   ['astron', 'geo_carto', 'math'],
#   ['prof', 'geo_carto', 'phys', 'astron', 'math', 'anc_lang']],
#  ['cnp01353680',
#   ['juri', 'prof'],
#   ['prof', 'juri', 'theol', 'math', 'anc_lang']],
#  ['cnp01310736', [], ['astron']],
#  ['cnp00620144', ['phys'], ['prof', 'math', 'phys']],
#  ['cnp02187878', ['astron', 'med'], ['med', 'astron']],
#  ['cnp01907258', [], ['prof', 'math']],
#  ['cnp00938379', ['math', 'philo'], ['prof', 'math', 'philo']],
#  ['cnp00935714', ['math'], ['prof', 'math', 'cleric', 'theol']],
#  ['cnp01355792', ['math', 'philo'], ['prof', 'math', 'philo']],
#  ['cnp01956097', ['inge', 'math'], ['huma', 'inge', 'math']],
#  ['cnp01337942',
#   ['math', 'phys', 'prof'],
#   ['prof', 'phys', 'theol', 'math', 'philo']],
#  ['cnp01425174',
#   ['cleric', 'math', 'theol'],
#   ['cleric', 'math', 'theol', 'astron']],
#  ['cnp01341011', ['math'], ['math']],
#  ['cnp01296840',
#   ['math', 'philo', 'scholar', 'theol'],
#   ['prof', 'theol', 'math', 'philo', 'scholar', 'cleric']],
#  ['cnp00482858',
#   ['astron', 'cleric', 'math', 'prof', 'theol'],
#   ['prof', 'theol', 'astron', 'math', 'philo', 'cleric']],
#  ['cnp02163250', [], []],
#  ['cnp01371511',
#   ['book', 'theol'],
#   ['book', 'theol', 'math', 'philo', 'scholar']],
#  ['cnp01406883', ['math', 'theol'], ['prof', 'math', 'theol', 'scholar']],
#  ['cnp02168144', [], ['cleric', 'philo', 'math']],
#  ['cnp01502265', ['cleric', 'theol'], ['cleric', 'theol']],
#  ['cnp01481635',
#   ['math', 'philo', 'phys', 'prof', 'theol'],
#   ['prof', 'phys', 'theol', 'math', 'philo', 'anc_lang', 'scholar', 'liter']],
#  ['cnp01283791', ['cleric', 'prof'], ['prof', 'cleric', 'math']],
#  ['cnp01294650', ['prof'], ['prof', 'math']],
#  ['cnp00555044',
#   ['astron', 'cleric', 'math'],
#   ['prof', 'astron', 'math', 'anc_lang', 'cleric']],
#  ['cnp00114038', ['geo_carto', 'math'], []],
#  ['cnp01271242', ['math'], ['math']],
#  ['cnp01427068', ['math'], ['math', 'cleric']],
#  ['cnp01307036',
#   ['liter', 'math'],
#   ['prof', 'huma', 'math', 'cleric', 'liter']],
#  ['cnp02213909', ['inge', 'math'], ['inge', 'math']],
#  ['cnp00395781', ['artist', 'book'], ['artist', 'book']],
#  ['cnp00382785', ['math'], ['prof', 'math', 'theol']],
#  ['cnp01313448', ['math'], ['math', 'scholar']],
#  ['cnp02238866', ['math'], ['math', 'anc_lang', 'astron']],
#  ['cnp01386031', [], ['math', 'astron']],
#  ['cnp00959838',
#   ['astron', 'math', 'prof'],
#   ['prof', 'astron', 'math', 'philo', 'scholar']],
#  ['cnp00401670', ['archi', 'astron', 'math', 'phys'], []],
#  ['cnp01441824',
#   ['geo_carto', 'histo', 'math'],
#   ['math', 'histo', 'geo_carto']],
#  ['cnp00873272', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp00420502', ['cleric'], ['cleric']],
#  ['cnp01207886', ['math', 'philo', 'prof', 'scholar', 'theol'], []],
#  ['cnp02265415', [], ['astron']],
#  ['cnp01273354', ['astrol'], ['astrol']],
#  ['cnp01229576', ['math'], ['prof', 'math', 'cleric']],
#  ['cnp00155913', ['med'], ['med']],
#  ['cnp01328111', [], ['math', 'anc_lang', 'phys']],
#  ['cnp01311691', [], ['cleric', 'astron']],
#  ['cnp02163079', [], []],
#  ['cnp02091188',
#   ['cleric', 'prof', 'theol'],
#   ['prof', 'cleric', 'theol', 'astron']],
#  ['cnp01939035', ['archi', 'astron'], ['archi', 'astron']],
#  ['cnp01411736', ['theol'], ['prof', 'phys', 'theol', 'math', 'anc_lang']],
#  ['cnp02060705', ['astron'], []],
#  ['cnp00149586',
#   ['astron', 'math', 'philo', 'prof', 'theol'],
#   ['prof', 'theol', 'astron', 'math', 'philo', 'cleric']],
#  ['cnp00357110', [], []],
#  ['cnp00405760', ['math'], ['math', 'philo', 'cleric']],
#  ['cnp01327508', [], ['prof', 'math', 'geo_carto', 'astron']],
#  ['cnp01355708', ['liter'], ['juri', 'liter']],
#  ['cnp01331171',
#   ['astron', 'math', 'phys', 'scholar'],
#   ['prof', 'phys', 'astron', 'math', 'philo', 'scholar', 'liter']],
#  ['cnp00616670',
#   ['astron', 'geo_carto', 'phys'],
#   ['prof', 'geo_carto', 'phys', 'astron', 'math']],
#  ['cnp01340546', ['geo_carto'], ['math', 'geo_carto']],
#  ['cnp01361348',
#   ['astron', 'liter', 'math'],
#   ['huma', 'liter', 'math', 'astron']],
#  ['cnp01167073', ['math', 'prof'], ['prof', 'math']],
#  ['cnp01327525', ['astron', 'cleric'], ['cleric', 'histo', 'astron']],
#  ['cnp00978256', ['math'], ['math', 'geo_carto', 'scholar']],
#  ['cnp00398351', ['math'], ['math']],
#  ['cnp00989107', [], []],
#  ['cnp01155894', ['math', 'phys'], []],
#  ['cnp00934743',
#   ['astron', 'math', 'theol'],
#   ['prof', 'math', 'theol', 'astron']],
#  ['cnp00454735', ['cleric'], ['prof', 'cleric', 'math', 'theol']],
#  ['cnp01227314', ['math', 'prof'], ['prof', 'math']],
#  ['cnp02252448', ['juri'], ['math', 'juri', 'astron']],
#  ['cnp01364665',
#   ['math', 'phys'],
#   ['prof', 'phys', 'astron', 'math', 'philo', 'anc_lang', 'scholar', 'med']],
#  ['cnp01127346', ['book', 'math', 'philo'], ['prof', 'math', 'philo', 'book']],
#  ['cnp01322254',
#   ['liter', 'math', 'philo', 'theol'],
#   ['prof', 'juri', 'theol', 'math', 'philo', 'liter']],
#  ['cnp02213004', ['astron', 'math'], []],
#  ['cnp02210701', ['math'], ['math']],
#  ['cnp00421828', ['math'], ['prof', 'math']],
#  ['cnp01979544', ['prof'], ['prof', 'math']],
#  ['cnp00951342', ['prof'], ['prof', 'math', 'anc_lang']],
#  ['cnp02163090', ['astron'], ['astron']],
#  ['cnp00111937', ['math'], []],
#  ['cnp01281827', ['med'], ['prof', 'math', 'philo', 'med']],
#  ['cnp00473300', [], ['cleric', 'phys', 'math']],
#  ['cnp00800049', ['math', 'theol'], ['math', 'theol', 'astron']],
#  ['cnp01088897', ['juri', 'math'], ['math', 'juri']],
#  ['cnp02334268', [], ['math']],
#  ['cnp01370536', ['med'], ['huma', 'med']],
#  ['cnp00102076', [], ['cleric']],
#  ['cnp01167258', ['astron', 'math', 'prof'], ['prof', 'math', 'astron']],
#  ['cnp01994802', ['med'], ['math', 'med']],
#  ['cnp02207805', ['math'], []],
#  ['cnp01422962', ['juri'], ['juri']],
#  ['cnp00472229',
#   ['histo', 'math', 'prof'],
#   ['prof', 'math', 'histo', 'cleric']],
#  ['cnp02189751', ['astron', 'math', 'philo'], []],
#  ['cnp02210773', ['astron', 'math'], []],
#  ['cnp01088135', [], ['cleric', 'philo', 'math']],
#  ['cnp00547788', ['math'], ['math']],
#  ['cnp02071743', ['artist', 'math'], ['artist', 'math']],
#  ['cnp02209689', ['math', 'scholar', 'theol'], []],
#  ['cnp00105985', ['math', 'prof'], ['prof', 'math', 'inge']],
#  ['cnp01304917', [], ['prof', 'math']],
#  ['cnp00352902', ['math', 'philo'], []],
#  ['cnp01317909',
#   ['astron', 'math', 'phys'],
#   ['phys', 'astron', 'math', 'philo', 'scholar']],
#  ['cnp00416288', ['math', 'philo', 'theol'], ['math', 'philo', 'theol']],
#  ['cnp01375132', ['histo'], ['prof', 'math', 'histo']],
#  ['cnp00424400', ['math', 'med', 'phys'], ['math', 'phys', 'med', 'scholar']],
#  ['cnp00381221',
#   ['astron', 'cleric', 'prof', 'theol'],
#   ['prof', 'cleric', 'theol', 'astron']],
#  ['cnp02213140', ['archi', 'math'], []],
#  ['cnp00387676', ['math', 'philo'], ['prof', 'math', 'philo', 'phys']],
#  ['cnp01339506', [], ['prof', 'math', 'philo']],
#  ['cnp01885482', ['math', 'phys'], ['prof', 'math', 'phys', 'scholar']],
#  ['cnp00384742',
#   ['astron', 'math'],
#   ['prof', 'phys', 'astron', 'math', 'philo', 'med']],
#  ['cnp01336730', ['math'], ['math', 'cleric', 'theol']],
#  ['cnp01260483', ['anc_lang_philol', 'juri'], ['juri', 'anc_lang_philol']],
#  ['cnp01229790', ['math', 'prof'], ['prof', 'math', 'juri']],
#  ['cnp02153688', [], []],
#  ['cnp01340685', ['math', 'philo', 'phys'], ['prof', 'math', 'philo', 'phys']],
#  ['cnp00475918', ['med', 'philo', 'prof'], ['prof', 'math', 'philo', 'med']],
#  ['cnp01387988', ['math'], ['prof', 'math', 'philo', 'anc_lang', 'med']],
#  ['cnp02163844', ['astron', 'histo'], ['histo', 'astron']],
#  ['cnp00415975', ['math'], ['math']],
#  ['cnp02163209', [], []],
#  ['cnp02181704', ['math', 'philo'], ['prof', 'math', 'philo']],
#  ['cnp01142873', [], []],
#  ['cnp02308630', [], ['liter']],
#  ['cnp00415435', ['math'], ['math']],
#  ['cnp01406818', ['math'], ['math']],
#  ['cnp02147246', ['math'], []],
#  ['cnp01326430', [], ['inge', 'math']],
#  ['cnp01005241', ['math', 'med', 'philo', 'prof'], []],
#  ['cnp01085443',
#   ['med', 'prof'],
#   ['prof', 'juri', 'phys', 'math', 'philo', 'scholar', 'med']],
#  ['cnp01132050', ['book', 'prof'], ['prof', 'math', 'philo', 'book']],
#  ['cnp00514820', ['med', 'prof'], ['prof', 'math', 'phys', 'med']],
#  ['cnp02106929', ['astron', 'philo', 'phys'], []],
#  ['cnp02062635', [], []],
#  ['cnp00387153', ['math'], ['math', 'astron']],
#  ['cnp00390713',
#   ['astron', 'phys', 'prof'],
#   ['prof', 'math', 'phys', 'astron']],
#  ['cnp00954353', ['astron', 'math'], []],
#  ['cnp00961968', ['math', 'philo'], ['math', 'philo']],
#  ['cnp01324793',
#   ['book', 'juri', 'math', 'philo'],
#   ['prof', 'book', 'juri', 'math', 'philo', 'scholar']],
#  ['cnp01310072', [], ['math']],
#  ['cnp01196433', ['math', 'prof', 'theol'], ['prof', 'math', 'theol']],
#  ['cnp01428444', ['math'], ['math', 'phys', 'astron']],
#  ['cnp02069898', ['cleric', 'math'], ['cleric', 'math']],
#  ['cnp02163256', [], []],
#  ['cnp02128642',
#   ['geo_carto', 'liter', 'math'],
#   ['math', 'geo_carto', 'liter']],
#  ['cnp00381182', ['juri'], ['juri', 'theol', 'math', 'philo', 'anc_lang']],
#  ['cnp01331537', ['math'], ['huma', 'math', 'prof']],
#  ['cnp00936828',
#   ['anc_lang_philol', 'math'],
#   ['prof', 'math', 'anc_lang_philol']],
#  ['cnp01406268', [], ['prof', 'math', 'philo']],
#  ['cnp01496383',
#   ['artist', 'juri', 'liter', 'math', 'phys', 'prof'],
#   ['prof',
#    'juri',
#    'artist',
#    'huma',
#    'phys',
#    'math',
#    'anc_lang',
#    'scholar',
#    'liter']],
#  ['cnp02163251', [], []],
#  ['cnp02294549', [], ['prof', 'cleric', 'phys', 'math']],
#  ['cnp00962937', ['math', 'philo'], []],
#  ['cnp01087627', ['math', 'philo'], []],
#  ['cnp00388799',
#   ['cleric', 'math', 'philo', 'phys', 'theol'],
#   ['prof', 'phys', 'theol', 'math', 'philo', 'cleric']],
#  ['cnp01327702',
#   ['astron', 'geo_carto', 'math', 'phys'],
#   ['geo_carto', 'phys', 'astron', 'math', 'anc_lang']],
#  ['cnp01006600', ['math', 'phys', 'scholar'], ['math', 'phys', 'scholar']],
#  ['cnp01423328', ['archi', 'math'], ['prof', 'math', 'archi']],
#  ['cnp00985092', ['astron'], []],
#  ['cnp01443734',
#   ['histo', 'liter', 'math', 'philo', 'theol'],
#   ['prof', 'histo', 'theol', 'math', 'philo', 'liter']],
#  ['cnp01303858', [], ['math']],
#  ['cnp01332040', ['liter'], ['huma', 'math', 'liter']]]

# %% [markdown]
# ## Add aggregation codes
#
# !!! This step must be carefully considered and adapted in the point of view of heuristic

# %%
jl_list = []
for jl in joined_list:
    if 'med' in jl[1] and ('astrol' in jl[1] or 'astron' in jl[1] or 'math' in jl[1]):
        jl_list.append([jl[0], 'med_math', jl[1]])
        pass
    elif ('theol' in jl[1] or 'cleric' in jl[1]) and ('astrol' in jl[1] or 'astron' in jl[1] or 'math' in jl[1]):
        jl_list.append([jl[0], 'theol_math', jl[1]])
        pass
    elif 'med' in jl[1]:
        jl_list.append([jl[0], 'med', jl[1]])
        pass
    elif ('theol' in jl[1] or 'cleric' in jl[1]) in jl[1]:
        jl_list.append([jl[0], 'theol', jl[1]])
        pass
    elif 'astrol' in jl[1]:
        jl_list.append([jl[0], 'astrol', jl[1]])
        pass
    elif 'astron' in jl[1]:
        jl_list.append([jl[0], 'astron', jl[1]])
        pass
    elif 'math' in jl[1]:
        jl_list.append([jl[0], 'math', jl[1]])
        pass
    elif 'philo' in jl[1] or 'phys' in jl[1]:
        jl_list.append([jl[0], 'philo_phys', jl[1]])
        pass
    else:
        jl_list.append([jl[0], 'other', jl[1]])

# %%
print(len(jl_list))
pprint.pprint(jl_list)
# Out:
# 1038
# [['cnp01352012', 'other', ['theol']],
#  ['cnp02088071', 'med_math', ['astrol', 'med', 'philo']],
#  ['cnp01881207', 'philo_phys', ['philo', 'theol']],
#  ['cnp01879247', 'med', ['huma', 'med']],
#  ['cnp00996213', 'med_math', ['astrol', 'math', 'med', 'prof']],
#  ['cnp01320054', 'astron', ['astron', 'histo', 'scholar']],
#  ['cnp01363268', 'med', ['med']],
#  ['cnp01241028', 'other', []],
#  ['cnp00873006', 'other', ['anc_lang_philol']],
#  ['cnp01329886', 'math', ['huma', 'liter', 'math', 'philo']],
#  ['cnp01363122', 'theol_math', ['huma', 'math', 'philo', 'theol']],
#  ['cnp00350996', 'med_math', ['astron', 'med', 'theol']],
#  ['cnp02222242', 'other', []],
#  ['cnp01884261', 'other', []],
#  ['cnp00397446', 'math', ['geo_carto', 'math']],
#  ['cnp01368034', 'med', ['med', 'philo']],
#  ['cnp01335792', 'philo_phys', ['philo', 'scholar']],
#  ['cnp00888506', 'other', ['prof', 'theol']],
#  ['cnp01879502', 'other', []],
#  ['cnp00556047', 'other', []],
#  ['cnp01362970', 'philo_phys', ['histo', 'philo']],
#  ['cnp01115869', 'math', ['math']],
#  ['cnp00402391', 'astron', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01365166', 'med', ['med']],
#  ['cnp02088587', 'med', ['med', 'theol']],
#  ['cnp01409583', 'other', []],
#  ['cnp01114322', 'math', ['liter', 'math']],
#  ['cnp00100623', 'other', ['juri', 'liter', 'theol']],
#  ['cnp01352888', 'med_math', ['astrol', 'med']],
#  ['cnp01392374', 'theol_math', ['astron', 'cleric', 'math']],
#  ['cnp01172052', 'astron', ['artist', 'astron', 'geo_carto']],
#  ['cnp01876151',
#   'theol_math',
#   ['astron', 'geo_carto', 'huma', 'math', 'theol']],
#  ['cnp01317063', 'math', ['artist', 'math']],
#  ['cnp01319857', 'other', ['prof']],
#  ['cnp00398396', 'med_math', ['astrol', 'histo', 'med']],
#  ['cnp01471426', 'med_math', ['astron', 'math', 'med', 'philo']],
#  ['cnp00412417', 'math', ['math']],
#  ['cnp01875338', 'med', ['med']],
#  ['cnp01470125', 'other', ['artist']],
#  ['cnp01309925', 'other', []],
#  ['cnp01320896', 'theol_math', ['astron', 'cleric', 'geo_carto', 'math']],
#  ['cnp00400924', 'other', ['cleric', 'theol']],
#  ['cnp01876860', 'med', ['med']],
#  ['cnp01331039', 'other', []],
#  ['cnp01329937', 'other', ['archi', 'inge']],
#  ['cnp01486719', 'med_math', ['astrol', 'med', 'theol']],
#  ['cnp01180030', 'math', ['archi', 'math']],
#  ['cnp01255966', 'other', []],
#  ['cnp01341438', 'other', []],
#  ['cnp01880057', 'other', ['huma']],
#  ['cnp01316341', 'med', ['med']],
#  ['cnp01233195', 'math', ['math']],
#  ['cnp01118781', 'med_math', ['astron', 'med']],
#  ['cnp01147469', 'astron', ['astron', 'math']],
#  ['cnp00917420', 'theol_math', ['math', 'theol']],
#  ['cnp01120503', 'math', ['math']],
#  ['cnp00526061', 'other', []],
#  ['cnp01320560', 'other', ['theol']],
#  ['cnp02223694', 'other', []],
#  ['cnp01329458', 'other', ['theol']],
#  ['cnp01875480', 'theol_math', ['cleric', 'huma', 'math', 'theol']],
#  ['cnp02236633', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp01919968', 'other', []],
#  ['cnp01877797', 'astron', ['astron', 'math']],
#  ['cnp00639317', 'other', []],
#  ['cnp01884758', 'other', []],
#  ['cnp01330865',
#   'med_math',
#   ['anc_lang_philol',
#    'cleric',
#    'huma',
#    'math',
#    'med',
#    'philo',
#    'prof',
#    'scholar',
#    'theol']],
#  ['cnp01313334', 'math', ['math', 'prof']],
#  ['cnp01881119', 'astron', ['artist', 'astron', 'geo_carto', 'math']],
#  ['cnp01290195', 'other', []],
#  ['cnp01876551', 'math', ['geo_carto', 'math', 'prof']],
#  ['cnp01019887', 'other', ['theol']],
#  ['cnp01347892', 'astron', ['astron', 'geo_carto', 'math']],
#  ['cnp01323680', 'theol_math', ['geo_carto', 'math', 'prof', 'theol']],
#  ['cnp01875467', 'med', ['med']],
#  ['cnp01880016', 'other', ['cleric', 'prof', 'theol']],
#  ['cnp00579703', 'other', ['artist']],
#  ['cnp01443317', 'astrol', ['astrol', 'histo', 'math']],
#  ['cnp01875826', 'math', ['huma', 'math']],
#  ['cnp00405470', 'math', ['math']],
#  ['cnp00569865', 'other', ['archi']],
#  ['cnp01356340', 'math', ['inge', 'math', 'prof']],
#  ['cnp01350201', 'math', ['inge', 'math']],
#  ['cnp01876658', 'other', ['theol']],
#  ['cnp01349348', 'other', ['anc_lang_philol', 'scholar']],
#  ['cnp01443388', 'med_math', ['math', 'med', 'scholar']],
#  ['cnp01121159', 'other', ['prof']],
#  ['cnp01392199', 'other', ['artist', 'geo_carto']],
#  ['cnp00545294', 'other', ['artist']],
#  ['cnp01875706', 'other', ['juri']],
#  ['cnp01084480', 'astron', ['astron', 'math', 'prof']],
#  ['cnp00482208', 'math', ['archi', 'liter', 'math']],
#  ['cnp01364712', 'other', ['artist']],
#  ['cnp01112298', 'other', []],
#  ['cnp01114860', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01437248', 'med_math', ['astron', 'math', 'med', 'philo', 'scholar']],
#  ['cnp02156073', 'astron', ['astron', 'math', 'philo']],
#  ['cnp02078749', 'astron', ['astron', 'math']],
#  ['cnp01122000', 'theol_math', ['astrol', 'cleric', 'prof', 'theol']],
#  ['cnp00950341', 'other', ['prof', 'theol']],
#  ['cnp01179438', 'med', ['histo', 'med']],
#  ['cnp01112480', 'med', ['med']],
#  ['cnp01468914', 'other', []],
#  ['cnp01345792', 'other', []],
#  ['cnp01876067', 'other', []],
#  ['cnp01875828', 'other', ['theol']],
#  ['cnp01875825', 'other', ['cleric', 'theol']],
#  ['cnp01877605', 'med_math', ['astron', 'histo', 'med', 'phys']],
#  ['cnp01336086', 'med', ['med']],
#  ['cnp00125017', 'med_math', ['astrol', 'astron', 'med']],
#  ['cnp01876979', 'med_math', ['astron', 'math', 'med']],
#  ['cnp01334753', 'philo_phys', ['liter', 'philo']],
#  ['cnp01879181', 'med_math', ['math', 'med']],
#  ['cnp01875669', 'other', []],
#  ['cnp01361113', 'other', ['liter']],
#  ['cnp01352300', 'other', ['archi']],
#  ['cnp01307139', 'math', ['math', 'philo', 'scholar']],
#  ['cnp01363533', 'other', []],
#  ['cnp01340478', 'med', ['med']],
#  ['cnp01324006', 'other', ['huma']],
#  ['cnp02239016', 'other', []],
#  ['cnp01395548', 'astron', ['astron']],
#  ['cnp02163127', 'other', []],
#  ['cnp01292034', 'astrol', ['astrol']],
#  ['cnp01443254', 'astron', ['astron', 'math']],
#  ['cnp01355754', 'theol_math', ['geo_carto', 'math', 'philo', 'theol']],
#  ['cnp01875767', 'med_math', ['astrol', 'math', 'med']],
#  ['cnp01876433', 'other', ['cleric', 'prof', 'theol']],
#  ['cnp01875723', 'astron', ['astron', 'math']],
#  ['cnp01323251', 'math', ['huma', 'math', 'philo', 'prof']],
#  ['cnp01120341', 'astrol', ['astrol', 'astron', 'math']],
#  ['cnp01387069', 'other', ['artist']],
#  ['cnp02170729', 'med_math', ['math', 'med', 'prof']],
#  ['cnp01337057', 'other', ['liter']],
#  ['cnp01303529', 'astron', ['astron', 'math']],
#  ['cnp01124849', 'astron', ['astron', 'math']],
#  ['cnp01287286', 'med_math', ['astron', 'med']],
#  ['cnp01368037', 'other', []],
#  ['cnp01875207', 'other', ['cleric', 'theol']],
#  ['cnp01200592', 'math', ['geo_carto', 'math']],
#  ['cnp02266756', 'other', []],
#  ['cnp02134922', 'med_math', ['math', 'med']],
#  ['cnp02230942', 'other', []],
#  ['cnp00989664', 'other', ['anc_lang_philol', 'cleric', 'theol']],
#  ['cnp01875685', 'med', ['med', 'philo']],
#  ['cnp01407758', 'other', []],
#  ['cnp01347099', 'other', ['book', 'histo', 'juri']],
#  ['cnp01481137', 'other', ['cleric', 'theol']],
#  ['cnp01089747', 'math', ['math']],
#  ['cnp01235486', 'math', ['math']],
#  ['cnp01356128', 'other', []],
#  ['cnp01358480', 'other', ['liter']],
#  ['cnp00402987', 'astron', ['astron', 'book', 'geo_carto', 'inge', 'math']],
#  ['cnp01333594', 'other', []],
#  ['cnp01345049', 'math', ['math']],
#  ['cnp01441705', 'med_math', ['astron', 'math', 'med']],
#  ['cnp01443175', 'med', ['histo', 'huma', 'med', 'prof', 'scholar']],
#  ['cnp02163173', 'other', []],
#  ['cnp00888077', 'math', ['math', 'prof']],
#  ['cnp01318480', 'other', []],
#  ['cnp01904447', 'math', ['math']],
#  ['cnp01025752', 'other', ['liter', 'prof']],
#  ['cnp01124424', 'math', ['math']],
#  ['cnp00876424', 'other', ['theol']],
#  ['cnp02163146', 'other', []],
#  ['cnp01113305', 'med_math', ['math', 'med']],
#  ['cnp01877782', 'astrol', ['astrol', 'astron', 'math']],
#  ['cnp01056939', 'other', ['prof']],
#  ['cnp00450702', 'med_math', ['math', 'med']],
#  ['cnp02163189', 'other', []],
#  ['cnp01919710', 'other', []],
#  ['cnp01878121', 'med', ['med', 'prof']],
#  ['cnp01029668', 'astron', ['astron', 'math']],
#  ['cnp01350014', 'med', ['artist', 'med', 'philo', 'prof']],
#  ['cnp01920049', 'other', []],
#  ['cnp01409038', 'astron', ['astron', 'juri', 'math']],
#  ['cnp01078149', 'astron', ['astron', 'math']],
#  ['cnp01302722', 'philo_phys', ['philo']],
#  ['cnp02252061', 'math', ['archi', 'math']],
#  ['cnp01368443', 'other', ['liter']],
#  ['cnp01880790', 'math', ['math', 'philo', 'phys']],
#  ['cnp01303321', 'med_math', ['artist', 'astron', 'math', 'med', 'prof']],
#  ['cnp01302340', 'math', ['juri', 'math']],
#  ['cnp01363433', 'astron', ['astron', 'geo_carto', 'liter', 'math']],
#  ['cnp00453662', 'med_math', ['astron', 'med']],
#  ['cnp01302373', 'med', ['med', 'prof', 'scholar']],
#  ['cnp01240021', 'astron', ['astron', 'math']],
#  ['cnp00394082', 'med_math', ['geo_carto', 'math', 'med']],
#  ['cnp01231917', 'other', ['huma']],
#  ['cnp01104400', 'astron', ['astron', 'huma', 'math']],
#  ['cnp01390409', 'other', ['cleric']],
#  ['cnp01365922', 'med_math', ['math', 'med', 'philo']],
#  ['cnp01875401', 'med_math', ['astrol', 'med']],
#  ['cnp01333847', 'other', ['huma', 'liter', 'prof']],
#  ['cnp01337628', 'med', ['med']],
#  ['cnp01879907', 'astron', ['astron', 'math']],
#  ['cnp01327594', 'med_math', ['astrol', 'med']],
#  ['cnp00122851', 'other', ['theol']],
#  ['cnp01237076', 'med', ['med']],
#  ['cnp01033767', 'math', ['math']],
#  ['cnp01919971', 'other', []],
#  ['cnp01113388', 'med', ['med']],
#  ['cnp01116302', 'math', ['math', 'prof']],
#  ['cnp01389779', 'other', []],
#  ['cnp01340100', 'med_math', ['astron', 'math', 'med']],
#  ['cnp00407311', 'math', ['math']],
#  ['cnp01107316', 'math', ['math']],
#  ['cnp02101603', 'other', []],
#  ['cnp00476702',
#   'theol_math',
#   ['archi', 'artist', 'astron', 'geo_carto', 'inge', 'scholar', 'theol']],
#  ['cnp00014570', 'other', ['anc_lang_philol', 'histo', 'huma']],
#  ['cnp01105937', 'astron', ['astron', 'liter']],
#  ['cnp01358036', 'med_math', ['math', 'med']],
#  ['cnp01919917', 'other', []],
#  ['cnp01320637', 'math', ['anc_lang_philol', 'math']],
#  ['cnp00444650', 'other', ['juri']],
#  ['cnp01307458', 'math', ['math']],
#  ['cnp01301986', 'astron', ['astron', 'math']],
#  ['cnp01079978', 'med_math', ['math', 'med', 'prof']],
#  ['cnp01919930', 'other', []],
#  ['cnp01311921', 'math', ['math']],
#  ['cnp01880451', 'astron', ['astron']],
#  ['cnp01109829', 'med_math', ['astron', 'math', 'med']],
#  ['cnp01920024', 'med_math', ['astrol', 'med']],
#  ['cnp00157873', 'math', ['math']],
#  ['cnp00485397', 'med_math', ['math', 'med', 'phys', 'prof']],
#  ['cnp02105686', 'astron', ['astron']],
#  ['cnp01879549', 'other', ['archi']],
#  ['cnp00416575', 'theol_math', ['cleric', 'math', 'theol']],
#  ['cnp01124562',
#   'med_math',
#   ['archi', 'artist', 'astron', 'liter', 'med', 'prof']],
#  ['cnp01358244', 'other', []],
#  ['cnp01377638', 'math', ['archi', 'inge', 'math']],
#  ['cnp01919886', 'other', []],
#  ['cnp01103897', 'astron', ['astron', 'geo_carto']],
#  ['cnp01306733', 'other', []],
#  ['cnp01880764', 'math', ['math']],
#  ['cnp00096056', 'math', ['anc_lang_philol', 'math']],
#  ['cnp01291699', 'med', ['med', 'prof', 'theol']],
#  ['cnp01322847', 'math', ['math']],
#  ['cnp02162972', 'other', []],
#  ['cnp01303545', 'med_math', ['astrol', 'astron', 'cleric', 'med', 'theol']],
#  ['cnp01919940', 'other', []],
#  ['cnp01082076', 'med', ['med', 'prof']],
#  ['cnp01045770', 'other', []],
#  ['cnp01113293', 'med_math', ['math', 'med', 'phys']],
#  ['cnp01422536', 'math', ['math']],
#  ['cnp01303513', 'theol_math', ['histo', 'math', 'theol']],
#  ['cnp01355346', 'other', []],
#  ['cnp01368065', 'math', ['math']],
#  ['cnp02163025', 'other', []],
#  ['cnp00458518', 'astron', ['astron', 'math']],
#  ['cnp00571276', 'astron', ['astron']],
#  ['cnp01468084', 'other', ['liter']],
#  ['cnp00962892', 'med_math', ['math', 'med', 'phys', 'prof']],
#  ['cnp01237192', 'astron', ['astron', 'philo']],
#  ['cnp01259618', 'math', ['inge', 'math']],
#  ['cnp01342652', 'math', ['math']],
#  ['cnp01919686', 'other', []],
#  ['cnp01919799', 'med', ['anc_lang_philol', 'book', 'huma', 'med', 'prof']],
#  ['cnp01309947', 'other', []],
#  ['cnp00922870', 'other', []],
#  ['cnp01338415', 'astron', ['astron', 'math']],
#  ['cnp01112934', 'astron', ['astron']],
#  ['cnp01944825', 'math', ['math']],
#  ['cnp02163156', 'other', []],
#  ['cnp01286849', 'astron', ['astron']],
#  ['cnp01110021', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01879400', 'philo_phys', ['anc_lang_philol', 'inge', 'philo']],
#  ['cnp02163192', 'med', ['med']],
#  ['cnp00446750', 'other', ['huma']],
#  ['cnp01329248', 'other', []],
#  ['cnp02231369', 'other', ['juri', 'scholar']],
#  ['cnp00481169', 'math', ['geo_carto', 'math']],
#  ['cnp02163276', 'other', []],
#  ['cnp01467090', 'other', []],
#  ['cnp00605131', 'other', []],
#  ['cnp01104779', 'astron', ['astron', 'book', 'math', 'prof']],
#  ['cnp01133177', 'other', ['geo_carto']],
#  ['cnp01919833', 'other', []],
#  ['cnp02163082', 'other', []],
#  ['cnp01377920', 'math', ['geo_carto', 'math']],
#  ['cnp01328166', 'astron', ['astron']],
#  ['cnp01291829', 'math', ['math']],
#  ['cnp01356171', 'astron', ['artist', 'astron', 'prof']],
#  ['cnp02237779', 'other', []],
#  ['cnp01316739', 'other', ['histo', 'liter']],
#  ['cnp02222256', 'astron', ['astron', 'math']],
#  ['cnp00444503', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01359016', 'med_math', ['astron', 'liter', 'med', 'prof']],
#  ['cnp01919691', 'other', []],
#  ['cnp01895099', 'med_math', ['math', 'med', 'prof']],
#  ['cnp01878530', 'math', ['math']],
#  ['cnp00369337', 'med_math', ['cleric', 'math', 'med']],
#  ['cnp00444510', 'other', []],
#  ['cnp01343086', 'astron', ['astron', 'math', 'phys']],
#  ['cnp01876902', 'med_math', ['astron', 'cleric', 'math', 'med']],
#  ['cnp01877738', 'med_math', ['math', 'med', 'phys']],
#  ['cnp00384901', 'med', ['med', 'prof']],
#  ['cnp00475665', 'other', ['cleric']],
#  ['cnp00386604', 'med_math', ['math', 'med']],
#  ['cnp00883349', 'med_math', ['math', 'med']],
#  ['cnp01327326', 'theol_math', ['cleric', 'math']],
#  ['cnp00094435', 'other', []],
#  ['cnp01344864', 'med_math', ['math', 'med']],
#  ['cnp01024644', 'other', ['theol']],
#  ['cnp01307826', 'other', []],
#  ['cnp01054493', 'med', ['med']],
#  ['cnp01273329', 'theol_math', ['astron', 'cleric']],
#  ['cnp01920011', 'med_math', ['astrol', 'math', 'med']],
#  ['cnp01920012', 'other', []],
#  ['cnp00543426', 'other', ['scholar']],
#  ['cnp01103907', 'astron', ['astron']],
#  ['cnp00366743', 'theol_math', ['artist', 'astron', 'cleric', 'math']],
#  ['cnp01919970', 'other', []],
#  ['cnp00099596', 'other', []],
#  ['cnp01330272', 'theol_math', ['cleric', 'math', 'philo']],
#  ['cnp01919706', 'other', []],
#  ['cnp00976839', 'theol_math', ['astron', 'book', 'cleric']],
#  ['cnp00951038', 'astron', ['astron', 'math']],
#  ['cnp00394836', 'astron', ['astron', 'math', 'philo', 'phys']],
#  ['cnp02163119', 'math', ['math']],
#  ['cnp01327958', 'med_math', ['astron', 'book', 'math', 'med', 'prof']],
#  ['cnp01920041', 'other', []],
#  ['cnp00424447', 'astron', ['astron', 'math']],
#  ['cnp01879023',
#   'philo_phys',
#   ['book', 'cleric', 'geo_carto', 'histo', 'philo', 'prof']],
#  ['cnp01347493', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01900808', 'other', []],
#  ['cnp01233501', 'other', ['geo_carto']],
#  ['cnp01395469', 'other', ['liter']],
#  ['cnp02143831', 'math', ['math']],
#  ['cnp01340415', 'other', []],
#  ['cnp02251223', 'math', ['archi', 'inge', 'math']],
#  ['cnp00871211', 'astron', ['astron', 'math', 'scholar']],
#  ['cnp00468695', 'math', ['math', 'phys']],
#  ['cnp01406042', 'math', ['archi', 'math']],
#  ['cnp00877897', 'astron', ['astron']],
#  ['cnp01106465', 'astron', ['astron']],
#  ['cnp01919647', 'other', ['histo', 'prof']],
#  ['cnp00404027', 'med', ['med']],
#  ['cnp01358327', 'other', []],
#  ['cnp00892467', 'med', ['med']],
#  ['cnp02163051', 'other', ['cleric']],
#  ['cnp01908712', 'theol_math', ['cleric', 'liter', 'math', 'philo', 'prof']],
#  ['cnp01408867', 'other', []],
#  ['cnp01108514', 'theol_math', ['astron', 'cleric', 'theol']],
#  ['cnp01327988', 'med_math', ['astrol', 'astron', 'juri', 'math', 'med']],
#  ['cnp01355841', 'astron', ['astron']],
#  ['cnp01208565', 'other', ['liter', 'theol']],
#  ['cnp01876214', 'math', ['anc_lang_philol', 'math', 'prof']],
#  ['cnp01378567', 'math', ['geo_carto', 'math']],
#  ['cnp01355990', 'astrol', ['artist', 'astrol', 'math']],
#  ['cnp01379493', 'other', ['archi', 'artist']],
#  ['cnp01321061', 'other', ['archi', 'artist']],
#  ['cnp01421274', 'other', []],
#  ['cnp01233301', 'other', []],
#  ['cnp00414862', 'other', ['geo_carto']],
#  ['cnp01877766', 'other', ['scholar']],
#  ['cnp01328010', 'med_math', ['astron', 'med', 'phys', 'prof']],
#  ['cnp01919680', 'other', []],
#  ['cnp01919798', 'other', []],
#  ['cnp00401494', 'med_math', ['astron', 'math', 'med']],
#  ['cnp02163157', 'other', []],
#  ['cnp00990253', 'other', []],
#  ['cnp00946324', 'theol_math', ['cleric', 'math']],
#  ['cnp00519261', 'astrol', ['astrol', 'astron', 'geo_carto', 'math']],
#  ['cnp01919936', 'other', []],
#  ['cnp01073264', 'other', []],
#  ['cnp01920059', 'other', []],
#  ['cnp01026086', 'med', ['med', 'prof']],
#  ['cnp00951475', 'astron', ['astron', 'math', 'prof']],
#  ['cnp00370488', 'theol_math', ['cleric', 'math', 'scholar']],
#  ['cnp02224706', 'other', []],
#  ['cnp01908276', 'other', []],
#  ['cnp01351342', 'math', ['math']],
#  ['cnp01919735', 'astron', ['astron', 'book', 'prof']],
#  ['cnp00125588', 'other', []],
#  ['cnp00386550', 'astron', ['astron', 'math']],
#  ['cnp01399888', 'other', []],
#  ['cnp01121780', 'other', []],
#  ['cnp01919933', 'other', []],
#  ['cnp02330678', 'other', []],
#  ['cnp00125422', 'astron', ['astron', 'math']],
#  ['cnp01395468', 'other', []],
#  ['cnp01877518', 'astron', ['astron', 'book', 'liter', 'math', 'prof']],
#  ['cnp00455882', 'math', ['math']],
#  ['cnp01475871', 'math', ['math']],
#  ['cnp01391905', 'med_math', ['astron', 'geo_carto', 'math', 'med']],
#  ['cnp02163132', 'other', []],
#  ['cnp01917023', 'other', []],
#  ['cnp01391968', 'astron', ['astron', 'math']],
#  ['cnp00370784', 'math', ['liter', 'math']],
#  ['cnp02094405', 'med_math', ['math', 'med']],
#  ['cnp00980603', 'math', ['liter', 'math']],
#  ['cnp01018318', 'math', ['math']],
#  ['cnp00506076', 'other', ['prof', 'theol']],
#  ['cnp00998676', 'astron', ['astron', 'juri']],
#  ['cnp00951955', 'math', ['math']],
#  ['cnp01920892', 'math', ['anc_lang_philol', 'histo', 'math', 'prof']],
#  ['cnp01351361', 'other', ['scholar']],
#  ['cnp02163042', 'other', []],
#  ['cnp00623575', 'med', ['med']],
#  ['cnp01093544', 'med_math', ['math', 'med']],
#  ['cnp01002233', 'other', ['cleric']],
#  ['cnp01318008', 'med_math', ['astrol', 'astron', 'math', 'med']],
#  ['cnp01330261', 'other', []],
#  ['cnp00930944', 'other', []],
#  ['cnp00108734', 'theol_math', ['math', 'theol']],
#  ['cnp01920048', 'theol_math', ['astron', 'cleric']],
#  ['cnp00390667', 'philo_phys', ['philo', 'prof']],
#  ['cnp01344682', 'philo_phys', ['philo', 'phys', 'scholar']],
#  ['cnp01377073', 'other', []],
#  ['cnp00475681', 'other', ['liter', 'theol']],
#  ['cnp01313208', 'other', []],
#  ['cnp01334817', 'med', ['liter', 'med']],
#  ['cnp01374654', 'med_math', ['math', 'med', 'prof']],
#  ['cnp00389786', 'math', ['math', 'prof']],
#  ['cnp00385731', 'math', ['archi', 'inge', 'math']],
#  ['cnp01273893', 'philo_phys', ['liter', 'philo']],
#  ['cnp01316924', 'theol_math', ['math', 'theol']],
#  ['cnp01899827', 'other', []],
#  ['cnp01045073', 'other', []],
#  ['cnp01304679', 'other', []],
#  ['cnp02163255', 'other', []],
#  ['cnp01303999', 'other', []],
#  ['cnp00915396', 'astron', ['astron', 'math']],
#  ['cnp01037256', 'theol_math', ['astron', 'prof', 'theol']],
#  ['cnp01377125', 'theol_math', ['math', 'theol']],
#  ['cnp01322085', 'math', ['math', 'philo', 'phys', 'prof']],
#  ['cnp02033956', 'math', ['geo_carto', 'math']],
#  ['cnp00969971', 'math', ['anc_lang_philol', 'histo', 'math']],
#  ['cnp00389349', 'math', ['math']],
#  ['cnp02163239', 'other', []],
#  ['cnp00504169', 'math', ['math']],
#  ['cnp01919685', 'other', []],
#  ['cnp02149411', 'other', ['archi']],
#  ['cnp00921622', 'math', ['archi', 'math']],
#  ['cnp01327704', 'other', []],
#  ['cnp02163138', 'other', []],
#  ['cnp02248072', 'math', ['juri', 'math']],
#  ['cnp01033200', 'math', ['geo_carto', 'math']],
#  ['cnp02163160', 'other', []],
#  ['cnp00507343', 'med_math', ['astrol', 'astron', 'med']],
#  ['cnp01901801', 'other', []],
#  ['cnp00416849', 'med_math', ['astron', 'math', 'med']],
#  ['cnp02062689', 'math', ['math']],
#  ['cnp01291828', 'math', ['math']],
#  ['cnp02230350', 'other', []],
#  ['cnp00398978', 'math', ['geo_carto', 'liter', 'math']],
#  ['cnp00388107', 'med_math', ['math', 'med', 'phys']],
#  ['cnp00390875', 'math', ['juri', 'math']],
#  ['cnp01920009', 'other', []],
#  ['cnp01368847', 'other', []],
#  ['cnp01335791', 'math', ['math', 'philo']],
#  ['cnp01317013', 'math', ['archi', 'inge', 'math']],
#  ['cnp00447681', 'math', ['math', 'prof', 'scholar']],
#  ['cnp01440545', 'math', ['archi', 'book', 'geo_carto', 'math']],
#  ['cnp01089507', 'math', ['math']],
#  ['cnp00466008', 'med', ['med']],
#  ['cnp00295424', 'other', ['book', 'juri', 'liter']],
#  ['cnp01026399', 'theol_math', ['cleric', 'inge', 'math']],
#  ['cnp00458133', 'theol_math', ['cleric', 'math']],
#  ['cnp00497608', 'theol_math', ['astron', 'cleric']],
#  ['cnp00918436', 'other', ['cleric']],
#  ['cnp01319583', 'other', []],
#  ['cnp00918450', 'astron', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01390435', 'other', []],
#  ['cnp02205996', 'astron', ['astron']],
#  ['cnp01919797', 'other', []],
#  ['cnp02206734', 'med_math', ['astron', 'med']],
#  ['cnp01053665', 'other', ['cleric', 'prof']],
#  ['cnp00390534', 'med_math', ['math', 'med']],
#  ['cnp01348997', 'other', []],
#  ['cnp01146927', 'math', ['math']],
#  ['cnp01339954', 'philo_phys', ['philo']],
#  ['cnp00354610', 'other', []],
#  ['cnp02239623', 'astron', ['astron', 'math']],
#  ['cnp01325603', 'other', []],
#  ['cnp01919813', 'other', []],
#  ['cnp01341138', 'other', []],
#  ['cnp02163280', 'other', []],
#  ['cnp01921111', 'math', ['math', 'philo', 'phys', 'scholar']],
#  ['cnp00452326', 'med_math', ['astron', 'math', 'med']],
#  ['cnp01338526', 'astron', ['astron']],
#  ['cnp02111485', 'math', ['juri', 'math', 'philo']],
#  ['cnp01877772', 'med_math', ['math', 'med']],
#  ['cnp02335717', 'other', []],
#  ['cnp02163012', 'other', []],
#  ['cnp02069815', 'other', []],
#  ['cnp00461448', 'math', ['math']],
#  ['cnp02234984', 'math', ['math']],
#  ['cnp01364670', 'astron', ['astron']],
#  ['cnp01878958', 'med_math', ['math', 'med', 'prof']],
#  ['cnp00389779', 'math', ['book', 'math']],
#  ['cnp02163235', 'other', []],
#  ['cnp00401645', 'astron', ['astron', 'math']],
#  ['cnp01093384', 'math', ['math']],
#  ['cnp01918226', 'other', []],
#  ['cnp00617340', 'math', ['geo_carto', 'math', 'phys']],
#  ['cnp02223923', 'other', []],
#  ['cnp00473662', 'theol_math', ['astron', 'philo', 'theol']],
#  ['cnp02163183', 'other', ['theol']],
#  ['cnp02293390', 'other', []],
#  ['cnp00649901', 'math', ['math']],
#  ['cnp01003527', 'theol_math', ['math', 'philo', 'prof', 'theol']],
#  ['cnp01085022', 'math', ['math', 'prof']],
#  ['cnp01487024', 'math', ['book', 'liter', 'math']],
#  ['cnp00384916', 'other', ['theol']],
#  ['cnp00689671', 'theol_math', ['cleric', 'math', 'prof', 'scholar']],
#  ['cnp01328238', 'med_math', ['math', 'med']],
#  ['cnp02211160', 'astron', ['astron', 'math', 'phys']],
#  ['cnp01321618', 'astron', ['astron', 'histo', 'math', 'philo']],
#  ['cnp01470260', 'other', []],
#  ['cnp02063829', 'math', ['math']],
#  ['cnp01344806', 'other', []],
#  ['cnp01337555', 'astron', ['astron']],
#  ['cnp00951915', 'other', []],
#  ['cnp02163131', 'other', []],
#  ['cnp01919977', 'other', []],
#  ['cnp01919983', 'other', []],
#  ['cnp00064282', 'math', ['math']],
#  ['cnp01316530', 'math', ['math']],
#  ['cnp01323244', 'med_math', ['astron', 'math', 'med']],
#  ['cnp00445951', 'other', ['cleric', 'prof']],
#  ['cnp02190631', 'astrol', ['astrol']],
#  ['cnp01330172', 'other', []],
#  ['cnp02163037', 'other', []],
#  ['cnp01919746', 'astron', ['astron', 'math']],
#  ['cnp02163116', 'other', []],
#  ['cnp01323399', 'med', ['med']],
#  ['cnp01939722', 'other', []],
#  ['cnp02140267', 'math', ['math']],
#  ['cnp00105837', 'other', []],
#  ['cnp00506366', 'med', ['med']],
#  ['cnp02236952', 'other', []],
#  ['cnp00489873', 'theol_math', ['geo_carto', 'math', 'theol']],
#  ['cnp02230372', 'other', []],
#  ['cnp01327695', 'other', []],
#  ['cnp01345096', 'theol_math', ['astron', 'juri', 'math', 'theol']],
#  ['cnp01358202', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01341055', 'theol_math', ['book', 'math', 'philo', 'theol']],
#  ['cnp02232803', 'philo_phys', ['philo', 'prof']],
#  ['cnp01391658', 'math', ['geo_carto', 'math']],
#  ['cnp01199180', 'math', ['math', 'philo']],
#  ['cnp01002799', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp01229337', 'other', ['juri', 'scholar']],
#  ['cnp02230529', 'math', ['math']],
#  ['cnp01919890', 'other', []],
#  ['cnp00283188', 'other', []],
#  ['cnp00388517', 'astron', ['astron', 'math', 'prof']],
#  ['cnp02261078', 'astron', ['astron', 'math']],
#  ['cnp01345246', 'med', ['med']],
#  ['cnp02104967', 'math', ['math']],
#  ['cnp02078294', 'other', ['artist']],
#  ['cnp02236239', 'math', ['math', 'phys', 'prof']],
#  ['cnp00386587', 'theol_math', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp02140516', 'astron', ['astron']],
#  ['cnp00876263', 'math', ['math']],
#  ['cnp01908394', 'other', ['artist']],
#  ['cnp01392446', 'other', []],
#  ['cnp01377339', 'other', []],
#  ['cnp01919715', 'astrol', ['astrol']],
#  ['cnp01470045', 'math', ['juri', 'liter', 'math']],
#  ['cnp01325201', 'astron', ['artist', 'astron', 'math']],
#  ['cnp00611392', 'astron', ['astron', 'juri']],
#  ['cnp01380775', 'theol_math', ['cleric', 'math', 'philo']],
#  ['cnp00106298', 'med', ['med']],
#  ['cnp00483287', 'math', ['math']],
#  ['cnp01341135', 'philo_phys', ['phys']],
#  ['cnp01483154', 'math', ['math']],
#  ['cnp00496933', 'math', ['math']],
#  ['cnp01375612', 'other', []],
#  ['cnp00352036', 'astrol', ['astrol', 'astron', 'book', 'math']],
#  ['cnp01127978', 'other', []],
#  ['cnp01324836', 'other', []],
#  ['cnp00387106', 'med_math', ['histo', 'math', 'med', 'prof']],
#  ['cnp01919870', 'other', []],
#  ['cnp00433134', 'med_math', ['math', 'med', 'prof']],
#  ['cnp00399615', 'math', ['math']],
#  ['cnp01435092', 'med', ['med']],
#  ['cnp01919694', 'astron', ['astron']],
#  ['cnp00347201', 'other', []],
#  ['cnp01012117', 'theol_math', ['astron', 'cleric']],
#  ['cnp00364411', 'theol_math', ['math', 'philo', 'prof', 'theol']],
#  ['cnp02193879', 'math', ['book', 'math']],
#  ['cnp01469355', 'math', ['math']],
#  ['cnp00432861', 'other', ['juri', 'prof']],
#  ['cnp01364652', 'other', ['histo']],
#  ['cnp00390888', 'math', ['math', 'phys']],
#  ['cnp00482504', 'med', ['anc_lang_philol', 'med']],
#  ['cnp01330573', 'math', ['archi', 'book', 'inge', 'math']],
#  ['cnp00886194', 'other', []],
#  ['cnp00380320', 'med', ['med']],
#  ['cnp01002798', 'other', ['scholar', 'theol']],
#  ['cnp00038260', 'math', ['math', 'phys']],
#  ['cnp00877968', 'astron', ['astron', 'math']],
#  ['cnp00391433', 'med_math', ['astron', 'math', 'med']],
#  ['cnp01340180', 'astron', ['astron', 'math']],
#  ['cnp01010326', 'theol_math', ['math', 'theol']],
#  ['cnp00069034', 'math', ['math']],
#  ['cnp00474060', 'med', ['med', 'prof']],
#  ['cnp01094218', 'math', ['math', 'philo', 'phys', 'prof']],
#  ['cnp02235964', 'med', ['med']],
#  ['cnp00454903', 'math', ['book', 'math', 'phys']],
#  ['cnp02299102', 'math', ['math']],
#  ['cnp01318964', 'theol_math', ['astron', 'theol']],
#  ['cnp02327523', 'other', []],
#  ['cnp01919967', 'other', []],
#  ['cnp01920211', 'philo_phys', ['liter', 'phys']],
#  ['cnp01373606', 'other', ['artist']],
#  ['cnp01323643', 'other', []],
#  ['cnp00930960', 'math', ['archi', 'math']],
#  ['cnp01992297', 'astron', ['astron', 'math']],
#  ['cnp00368388', 'math', ['math', 'prof']],
#  ['cnp01364676', 'astron', ['astron', 'math', 'phys']],
#  ['cnp01320598', 'philo_phys', ['philo']],
#  ['cnp01320899', 'other', ['theol']],
#  ['cnp00147670', 'math', ['math']],
#  ['cnp02154944', 'other', []],
#  ['cnp01389635', 'math', ['math', 'phys']],
#  ['cnp02335307', 'theol_math', ['astron', 'histo', 'theol']],
#  ['cnp02244888', 'theol_math', ['liter', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01479020', 'theol_math', ['liter', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01010218', 'astron', ['astron', 'math', 'prof']],
#  ['cnp02163221', 'other', []],
#  ['cnp01440456', 'other', ['archi']],
#  ['cnp01316503', 'med_math', ['liter', 'math', 'med', 'phys']],
#  ['cnp01481978', 'astron', ['astron']],
#  ['cnp00506412', 'astron', ['astron']],
#  ['cnp01370532', 'other', []],
#  ['cnp01358935', 'other', ['histo', 'theol']],
#  ['cnp02338184', 'other', []],
#  ['cnp00385275', 'math', ['math', 'philo', 'prof']],
#  ['cnp01890712', 'other', []],
#  ['cnp00669927', 'other', []],
#  ['cnp00019029', 'other', ['anc_lang_philol', 'scholar', 'theol']],
#  ['cnp00529491', 'other', []],
#  ['cnp01476352', 'astron', ['astron', 'math', 'phys']],
#  ['cnp01914334', 'other', []],
#  ['cnp00952066', 'other', ['prof', 'theol']],
#  ['cnp01919643', 'med', ['med', 'prof']],
#  ['cnp01338801', 'theol_math', ['math', 'theol']],
#  ['cnp00951195', 'math', ['math']],
#  ['cnp00434558', 'math', ['math', 'prof']],
#  ['cnp01919866', 'other', []],
#  ['cnp01391974', 'other', ['inge']],
#  ['cnp00950513', 'math', ['math', 'phys']],
#  ['cnp01311444', 'theol_math', ['cleric', 'math']],
#  ['cnp00455142', 'astron', ['astron', 'juri']],
#  ['cnp00471549', 'theol_math', ['math', 'theol']],
#  ['cnp00833377', 'med_math', ['math', 'med']],
#  ['cnp01891255', 'philo_phys', ['histo', 'phys']],
#  ['cnp02068029', 'theol_math', ['cleric', 'math', 'prof', 'theol']],
#  ['cnp01919823', 'other', []],
#  ['cnp01497657', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp01337449', 'other', []],
#  ['cnp00400188', 'astron', ['astron', 'math']],
#  ['cnp00951338', 'math', ['geo_carto', 'math']],
#  ['cnp01377626', 'other', []],
#  ['cnp01390742', 'other', []],
#  ['cnp01919771', 'other', []],
#  ['cnp00597936', 'theol_math', ['astron', 'cleric']],
#  ['cnp01390739', 'other', []],
#  ['cnp00952457', 'other', ['liter', 'prof']],
#  ['cnp02230304', 'other', []],
#  ['cnp02183983', 'astrol', ['astrol', 'astron', 'liter']],
#  ['cnp01481855',
#   'theol_math',
#   ['astron', 'cleric', 'juri', 'math', 'phys', 'prof']],
#  ['cnp00537706', 'math', ['math']],
#  ['cnp02163226', 'other', []],
#  ['cnp01439830', 'math', ['math', 'philo', 'phys', 'prof']],
#  ['cnp00369131', 'theol_math', ['astron', 'cleric', 'liter', 'theol']],
#  ['cnp01289741', 'other', ['cleric']],
#  ['cnp00993973', 'astron', ['astron', 'math']],
#  ['cnp01267785', 'theol_math', ['astron', 'theol']],
#  ['cnp01049147', 'med', ['med', 'prof']],
#  ['cnp00908508', 'other', ['inge']],
#  ['cnp00386174', 'astron', ['astron', 'geo_carto', 'math', 'prof']],
#  ['cnp01316493', 'other', []],
#  ['cnp02158412', 'theol_math', ['math', 'theol']],
#  ['cnp01391574', 'other', []],
#  ['cnp00371858', 'med_math', ['math', 'med']],
#  ['cnp01440125', 'astron', ['artist', 'astron', 'math']],
#  ['cnp01919777', 'other', []],
#  ['cnp01471258', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp02179557', 'math', ['archi', 'artist', 'math']],
#  ['cnp01919770', 'astrol', ['astrol']],
#  ['cnp01919841', 'astron', ['astron']],
#  ['cnp01329452', 'other', []],
#  ['cnp01391697', 'other', ['geo_carto']],
#  ['cnp00946101', 'math', ['math', 'philo', 'scholar']],
#  ['cnp02121737', 'math', ['math']],
#  ['cnp01392357', 'astron', ['astron', 'math', 'philo']],
#  ['cnp00950867', 'math', ['juri', 'math', 'prof']],
#  ['cnp02163035', 'other', []],
#  ['cnp00387057', 'theol_math', ['math', 'theol']],
#  ['cnp00967216', 'math', ['liter', 'math']],
#  ['cnp01327984', 'astron', ['astron', 'math']],
#  ['cnp01324799', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp01322061', 'math', ['math']],
#  ['cnp00937233', 'other', ['juri', 'prof']],
#  ['cnp00469354', 'astron', ['astron', 'geo_carto', 'histo', 'math']],
#  ['cnp01471432', 'other', []],
#  ['cnp00681549', 'other', []],
#  ['cnp02163278', 'other', []],
#  ['cnp00557114', 'theol_math', ['astron', 'cleric']],
#  ['cnp00301902', 'med_math', ['math', 'med', 'philo', 'scholar']],
#  ['cnp01940714', 'med_math', ['math', 'med', 'philo']],
#  ['cnp00670663', 'other', ['prof']],
#  ['cnp00388939', 'med', ['med']],
#  ['cnp00419809', 'med_math', ['math', 'med', 'philo', 'prof']],
#  ['cnp01316895', 'other', []],
#  ['cnp00438816', 'other', ['prof', 'theol']],
#  ['cnp01338123', 'other', []],
#  ['cnp00400398', 'astron', ['astron']],
#  ['cnp01310386', 'other', ['cleric']],
#  ['cnp01905556', 'other', []],
#  ['cnp00343317', 'theol_math', ['math', 'philo', 'prof', 'theol']],
#  ['cnp00395926', 'med', ['med']],
#  ['cnp00467311', 'other', []],
#  ['cnp00967217', 'math', ['geo_carto', 'inge', 'math']],
#  ['cnp01498919', 'math', ['book', 'juri', 'math', 'philo']],
#  ['cnp00950470', 'math', ['math']],
#  ['cnp02294466', 'other', []],
#  ['cnp01093464', 'other', []],
#  ['cnp02226095', 'other', []],
#  ['cnp00872719', 'theol_math', ['math', 'theol']],
#  ['cnp01362737', 'math', ['liter', 'math']],
#  ['cnp01363143', 'other', []],
#  ['cnp00422532', 'math', ['anc_lang_philol', 'liter', 'math']],
#  ['cnp00552352', 'other', []],
#  ['cnp00449362', 'math', ['math', 'philo', 'phys', 'prof']],
#  ['cnp01989297', 'math', ['juri', 'math', 'prof']],
#  ['cnp02229154', 'other', []],
#  ['cnp01005388', 'other', ['prof']],
#  ['cnp00449554', 'med_math', ['math', 'med', 'phys', 'scholar']],
#  ['cnp02327618', 'math', ['math']],
#  ['cnp01273643', 'math', ['juri', 'math']],
#  ['cnp00846462', 'astron', ['astron']],
#  ['cnp01281146', 'math', ['archi', 'artist', 'liter', 'math']],
#  ['cnp01427020', 'math', ['geo_carto', 'math', 'scholar']],
#  ['cnp02244185', 'math', ['math']],
#  ['cnp01324750', 'other', []],
#  ['cnp01341195', 'math', ['math', 'scholar']],
#  ['cnp02328440', 'math', ['math']],
#  ['cnp01403284', 'other', []],
#  ['cnp01320800', 'math', ['math']],
#  ['cnp01941103', 'math', ['juri', 'math']],
#  ['cnp00855016', 'math', ['math']],
#  ['cnp02135612', 'astron', ['astron']],
#  ['cnp01511009', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01945055', 'math', ['math']],
#  ['cnp02163135', 'other', []],
#  ['cnp00978103', 'astron', ['astron', 'book']],
#  ['cnp01939693', 'math', ['math']],
#  ['cnp00290787', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp00399397', 'med_math', ['astron', 'book', 'med', 'prof']],
#  ['cnp01358620', 'math', ['math']],
#  ['cnp01482767', 'other', ['prof', 'theol']],
#  ['cnp01919860', 'other', []],
#  ['cnp00400516', 'math', ['math', 'phys']],
#  ['cnp01880566', 'other', ['cleric']],
#  ['cnp01323883', 'math', ['math', 'prof']],
#  ['cnp01919745', 'other', []],
#  ['cnp02163098', 'math', ['histo', 'math']],
#  ['cnp02338026', 'other', ['juri', 'prof', 'theol']],
#  ['cnp01306191', 'other', []],
#  ['cnp01325602', 'math', ['math']],
#  ['cnp02235906', 'med', ['med']],
#  ['cnp00613664', 'other', ['theol']],
#  ['cnp00390440', 'med_math', ['astron', 'math', 'med', 'phys', 'prof']],
#  ['cnp01327562', 'theol_math', ['astron', 'cleric', 'geo_carto']],
#  ['cnp02239207', 'astron', ['astron', 'math', 'philo']],
#  ['cnp01143314', 'math', ['archi', 'math']],
#  ['cnp01318599', 'other', []],
#  ['cnp01345497', 'theol_math', ['cleric', 'math']],
#  ['cnp00345796', 'astron', ['astron', 'inge', 'phys']],
#  ['cnp00940854', 'med_math', ['math', 'med', 'prof']],
#  ['cnp01130536', 'other', ['archi']],
#  ['cnp01358501', 'math', ['math', 'phys', 'scholar']],
#  ['cnp01344695', 'philo_phys', ['phys']],
#  ['cnp01310208', 'other', []],
#  ['cnp01438995', 'philo_phys', ['liter', 'philo', 'scholar']],
#  ['cnp00950783', 'math', ['math']],
#  ['cnp01073918', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp01323465', 'theol_math', ['liter', 'math', 'theol']],
#  ['cnp01381608', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp00424957', 'astron', ['astron', 'prof']],
#  ['cnp01049625', 'other', []],
#  ['cnp01331399', 'other', []],
#  ['cnp00289676', 'math', ['math']],
#  ['cnp00611867', 'astron', ['astron', 'math', 'prof']],
#  ['cnp02163061', 'other', []],
#  ['cnp00459835', 'astron', ['astron', 'math', 'prof']],
#  ['cnp02176412', 'other', []],
#  ['cnp01921159', 'other', []],
#  ['cnp01379874', 'other', []],
#  ['cnp01391847', 'other', []],
#  ['cnp01919821', 'other', []],
#  ['cnp02270525', 'theol_math', ['cleric', 'math']],
#  ['cnp01969331', 'other', []],
#  ['cnp01208519', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp01065866', 'math', ['math']],
#  ['cnp01386056', 'med_math', ['astron', 'math', 'med']],
#  ['cnp00950611', 'astron', ['astron', 'math']],
#  ['cnp01884314', 'theol_math', ['astron', 'liter', 'theol']],
#  ['cnp01033546', 'other', []],
#  ['cnp01321930', 'math', ['math', 'philo']],
#  ['cnp00526372', 'other', []],
#  ['cnp00376916', 'math', ['math', 'phys', 'prof']],
#  ['cnp01373057', 'other', []],
#  ['cnp00481758', 'theol_math', ['astron', 'theol']],
#  ['cnp00394712', 'astron', ['astron']],
#  ['cnp01320816', 'math', ['liter', 'math']],
#  ['cnp00634712', 'math', ['math', 'philo']],
#  ['cnp00474052', 'philo_phys', ['cleric', 'philo', 'prof']],
#  ['cnp02242965', 'math', ['math']],
#  ['cnp01956587', 'other', []],
#  ['cnp02087919', 'math', ['math', 'philo']],
#  ['cnp02134621', 'theol_math', ['math', 'theol']],
#  ['cnp02128577', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp02328026', 'math', ['math', 'prof']],
#  ['cnp02230235', 'other', []],
#  ['cnp00950396', 'math', ['math']],
#  ['cnp02266642', 'other', []],
#  ['cnp01336175', 'theol_math', ['math', 'theol']],
#  ['cnp01337053', 'other', []],
#  ['cnp01436478', 'med_math', ['math', 'med', 'phys', 'prof']],
#  ['cnp01914406', 'other', []],
#  ['cnp00386421', 'theol_math', ['astron', 'cleric', 'math']],
#  ['cnp02163036', 'other', []],
#  ['cnp00974393', 'math', ['math', 'prof']],
#  ['cnp00950031', 'theol_math', ['cleric', 'math']],
#  ['cnp01358615', 'math', ['math']],
#  ['cnp01511015', 'math', ['histo', 'juri', 'math']],
#  ['cnp01881153', 'other', ['liter']],
#  ['cnp00405665', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp02137514', 'math', ['math']],
#  ['cnp01371119', 'other', []],
#  ['cnp02329782', 'math', ['math']],
#  ['cnp01392135', 'other', ['cleric']],
#  ['cnp01944401', 'math', ['math']],
#  ['cnp01271878', 'astron', ['artist', 'astron', 'math', 'prof']],
#  ['cnp01338632', 'math', ['math']],
#  ['cnp01905866', 'other', []],
#  ['cnp00406843', 'other', ['liter']],
#  ['cnp00389082', 'math', ['math', 'prof']],
#  ['cnp01267813', 'other', ['artist']],
#  ['cnp01920140', 'other', ['anc_lang_philol']],
#  ['cnp01946728', 'math', ['math']],
#  ['cnp01372944', 'other', []],
#  ['cnp01326948', 'math', ['math']],
#  ['cnp01340039', 'astron', ['astron', 'math', 'phys']],
#  ['cnp01150291', 'theol_math', ['math', 'theol']],
#  ['cnp01501297', 'math', ['math', 'phys']],
#  ['cnp00973415', 'theol_math', ['astron', 'cleric', 'math', 'prof', 'theol']],
#  ['cnp01938795', 'math', ['math', 'phys']],
#  ['cnp00396411', 'med', ['med', 'scholar']],
#  ['cnp01341197', 'other', []],
#  ['cnp00942919', 'astron', ['astron']],
#  ['cnp01166090', 'math', ['histo', 'math']],
#  ['cnp00387315', 'math', ['math', 'phys']],
#  ['cnp01360525', 'other', []],
#  ['cnp01330343', 'astron', ['astron', 'liter', 'math']],
#  ['cnp00390358',
#   'theol_math',
#   ['cleric', 'math', 'phys', 'prof', 'scholar', 'theol']],
#  ['cnp01006233', 'med', ['med', 'prof']],
#  ['cnp01391728', 'other', ['geo_carto']],
#  ['cnp01416537', 'math', ['math', 'phys']],
#  ['cnp00458613', 'other', []],
#  ['cnp00408365', 'other', ['scholar']],
#  ['cnp02306517', 'other', []],
#  ['cnp01391475', 'math', ['juri', 'math', 'prof']],
#  ['cnp01128300', 'other', []],
#  ['cnp00415445', 'math', ['juri', 'math']],
#  ['cnp01397344', 'other', []],
#  ['cnp01310754', 'other', []],
#  ['cnp00873636', 'astron', ['astron', 'math', 'prof']],
#  ['cnp02218403', 'other', []],
#  ['cnp01323455', 'math', ['math']],
#  ['cnp01327945', 'astron', ['astron', 'geo_carto', 'math']],
#  ['cnp01353680', 'other', ['juri', 'prof']],
#  ['cnp01310736', 'other', []],
#  ['cnp00620144', 'philo_phys', ['phys']],
#  ['cnp02187878', 'med_math', ['astron', 'med']],
#  ['cnp01907258', 'other', []],
#  ['cnp00938379', 'math', ['math', 'philo']],
#  ['cnp00935714', 'math', ['math']],
#  ['cnp01355792', 'math', ['math', 'philo']],
#  ['cnp01956097', 'math', ['inge', 'math']],
#  ['cnp01337942', 'math', ['math', 'phys', 'prof']],
#  ['cnp01425174', 'theol_math', ['cleric', 'math', 'theol']],
#  ['cnp01341011', 'math', ['math']],
#  ['cnp01296840', 'theol_math', ['math', 'philo', 'scholar', 'theol']],
#  ['cnp00482858', 'theol_math', ['astron', 'cleric', 'math', 'prof', 'theol']],
#  ['cnp02163250', 'other', []],
#  ['cnp01371511', 'other', ['book', 'theol']],
#  ['cnp01406883', 'theol_math', ['math', 'theol']],
#  ['cnp02168144', 'other', []],
#  ['cnp01502265', 'other', ['cleric', 'theol']],
#  ['cnp01481635', 'theol_math', ['math', 'philo', 'phys', 'prof', 'theol']],
#  ['cnp01283791', 'other', ['cleric', 'prof']],
#  ['cnp01294650', 'other', ['prof']],
#  ['cnp00555044', 'theol_math', ['astron', 'cleric', 'math']],
#  ['cnp00114038', 'math', ['geo_carto', 'math']],
#  ['cnp01271242', 'math', ['math']],
#  ['cnp01427068', 'math', ['math']],
#  ['cnp01307036', 'math', ['liter', 'math']],
#  ['cnp02213909', 'math', ['inge', 'math']],
#  ['cnp00395781', 'other', ['artist', 'book']],
#  ['cnp00382785', 'math', ['math']],
#  ['cnp01313448', 'math', ['math']],
#  ['cnp02238866', 'math', ['math']],
#  ['cnp01386031', 'other', []],
#  ['cnp00959838', 'astron', ['astron', 'math', 'prof']],
#  ['cnp00401670', 'astron', ['archi', 'astron', 'math', 'phys']],
#  ['cnp01441824', 'math', ['geo_carto', 'histo', 'math']],
#  ['cnp00873272', 'astron', ['astron', 'math', 'prof']],
#  ['cnp00420502', 'other', ['cleric']],
#  ['cnp01207886', 'theol_math', ['math', 'philo', 'prof', 'scholar', 'theol']],
#  ['cnp02265415', 'other', []],
#  ['cnp01273354', 'astrol', ['astrol']],
#  ['cnp01229576', 'math', ['math']],
#  ['cnp00155913', 'med', ['med']],
#  ['cnp01328111', 'other', []],
#  ['cnp01311691', 'other', []],
#  ['cnp02163079', 'other', []],
#  ['cnp02091188', 'other', ['cleric', 'prof', 'theol']],
#  ['cnp01939035', 'astron', ['archi', 'astron']],
#  ['cnp01411736', 'other', ['theol']],
#  ['cnp02060705', 'astron', ['astron']],
#  ['cnp00149586', 'theol_math', ['astron', 'math', 'philo', 'prof', 'theol']],
#  ['cnp00357110', 'other', []],
#  ['cnp00405760', 'math', ['math']],
#  ['cnp01327508', 'other', []],
#  ['cnp01355708', 'other', ['liter']],
#  ['cnp01331171', 'astron', ['astron', 'math', 'phys', 'scholar']],
#  ['cnp00616670', 'astron', ['astron', 'geo_carto', 'phys']],
#  ['cnp01340546', 'other', ['geo_carto']],
#  ['cnp01361348', 'astron', ['astron', 'liter', 'math']],
#  ['cnp01167073', 'math', ['math', 'prof']],
#  ['cnp01327525', 'theol_math', ['astron', 'cleric']],
#  ['cnp00978256', 'math', ['math']],
#  ['cnp00398351', 'math', ['math']],
#  ['cnp00989107', 'other', []],
#  ['cnp01155894', 'math', ['math', 'phys']],
#  ['cnp00934743', 'theol_math', ['astron', 'math', 'theol']],
#  ['cnp00454735', 'other', ['cleric']],
#  ['cnp01227314', 'math', ['math', 'prof']],
#  ['cnp02252448', 'other', ['juri']],
#  ['cnp01364665', 'math', ['math', 'phys']],
#  ['cnp01127346', 'math', ['book', 'math', 'philo']],
#  ['cnp01322254', 'theol_math', ['liter', 'math', 'philo', 'theol']],
#  ['cnp02213004', 'astron', ['astron', 'math']],
#  ['cnp02210701', 'math', ['math']],
#  ['cnp00421828', 'math', ['math']],
#  ['cnp01979544', 'other', ['prof']],
#  ['cnp00951342', 'other', ['prof']],
#  ['cnp02163090', 'astron', ['astron']],
#  ['cnp00111937', 'math', ['math']],
#  ['cnp01281827', 'med', ['med']],
#  ['cnp00473300', 'other', []],
#  ['cnp00800049', 'theol_math', ['math', 'theol']],
#  ['cnp01088897', 'math', ['juri', 'math']],
#  ['cnp02334268', 'other', []],
#  ['cnp01370536', 'med', ['med']],
#  ['cnp00102076', 'other', []],
#  ['cnp01167258', 'astron', ['astron', 'math', 'prof']],
#  ['cnp01994802', 'med', ['med']],
#  ['cnp02207805', 'math', ['math']],
#  ['cnp01422962', 'other', ['juri']],
#  ['cnp00472229', 'math', ['histo', 'math', 'prof']],
#  ['cnp02189751', 'astron', ['astron', 'math', 'philo']],
#  ['cnp02210773', 'astron', ['astron', 'math']],
#  ['cnp01088135', 'other', []],
#  ['cnp00547788', 'math', ['math']],
#  ['cnp02071743', 'math', ['artist', 'math']],
#  ['cnp02209689', 'theol_math', ['math', 'scholar', 'theol']],
#  ['cnp00105985', 'math', ['math', 'prof']],
#  ['cnp01304917', 'other', []],
#  ['cnp00352902', 'math', ['math', 'philo']],
#  ['cnp01317909', 'astron', ['astron', 'math', 'phys']],
#  ['cnp00416288', 'theol_math', ['math', 'philo', 'theol']],
#  ['cnp01375132', 'other', ['histo']],
#  ['cnp00424400', 'med_math', ['math', 'med', 'phys']],
#  ['cnp00381221', 'theol_math', ['astron', 'cleric', 'prof', 'theol']],
#  ['cnp02213140', 'math', ['archi', 'math']],
#  ['cnp00387676', 'math', ['math', 'philo']],
#  ['cnp01339506', 'other', []],
#  ['cnp01885482', 'math', ['math', 'phys']],
#  ['cnp00384742', 'astron', ['astron', 'math']],
#  ['cnp01336730', 'math', ['math']],
#  ['cnp01260483', 'other', ['anc_lang_philol', 'juri']],
#  ['cnp01229790', 'math', ['math', 'prof']],
#  ['cnp02153688', 'other', []],
#  ['cnp01340685', 'math', ['math', 'philo', 'phys']],
#  ['cnp00475918', 'med', ['med', 'philo', 'prof']],
#  ['cnp01387988', 'math', ['math']],
#  ['cnp02163844', 'astron', ['astron', 'histo']],
#  ['cnp00415975', 'math', ['math']],
#  ['cnp02163209', 'other', []],
#  ['cnp02181704', 'math', ['math', 'philo']],
#  ['cnp01142873', 'other', []],
#  ['cnp02308630', 'other', []],
#  ['cnp00415435', 'math', ['math']],
#  ['cnp01406818', 'math', ['math']],
#  ['cnp02147246', 'math', ['math']],
#  ['cnp01326430', 'other', []],
#  ['cnp01005241', 'med_math', ['math', 'med', 'philo', 'prof']],
#  ['cnp01085443', 'med', ['med', 'prof']],
#  ['cnp01132050', 'other', ['book', 'prof']],
#  ['cnp00514820', 'med', ['med', 'prof']],
#  ['cnp02106929', 'astron', ['astron', 'philo', 'phys']],
#  ['cnp02062635', 'other', []],
#  ['cnp00387153', 'math', ['math']],
#  ['cnp00390713', 'astron', ['astron', 'phys', 'prof']],
#  ['cnp00954353', 'astron', ['astron', 'math']],
#  ['cnp00961968', 'math', ['math', 'philo']],
#  ['cnp01324793', 'math', ['book', 'juri', 'math', 'philo']],
#  ['cnp01310072', 'other', []],
#  ['cnp01196433', 'theol_math', ['math', 'prof', 'theol']],
#  ['cnp01428444', 'math', ['math']],
#  ['cnp02069898', 'theol_math', ['cleric', 'math']],
#  ['cnp02163256', 'other', []],
#  ['cnp02128642', 'math', ['geo_carto', 'liter', 'math']],
#  ['cnp00381182', 'other', ['juri']],
#  ['cnp01331537', 'math', ['math']],
#  ['cnp00936828', 'math', ['anc_lang_philol', 'math']],
#  ['cnp01406268', 'other', []],
#  ['cnp01496383', 'math', ['artist', 'juri', 'liter', 'math', 'phys', 'prof']],
#  ['cnp02163251', 'other', []],
#  ['cnp02294549', 'other', []],
#  ['cnp00962937', 'math', ['math', 'philo']],
#  ['cnp01087627', 'math', ['math', 'philo']],
#  ['cnp00388799', 'theol_math', ['cleric', 'math', 'philo', 'phys', 'theol']],
#  ['cnp01327702', 'astron', ['astron', 'geo_carto', 'math', 'phys']],
#  ['cnp01006600', 'math', ['math', 'phys', 'scholar']],
#  ['cnp01423328', 'math', ['archi', 'math']],
#  ['cnp00985092', 'astron', ['astron']],
#  ['cnp01443734', 'theol_math', ['histo', 'liter', 'math', 'philo', 'theol']],
#  ['cnp01303858', 'other', []],
#  ['cnp01332040', 'other', ['liter']]]

# %%
counter= Counter([t[1] for t in jl_list])
c_jl_list = list(zip(counter.keys(), counter.values()))
sorted_jl_list = sorted(c_jl_list, key=itemgetter(1), reverse=True)
sorted_jl_list
# Out:
# [('other', 386),
#  ('math', 248),
#  ('astron', 132),
#  ('theol_math', 100),
#  ('med_math', 84),
#  ('med', 56),
#  ('philo_phys', 20),
#  ('astrol', 12)]

# %%
values_l = [x[0] for x in sorted_jl_list]

# %% [markdown]
# # Interactively plot birth dates and activities

# %%
query = """
SELECT MAX(person_id) AS person_id, entity_std_name, 
v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)"
FROM v_persons_birth_year_and_place
GROUP BY entity_std_name,  v1 ,  "min(v2)" , "min(v3)", "min(v4)", "min(v5)" 
ORDER BY v1 ;
"""

# %%
cn = sql.connect('db_stores/CERL.db')

# %%
c = cn.cursor()
c.execute(query)
result_l = c.fetchall()

# %%
cn.close()

# %%
print(len(result_l))
result_l[:2]  ## number : 1030 persons
# Out:
# 1030
# [('cnp01352012',
#   'Matthaeus Silvagius',
#   '1400',
#   'cnl00008119',
#   'Catania',
#   '15.0894444444444',
#   '37.5'),
#  ('cnp02088071',
#   'Salio, Girolamo',
#   '1400',
#   'cnl00009081',
#   'Faenza',
#   '11.88',
#   '44.28')]

# %% [markdown]
# ## Join activity codes

# %%
joined_result_l = []
for rl in result_l:
    for j in jl_list:
        if rl[0] == j[0]:
            out = list(rl) + [j[1]]
    joined_result_l.append(out)

# %%
print(len(joined_result_l))
joined_result_l
# Out:
# 1030
# [['cnp01352012',
#   'Matthaeus Silvagius',
#   '1400',
#   'cnl00008119',
#   'Catania',
#   '15.0894444444444',
#   '37.5',
#   'other'],
#  ['cnp02088071',
#   'Salio, Girolamo',
#   '1400',
#   'cnl00009081',
#   'Faenza',
#   '11.88',
#   '44.28',
#   'med_math'],
#  ['cnp01881207',
#   'Kues, Nikolaus',
#   '1401',
#   'cnl00019522',
#   'Bernkastel-Kues',
#   '7.06472222222222',
#   '49.9166666666667',
#   'philo_phys'],
#  ['cnp01879247',
#   'Leonico Tomeo, Niccolò',
#   '1428',
#   'cnl00006586',
#   'Venezia',
#   '11.55',
#   '45.4391666666667',
#   'med'],
#  ['cnp00996213',
#   'Paulus',
#   '1445',
#   'cnl00011695',
#   'Middelburg',
#   '3.62',
#   '51.5',
#   'med_math'],
#  ['cnp01320054',
#   'Avraham ben Shemuʾel Zakut',
#   '1450',
#   'cnl00027007',
#   'Salamanca',
#   '-5.65',
#   '40.9691666666667',
#   'astron'],
#  ['cnp01363268',
#   'Gazio, Antonio',
#   '1450',
#   'cnl00027154',
#   'Padova',
#   '11.88',
#   '45.42',
#   'med'],
#  ['cnp01241028',
#   'Vespucci, Amerigo',
#   '1451',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp00873006',
#   'Franciscus',
#   '1452',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'other'],
#  ['cnp01329886',
#   'Barbarus, Hermolaus',
#   '1453',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'math'],
#  ['cnp01363122',
#   'Donati, Girolamo',
#   '1454',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'theol_math'],
#  ['cnp00350996',
#   'Faber, Wenzeslaus',
#   '1455',
#   'cnl00020548',
#   'České Budějovice',
#   '14.47',
#   '48.9691666666667',
#   'med_math'],
#  ['cnp02222242',
#   'Paulus de Middelburg',
#   '1455',
#   'cnl00011695',
#   'Middelburg',
#   '3.62',
#   '51.5',
#   'other'],
#  ['cnp01884261',
#   'Acquaviva, Andrea Matteo',
#   '1456',
#   'cnl00023979',
#   'Conversano',
#   '17.1166666666667',
#   '40.9666666666667',
#   'other'],
#  ['cnp00397446',
#   'Behaim, Martin',
#   '1459',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'math'],
#  ['cnp01368034',
#   'Leone, Ambrogio',
#   '1459',
#   'cnl00023347',
#   'Nola',
#   '14.5330555555556',
#   '40.9330555555556',
#   'med'],
#  ['cnp01335792',
#   'Del Medigo, Elijah',
#   '1460',
#   'cnl00029370',
#   'Iraklion',
#   '25.1330555555556',
#   '35.3330555555556',
#   'philo_phys'],
#  ['cnp00888506',
#   'Falkener, Michael',
#   '1460',
#   'cnl00033303',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'other'],
#  ['cnp01879502',
#   'Köbel, Jacob',
#   '1460',
#   'cnl00016078',
#   'Heidelberg',
#   '8.69944444444445',
#   '49.42',
#   'other'],
#  ['cnp00556047',
#   'Ostrozʹkyj, Kostjantyn Ivanovyč',
#   '1460',
#   'cnl00012580',
#   'Ostrog',
#   '19.03',
#   '42.67',
#   'other'],
#  ['cnp01362970',
#   'Pontico Virunio, Lodovico',
#   '1460',
#   'cnl00007293',
#   'Belluno',
#   '12.22',
#   '46.1494444444444',
#   'philo_phys'],
#  ['cnp01115869',
#   'Widmann, Johannes',
#   '1460',
#   'cnl00008216',
#   'Cheb',
#   '12.3694444444444',
#   '50.0794444444444',
#   'math'],
#  ['cnp00402391',
#   'Etzlaub, Erhard',
#   '1462',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01365166',
#   'Manardi, Giovanni',
#   '1462',
#   'cnl00017144',
#   'Ferrara',
#   '11.58',
#   '44.7991666666667',
#   'med'],
#  ['cnp02088587',
#   'Bulow, Nicolaus',
#   '1465',
#   'cnl00010970',
#   'Lubeck',
#   '10.6991666666667',
#   '53.8691666666667',
#   'med'],
#  ['cnp01409583',
#   'Zúñiga y Pimontel, Juan de',
#   '1465',
#   'cnl00022308',
#   'Plasencia',
#   '-6.08472222222222',
#   '40.0391666666667',
#   'other'],
#  ['cnp01114322',
#   'Ceresara, Paride',
#   '1466',
#   'cnl00016132',
#   'Mantova',
#   '10.7830555555556',
#   '45.1491666666667',
#   'math'],
#  ['cnp00100623',
#   'Augustinus',
#   '1467',
#   'cnl00006250',
#   'Olmütz',
#   '17.25',
#   '49.5791666666667',
#   'other'],
#  ['cnp01352888',
#   'Cocles, Bartolommeo della R.',
#   '1467',
#   'cnl00028839',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'med_math'],
#  ['cnp01392374',
#   'Werner, Johannes',
#   '1468',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'theol_math'],
#  ['cnp01172052',
#   'Ruysch, Johannes',
#   '1470',
#   'cnl00015951',
#   'Utrecht',
#   '5.12916666666667',
#   '52.0791666666667',
#   'astron'],
#  ['cnp01876151',
#   'Ziegler, Jakob',
#   '1470',
#   'cnl00010931',
#   'Landau',
#   '8.11972222222222',
#   '49.2',
#   'theol_math'],
#  ['cnp01317063',
#   'Dürer, Albrecht',
#   '1471',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'math'],
#  ['cnp01319857',
#   'Böschenstein, Johann',
#   '1472',
#   'cnl00029600',
#   'Esslingen',
#   '9.3',
#   '48.75',
#   'other'],
#  ['cnp00398396',
#   'Grünpeck, Joseph',
#   '1473',
#   'cnl00016020',
#   'Burghausen',
#   '12.83',
#   '48.17',
#   'med_math'],
#  ['cnp01471426',
#   'Kopernik, Mikołaj',
#   '1473',
#   'cnl00014634',
#   'Toruń',
#   '18.6',
#   '53.03',
#   'med_math'],
#  ['cnp00412417',
#   'Alexander, Andreas',
#   '1475',
#   'cnl00006272',
#   'Regensburg',
#   '12.0991666666667',
#   '49.02',
#   'math'],
#  ['cnp01875338',
#   'Corti, Matteo',
#   '1475',
#   'cnl00012683',
#   'Pavia',
#   '9.16944444444444',
#   '45.17',
#   'med'],
#  ['cnp01470125',
#   'Serlio, Sebastiano',
#   '1475',
#   'cnl00017069',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'other'],
#  ['cnp01309925',
#   'Cadamosto, Marcantonio',
#   '1476',
#   'cnl00011286',
#   'Lodi',
#   '9.5',
#   '45.32',
#   'other'],
#  ['cnp01320896',
#   'Schöner, Johannes',
#   '1477',
#   'cnl00031757',
#   'Karlstadt',
#   '9.76916666666667',
#   '49.96',
#   'theol_math'],
#  ['cnp00400924',
#   'Zell, Matthäus',
#   '1477',
#   'cnl00038731',
#   'Kaysersberg',
#   '7.26361111111111',
#   '48.1377777777778',
#   'other'],
#  ['cnp01876860',
#   'Fracastoro, Girolamo',
#   '1478',
#   'cnl00017004',
#   'Verona',
#   '11',
#   '45.4294444444444',
#   'med'],
#  ['cnp01331039',
#   'Calcagnini, Celio',
#   '1479',
#   'cnl00017144',
#   'Ferrara',
#   '11.58',
#   '44.7991666666667',
#   'other'],
#  ['cnp01329937',
#   'Biringuccio, Vannoccio',
#   '1480',
#   'cnl00017267',
#   'Siena',
#   '11.33',
#   '43.32',
#   'other'],
#  ['cnp01486719',
#   'Faust, Johannes',
#   '1480',
#   'cnl00010684',
#   'Knittlingen',
#   '8.75972222222222',
#   '49.03',
#   'med_math'],
#  ['cnp01180030',
#   'Tscherte, Hans',
#   '1480',
#   'cnl00007666',
#   'Brünn',
#   '16.6291666666667',
#   '49.2',
#   'math'],
#  ['cnp01255966',
#   'Bild, Veit',
#   '1481',
#   'cnl00035342',
#   'Höchstädt a. d. Donau',
#   '10.5680555555556',
#   '48.6111111111111',
#   'other'],
#  ['cnp01341438',
#   'Gaurico, Pomponio',
#   '1481',
#   'cnl00021727',
#   'Gauro',
#   '14.1052777777778',
#   '40.8480555555556',
#   'other'],
#  ['cnp01880057',
#   'Gerbel, Nikolaus',
#   '1485',
#   'cnl00007755',
#   'Pforzheim',
#   '8.69944444444445',
#   '48.8830555555556',
#   'other'],
#  ['cnp01316341',
#   'Agrippa von Nettesheim, Heinrich Cornelius',
#   '1486',
#   'cnl00006161',
#   'Köln',
#   '6.95',
#   '50.9291666666667',
#   'med'],
#  ['cnp01233195',
#   'Colomb, Fernand',
#   '1487',
#   'cnl00031272',
#   'Cordoba',
#   '-64.1830555555556',
#   '-31.3991666666667',
#   'math'],
#  ['cnp01118781',
#   'Copp, Johann',
#   '1487',
#   'cnl00010938',
#   'Landsberg am Lech',
#   '10.8691666666667',
#   '48.0491666666667',
#   'med_math'],
#  ['cnp01147469',
#   'Kratzer, Nikolaus',
#   '1487',
#   'cnl00030740',
#   'München',
#   '11.58',
#   '48.1491666666667',
#   'astron'],
#  ['cnp00917420',
#   'Styfel, Michael',
#   '1487',
#   'cnl00029600',
#   'Esslingen',
#   '9.3',
#   '48.75',
#   'theol_math'],
#  ['cnp01120503',
#   'Albert, Johannes',
#   '1488',
#   'cnl00003307',
#   'Zörbig',
#   '12.1166666666667',
#   '51.6330555555556',
#   'math'],
#  ['cnp00526061',
#   'Marigliano, Giovanni',
#   '1488',
#   'cnl00023347',
#   'Nola',
#   '14.5330555555556',
#   '40.9330555555556',
#   'other'],
#  ['cnp01320560',
#   'Münster, Sebastian',
#   '1488',
#   'cnl00000707',
#   'Ingenheim',
#   '8.06',
#   '49.9697222222222',
#   'other'],
#  ['cnp02223694',
#   'Pruckner, Nicolaus',
#   '1488',
#   'cnl00007110',
#   'Windsheim',
#   '10.4197222222222',
#   '49.5',
#   'other'],
#  ['cnp01329458',
#   'Radini Tedeschi, Tommaso',
#   '1488',
#   'cnl00012778',
#   'Piacenza',
#   '9.66944444444444',
#   '45.02',
#   'other'],
#  ['cnp01875480',
#   'Venatorius, Thomas',
#   '1488',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'theol_math'],
#  ['cnp02236633',
#   'Mello, Francisco de',
#   '1490',
#   'cnl00017007',
#   'Lisboa',
#   '-9.13',
#   '38.7194444444444',
#   'theol_math'],
#  ['cnp01919968',
#   'Schnellenberg, Tarquinius',
#   '1490',
#   'cnl00032952',
#   'Attendorn',
#   '7.9',
#   '51.1166666666667',
#   'other'],
#  ['cnp01877797',
#   'Schreiber, Heinrich',
#   '1492',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'astron'],
#  ['cnp00639317',
#   'Bellarmato, Girolamo',
#   '1493',
#   'cnl00017267',
#   'Siena',
#   '11.33',
#   '43.32',
#   'other'],
#  ['cnp01884758',
#   'Giannotti Rangoni, Tommaso',
#   '1493',
#   'cnl00017679',
#   'Ravenna',
#   '12.1997222222222',
#   '44.42',
#   'other'],
#  ['cnp01330865',
#   'Grynäus, Simon',
#   '1493',
#   'cnl00006192',
#   'Basel',
#   '14.4191666666667',
#   '46.9477777777778',
#   'med_math'],
#  ['cnp01313334',
#   'Bronkhorst, Jan',
#   '1494',
#   'cnl00016323',
#   'Nijmegen',
#   '5.87',
#   '51.8291666666667',
#   'math'],
#  ['cnp01881119',
#   'Finé, Oronce',
#   '1494',
#   'cnl00018306',
#   'Briançon',
#   '6.6356',
#   '44.8964',
#   'astron'],
#  ['cnp01290195',
#   'Scheube, Johann',
#   '1494',
#   'cnl00010595',
#   'Kirchheim unter Teck',
#   '9.44944444444445',
#   '48.6494444444444',
#   'other'],
#  ['cnp01876551',
#   'Scheubel, Johann',
#   '1494',
#   'cnl00010595',
#   'Kirchheim unter Teck',
#   '9.44944444444445',
#   '48.6494444444444',
#   'math'],
#  ['cnp01019887',
#   'Alber, Matthäus',
#   '1495',
#   'cnl00013213',
#   'Reutlingen',
#   '9.22',
#   '48.4797222222222',
#   'other'],
#  ['cnp01347892',
#   'Apian, Petrus',
#   '1495',
#   'cnl00011083',
#   'Leisnig',
#   '12.9197222222222',
#   '51.17',
#   'astron'],
#  ['cnp01323680',
#   'Wissenburg, Wolfgang',
#   '1496',
#   'cnl00006413',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'theol_math'],
#  ['cnp01875467',
#   'Fernel, Jean',
#   '1497',
#   'cnl00011844',
#   'Montdidier',
#   '2.56972222222222',
#   '49.6497222222222',
#   'med'],
#  ['cnp01880016',
#   'Osiander, Andreas',
#   '1498',
#   'cnl00016071',
#   'Gunzenhausen',
#   '10.75',
#   '49.1',
#   'other'],
#  ['cnp00579703',
#   'Zündt, Mathis',
#   '1498',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01443317',
#   'Carion, Johann',
#   '1499',
#   'cnl00007441',
#   'Bietigheim-Bissingen',
#   '9.13',
#   '48.9697222222222',
#   'astrol'],
#  ['cnp01875826',
#   'Ringelberg, Joachim Sterck van',
#   '1499',
#   'cnl00006404',
#   'Antwerpen',
#   '4.41944444444445',
#   '51.2191666666667',
#   'math'],
#  ['cnp00405470',
#   'Rudolff, Christoph',
#   '1499',
#   'cnl00010398',
#   'Jauer',
#   '16.18',
#   '51.05',
#   'math'],
#  ['cnp00569865',
#   'Schönitz, Hans',
#   '1499',
#   'cnl00029460',
#   'Halle, Saale',
#   '12',
#   '51.5',
#   'other'],
#  ['cnp01356340',
#   'Tartaglia, Niccolò',
#   '1499',
#   'cnl00006938',
#   'Brescia',
#   '10.2166666666667',
#   '45.5416666666667',
#   'math'],
#  ['cnp01350201',
#   'Agrippa, Camillo',
#   '1500',
#   'cnl00006209',
#   'Milano',
#   '12.48',
#   '41.8991666666667',
#   'math'],
#  ['cnp01876658',
#   'Aleaume, Jean',
#   '1500',
#   'cnl00016168',
#   'Orléans',
#   '1.89916666666667',
#   '47.92',
#   'other'],
#  ['cnp01349348',
#   'Bongo, Pietro',
#   '1500',
#   'cnl00028170',
#   'Bergamo',
#   '9.66666666666667',
#   '45.7',
#   'other'],
#  ['cnp01443388',
#   'Dryander, Johann',
#   '1500',
#   'cnl00031504',
#   'Wetter',
#   '8.71666666666667',
#   '50.8991666666667',
#   'med_math'],
#  ['cnp01121159',
#   'Fischer, Johann',
#   '1500',
#   'cnl00004200',
#   'Neustadt, Saale',
#   '10.2166666666667',
#   '50.3166666666667',
#   'other'],
#  ['cnp01392199',
#   'Forlani, Paolo',
#   '1500',
#   'cnl00027166',
#   'Verona',
#   '11',
#   '45.4294444444444',
#   'other'],
#  ['cnp00545294',
#   'Gerung, Matthias',
#   '1500',
#   'cnl00016162',
#   'Nördlingen',
#   '10.5',
#   '48.85',
#   'other'],
#  ['cnp01875706',
#   'Gribaldi, Matteo',
#   '1500',
#   'cnl00008235',
#   'Chieri',
#   '7.82',
#   '45.02',
#   'other'],
#  ['cnp01084480',
#   'Imser, Philipp',
#   '1500',
#   'cnl00016230',
#   'Straßburg',
#   '7.75',
#   '48.5791666666667',
#   'astron'],
#  ['cnp00482208',
#   'Perret, Jacques',
#   '1500',
#   'cnl00008103',
#   'Chambéry',
#   '5.9',
#   '45.6',
#   'math'],
#  ['cnp01364712',
#   'Rossi, Joseph de',
#   '1500',
#   'cnl00016128',
#   'Milano',
#   '9.19944444444445',
#   '45.46',
#   'other'],
#  ['cnp01112298',
#   'Seehofer, Leonhard',
#   '1500',
#   'cnl00015987',
#   'Amberg',
#   '11.8591666666667',
#   '49.4391666666667',
#   'other'],
#  ['cnp01114860',
#   'Vögelin, Johannes',
#   '1500',
#   'cnl00016079',
#   'Heilbronn',
#   '9.22',
#   '49.14',
#   'astron'],
#  ['cnp01437248',
#   'Cardano, Gerolamo',
#   '1501',
#   'cnl00012683',
#   'Pavia',
#   '9.16944444444444',
#   '45.17',
#   'med_math'],
#  ['cnp02156073',
#   'Catena, Pietro',
#   '1501',
#   'cnl00006330',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'astron'],
#  ['cnp02078749',
#   'Zahrádka, Jan',
#   '1501',
#   'cnl00026998',
#   'Prag',
#   '14.4191666666667',
#   '50.09',
#   'astron'],
#  ['cnp01122000',
#   'Garcaeus, Johannes',
#   '1502',
#   'cnl00030898',
#   'Pritzwalk',
#   '12.1830555555556',
#   '53.1494444444444',
#   'theol_math'],
#  ['cnp00950341',
#   'Medler, Nicolaus',
#   '1502',
#   'cnl00016089',
#   'Hof',
#   '11.9191666666667',
#   '50.32',
#   'other'],
#  ['cnp01179438',
#   'Seyfried, Georg',
#   '1502',
#   'cnl00010620',
#   'Kitzingen',
#   '10.1694444444444',
#   '49.7294444444444',
#   'med'],
#  ['cnp01112480',
#   'Sibenbürger, Dionysius',
#   '1502',
#   'cnl00007676',
#   'Braunau',
#   '12.62',
#   '48.2591666666667',
#   'med'],
#  ['cnp01468914',
#   'Bartoli, Cosimo',
#   '1503',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01345792',
#   'Cousin, Jean',
#   '1503',
#   'cnl00022784',
#   'Soucy',
#   '3.325',
#   '48.2503',
#   'other'],
#  ['cnp01876067',
#   'Hirschvogel, Augustin',
#   '1503',
#   'cnl00018227',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01875828',
#   'Cruciger, Caspar',
#   '1504',
#   'cnl00016122',
#   'Leipzig',
#   '12.33',
#   '51.2991666666667',
#   'other'],
#  ['cnp01875825',
#   'Mathesius, Johannes',
#   '1504',
#   'cnl00013298',
#   'Rochlitz',
#   '12.8',
#   '51.0497222222222',
#   'other'],
#  ['cnp01877605',
#   'Gasser, Achille Pirminius',
#   '1505',
#   'cnl00027549',
#   'Lindau',
#   '9.67916666666667',
#   '47.5491666666667',
#   'med_math'],
#  ['cnp01336086',
#   'Lemnius, Levinus',
#   '1505',
#   'cnl00016356',
#   'Zierikzee',
#   '3.92',
#   '51.65',
#   'med'],
#  ['cnp00125017',
#   'Raimondo, Annibale',
#   '1505',
#   'cnl00027166',
#   'Verona',
#   '11',
#   '45.4294444444444',
#   'med_math'],
#  ['cnp01876979',
#   'Gemma Frisius',
#   '1508',
#   'cnl00014666',
#   'Dokkum',
#   '6',
#   '53.33',
#   'med_math'],
#  ['cnp01334753',
#   'Piccolomini, Alessandro',
#   '1508',
#   'cnl00017267',
#   'Siena',
#   '11.33',
#   '43.32',
#   'philo_phys'],
#  ['cnp01879181',
#   'Commandino, Federico',
#   '1509',
#   'cnl00014894',
#   'Urbino',
#   '12.63',
#   '43.7194444444444',
#   'med_math'],
#  ['cnp01875669',
#   'Simeoni, Gabriello',
#   '1509',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01361113',
#   'Caburacci, Francesco',
#   '1510',
#   'cnl00010310',
#   'Imola',
#   '11.6997222222222',
#   '44.35',
#   'other'],
#  ['cnp01352300',
#   'Cataneo, Pietro',
#   '1510',
#   'cnl00017267',
#   'Siena',
#   '11.33',
#   '43.32',
#   'other'],
#  ['cnp01307139',
#   'Gabriele, Giacomo',
#   '1510',
#   'cnl00006330',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'math'],
#  ['cnp01363533',
#   'Gosselin, Jean',
#   '1510',
#   'cnl00015114',
#   'Vire',
#   '-0.88',
#   '48.83',
#   'other'],
#  ['cnp01340478',
#   'Mizauld, Antoine',
#   '1510',
#   'cnl00018297',
#   'Montluçon',
#   '2.6033',
#   '46.3408',
#   'med'],
#  ['cnp01324006',
#   'Postel, Guillaume',
#   '1510',
#   'cnl00020592',
#   'Barenton',
#   '-0.8308',
#   '48.6',
#   'other'],
#  ['cnp02239016',
#   'Velsius, Justus',
#   '1510',
#   'cnl00017263',
#   'Den Haag',
#   '4.31666666666667',
#   '52.0830555555556',
#   'other'],
#  ['cnp01395548',
#   'Amici, Giovanni Battista',
#   '1511',
#   'cnl00008044',
#   'Cosenza',
#   '16.25',
#   '39.31',
#   'astron'],
#  ['cnp02163127',
#   'Misocacus, Wilhelm',
#   '1511',
#   'cnl00006364',
#   'Bruxelles',
#   '4.36305555555556',
#   '50.8430555555556',
#   'other'],
#  ['cnp01292034',
#   'Mysocacus, Wilhelm',
#   '1511',
#   'cnl00006364',
#   'Bruxelles',
#   '4.36305555555556',
#   '50.8430555555556',
#   'astrol'],
#  ['cnp01443254',
#   'Reinhold, Erasmus',
#   '1511',
#   'cnl00013481',
#   'Saalfeld',
#   '11.3697222222222',
#   '50.6497222222222',
#   'astron'],
#  ['cnp01355754',
#   'Mercator, Gerard',
#   '1512',
#   'cnl00022601',
#   'Rupelmonde',
#   '4.290833',
#   '51.126111',
#   'theol_math'],
#  ['cnp01875767',
#   'Ferrier, Auger',
#   '1513',
#   'cnl00028830',
#   'Toulouse',
#   '1.43916666666667',
#   '43.6',
#   'med_math'],
#  ['cnp01876433',
#   'Gigas, Ioannes',
#   '1514',
#   'cnl00012314',
#   'Nordhausen',
#   '10.7913888888889',
#   '51.5002777777778',
#   'other'],
#  ['cnp01875723',
#   'Joachimus, Georgius',
#   '1514',
#   'cnl00000429',
#   'Feldkirch',
#   '8.59972222222222',
#   '47.2294444444444',
#   'astron'],
#  ['cnp01323251',
#   'Ramus, Petrus',
#   '1515',
#   'cnl00020518',
#   'Cuts',
#   '3.1006',
#   '49.5319',
#   'math'],
#  ['cnp01120341',
#   'Engelhart, Valentin',
#   '1516',
#   'cnl00016067',
#   'Gotha',
#   '10.72',
#   '50.95',
#   'astrol'],
#  ['cnp01387069',
#   'Floris, Frans',
#   '1516',
#   'cnl00006404',
#   'Antwerpen',
#   '4.41944444444445',
#   '51.2191666666667',
#   'other'],
#  ['cnp02170729',
#   'Vigelius, Volcuinus',
#   '1516',
#   'cnl00031504',
#   'Wetter',
#   '8.71666666666667',
#   '50.8991666666667',
#   'med_math'],
#  ['cnp01337057',
#   'Peletier, Jacques',
#   '1517',
#   'cnl00008313',
#   'Le Mans',
#   '0.2',
#   '48',
#   'other'],
#  ['cnp01303529',
#   'Heller, Joachim',
#   '1518',
#   'cnl00015349',
#   'Weißenfels',
#   '11.97',
#   '51.2',
#   'astron'],
#  ['cnp01124849',
#   'Hommel, Johann',
#   '1518',
#   'cnl00016139',
#   'Memmingen',
#   '10.1805555555556',
#   '46.5180555555556',
#   'astron'],
#  ['cnp01287286',
#   'Geuß, Wolfgang',
#   '1519',
#   'cnl00013842',
#   'Schneeberg',
#   '12.63',
#   '50.6',
#   'med_math'],
#  ['cnp01368037',
#   'Mei, Girolamo',
#   '1519',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01875207',
#   'Vogel, Matthäus',
#   '1519',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01200592',
#   'Adger, Cornelius',
#   '1520',
#   'cnl00009950',
#   'Leeuwarden',
#   '5.78',
#   '53.2',
#   'math'],
#  ['cnp02266756',
#   'Arcandam',
#   '1520',
#   'cnl00018297',
#   'Montluçon',
#   '2.6033',
#   '46.3408',
#   'other'],
#  ['cnp02134922',
#   'Ausonio, Ettore',
#   '1520',
#   'cnl00010359',
#   'Padova',
#   '11.88',
#   '45.42',
#   'med_math'],
#  ['cnp02230942',
#   'Belli, Silvio',
#   '1520',
#   'cnl00006333',
#   'Vicenza',
#   '11.55',
#   '45.5491666666667',
#   'other'],
#  ['cnp00989664',
#   'Lauterwald, Matthias',
#   '1520',
#   'cnl00029118',
#   'Elbląg',
#   '19.3991666666667',
#   '54.1666666666667',
#   'other'],
#  ['cnp01875685',
#   'Dietrich, Sebastian',
#   '1521',
#   'cnl00007110',
#   'Windsheim',
#   '10.4197222222222',
#   '49.5',
#   'med'],
#  ['cnp01407758',
#   'Gugler, Nicolaus',
#   '1521',
#   'cnl00026842',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01347099',
#   'Beuther, Michael',
#   '1522',
#   'cnl00008016',
#   'Karlstadt',
#   '9.76916666666667',
#   '49.96',
#   'other'],
#  ['cnp01481137',
#   'Chemnitz, Martin',
#   '1522',
#   'cnl00014764',
#   'Treuenbrietzen',
#   '12.8697222222222',
#   '52.1',
#   'other'],
#  ['cnp01089747',
#   'Brechtel, Stephan',
#   '1523',
#   'cnl00015997',
#   'Bamberg',
#   '10.8691666666667',
#   '49.8691666666667',
#   'math'],
#  ['cnp01235486',
#   'Giuntini, Francesco',
#   '1523',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'math'],
#  ['cnp01356128',
#   'Yciar, Juan de',
#   '1523',
#   'cnl00029313',
#   'Durango',
#   '-2.63305555555556',
#   '43.1666666666667',
#   'other'],
#  ['cnp01358480',
#   'Chavigny, Jean-Aimé',
#   '1524',
#   'cnl00007239',
#   'Beaune',
#   '4.83305555555556',
#   '47.0166666666667',
#   'other'],
#  ['cnp00402987',
#   'Stoltz, Tilmann',
#   '1524',
#   'cnl00014053',
#   'Siegen',
#   '8.01666666666667',
#   '50.8666666666667',
#   'astron'],
#  ['cnp01333594',
#   'Vieri, Francesco',
#   '1524',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01345049',
#   'Chacón, Pedro',
#   '1525',
#   'cnl00018435',
#   'Toledo',
#   '-4.01916666666667',
#   '39.8691666666667',
#   'math'],
#  ['cnp01441705',
#   'Hájek z Hájku, Tadeáš',
#   '1525',
#   'cnl00026998',
#   'Prag',
#   '14.4191666666667',
#   '50.09',
#   'med_math'],
#  ['cnp01443175',
#   'Peucer, Kaspar',
#   '1525',
#   'cnl00007222',
#   'Bautzen',
#   '14.4291666666667',
#   '51.1791666666667',
#   'med'],
#  ['cnp02163173',
#   'Röder, Sebastian',
#   '1525',
#   'cnl00013481',
#   'Saalfeld',
#   '11.3697222222222',
#   '50.6497222222222',
#   'other'],
#  ['cnp00888077',
#   'Schönfeld, Victorin',
#   '1525',
#   'cnl00007222',
#   'Bautzen',
#   '14.4291666666667',
#   '51.1791666666667',
#   'math'],
#  ['cnp01318480',
#   'Staden, Hans',
#   '1525',
#   'cnl00030402',
#   'Homberg',
#   '9.40555555555556',
#   '51.0338888888889',
#   'other'],
#  ['cnp01904447',
#   'Bombelli, Rafael',
#   '1526',
#   'cnl00017069',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'math'],
#  ['cnp01025752',
#   'Brotbeihel, Mathias',
#   '1526',
#   'cnl00010528',
#   'Kaufbeuren',
#   '10.6197222222222',
#   '47.88',
#   'other'],
#  ['cnp01124424',
#   'Heiden, Christian',
#   '1526',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'math'],
#  ['cnp00876424',
#   'Jagenteufel, Nikolaus',
#   '1526',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'other'],
#  ['cnp02163146',
#   'Petricovius, Thomas',
#   '1526',
#   'cnl00033733',
#   'Piotrków Trybunalski',
#   '19.6830555555556',
#   '51.3991666666667',
#   'other'],
#  ['cnp01113305',
#   'Stoius, Matthias',
#   '1526',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'med_math'],
#  ['cnp01877782',
#   'Dee, John',
#   '1527',
#   'cnl00006402',
#   'London',
#   '-0.13',
#   '51.5091666666667',
#   'astrol'],
#  ['cnp01056939',
#   'Dummerich, Paul',
#   '1527',
#   'cnl00029460',
#   'Halle, Saale',
#   '12',
#   '51.5',
#   'other'],
#  ['cnp00450702',
#   'Hosmann, Peter',
#   '1527',
#   'cnl00010983',
#   'Lauban',
#   '15.2794444444444',
#   '51.1194444444444',
#   'med_math'],
#  ['cnp02163189',
#   'Rychart, Johann',
#   '1527',
#   'cnl00016230',
#   'Straßburg',
#   '7.75',
#   '48.5791666666667',
#   'other'],
#  ['cnp01919710',
#   'Fabricius, Paul',
#   '1528',
#   'cnl00010983',
#   'Lauban',
#   '15.2794444444444',
#   '51.1194444444444',
#   'other'],
#  ['cnp01878121',
#   'Lonicer, Adam',
#   '1528',
#   'cnl00011508',
#   'Marburg',
#   '8.76916666666667',
#   '50.82',
#   'med'],
#  ['cnp01029668',
#   'Schöner, Andreas',
#   '1528',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01350014',
#   'Wecker, Johann Jacob',
#   '1528',
#   'cnl00015955',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'med'],
#  ['cnp01920049',
#   'Wickner, Abdias Sixtus',
#   '1528',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01409038',
#   'Dasypodius, Conradus',
#   '1529',
#   'cnl00009233',
#   'Frauenfeld',
#   '8.9',
#   '47.5497222222222',
#   'astron'],
#  ['cnp01078149',
#   'Fabricius, Paulus',
#   '1529',
#   'cnl00010983',
#   'Lauban',
#   '15.2794444444444',
#   '51.1194444444444',
#   'astron'],
#  ['cnp01302722',
#   'Francesco, Patrizi',
#   '1529',
#   'cnl00008224',
#   'Cres',
#   '14.41',
#   '44.96',
#   'philo_phys'],
#  ['cnp02252061',
#   'Sozi, Raffaello',
#   '1529',
#   'cnl00012718',
#   'Perugia',
#   '12.38',
#   '43.1',
#   'math'],
#  ['cnp01368443',
#   'Zane, Giacomo',
#   '1529',
#   'cnl00006330',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'other'],
#  ['cnp01880790',
#   'Benedetti, Giovanni Battista',
#   '1530',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'math'],
#  ['cnp01303321',
#   'Brucaeus, Henricus',
#   '1530',
#   'cnl00006027',
#   'Alost',
#   '4.03',
#   '50.9291666666667',
#   'med_math'],
#  ['cnp01302340',
#   'Graminaeus, Theodor',
#   '1530',
#   'cnl00013317',
#   'Roermond',
#   '6',
#   '51.2',
#   'math'],
#  ['cnp01363433',
#   'Murer, Jos',
#   '1530',
#   'cnl00029143',
#   'Zürich',
#   '8.55',
#   '47.3691666666667',
#   'astron'],
#  ['cnp00453662',
#   'Rosa, Andreas',
#   '1530',
#   'cnl00013475',
#   'Schweinfurt',
#   '10.23',
#   '50.0491666666667',
#   'med_math'],
#  ['cnp01302373',
#   'Schönborn, Bartholomaeus',
#   '1530',
#   'cnl00015564',
#   'Wittenberg',
#   '9.97',
#   '53.42',
#   'med'],
#  ['cnp01240021',
#   'Simi, Nicolò',
#   '1530',
#   'cnl00028839',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'astron'],
#  ['cnp00394082',
#   'Apianus, Philipp',
#   '1531',
#   'cnl00016096',
#   'Ingolstadt',
#   '11.4291666666667',
#   '48.77',
#   'med_math'],
#  ['cnp01231917',
#   'Bottrigari, Ercole',
#   '1531',
#   'cnl00017069',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'other'],
#  ['cnp01104400',
#   'Lauterbach, Hieronymus',
#   '1531',
#   'cnl00011265',
#   'Löbau',
#   '14.6697222222222',
#   '51.1',
#   'astron'],
#  ['cnp01390409',
#   'Leemann, Burkhard',
#   '1531',
#   'cnl00029143',
#   'Zürich',
#   '8.55',
#   '47.3691666666667',
#   'other'],
#  ['cnp01365922',
#   'Moleti, Giuseppe',
#   '1531',
#   'cnl00011678',
#   'Messina',
#   '15.55',
#   '38.1894444444444',
#   'med_math'],
#  ['cnp01875401',
#   'Thurneisser, Leonhard',
#   '1531',
#   'cnl00006413',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'med_math'],
#  ['cnp01333847',
#   'Holzmann, Wilhelm',
#   '1532',
#   'cnl00015995',
#   'Augsburg',
#   '10.88',
#   '48.3691666666667',
#   'other'],
#  ['cnp01337628',
#   'Maestro Quoquim',
#   '1532',
#   'cnl00014034',
#   'Sevilla',
#   '-5.99',
#   '37.38',
#   'med'],
#  ['cnp01879907',
#   'Codicillus, Petrus',
#   '1533',
#   'cnl00026998',
#   'Prag',
#   '14.4191666666667',
#   '50.09',
#   'astron'],
#  ['cnp01327594',
#   'Dariot, Claude',
#   '1533',
#   'cnl00016031',
#   'Dioni',
#   '5.01916666666667',
#   '47.32',
#   'med_math'],
#  ['cnp00122851',
#   'Hilderich, Edo',
#   '1533',
#   'cnl00010417',
#   'Jever',
#   '7.9',
#   '53.5794444444444',
#   'other'],
#  ['cnp01237076',
#   'Masini, Nicolò',
#   '1533',
#   'cnl00008147',
#   'Cesena',
#   '12.25',
#   '44.14',
#   'med'],
#  ['cnp01033767',
#   'Risner, Friedrich',
#   '1533',
#   'cnl00007106',
#   'Hersfeld',
#   '9.69972222222222',
#   '50.8697222222222',
#   'math'],
#  ['cnp01919971',
#   'Schönfeld[t], Victorinus',
#   '1533',
#   'cnl00007222',
#   'Bautzen',
#   '14.4291666666667',
#   '51.1791666666667',
#   'other'],
#  ['cnp01113388',
#   'Strauß, Jakob',
#   '1533',
#   'cnl00029132',
#   'Ljubljana',
#   '14.58',
#   '46.07',
#   'med'],
#  ['cnp01116302',
#   'Wolckenstein, David',
#   '1534',
#   'cnl00033303',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'math'],
#  ['cnp01389779',
#   'Diedo, Gerolamo',
#   '1535',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'other'],
#  ['cnp01340100',
#   'Gemma, Cornelius',
#   '1535',
#   'cnl00006764',
#   'Löwen',
#   '4.7',
#   '50.8833333333333',
#   'med_math'],
#  ['cnp00407311',
#   'Neodomus, Nicolaus',
#   '1535',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'math'],
#  ['cnp01107316',
#   'Neodomus, Nikolaus',
#   '1535',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'math'],
#  ['cnp02101603',
#   'Contarini, Giacomo',
#   '1536',
#   'cnl00001061',
#   'Nicosia',
#   '33.35',
#   '35.1666666666667',
#   'other'],
#  ['cnp00476702',
#   'Danti, Egnazio',
#   '1536',
#   'cnl00012718',
#   'Perugia',
#   '12.38',
#   '43.1',
#   'theol_math'],
#  ['cnp00014570',
#   'Dresser, Matthaeus',
#   '1536',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'other'],
#  ['cnp01105937',
#   'Meder, Georg',
#   '1536',
#   'cnl00004120',
#   'Mainbernheim',
#   '10.2166666666667',
#   '49.7166666666667',
#   'astron'],
#  ['cnp01358036',
#   'Monantheuil, Henri',
#   '1536',
#   'cnl00013170',
#   'Reims',
#   '4.03',
#   '49.25',
#   'med_math'],
#  ['cnp01919917',
#   'Nolthius, Andreas',
#   '1536',
#   'cnl00008881',
#   'Einbeck',
#   '9.86972222222222',
#   '51.82',
#   'other'],
#  ['cnp01320637',
#   'Raimondi, Giovanni Battista',
#   '1536',
#   'cnl00008073',
#   'Napoli',
#   '14.25',
#   '40.8294444444444',
#   'math'],
#  ['cnp00444650',
#   'Rockenbach, Abraham',
#   '1536',
#   'cnl00008637',
#   'Dinkelsbühl',
#   '10.32',
#   '49.07',
#   'other'],
#  ['cnp01307458',
#   'Barozzi, Francesco',
#   '1537',
#   'cnl00017694',
#   'Iraklion',
#   '25.1330555555556',
#   '35.3330555555556',
#   'math'],
#  ['cnp01301986',
#   'Clavius, Christoph',
#   '1537',
#   'cnl00015997',
#   'Bamberg',
#   '10.8691666666667',
#   '49.8691666666667',
#   'astron'],
#  ['cnp01079978',
#   'Flach, Jakob',
#   '1537',
#   'cnl00010282',
#   'Jena',
#   '11.58',
#   '50.9291666666667',
#   'med_math'],
#  ['cnp01919930',
#   'Praetorius, Johann',
#   '1537',
#   'cnl00033727',
#   'Jáchymov',
#   '12.9230555555556',
#   '50.3655555555556',
#   'other'],
#  ['cnp01311921',
#   'Praetorius, Johannes',
#   '1537',
#   'cnl00009663',
#   'Joachimsthal',
#   '13.75',
#   '52.9694444444444',
#   'math'],
#  ['cnp01880451',
#   'Gallucci, Giovanni Paolo',
#   '1538',
#   'cnl00013606',
#   'Salò',
#   '10.52',
#   '45.6',
#   'astron'],
#  ['cnp01109829',
#   'Reinhold, Erasmus',
#   '1538',
#   'cnl00015564',
#   'Wittenberg',
#   '9.97',
#   '53.42',
#   'med_math'],
#  ['cnp01920024',
#   'Upilio, Wilhelm',
#   '1538',
#   'cnl00007110',
#   'Windsheim',
#   '10.4197222222222',
#   '49.5',
#   'med_math'],
#  ['cnp00157873',
#   'Ceulen, Ludolf',
#   '1539',
#   'cnl00016086',
#   'Hildesheim',
#   '9.97',
#   '52.1491666666667',
#   'math'],
#  ['cnp00485397',
#   'Schato, Andreas',
#   '1539',
#   'cnl00014692',
#   'Torgau',
#   '13',
#   '51.57',
#   'med_math'],
#  ['cnp02105686',
#   'Byǆovský z Florentina, Marek',
#   '1540',
#   'cnl00043071',
#   'Nový Bydžov',
#   '15.4905555555556',
#   '50.2413888888889',
#   'astron'],
#  ['cnp01879549',
#   'Cataneo, Girolamo',
#   '1540',
#   'cnl00012338',
#   'Novara',
#   '8.62',
#   '45.44',
#   'other'],
#  ['cnp00416575',
#   'Fruauf, Laurentius',
#   '1540',
#   'cnl00013153',
#   'Reichenbach im Vogtland',
#   '12.32',
#   '50.6097222222222',
#   'theol_math'],
#  ['cnp01124562',
#   'Hirschfeld, Michael',
#   '1540',
#   'cnl00012314',
#   'Nordhausen',
#   '10.7913888888889',
#   '51.5002777777778',
#   'med_math'],
#  ['cnp01358244',
#   'Le Baillif, Roch',
#   '1540',
#   'cnl00009084',
#   'Falaise',
#   '-0.2',
#   '48.9',
#   'other'],
#  ['cnp01377638',
#   'Lorini, Buonaiuto',
#   '1540',
#   'cnl00017011',
#   'Firenze',
#   '-87.6680555555556',
#   '34.8269444444445',
#   'math'],
#  ['cnp01919886',
#   'Mencius, Simon',
#   '1540',
#   'cnl00013035',
#   'Quedlinburg',
#   '11.15',
#   '51.78',
#   'other'],
#  ['cnp01103897',
#   'Mercator, Bartholomäus',
#   '1540',
#   'cnl00006764',
#   'Löwen',
#   '4.7',
#   '50.8833333333333',
#   'astron'],
#  ['cnp01306733',
#   'Monaldi, Miho',
#   '1540',
#   'cnl00008750',
#   'Dubrovnik',
#   '18.0894444444444',
#   '42.6494444444444',
#   'other'],
#  ['cnp01880764',
#   'Rasch, Johann',
#   '1540',
#   'cnl00033736',
#   'Pöchlarn',
#   '15.1991666666667',
#   '48.2',
#   'math'],
#  ['cnp00096056',
#   'Snel, Rudolf',
#   '1540',
#   'cnl00012605',
#   'Oudewater',
#   '4.87972222222222',
#   '52.03',
#   'math'],
#  ['cnp01291699',
#   'Suter, Jacob',
#   '1540',
#   'cnl00010761',
#   'Ravensburg',
#   '9.61944444444445',
#   '47.78',
#   'med'],
#  ['cnp01322847',
#   'Viète, François',
#   '1540',
#   'cnl00017406',
#   'Fontenay-le-Comte',
#   '-0.8061',
#   '46.466',
#   'math'],
#  ['cnp02162972',
#   'Bathodius, Lucas',
#   '1541',
#   'cnl00016230',
#   'Straßburg',
#   '7.75',
#   '48.5791666666667',
#   'other'],
#  ['cnp01303545',
#   'Caesius, Georg',
#   '1542',
#   'cnl00013386',
#   'Rothenburg ob der Tauber',
#   '10.1788888888889',
#   '49.3769444444444',
#   'med_math'],
#  ['cnp01919940',
#   'Reinstein, Johannes',
#   '1542',
#   'cnl00012940',
#   'Pössneck',
#   '11.5997222222222',
#   '50.7',
#   'other'],
#  ['cnp01082076',
#   'Mathesius, Johannes',
#   '1544',
#   'cnl00033727',
#   'Jáchymov',
#   '12.9230555555556',
#   '50.3655555555556',
#   'med'],
#  ['cnp01045770',
#   'Meine, Matthias',
#   '1544',
#   'cnl00006805',
#   'Danzig (Germany)',
#   '18.67',
#   '54.35',
#   'other'],
#  ['cnp01113293',
#   'Stockmann, Erasmus',
#   '1544',
#   'cnl00027108',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'med_math'],
#  ['cnp01422536',
#   'Thalius, Daniel',
#   '1544',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'math'],
#  ['cnp01303513',
#   'Wursteisen, Christian',
#   '1544',
#   'cnl00015955',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'theol_math'],
#  ['cnp01355346',
#   'Cysat, Renward',
#   '1545',
#   'cnl00027772',
#   'Luzern',
#   '8.26944444444445',
#   '47.0791666666667',
#   'other'],
#  ['cnp01368065',
#   'Dal Monte, Guidobaldo',
#   '1545',
#   'cnl00012727',
#   'Pesaro',
#   '12.89',
#   '43.8994444444444',
#   'math'],
#  ['cnp02163025',
#   'Fontanus, Valentin',
#   '1545',
#   'cnl00033710',
#   '',
#   '16.8666666666667',
#   '51.5494444444444',
#   'other'],
#  ['cnp00458518',
#   'Stempel, Gerhard',
#   '1546',
#   'cnl00016297',
#   'Gouda',
#   '4.7',
#   '52.02',
#   'astron'],
#  ['cnp00571276',
#   'Wittich, Paul',
#   '1546',
#   'cnl00033303',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'astron'],
#  ['cnp01468084',
#   'Alemán, Mateo',
#   '1547',
#   'cnl00014034',
#   'Sevilla',
#   '-5.99',
#   '37.38',
#   'other'],
#  ['cnp00962892',
#   'Pegelius, Magnus',
#   '1547',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'med_math'],
#  ['cnp00962892',
#   'Pegelius, Magnus',
#   '1547',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'med_math'],
#  ['cnp01237192',
#   'Mazzoni, Jacopo',
#   '1548',
#   'cnl00008147',
#   'Cesena',
#   '12.25',
#   '44.14',
#   'astron'],
#  ['cnp01259618',
#   'Stevin, Simon',
#   '1548',
#   'cnl00007767',
#   'Bruges',
#   '3.14',
#   '51.13',
#   'math'],
#  ['cnp01342652',
#   'Coignet, Michel',
#   '1549',
#   'cnl00029116',
#   'Antwerpen',
#   '4.41944444444445',
#   '51.2191666666667',
#   'math'],
#  ['cnp01919686',
#   'Cöllen, Lucas',
#   '1549',
#   'cnl00006821',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'other'],
#  ['cnp01919799',
#   'Henisch, Georg',
#   '1549',
#   'cnl00000220',
#   'Bardejov',
#   '15.5666666666667',
#   '49.28',
#   'med'],
#  ['cnp01309947',
#   'Crispo, Giovanni Battista',
#   '1550',
#   'cnl00009335',
#   'Gallipoli',
#   '17.98',
#   '40.06',
#   'other'],
#  ['cnp00922870',
#   'Martínez, Enrico',
#   '1550',
#   'cnl00027108',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'other'],
#  ['cnp01338415',
#   'Moestlin, Michael',
#   '1550',
#   'cnl00016066',
#   'Göppingen',
#   '9.66972222222222',
#   '48.7',
#   'astron'],
#  ['cnp01112934',
#   'Stadius, Georg',
#   '1550',
#   'cnl00001408',
#   'Stein, Donau',
#   '15.5816666666667',
#   '48.4016666666667',
#   'astron'],
#  ['cnp01944825',
#   'Volkmer, Tobias',
#   '1550',
#   'cnl00029873',
#   'Braunschweig',
#   '10.5205555555556',
#   '52.2691666666667',
#   'math'],
#  ['cnp02163156',
#   'Raymarus Ursus, Nicolaus',
#   '1551',
#   'cnl00033737',
#   'Hennstedt',
#   '9.16666666666667',
#   '54.2830555555556',
#   'other'],
#  ['cnp01286849',
#   'Stöberlein, Leonhard',
#   '1551',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01110021',
#   'Ursus, Nicolaus Raimarus',
#   '1551',
#   'cnl00033737',
#   'Hennstedt',
#   '9.16666666666667',
#   '54.2830555555556',
#   'astron'],
#  ['cnp01879400',
#   'Verantius, Faustus',
#   '1551',
#   'cnl00004370',
#   'Sibenik',
#   '15.8830555555556',
#   '43.7330555555556',
#   'philo_phys'],
#  ['cnp02163192',
#   'Ryff, Peter',
#   '1552',
#   'cnl00006413',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'med'],
#  ['cnp01329248',
#   'Baldi, Bernardino',
#   '1553',
#   'cnl00014894',
#   'Urbino',
#   '12.63',
#   '43.7194444444444',
#   'other'],
#  ['cnp02231369',
#   'Herwart von Hohenburg, Johann Georg',
#   '1553',
#   'cnl00015995',
#   'Augsburg',
#   '10.88',
#   '48.3691666666667',
#   'other'],
#  ['cnp00481169',
#   'Krabbe, Johannes',
#   '1553',
#   'cnl00009875',
#   'Hann. Münden',
#   '9.65',
#   '51.4166666666667',
#   'math'],
#  ['cnp02163276',
#   'Zeysius, Matthaeus',
#   '1553',
#   'cnl00006174',
#   'Kostrzyn nad Odrą',
#   '14.65',
#   '52.5791666666667',
#   'other'],
#  ['cnp01467090',
#   'Bayern, Ernst von',
#   '1554',
#   'cnl00030740',
#   'München',
#   '11.58',
#   '48.1491666666667',
#   'other'],
#  ['cnp00605131',
#   'Brechtel, Franz Joachim',
#   '1554',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01104779',
#   'Limnaeus, Georg',
#   '1554',
#   'cnl00010282',
#   'Jena',
#   '11.58',
#   '50.9291666666667',
#   'astron'],
#  ['cnp01133177',
#   'Pfinzing, Paul',
#   '1554',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01919833',
#   'Jacobi, Valentin',
#   '1555',
#   'cnl00015356',
#   'Weissensee',
#   '11.07',
#   '51.18',
#   'other'],
#  ['cnp02163082',
#   'Jebinger, Stephan',
#   '1555',
#   'cnl00033720',
#   'Schärding',
#   '13.4330555555556',
#   '48.45',
#   'other'],
#  ['cnp01377920',
#   'Lavanha, João Baptista',
#   '1555',
#   'cnl00017007',
#   'Lisboa',
#   '-9.13',
#   '38.7194444444444',
#   'math'],
#  ['cnp01328166',
#   'Magini, Giovanni Antonio',
#   '1555',
#   'cnl00010359',
#   'Padova',
#   '11.88',
#   '45.42',
#   'astron'],
#  ['cnp01291829',
#   'Miller, Onophrius',
#   '1555',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'math'],
#  ['cnp01356171',
#   'Calvisius, Sethus',
#   '1556',
#   'cnl00046349',
#   'Gorsleben',
#   '11.1830555555556',
#   '51.2666666666667',
#   'astron'],
#  ['cnp02237779',
#   'Moerman, Jan',
#   '1556',
#   'cnl00029116',
#   'Antwerpen',
#   '4.41944444444445',
#   '51.2191666666667',
#   'other'],
#  ['cnp01316739',
#   'Caesar, Gaius Iulius',
#   '1557',
#   'cnl00016199',
#   'Roma',
#   '12.48',
#   '41.8991666666667',
#   'other'],
#  ['cnp02222256',
#   'Carello, Giovanni Battista',
#   '1557',
#   'cnl00012778',
#   'Piacenza',
#   '9.66944444444444',
#   '45.02',
#   'astron'],
#  ['cnp00444503',
#   'Herlitz, David',
#   '1557',
#   'cnl00015727',
#   'Zeitz',
#   '12.15',
#   '51.0494444444444',
#   'astron'],
#  ['cnp01359016',
#   'Tancke, Joachim',
#   '1557',
#   'cnl00012710',
#   'Perleberg',
#   '11.8697222222222',
#   '53.07',
#   'med_math'],
#  ['cnp01919691',
#   'Cuno, Jacob',
#   '1558',
#   'cnl00009211',
#   'Frankfurt an der Oder',
#   '14.55',
#   '52.35',
#   'other'],
#  ['cnp01895099',
#   'Meurer, Christoph',
#   '1558',
#   'cnl00016122',
#   'Leipzig',
#   '12.33',
#   '51.2991666666667',
#   'med_math'],
#  ['cnp01878530',
#   'Origanus, David',
#   '1558',
#   'cnl00009466',
#   'Glatz',
#   '16.6494444444444',
#   '50.4294444444444',
#   'math'],
#  ['cnp00369337',
#   'Sturm, Johannes',
#   '1559',
#   'cnl00011474',
#   'Mechelen',
#   '4.46944444444445',
#   '51.03',
#   'med_math'],
#  ['cnp00444510',
#   'Stöckel, Lucas',
#   '1559',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp01343086',
#   'Harriot, Thomas',
#   '1560',
#   'cnl00012616',
#   'Oxford',
#   '-1.25',
#   '51.75',
#   'astron'],
#  ['cnp01876902',
#   'Lansbergen, Philippus',
#   '1560',
#   'cnl00009341',
#   'Gent',
#   '3.72166666666667',
#   '51.0538888888889',
#   'med_math'],
#  ['cnp01877738',
#   'Lavater, Heinrich',
#   '1560',
#   'cnl00029143',
#   'Zürich',
#   '8.55',
#   '47.3691666666667',
#   'med_math'],
#  ['cnp00384901',
#   'Parcovius, Franciscus',
#   '1560',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'med'],
#  ['cnp00475665',
#   'André, Élie',
#   '1561',
#   'cnl00016013',
#   'Bordeaux',
#   '-0.569166666666667',
#   '44.8291666666667',
#   'other'],
#  ['cnp00386604',
#   'Finck, Thomas',
#   '1561',
#   'cnl00009157',
#   'Flensburg',
#   '9.42916666666667',
#   '54.78',
#   'med_math'],
#  ['cnp00883349',
#   'Liddel, Duncan',
#   '1561',
#   'cnl00026571',
#   'Aberdeen',
#   '-2.1',
#   '57.13',
#   'med_math'],
#  ['cnp01327326',
#   'Pitiscus, Bartholomaeus',
#   '1561',
#   'cnl00030251',
#   'Grünberg',
#   '15.4491666666667',
#   '51.9691666666667',
#   'theol_math'],
#  ['cnp00094435',
#   'Randt, Joachim',
#   '1561',
#   'cnl00010451',
#   'Jüterbog',
#   '13.0727777777778',
#   '52',
#   'other'],
#  ['cnp01344864',
#   'Romanus, Adrianus',
#   '1561',
#   'cnl00006404',
#   'Antwerpen',
#   '4.41944444444445',
#   '50.8833333333333',
#   'med_math'],
#  ['cnp01024644',
#   'Schülin, Johann',
#   '1561',
#   'cnl00008422',
#   'Crailsheim',
#   '10.08',
#   '49.1497222222222',
#   'other'],
#  ['cnp01307826',
#   'Sirigatti, Lorenzo',
#   '1561',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01054493',
#   'Mader, Timotheus',
#   '1562',
#   'cnl00009233',
#   'Frauenfeld',
#   '8.9',
#   '47.5497222222222',
#   'med'],
#  ['cnp01273329',
#   'Schuster, Johann Paul',
#   '1562',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'theol_math'],
#  ['cnp01920011',
#   'Stuer, Barnim',
#   '1562',
#   'cnl00014248',
#   'Zerbst',
#   '12.08',
#   '51.9697222222222',
#   'med_math'],
#  ['cnp01920012',
#   'Sutorius, Johann Paul',
#   '1562',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp00543426',
#   'Xu, Guangqi',
#   '1562',
#   'cnl00029818',
#   'Schanghai',
#   '121.466666666667',
#   '31.2330555555556',
#   'other'],
#  ['cnp01103907',
#   'Kreslin, Georg',
#   '1563',
#   'cnl00015990',
#   'Ansbach',
#   '10.58',
#   '49.2997222222222',
#   'astron'],
#  ['cnp00366743',
#   'Schaerer, Melchior',
#   '1563',
#   'cnl00016232',
#   'Stuttgart',
#   '9.17944444444444',
#   '48.77',
#   'theol_math'],
#  ['cnp01919970',
#   'Schönfeld[t], Burckhard Victorin',
#   '1563',
#   'cnl00011508',
#   'Marburg',
#   '8.76916666666667',
#   '50.82',
#   'other'],
#  ['cnp00099596',
#   'Adler, Bartholomaeus',
#   '1564',
#   'cnl00006642',
#   'Adorf',
#   '12.2697222222222',
#   '50.32',
#   'other'],
#  ['cnp01330272',
#   'Buscher, Heizo',
#   '1564',
#   'cnl00027245',
#   'Hannover',
#   '9.72',
#   '52.3591666666667',
#   'theol_math'],
#  ['cnp01919706',
#   'Fabricius, David',
#   '1564',
#   'cnl00009029',
#   'Esens',
#   '7.59944444444444',
#   '53.6494444444444',
#   'other'],
#  ['cnp00951038',
#   'Galgemair, Georg',
#   '1564',
#   'cnl00016035',
#   'Donauwörth',
#   '10.8',
#   '48.7',
#   'astron'],
#  ['cnp00394836',
#   'Galilei, Galileo',
#   '1564',
#   'cnl00012806',
#   'Pisa',
#   '10.38',
#   '43.7194444444444',
#   'astron'],
#  ['cnp02163119',
#   'Malleolus, Isaac',
#   '1564',
#   'cnl00016230',
#   'Straßburg',
#   '7.75',
#   '48.5791666666667',
#   'math'],
#  ['cnp01327958',
#   'Mulerius, Nicolaus',
#   '1564',
#   'cnl00007767',
#   'Bruges',
#   '3.14',
#   '51.13',
#   'med_math'],
#  ['cnp01920041',
#   'Wegener, Johann',
#   '1564',
#   'cnl00014398',
#   'Stralsund',
#   '13.0991666666667',
#   '54.2991666666667',
#   'other'],
#  ['cnp00424447',
#   'Wegenerus, Johannes',
#   '1564',
#   'cnl00014398',
#   'Stralsund',
#   '13.0991666666667',
#   '54.2991666666667',
#   'astron'],
#  ['cnp01879023',
#   'Bertius, Petrus',
#   '1565',
#   'cnl00020709',
#   'Beveren',
#   '4.25',
#   '51.2',
#   'philo_phys'],
#  ['cnp01347493',
#   'Brerewood, Edward',
#   '1565',
#   'cnl00008225',
#   'Chester',
#   '-2.58',
#   '53.17',
#   'astron'],
#  ['cnp01900808',
#   'Chiaramonti, Scipione',
#   '1565',
#   'cnl00008147',
#   'Cesena',
#   '12.25',
#   '44.14',
#   'other'],
#  ['cnp01233501',
#   'Crescenzio, Bartolomeo',
#   '1565',
#   'cnl00029123',
#   'Roma',
#   '12.48',
#   '41.8991666666667',
#   'other'],
#  ['cnp01395469',
#   'Delle Colombe, Lodovico',
#   '1565',
#   'cnl00033525',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp02143831',
#   'Fiammelli, Giovanni Francesco',
#   '1565',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'math'],
#  ['cnp01340415',
#   'Foscarini, Paolo Antonio',
#   '1565',
#   'cnl00004164',
#   'Montalto Uffugo',
#   '16.1491666666667',
#   '39.3991666666667',
#   'other'],
#  ['cnp02251223',
#   'Magenta, Giovanni',
#   '1565',
#   'cnl00006209',
#   'Milano',
#   '9.19944444444445',
#   '45.46',
#   'math'],
#  ['cnp00871211',
#   'Biancani, Giuseppe',
#   '1566',
#   'cnl00017069',
#   'Bologna',
#   '11.3491666666667',
#   '44.5',
#   'astron'],
#  ['cnp00468695',
#   'Ghetaldus, Marinus',
#   '1566',
#   'cnl00008750',
#   'Dubrovnik',
#   '18.0894444444444',
#   '42.6494444444444',
#   'math'],
#  ['cnp01406042',
#   "Aguillon, François d'",
#   '1567',
#   'cnl00006364',
#   'Bruxelles',
#   '4.36305555555556',
#   '50.8430555555556',
#   'math'],
#  ['cnp00877897',
#   'Messing, Bernhard',
#   '1567',
#   'cnl00002783',
#   'Riga',
#   '24.1063888888889',
#   '56.9488888888889',
#   'astron'],
#  ['cnp01106465',
#   'Möller, Bartholomaeus',
#   '1567',
#   'cnl00002783',
#   'Riga',
#   '24.1063888888889',
#   '56.9488888888889',
#   'astron'],
#  ['cnp01919647',
#   'Arthus, Gotthard',
#   '1568',
#   'cnl00006805',
#   'Danzig (Germany)',
#   '18.67',
#   '54.35',
#   'other'],
#  ['cnp01358327',
#   'Hartmann, Johann',
#   '1568',
#   'cnl00015987',
#   'Amberg',
#   '11.8591666666667',
#   '49.4391666666667',
#   'other'],
#  ['cnp00892467',
#   'Winckler, Nicolaus Eberhard',
#   '1568',
#   'cnl00008351',
#   'Schwäbisch Hall',
#   '9.73305555555556',
#   '49.1166666666667',
#   'med'],
#  ['cnp02163051',
#   'Grothenius, Andreas',
#   '1569',
#   'cnl00009564',
#   'Göttingen',
#   '9.93555555555556',
#   '51.5338888888889',
#   'other'],
#  ['cnp01908712',
#   'Nozzolini, Tolomeo',
#   '1569',
#   'cnl00012806',
#   'Pisa',
#   '10.38',
#   '43.7194444444444',
#   'theol_math'],
#  ['cnp01408867',
#   'Oddi, Mutio',
#   '1569',
#   'cnl00014894',
#   'Urbino',
#   '12.63',
#   '43.7194444444444',
#   'other'],
#  ['cnp01108514',
#   'Pflaum, Jakob',
#   '1569',
#   'cnl00016242',
#   'Augsburg',
#   '10',
#   '48.3691666666667',
#   'theol_math'],
#  ['cnp01327988',
#   'Argoli, Andrea',
#   '1570',
#   'cnl00039939',
#   'Tagliacozzo',
#   '13.2544444444444',
#   '42.0691666666667',
#   'med_math'],
#  ['cnp01355841',
#   'De Houtman, Frederick',
#   '1570',
#   'cnl00016297',
#   'Gouda',
#   '4.7',
#   '52.02',
#   'astron'],
#  ['cnp01208565',
#   'Micalori, Giacomo',
#   '1570',
#   'cnl00014894',
#   'Urbino',
#   '12.63',
#   '43.7194444444444',
#   'other'],
#  ['cnp01876214',
#   'Schmid, Erasmus',
#   '1570',
#   'cnl00008552',
#   'Delitzsch',
#   '12.3497222222222',
#   '51.53',
#   'math'],
#  ['cnp01378567',
#   'Bure, Anders',
#   '1571',
#   'cnl00034017',
#   'Sæby',
#   '10.5266666666667',
#   '57.3325',
#   'math'],
#  ['cnp01355990',
#   'Celio, Gaspare',
#   '1571',
#   'cnl00016199',
#   'Roma',
#   '12.48',
#   '41.8991666666667',
#   'astrol'],
#  ['cnp01379493',
#   'Dilich, Wilhelm',
#   '1571',
#   'cnl00029858',
#   'Wabern',
#   '9.34944444444445',
#   '51.1',
#   'other'],
#  ['cnp01321061',
#   'Parigi, Giulio',
#   '1571',
#   'cnl00017011',
#   'Firenze',
#   '11.25',
#   '43.7830555555556',
#   'other'],
#  ['cnp01421274',
#   'Ries, Ludwig',
#   '1571',
#   'cnl00016122',
#   'Leipzig',
#   '12.33',
#   '51.2991666666667',
#   'other'],
#  ['cnp01233301',
#   'Conti, Ingolfo',
#   '1572',
#   'cnl00010359',
#   'Padova',
#   '11.88',
#   '45.42',
#   'other'],
#  ['cnp00414862',
#   'Dou, Jan Pieterszoon',
#   '1572',
#   'cnl00031387',
#   'Leyden',
#   '4.5',
#   '52.1491666666667',
#   'other'],
#  ['cnp01877766',
#   'Drebbel, Cornelius',
#   '1572',
#   'cnl00006743',
#   'Alkmaar',
#   '4.75',
#   '52.63',
#   'other'],
#  ['cnp01328010',
#   'Goclenius, Rudolph',
#   '1572',
#   'cnl00015564',
#   'Wittenberg',
#   '12.65',
#   '51.8691666666667',
#   'med_math'],
#  ['cnp01919680',
#   'Caesius, Georg Friedrich',
#   '1573',
#   'cnl00013386',
#   'Rothenburg ob der Tauber',
#   '10.1788888888889',
#   '49.3769444444444',
#   'other'],
#  ['cnp01919798',
#   'Helwig, Martin',
#   '1573',
#   'cnl00029960',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'other'],
#  ['cnp00401494',
#   'Mayr, Simon aus Gunzenhausen',
#   '1573',
#   'cnl00016071',
#   'Gunzenhausen',
#   '10.75',
#   '49.1',
#   'med_math'],
#  ['cnp02163157',
#   'Rechperger, Wilhelm',
#   '1573',
#   'cnl00033738',
#   'Eggenburg',
#   '15.8166666666667',
#   '48.6491666666667',
#   'other'],
#  ['cnp00990253',
#   'Bothvid, Johannes',
#   '1575',
#   'cnl00012318',
#   'Norrköping',
#   '16.1797222222222',
#   '58.6',
#   'other'],
#  ['cnp00946324',
#   'Oughtred, William',
#   '1575',
#   'cnl00009051',
#   'Eton',
#   '-0.61',
#   '51.49',
#   'theol_math'],
#  ['cnp00519261',
#   'Pisani, Ottavio',
#   '1575',
#   'cnl00008073',
#   'Napoli',
#   '14.25',
#   '40.8294444444444',
#   'astrol'],
#  ['cnp01919936',
#   'Radenicius, Joachim',
#   '1575',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'other'],
#  ['cnp01073264',
#   'Romero, Mateo',
#   '1575',
#   'cnl00006608',
#   'Liège',
#   '5.57',
#   '50.63',
#   'other'],
#  ['cnp01920059',
#   'Wittich, Johann Alexander',
#   '1575',
#   'cnl00014170',
#   'Sorau',
#   '15.15',
#   '51.63',
#   'other'],
#  ['cnp01026086',
#   'Fabricius, Jacob',
#   '1576',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'med'],
#  ['cnp00951475',
#   'Hofmann, Heinrich',
#   '1576',
#   'cnl00010282',
#   'Jena',
#   '11.58',
#   '50.9291666666667',
#   'astron'],
#  ['cnp02224706',
#   'Terentius, Johannes',
#   '1576',
#   'cnl00007449',
#   'Bingen',
#   '7.9',
#   '49.9697222222222',
#   'other'],
#  ['cnp01908276',
#   'Ventimiglia, Carlo Maria',
#   '1576',
#   'cnl00017071',
#   'Palermo',
#   '13.3666666666667',
#   '38.1166666666667',
#   'other'],
#  ['cnp01351342',
#   'Castelli, Benedetto',
#   '1577',
#   'cnl00006938',
#   'Brescia',
#   '10.2166666666667',
#   '45.5416666666667',
#   'math'],
#  ['cnp01919735',
#   'Fülle, Johannes',
#   '1577',
#   'cnl00015300',
#   'Weida',
#   '12.07',
#   '50.77',
#   'astron'],
#  ['cnp00125588',
#   'Reina, Tommaso',
#   '1577',
#   'cnl00006209',
#   'Milano',
#   '9.19944444444445',
#   '45.46',
#   'other'],
#  ['cnp00386550',
#   'Rhodius, Ambrosius',
#   '1577',
#   'cnl00049682',
#   'Kemberg',
#   '12.6322222222222',
#   '51.7719444444444',
#   'astron'],
#  ['cnp01399888',
#   'Cardinael, Sybrandt Hansz.',
#   '1578',
#   'cnl00002507',
#   'Harlingen',
#   '5.42444444444445',
#   '53.1705555555556',
#   'other'],
#  ['cnp01121780',
#   'Fuchs, Bartholomaeus',
#   '1578',
#   'cnl00006272',
#   'Regensburg',
#   '12.0991666666667',
#   '49.02',
#   'other'],
#  ['cnp01919933',
#   'Pyrlaeus, Christian',
#   '1578',
#   'cnl00009829',
#   'Halle',
#   '4.23',
#   '50.7294444444444',
#   'other'],
#  ['cnp02330678',
#   'Schwerin, Johann',
#   '1578',
#   'cnl00006879',
#   'Anklam',
#   '13.6997222222222',
#   '53.8697222222222',
#   'other'],
#  ['cnp00125422',
#   'Ritter, Franz',
#   '1579',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01395468',
#   'Capra, Baldassarre',
#   '1580',
#   'cnl00016128',
#   'Milano',
#   '9.19944444444445',
#   '45.46',
#   'other'],
#  ['cnp01877518',
#   'Crüger, Peter',
#   '1580',
#   'cnl00007136',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'astron'],
#  ['cnp00455882',
# ...
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'math'],
#  ['cnp01355792',
#   'Bourguet, Louis',
#   '1678',
#   'cnl00026858',
#   'Nîmes',
#   '4.34916666666667',
#   '43.8291666666667',
#   'math'],
#  ['cnp01956097',
#   'Collas, John von',
#   '1678',
#   'cnl00032962',
#   'London',
#   '-0.13',
#   '51.5091666666667',
#   'math'],
#  ['cnp01337942',
#   'Hermann, Jacob',
#   '1678',
#   'cnl00015955',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'math'],
#  ['cnp01425174',
#   'Jalufky, Gottfried',
#   '1678',
#   'cnl00033303',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'theol_math'],
#  ['cnp01341011',
#   'Rémond de Montmort, Pierre',
#   '1678',
#   'cnl00028999',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'math'],
#  ['cnp01296840',
#   'Schmeltzer, Franz',
#   '1678',
#   'cnl00016260',
#   'Wien',
#   '16.37',
#   '48.21',
#   'theol_math'],
#  ['cnp00482858',
#   'Stübner, Friedrich David',
#   '1678',
#   'cnl00009976',
#   'Heilsbronn',
#   '10.8',
#   '49.3294444444444',
#   'theol_math'],
#  ['cnp02163250',
#   'Wahn, Hermann',
#   '1678',
#   'cnl00006821',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'other'],
#  ['cnp01371511',
#   'Abauzit, Firmin',
#   '1679',
#   'cnl00014913',
#   'Uzès',
#   '4.42',
#   '44.02',
#   'other'],
#  ['cnp01406883',
#   'Liebknecht, Johann Georg',
#   '1679',
#   'cnl00004500',
#   'Wasungen',
#   '10.3666666666667',
#   '',
#   'theol_math'],
#  ['cnp02168144',
#   'Mazière, Jean Simon',
#   '1679',
#   'cnl00012905',
#   'Pontoise',
#   '2.1',
#   '49.0497222222222',
#   'other'],
#  ['cnp01502265',
#   'Mentzer, Balthasar',
#   '1679',
#   'cnl00009442',
#   'Gießen',
#   '8.65',
#   '50.5791666666667',
#   'other'],
#  ['cnp01481635',
#   'Wolff, Christian',
#   '1679',
#   'cnl00029960',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'theol_math'],
#  ['cnp01283791',
#   'Funck, Johann Caspar',
#   '1680',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'other'],
#  ['cnp01294650',
#   'Funk, Johann Kaspar',
#   '1680',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'other'],
#  ['cnp00555044',
#   'Kögler, Ignaz',
#   '1680',
#   'cnl00010938',
#   'Landsberg am Lech',
#   '10.8691666666667',
#   '48.0491666666667',
#   'theol_math'],
#  ['cnp00114038',
#   'Niderndorff, Heinrich',
#   '1680',
#   'cnl00014053',
#   'Siegen',
#   '8.01666666666667',
#   '50.8666666666667',
#   'math'],
#  ['cnp01271242',
#   'Stedler, Johann Sebastian',
#   '1680',
#   'cnl00013908',
#   'Schwabach',
#   '11.0197222222222',
#   '49.3297222222222',
#   'math'],
#  ['cnp01427068',
#   'Campos, Manuel',
#   '1681',
#   'cnl00017007',
#   'Lisboa',
#   '-9.13',
#   '38.7194444444444',
#   'math'],
#  ['cnp01307036',
#   'Chelucci, Paolino',
#   '1681',
#   'cnl00009102',
#   'Lucca',
#   '10.48',
#   '43.8291666666667',
#   'math'],
#  ['cnp02213909',
#   'Gros, Emanuel',
#   '1681',
#   'cnl00031405',
#   'Bern',
#   '7.44694444444445',
#   '46.9477777777778',
#   'math'],
#  ['cnp00395781',
#   'Mattheson, Johann',
#   '1681',
#   'cnl00027108',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'other'],
#  ['cnp00382785',
#   'Dornemann, Christoph Heinrich',
#   '1682',
#   'cnl00015003',
#   'Verden',
#   '9.23',
#   '52.92',
#   'math'],
#  ['cnp01313448',
#   'Fagnano, Giulio Carlo',
#   '1682',
#   'cnl00014007',
#   'Senigallia',
#   '13.22',
#   '43.71',
#   'math'],
#  ['cnp02238866',
#   'Hadley, John',
#   '1682',
#   'cnl00021555',
#   'Bloomsbury',
#   '-0.1178',
#   '51.5262',
#   'math'],
#  ['cnp01386031',
#   'Christin, Jean-Pierre',
#   '1683',
#   'cnl00011383',
#   'Lyon',
#   '4.84944444444444',
#   '45.75',
#   'other'],
#  ['cnp00959838',
#   'Grischow, Augustin',
#   '1683',
#   'cnl00006879',
#   'Anklam',
#   '13.6997222222222',
#   '53.8697222222222',
#   'astron'],
#  ['cnp00959838',
#   'Grischow, Augustin',
#   '1683',
#   'cnl00006879',
#   'Anklam',
#   '13.6997222222222',
#   '53.8697222222222',
#   'astron'],
#  ['cnp00401670',
#   'Poleni, Giovanni',
#   '1683',
#   'cnl00006330',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'astron'],
#  ['cnp01441824',
#   'Hase, Johann Matthias',
#   '1684',
#   'cnl00027224',
#   'Augsburg',
#   '10.88',
#   '48.3691666666667',
#   'math'],
#  ['cnp00873272',
#   'Köes, Fridericus',
#   '1684',
#   'cnl00009567',
#   'Schleswig',
#   '9.55',
#   '54.52',
#   'astron'],
#  ['cnp00420502',
#   'Zill, Matthäus',
#   '1684',
#   'cnl00012517',
#   'Opava',
#   '17.8991666666667',
#   '49.9330555555556',
#   'other'],
#  ['cnp01207886',
#   'Bornmann, Reinhold Friedrich',
#   '1685',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'theol_math'],
#  ['cnp02265415',
#   'Delisle de La Croyère, Louis',
#   '1685',
#   'cnl00032963',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'other'],
#  ['cnp01273354',
#   'Lüdemann, Johann Christophorus',
#   '1685',
#   'cnl00027108',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'astrol'],
#  ['cnp01229576',
#   'Malcolm, Alexander',
#   '1685',
#   'cnl00019666',
#   'Edimbourgh',
#   '-3.2',
#   '55.95',
#   'math'],
#  ['cnp00155913',
#   'Messerschmidt, Daniel Gottlieb',
#   '1685',
#   'cnl00006805',
#   'Danzig (Germany)',
#   '18.67',
#   '54.35',
#   'med'],
#  ['cnp01328111',
#   'Poleni, Giovanni',
#   '1685',
#   'cnl00006586',
#   'Venezia',
#   '12.33',
#   '45.4391666666667',
#   'other'],
#  ['cnp01311691',
#   'Dalla Briga, Melchior',
#   '1686',
#   'cnl00008147',
#   'Cesena',
#   '12.25',
#   '44.14',
#   'other'],
#  ['cnp02163079',
#   'Jäger, Johann Andreas',
#   '1686',
#   'cnl00016264',
#   'Würzburg',
#   '9.93916666666667',
#   '49.7891666666667',
#   'other'],
#  ['cnp02091188',
#   'Krüger, Georg Wilhelm',
#   '1687',
#   'cnl00006190',
#   'Libau',
#   '21.0138888888889',
#   '56.5166666666667',
#   'other'],
#  ['cnp01939035',
#   'Munck, Jan',
#   '1687',
#   'cnl00004012',
#   'Hulst',
#   '4.04944444444444',
#   '51.2830555555556',
#   'astron'],
#  ['cnp01411736',
#   'Pels, Isaac',
#   '1687',
#   'cnl00009870',
#   'Hanau',
#   '8.91944444444444',
#   '50.13',
#   'other'],
#  ['cnp02060705',
#   'Trumpf, Joachim',
#   '1687',
#   'cnl00035513',
#   'Malchow',
#   '12.4219444444444',
#   '53.4747222222222',
#   'astron'],
#  ['cnp00149586',
#   'Wiedeburg, Johann Bernhard',
#   '1687',
#   'cnl00009997',
#   'Helmstedt',
#   '11',
#   '52.2291666666667',
#   'theol_math'],
#  ['cnp00357110',
#   'Burnet, William',
#   '1688',
#   'cnl00006281',
#   'Den Haag',
#   '4.31666666666667',
#   '52.0830555555556',
#   'other'],
#  ['cnp00405760',
#   'Castel, Louis-Bertrand',
#   '1688',
#   'cnl00011898',
#   'Montpellier',
#   '3.87944444444444',
#   '43.6',
#   'math'],
#  ['cnp01327508',
#   'Delisle, Joseph-Nicolas',
#   '1688',
#   'cnl00028999',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'other'],
#  ['cnp01355708',
#   'Drollinger, Carl Friedrich',
#   '1688',
#   'cnl00008779',
#   'Durlach',
#   '8.48',
#   '49',
#   'other'],
#  ['cnp01331171',
#   "Gravesande, Willem Jacob's",
#   '1688',
#   'cnl00031341',
#   "'s-Hertogenbosch",
#   '5.29916666666667',
#   '51.6830555555556',
#   'astron'],
#  ['cnp00616670',
#   "L'Isle, Joseph Nicolas",
#   '1688',
#   'cnl00032963',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'astron'],
#  ['cnp01340546',
#   'Robert de Vaugondy, Gilles',
#   '1688',
#   'cnl00032963',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'other'],
#  ['cnp01361348',
#   'Rost, Johann Leonhard',
#   '1688',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01167073',
#   'Clausberg, Christlieb',
#   '1689',
#   'cnl00006805',
#   'Danzig (Germany)',
#   '18.67',
#   '54.35',
#   'math'],
#  ['cnp01327525',
#   'Gaubil, Antoine',
#   '1689',
#   'cnl00018101',
#   'Gaillac',
#   '1.8992',
#   '43.9014',
#   'theol_math'],
#  ['cnp00978256',
#   'Humbert, Abraham',
#   '1689',
#   'cnl00032895',
#   'Berlin',
#   '13.4',
#   '52.52',
#   'math'],
#  ['cnp00398351',
#   'Goldbach, Christian',
#   '1690',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'math'],
#  ['cnp00989107',
#   'González Mateo, Diego',
#   '1690',
#   'cnl00007867',
#   'Burgos',
#   '-3.7',
#   '42.35',
#   'other'],
#  ['cnp01155894',
#   'Kühn, Heinrich',
#   '1690',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'math'],
#  ['cnp00934743',
#   'Langhansen, Christoph',
#   '1691',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'theol_math'],
#  ['cnp00454735',
#   'Orth, Johann Gottfried',
#   '1691',
#   'cnl00043111',
#   'Kraftsdorf',
#   '11.9294444444444',
#   '50.8758333333333',
#   'other'],
#  ['cnp01227314',
#   'Richter, Georg Friedrich',
#   '1691',
#   'cnl00030357',
#   'Schneeberg',
#   '12.63',
#   '50.6',
#   'math'],
#  ['cnp02252448',
#   'Hüsgen, Wilhelm Friedrich',
#   '1692',
#   'cnl00012214',
#   'Neuwied',
#   '7.45944444444444',
#   '50.4294444444444',
#   'other'],
#  ['cnp01364665',
#   'Musschenbroek, Petrus van',
#   '1692',
#   'cnl00027151',
#   'Leyden',
#   '4.5',
#   '52.1491666666667',
#   'math'],
#  ['cnp01127346',
#   'Strähler, Daniel',
#   '1692',
#   'cnl00029460',
#   'Halle, Saale',
#   '12',
#   '51.5',
#   'math'],
#  ['cnp01322254',
#   'Bilfinger, Georg Bernhard',
#   '1693',
#   'cnl00032319',
#   'Cannstadt',
#   '9.21666666666667',
#   '48.7991666666667',
#   'theol_math'],
#  ['cnp02213004',
#   'Chatelard, Jean Jacques',
#   '1693',
#   'cnl00011383',
#   'Lyon',
#   '4.84944444444444',
#   '45.75',
#   'astron'],
#  ['cnp02210701',
#   'Checcozzi, Sebastiano',
#   '1693',
#   'cnl00006333',
#   'Vicenza',
#   '11.55',
#   '45.5491666666667',
#   'math'],
#  ['cnp00421828',
#   'Hausen, Christian August',
#   '1693',
#   'cnl00006089',
#   'Dresden ',
#   '13.75',
#   '51.0491666666667',
#   'math'],
#  ['cnp01979544',
#   'Mayer, Bartholomaeus',
#   '1693',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'other'],
#  ['cnp00951342',
#   'Chapuset, Johann Carl',
#   '1694',
#   'cnl00029122',
#   'Altdorf',
#   '11.3491666666667',
#   '49.3830555555556',
#   'other'],
#  ['cnp02163090',
#   'Kirch, Christfried',
#   '1694',
#   'cnl00009734',
#   'Guben',
#   '14.72',
#   '51.95',
#   'astron'],
#  ['cnp00111937',
#   'Lindner, Kornelius',
#   '1694',
#   'cnl00006272',
#   'Regensburg',
#   '12.0991666666667',
#   '49.02',
#   'math'],
#  ['cnp01281827',
#   'Meier, Arnold',
#   '1694',
#   'cnl00007698',
#   'Bremen',
#   '8.8',
#   '53.0791666666667',
#   'med'],
#  ['cnp00473300',
#   'Merklein, Albrecht Daniel',
#   '1694',
#   'cnl00007110',
#   'Windsheim',
#   '10.4197222222222',
#   '49.5',
#   'other'],
#  ['cnp00800049',
#   'Thomas, Corbinianus',
#   '1694',
#   'cnl00027224',
#   'Augsburg',
#   '10.88',
#   '48.3691666666667',
#   'theol_math'],
#  ['cnp01088897',
#   'Bernoulli, Nicolas',
#   '1695',
#   'cnl00015955',
#   'Basel',
#   '7.59916666666667',
#   '47.57',
#   'math'],
#  ['cnp02334268',
#   'Bernoulli, Nicolas II',
#   '1695',
#   'cnl00027002',
#   'Groningen',
#   '6.54916666666667',
#   '53.2191666666667',
#   'other'],
#  ['cnp01370536',
#   'Cocchi, Antonio Celestino',
#   '1695',
#   'cnl00007303',
#   'Benevento',
#   '14.75',
#   '41.13',
#   'med'],
#  ['cnp00102076',
#   'Pittermann, Ignatius',
#   '1695',
#   'cnl00016260',
#   'Wien',
#   '16.37',
#   '48.21',
#   'other'],
#  ['cnp01167258',
#   'Rohlfs, Nicolaus',
#   '1695',
#   'cnl00027108',
#   'Hamburg',
#   '10',
#   '53.5491666666667',
#   'astron'],
#  ['cnp01994802',
#   'Schumann, Johann Friedrich',
#   '1695',
#   'cnl00006281',
#   'Den Haag',
#   '4.31666666666667',
#   '52.0830555555556',
#   'med'],
#  ['cnp02207805',
#   'Fréard du Castel, Raoul-Adrien',
#   '1696',
#   'cnl00007228',
#   'Bayeux',
#   '-0.7',
#   '49.27',
#   'math'],
#  ['cnp01422962',
#   'Imhof, Christoph Friedrich',
#   '1696',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp00472229',
#   'Roderique, Johannes Ignatius',
#   '1696',
#   'cnl00011476',
#   'Malmedy',
#   '6.03',
#   '50.42',
#   'math'],
#  ['cnp02210773',
#   'Mayer, Friedrich Christoph',
#   '1697',
#   'cnl00010595',
#   'Kirchheim unter Teck',
#   '9.44944444444445',
#   '48.6494444444444',
#   'astron'],
#  ['cnp01088135',
#   'Mayer, Johann',
#   '1697',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'other'],
#  ['cnp00547788',
#   'Rampinelli, Ramiro',
#   '1697',
#   'cnl00006938',
#   'Brescia',
#   '10.2166666666667',
#   '45.5416666666667',
#   'math'],
#  ['cnp02071743',
#   'Unseld, Johann Martin',
#   '1697',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'math'],
#  ['cnp02209689',
#   'Cavallery, Antoine',
#   '1698',
#   'cnl00007229',
#   'Bayonne',
#   '-1.47944444444444',
#   '43.4794444444444',
#   'theol_math'],
#  ['cnp00105985',
#   'Deidier, ...',
#   '1698',
#   'cnl00006410',
#   'Marseille',
#   '5.4',
#   '43.2997222222222',
#   'math'],
#  ['cnp01304917',
#   'Deidier, Abbé',
#   '1698',
#   'cnl00006410',
#   'Marseille',
#   '5.4',
#   '43.2997222222222',
#   'other'],
#  ['cnp00352902',
#   'Lange, Johann Joachim',
#   '1698',
#   'cnl00033463',
#   'Berlin',
#   '13.4',
#   '52.52',
#   'math'],
#  ['cnp01317909',
#   'Maupertuis, Pierre-Louis Moreau de',
#   '1698',
#   'cnl00013565',
#   'Saint-Malo',
#   '-2.02',
#   '48.6491666666667',
#   'astron'],
#  ['cnp00416288',
#   'Carpov, Jakob',
#   '1699',
#   'cnl00009511',
#   'Goslar',
#   '10.4294444444444',
#   '51.8994444444444',
#   'theol_math'],
#  ['cnp01375132',
#   'Gebhardi, Johann Ludwig Levin',
#   '1699',
#   'cnl00007683',
#   'Braunschweig',
#   '10.5205555555556',
#   '52.2691666666667',
#   'other'],
#  ['cnp00424400',
#   'Nebel, Wilhelm Bernhard',
#   '1699',
#   'cnl00011508',
#   'Marburg',
#   '8.76916666666667',
#   '50.82',
#   'med_math'],
#  ['cnp00381221',
#   'Becker, Johann Hermann',
#   '1700',
#   'cnl00006277',
#   'Rostock',
#   '12.13',
#   '54.0791666666667',
#   'theol_math'],
#  ['cnp02213140',
#   'Soliani Raschini, Antonio',
#   '1700',
#   'cnl00003477',
#   'Brescello',
#   '10.5166666666667',
#   '44.8997222222222',
#   'math'],
#  ['cnp00387676',
#   'Frobes, Johann Nicolaus',
#   '1701',
#   'cnl00009511',
#   'Goslar',
#   '10.4294444444444',
#   '51.8994444444444',
#   'math'],
#  ['cnp01339506',
#   'Frobesius, Johannes Nicolaus',
#   '1701',
#   'cnl00009511',
#   'Goslar',
#   '10.4294444444444',
#   '51.8994444444444',
#   'other'],
#  ['cnp01885482',
#   'Krafft, Georg W.',
#   '1701',
#   'cnl00014820',
#   'Tuttlingen',
#   '8.82',
#   '47.9797222222222',
#   'math'],
#  ['cnp00384742',
#   'Adelbulner, Michael',
#   '1702',
#   'cnl00016163',
#   'Nürnberg',
#   '11.07',
#   '49.45',
#   'astron'],
#  ['cnp01336730',
#   'Bayes, Thomas',
#   '1702',
#   'cnl00017101',
#   'London',
#   '-0.13',
#   '51.5091666666667',
#   'math'],
#  ['cnp01260483',
#   'Reitz, Wilhelm Otto',
#   '1702',
#   'cnl00019774',
#   'Offenbach am Main',
#   '8.76972222222222',
#   '50.1',
#   'other'],
#  ['cnp01229790',
#   'Verch, Johann Samuel',
#   '1702',
#   'cnl00006805',
#   'Danzig (Germany)',
#   '18.67',
#   '54.35',
#   'math'],
#  ['cnp02153688',
#   'Dubourg, Matthew',
#   '1703',
#   'cnl00032962',
#   'London',
#   '-0.13',
#   '51.5091666666667',
#   'other'],
#  ['cnp01340685',
#   'Fromond, Claudio',
#   '1703',
#   'cnl00008435',
#   'Cremona',
#   '10.0291666666667',
#   '45.1191666666667',
#   'math'],
#  ['cnp00475918',
#   'Hoffmann, Adolph Friedrich',
#   '1703',
#   'cnl00011083',
#   'Leisnig',
#   '12.9197222222222',
#   '51.17',
#   'med'],
#  ['cnp01387988',
#   'Cramer, Gabriel',
#   '1704',
#   'cnl00006399',
#   'Genève',
#   '6.16944444444445',
#   '46.2',
#   'math'],
#  ['cnp02163844',
#   'Godin, Louis',
#   '1704',
#   'cnl00028999',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'astron'],
#  ['cnp00415975',
#   'Meyland, Günther Anthon',
#   '1704',
#   'cnl00009219',
#   'Frankenhausen',
#   '11.0997222222222',
#   '51.35',
#   'math'],
#  ['cnp02163209',
#   'Schumacher, Christoph Siegmund ',
#   '1704',
#   'cnl00033742',
#   'Rothenburg ob der Tauber',
#   '10.1788888888889',
#   '49.3769444444444',
#   'other'],
#  ['cnp02181704',
#   'Gropper, Anton',
#   '1705',
#   'cnl00016096',
#   'Ingolstadt',
#   '11.4291666666667',
#   '48.77',
#   'math'],
#  ['cnp01142873',
#   'Dollond, John',
#   '1706',
#   'cnl00032962',
#   'London',
#   '-0.13',
#   '51.5091666666667',
#   'other'],
#  ['cnp02308630',
#   'Du Châtelet-Lomont, Gabrielle Emilie Le Tonnelier de Breteuil',
#   '1706',
#   'cnl00032963',
#   'Paris',
#   '2.33',
#   '48.8691666666667',
#   'other'],
#  ['cnp00415435',
#   'Heilbronner, Johann Christoph',
#   '1706',
#   'cnl00016242',
#   'Ulm',
#   '10',
#   '48.3994444444444',
#   'math'],
#  ['cnp01406818',
#   'Settimo, Girolamo',
#   '1706',
#   'cnl00019944',
#   'Modica',
#   '14.7613888888889',
#   '36.8666666666667',
#   'math'],
#  ['cnp02147246',
#   'Liedbeck, Lars',
#   '1707',
#   'cnl00010431',
#   'Jönköping',
#   '14.1797222222222',
#   '57.78',
#   'math'],
#  ['cnp01326430',
#   'Robins, Benjamin',
#   '1707',
#   'cnl00007207',
#   'Bath',
#   '-2.37916666666667',
#   '51.34',
#   'other'],
#  ['cnp01005241',
#   'Sanden, Christian Bernhard',
#   '1707',
#   'cnl00031254',
#   'Königsberg',
#   '20.5',
#   '54.71',
#   'med_math'],
#  ['cnp01085443',
#   'Stock, Johann Christian',
#   '1707',
#   'cnl00010282',
#   'Jena',
#   '11.58',
#   '50.9291666666667',
#   'med'],
#  ['cnp01132050',
#   'Habicht, Chr. Theoph.',
#   '1708',
#   'cnl00033303',
#   'Wroclaw',
#   '17.03',
#   '51.1',
#   'other'],
#  ['cnp00514820',
#   'Ludolf, Hieronymus',
#   '1708',
#   'cnl00008996',
#   'Erfurt',
#   '11.0291666666667',
#   '50.9791666666667',
#   'med'],
#  ...]

# %%
df_joined_result_l = pd.DataFrame(joined_result_l, \
                         columns= ['person_id', 'entity_std_name', \
                                   'birth_year', 'id_place', 'place_label', 'long', 'lat', 'activity'])
df_joined_result_l.head(10)
# Out:
#      person_id             entity_std_name birth_year     id_place  \
# 0  cnp01352012         Matthaeus Silvagius       1400  cnl00008119
# 1  cnp02088071             Salio, Girolamo       1400  cnl00009081
# 2  cnp01881207              Kues, Nikolaus       1401  cnl00019522
# 3  cnp01879247      Leonico Tomeo, Niccolò       1428  cnl00006586
# 4  cnp00996213                      Paulus       1445  cnl00011695
# 5  cnp01320054  Avraham ben Shemuʾel Zakut       1450  cnl00027007
# 6  cnp01363268              Gazio, Antonio       1450  cnl00027154
# 7  cnp01241028           Vespucci, Amerigo       1451  cnl00017011
# 8  cnp00873006                  Franciscus       1452  cnl00006586
# 9  cnp01329886         Barbarus, Hermolaus       1453  cnl00006586
#
#        place_label              long               lat    activity
# 0          Catania  15.0894444444444              37.5       other
# 1           Faenza             11.88             44.28    med_math
# 2  Bernkastel-Kues  7.06472222222222  49.9166666666667  philo_phys
# 3          Venezia             11.55  45.4391666666667         med
# 4       Middelburg              3.62              51.5    med_math
# 5        Salamanca             -5.65  40.9691666666667      astron
# 6           Padova             11.88             45.42         med
# 7          Firenze             11.25  43.7830555555556       other
# 8          Venezia             12.33  45.4391666666667       other
# 9          Venezia             12.33  45.4391666666667        math

# %% [markdown]
# ## Distribution of birth years grouped by periods and activities

# %%
year_activity_count = df_joined_result_l.groupby(['birth_year', 'activity'], as_index=False) \
      .agg({'person_id': 'count'}).sort_values(by=['birth_year'])
print(len(year_activity_count))
year_activity_count[:50] #[130:150]
# Out:
# 673
#    birth_year    activity  person_id
# 0        1400    med_math          1
# 1        1400       other          1
# 2        1401  philo_phys          1
# 3        1428         med          1
# 4        1445    med_math          1
# 5        1450      astron          1
# 6        1450         med          1
# 7        1451       other          1
# 8        1452       other          1
# 9        1453        math          1
# 10       1454  theol_math          1
# 11       1455    med_math          1
# 12       1455       other          1
# 13       1456       other          1
# 14       1459        math          1
# 15       1459         med          1
# 16       1460        math          1
# 17       1460       other          3
# 18       1460  philo_phys          2
# 20       1462         med          1
# 19       1462      astron          1
# 21       1465         med          1
# 22       1465       other          1
# 23       1466        math          1
# 24       1467    med_math          1
# 25       1467       other          1
# 26       1468  theol_math          1
# 27       1470      astron          1
# 28       1470  theol_math          1
# 29       1471        math          1
# 30       1472       other          1
# 31       1473    med_math          2
# 32       1475        math          1
# 33       1475         med          1
# 34       1475       other          1
# 35       1476       other          1
# 36       1477       other          1
# 37       1477  theol_math          1
# 38       1478         med          1
# 39       1479       other          1
# 42       1480       other          1
# 40       1480        math          1
# 41       1480    med_math          1
# 43       1481       other          2
# 44       1485       other          1
# 45       1486         med          1
# 46       1487      astron          1
# 47       1487        math          1
# 48       1487    med_math          1
# 49       1487  theol_math          1

# %%
year_activity_l = year_activity_count.values.tolist() 
print(year_activity_l[-1:])
year_activity_l[:3]
# Out:
# [['1799', 'other', 1]]
# [['1400', 'med_math', 1], ['1400', 'other', 1], ['1401', 'philo_phys', 1]]

# %%
### Create a list with intervals of 10 years, corresponding approximately to one generation.

def create_years_list(period = 10, y_start = 1391, y_end = 1801):

    y_list = []
    y_list.append(y_start)

    while y_start < y_end:
        y_start += period
        y_list.append(y_start)
    return y_list

# %%
def interactive_activity_periods(activity, remaining = False):
    
    output_l = []
    work_l = year_activity_l
    for a in activity:
        prov_l = []
        for l in work_l:            
            if a == l[1]:
                output_l.append(l)
            else:
                prov_l.append(l)
        work_l = prov_l

    # print(output_l)
    print('Activities: ', len(output_l))
    print('Remaining: ',len(work_l))
    # print('\n-----')
    
    period = 20 # 20 10
    y_list = create_years_list(period = period, y_start = 1391, y_end = 1811)
    
    
    
    with plt.style.context("ggplot"):
                
        fig, ax = plt.subplots(figsize=(18,9)) 


        width =  period - (period * 20 / 100)

        bottom_list = []
        i = 0
        while i < len(y_list):
            bottom_list.append(0)
            i += 1

        if remaining:
            i_list = []
            for i in y_list:
                i_n = 0
                for l in work_l:
                    ### + 35 years in order to visualize the activity period
                    if int(l[0]) + 35 >= i and int(l[0]) + 35 < (i + period):
                        i_n = i_n + l[2]            
                i_list.append([i, i_n]) 
            # print('BBB: ', i_list)            
            draw_l = [i[1] for i in i_list]
            ax.bar(y_list, draw_l, width, bottom = bottom_list, label='remaining' ) #, bottom = bottom_list)
            bottom_list = [x + y for x, y in zip(bottom_list, draw_l)]


        for a in activity:
            i_list = []
            for i in y_list:
                i_n = 0
                for l in output_l:
                    ### + 35 years in order to visualize the activity period
                    if l[1] == a and int(l[0]) + 35 >= i and int(l[0]) + 35 < (i + period):
                        i_n = i_n + l[2]            
                i_list.append([i, i_n]) 
            # print('AAA: ', i_list)            
            draw_l = [i[1] for i in i_list]
            ax.bar(y_list, draw_l, width, bottom = bottom_list, label=a ) #, bottom = bottom_list)
            bottom_list = [x + y for x, y in zip(bottom_list, draw_l)]
            # print(bottom_list)



        ax.set_ylabel('Freq')
        ax.set_title('Frequency by activity')
        plt.xticks(y_list,rotation=45)

        ax.legend()

        p_out = plt.show()

# %%
k = interactive(interactive_activity_periods, activity=SelectMultiple(
    options=sorted(values_l),
    value=['math'],
    #rows=10,
    description='Activities',
    disabled=False
), remaining = Checkbox(
    value=False,
    description='Show remaining',
    disabled=False
))

# %%
display(k)
# dir(k)
# Out:
# interactive(children=(SelectMultiple(description='Activities', index=(2,), options=('astrol', 'astron', 'math'…
